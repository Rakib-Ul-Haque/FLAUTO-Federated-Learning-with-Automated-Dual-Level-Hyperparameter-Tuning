# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# from sklearn.metrics import confusion_matrix
from torchvision.datasets import CIFAR10
from collections import Counter
import random
import copy
import torch.nn.functional as F
import os
import sys
import time
import pickle
import pandas as pd
from torch import Tensor
from typing import Type
import torchvision.models as models
from torchvision import transforms
from copy import deepcopy

# Set font family for plots
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# <H1>Load Dataset</H1>

# %%
# transform = transforms.Compose([
#     transforms.ToTensor(), #This transformation converts a PIL (Python Imaging Library) Image or numpy.ndarray (with shape (H x W x C) in the range [0, 255]) into a PyTorch tensor of shape (C x H x W) in the range [0.0, 1.0]. It essentially rearranges the dimensions of the image data and scales it to a float value between 0 and 1.
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])


# train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# # train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

subset_dataset = torch.load('val_dataset.pth',weights_only=False)
remaining_dataset = torch.load('test_dataset.pth',weights_only=False)

# Create DataLoaders
val_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(remaining_dataset, batch_size=32, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <H1>IID</H1>

# %%
def distribute_dataset_equally(dataset, num_clients):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    # Distribute data
    client_data = [[] for _ in range(num_clients)]
    for label, data in class_data.items():
        data_len = len(data)
        base_size = data_len // num_clients
        remain = data_len - base_size * num_clients

        current_idx = 0
        for i in range(num_clients):
            end_idx = current_idx + base_size + (1 if i < remain else 0)
            client_data[i].extend(data[current_idx:end_idx])
            current_idx = end_idx


    print_iid_distribution(client_data)
    plot_iid_dataset(client_data,num_clients)

    return client_data

# %%
#print client iid_data distribution
def print_iid_distribution(iid_datasets):
    # Check if the distribution is correct
    for i, client_data in enumerate(iid_datasets):
        print(f"Client {i + 1} data size: {len(client_data)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# Plot client iid_data distribution
def plot_iid_dataset(iid_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in iid_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define colors for each class
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")
    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number',labelpad=5)
    ax.set_ylabel('CIFAR-10 Classes',labelpad=15)
    ax.set_zlabel('Fraction of Distribution',labelpad=5)
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], rotation=45)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names, rotation=-60)

    #ax.view_init(elev=40, azim=60)
    ax.view_init(elev=40, azim=10)

    plt.subplots_adjust(left=0.01, right=0.99, bottom=0.01, top=0.99)

    plt.show()

# %% [markdown]
# <H1>non-IID</H1>

# %%
#Print the distribution non IID
def print_distribution(client_data):
    # Check distribution
    for l, client_data_value in enumerate(client_data):
        print(f"Client {l + 1} data size: {len(client_data_value)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data_value:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# #Non IID code
def distribute_dataset_dirichlet(dataset, num_clients, alpha):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    client_data = [[] for _ in range(num_clients)]
    for _, data_list in class_data.items():
        # Shuffle data for randomness
        np.random.shuffle(data_list)

        # Get proportions for data split based on Dirichlet distribution
        proportions = np.random.dirichlet([alpha]*num_clients)
        # print("Proportions: ", proportions)
        total_data = len(data_list)
        # print("total_data: ", total_data)
        data_splits = [int(proportions[i]*total_data) for i in range(num_clients)]
        # print("Data_Split: ", data_splits)

        # Adjust the splits to account for rounding errors
        # print("Before data_split:",data_splits)
        data_splits[-1] += total_data - sum(data_splits)
        print("After data_split:",data_splits)

        start_idx = 0
        for i, split in enumerate(data_splits):
            end_idx = start_idx + split
            client_data[i].extend(data_list[start_idx:end_idx])
            start_idx = end_idx
    print("Client Number: ",num_clients, "Alpha: ", alpha)
    print_distribution(client_data)
    plot_distribution(client_data, num_clients )
    return client_data

# %%
#show the graphs for nonIID
def plot_distribution(client_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in client_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        # print(total_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define distinct colors for classes using a colormap
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # # Generate the 3D bar chart
    # fig = plt.figure(figsize=(18, 12))
    # ax = fig.add_subplot(111, projection='3d')

    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")

    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number')
    ax.set_ylabel('CIFAR-10 Classes')
    ax.set_zlabel('Fraction of Distribution')
    ax.set_title('Distribution of CIFAR-10 Classes across Clients based on Dirichlet Distribution')
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], fontsize=12)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)
        
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Change output to 10 for CIFAR-10 classes

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Train

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag):
    global opti

    e_a, e_l=test(i_weights, test_loader)
    test_loss_epoch.append(e_l)
    
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate,  weight_decay=0.004)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate,  weight_decay=0.004)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    local_model.train()  # Set the model to training mode

    flag_counter=0
    lr=le_rate
    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        print(f"Round {roun}, cleint {cli+1}, epoch {epoch+1}, current LR: {optimizer.param_groups[0]['lr']}, epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")

        a_f_w = {k: v.clone() for k, v in local_model.state_dict().items()}
        
        e_a, e_l=test(a_f_w, test_loader)
        test_loss_epoch.append(e_l)
        
        print(f"test loss difference {test_loss_epoch[epoch] - test_loss_epoch[epoch-1]}")
        
        if abs(test_loss_epoch[epoch] - test_loss_epoch[epoch-1]) < 0.002:
            lr= lr * 0.5
            optimizer.param_groups[0]['lr'] = lr

            current_learning_rate = optimizer.param_groups[0]['lr']
            #print("Current learning rate:", current_learning_rate)

            flag_counter=flag_counter+1

            if flag_counter==5:
                break


    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    #print(f"\n Round {roun}, cleint {cli}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    
    
    epoch_rmd=model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data
    
    model_update = {}
    for key in local_model.state_dict():
        model_update[key] = torch.sub(i_weights[key], f_weights[key])
    
    return epoch_accuracy,epoch_loss, epoch_flag, model_update

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()  # Assuming a classification task
    #optimizer = torch.optim.SGD(lmodel.parameters(), lr=learning_rate)
    lmodel.load_state_dict(w)
    lmodel.eval()

    #checking the weights
    tw = lmodel.state_dict()
    #Print("Model's before testing the weights in global model",tw)

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    #print("Model's Test accuracy : {:.2f}%".format(test_accuracy))
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
def average_updates(w, n_k):
    w_avg = deepcopy(w[0])
    for key in w_avg.keys():
        w_avg[key] = torch.mul(w_avg[key], n_k[0])
        for i in range(1, len(w)):
            w_avg[key] = torch.add(w_avg[key], w[i][key], alpha=n_k[i])
        w_avg[key] = torch.div(w_avg[key], sum(n_k))
    return w_avg

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_cleints_list, participating_client_list, v
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        data_size=[]
        all_final_weights={}
        all_cleints_updates=[]
        train_accuracy_list=[]
        train_loss_list=[]
        
        # Randomly select clients
        selected_clients = random.sample(total_cleints_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
                #train model
                train_accuracy, train_loss, epoch_flag, model_update = train(i_w, E, train_loader, learning_rate, c, r,epoch_flag)

                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)
                
                all_cleints_updates.append(model_update)

                data_size.append(len(train_loader))
                
                
                # Accumulate weights for the selected client
                # for param_name, param_grad in c_f_weights.items():
                #     if param_name in all_final_weights:
                #         all_final_weights[param_name] += param_grad
                #     else:
                #         all_final_weights[param_name] = param_grad

            else:
                print(f"client {c} is not selectecd")
        
        round_epoch=(epoch_flag)
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)
        print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

        update_avg = average_updates( all_cleints_updates, data_size)

        if v is None:
            v = deepcopy(update_avg)
        else:
            for key in v.keys():
                v[key] = update_avg[key] + (v[key] * 0.99)
                
        for key in i_w:
            all_final_weights[key]=i_w[key] - (v[key] * 1)

        # for param_name in all_final_weights:
        #     all_final_weights[param_name] = all_final_weights[param_name].float() / len(selected_clients)

        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

        #model deviation code
        round_rmd=model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)

        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
        round_results.loc[len(round_results)] = round_data
            
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=20
participating_client=20
epochs=5
learning_rate=0.01
round_no=30
batch_size=128
distributions = "non_iid" # 'non_iid'
data_class=10
alpha=0.5
opti="sgd" # or sgd or adam
v=None
# List of clients

test_loss_epoch=[]

total_cleints_list = list(range(0, client_no))
# print(total_cleints_list)
participating_client_list=[]

method="fed_HPO"

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

#===================================loading the saved weight list====================================================
global_model = model().to(device)
# initial_weights={k: v.clone() for k, v in global_model.state_dict().items()}
# Save the initial weights
file_path = "s_cnn.pth"
# torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=True)
Print("Model's initial weights", initial_weights)
# Out:
# Model's initial weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')

# %% [markdown]
# <H1>Divide data among cleints</H1>

# %%
# #=================================loading IID data===========================
# if distributions == 'iid':
#     client_datasets = distribute_dataset_equally(train_dataset,client_no)
    
# elif distributions == 'non_iid':
#     client_datasets = distribute_dataset_dirichlet(train_dataset, client_no, alpha)
# else:
#     print("provide a valid distribution Please")

# %%
# # Save client_datasets to a file
# if distributions == 'iid':
#     with open('client_datasets_IID.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.5:
#     with open('client_datasets_non_IID_0_5.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.125:
#     with open('client_datasets_non_IID_0_125.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)

# print("client_datasets saved successfully.")

# %%
# Load client_datasets from a file
if distributions == 'iid':
    with open('20_client_datasets_IID.pkl', 'rb') as f:
        client_datasets = pickle.load(f)

elif distributions == 'non_iid' and alpha==0.5:
    with open('20_client_datasets_non_IID_0_5.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
    
elif distributions == 'non_iid' and alpha==0.125:
    with open('20_client_datasets_non_IID_0_125.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
        
print("client_datasets loaded successfully.")
print_distribution(client_datasets)
# Out:
# client_datasets loaded successfully.
# Client 1 data size: 1928
# Class distribution: {0: 93, 1: 405, 2: 144, 3: 3, 4: 342, 5: 365, 6: 25, 7: 64, 8: 248, 9: 239}
# Client 2 data size: 1997
# Class distribution: {0: 38, 1: 0, 2: 921, 3: 588, 4: 14, 5: 9, 6: 58, 7: 51, 8: 11, 9: 307}
# Client 3 data size: 3557
# Class distribution: {0: 849, 1: 41, 2: 2, 3: 208, 4: 645, 5: 640, 6: 853, 7: 151, 8: 20, 9: 148}
# Client 4 data size: 1954
# Class distribution: {0: 369, 1: 91, 2: 9, 3: 135, 4: 108, 5: 65, 6: 267, 7: 30, 8: 673, 9: 207}
# Client 5 data size: 3332
# Class distribution: {0: 25, 1: 0, 2: 866, 3: 1163, 4: 6, 5: 194, 6: 13, 7: 375, 8: 61, 9: 629}
# Client 6 data size: 2673
# Class distribution: {0: 241, 1: 643, 2: 161, 3: 26, 4: 2, 5: 861, 6: 65, 7: 182, 8: 462, 9: 30}
# Client 7 data size: 2750
# Class distribution: {0: 161, 1: 0, 2: 503, 3: 26, 4: 184, 5: 443, 6: 6, 7: 6, 8: 1412, 9: 9}
# Client 8 data size: 2071
# Class distribution: {0: 217, 1: 128, 2: 136, 3: 37, 4: 20, 5: 19, 6: 42, 7: 371, 8: 37, 9: 1064}
# Client 9 data size: 2185
# Class distribution: {0: 0, 1: 286, 2: 426, 3: 441, 4: 223, 5: 651, 6: 5, 7: 23, 8: 107, 9: 23}
# Client 10 data size: 1544
# Class distribution: {0: 602, 1: 10, 2: 2, 3: 16, 4: 91, 5: 47, 6: 299, 7: 192, 8: 255, 9: 30}
# Client 11 data size: 681
# Class distribution: {0: 2, 1: 43, 2: 1, 3: 75, 4: 26, 5: 75, 6: 101, 7: 1, 8: 205, 9: 152}
# Client 12 data size: 1524
# Class distribution: {0: 10, 1: 2, 2: 79, 3: 142, 4: 1, 5: 6, 6: 670, 7: 90, 8: 1, 9: 523}
# Client 13 data size: 1346
# Class distribution: {0: 281, 1: 82, 2: 8, 3: 208, 4: 116, 5: 206, 6: 5, 7: 128, 8: 158, 9: 154}
# Client 14 data size: 4708
# Class distribution: {0: 596, 1: 249, 2: 1220, 3: 246, 4: 932, 5: 595, 6: 18, 7: 717, 8: 33, 9: 102}
# Client 15 data size: 1893
# Class distribution: {0: 30, 1: 9, 2: 65, 3: 842, 4: 145, 5: 0, 6: 605, 7: 34, 8: 64, 9: 99}
# Client 16 data size: 2479
# Class distribution: {0: 0, 1: 924, 2: 71, 3: 176, 4: 10, 5: 259, 6: 54, 7: 897, 8: 0, 9: 88}
# Client 17 data size: 2031
# Class distribution: {0: 78, 1: 165, 2: 14, 3: 412, 4: 10, 5: 397, 6: 69, 7: 1, 8: 643, 9: 242}
# Client 18 data size: 6129
# Class distribution: {0: 673, 1: 1721, 2: 41, 3: 127, 4: 1129, 5: 118, 6: 29, 7: 1383, 8: 100, 9: 808}
# Client 19 data size: 1348
# Class distribution: {0: 70, 1: 153, 2: 1, 3: 96, 4: 46, 5: 35, 6: 541, 7: 159, 8: 139, 9: 108}
# Client 20 data size: 3870
# Class distribution: {0: 665, 1: 48, 2: 330, 3: 33, 4: 950, 5: 15, 6: 1275, 7: 145, 8: 371, 9: 38}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for cleints
round_train_accuracy=0
round_train_loss=0

train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True, drop_last=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
round_results.loc[len(round_results)] = round_data

Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')
#
#  train accuracy: 11.298678906616146
#  train_loss: 2.3002184583102134
#  test_accuracy: 10.013977635782748
#  test_loss: 2.3027472800720994

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
# Round 1, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 7.447916666666667, epoch_loss 2.297547149658203
# test loss difference -4.21102054586342e-05
# Round 1, cleint 1, epoch 2, current LR: 0.005, epoch_accuracy 16.145833333333332, epoch_loss 2.2807630062103272
# test loss difference 4.21102054586342e-05
# Round 1, cleint 1, epoch 3, current LR: 0.0025, epoch_accuracy 18.802083333333332, epoch_loss 2.271885712941488
# test loss difference 0.00025512463749377545
# Round 1, cleint 1, epoch 4, current LR: 0.00125, epoch_accuracy 20.572916666666668, epoch_loss 2.2677321910858153
# test loss difference 0.00021346917929365716
# Round 1, cleint 1, epoch 5, current LR: 0.000625, epoch_accuracy 20.677083333333332, epoch_loss 2.2640349864959717
# test loss difference 0.00012843372722803892
# Round 1, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 37.96875, epoch_loss 2.2237100124359133
# test loss difference -0.0030688706297463675
# Round 1, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 46.5625, epoch_loss 2.0881780783335366
# test loss difference 4.21102054586342e-05
# Round 1, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 46.354166666666664, epoch_loss 1.8697434822718302
# test loss difference 0.00025512463749377545
# Round 1, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 46.145833333333336, epoch_loss 1.691307783126831
# test loss difference 0.00021346917929365716
# Round 1, cleint 2, epoch 5, current LR: 0.00125, epoch_accuracy 46.09375, epoch_loss 1.6023086547851562
# test loss difference 0.00012843372722803892
# Round 1, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 14.23611111111111, epoch_loss 2.290917811570344
# test loss difference -0.0005844705782758197
# Round 1, cleint 3, epoch 2, current LR: 0.005, epoch_accuracy 24.855324074074073, epoch_loss 2.232250443211308
# test loss difference 4.21102054586342e-05
# Round 1, cleint 3, epoch 3, current LR: 0.0025, epoch_accuracy 24.971064814814813, epoch_loss 2.1906800976505987
# test loss difference 0.00025512463749377545
# Round 1, cleint 3, epoch 4, current LR: 0.00125, epoch_accuracy 26.099537037037038, epoch_loss 2.16143438551161
# test loss difference 0.00021346917929365716
# Round 1, cleint 3, epoch 5, current LR: 0.000625, epoch_accuracy 24.88425925925926, epoch_loss 2.146319627761841
# test loss difference 0.00012843372722803892
# Round 1, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 21.875, epoch_loss 2.283685874938965
# test loss difference -0.0007202511016553004
# Round 1, cleint 4, epoch 2, current LR: 0.005, epoch_accuracy 34.322916666666664, epoch_loss 2.2538671175638836
# test loss difference 4.21102054586342e-05
# Round 1, cleint 4, epoch 3, current LR: 0.0025, epoch_accuracy 34.635416666666664, epoch_loss 2.2369608243306476
# test loss difference 0.00025512463749377545
# Round 1, cleint 4, epoch 4, current LR: 0.00125, epoch_accuracy 34.21875, epoch_loss 2.229250160853068
# test loss difference 0.00021346917929365716
# Round 1, cleint 4, epoch 5, current LR: 0.000625, epoch_accuracy 34.53125, epoch_loss 2.2237977345784503
# test loss difference 0.00012843372722803892
# Round 1, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 34.70552884615385, epoch_loss 2.2214762614323544
# test loss difference -0.005461325660681471
# Round 1, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 34.88581730769231, epoch_loss 2.0193146650607767
# test loss difference 4.21102054586342e-05
# Round 1, cleint 5, epoch 3, current LR: 0.005, epoch_accuracy 34.85576923076923, epoch_loss 1.7321521777373095
# test loss difference 0.00025512463749377545
# Round 1, cleint 5, epoch 4, current LR: 0.0025, epoch_accuracy 34.46514423076923, epoch_loss 1.6609206612293537
# test loss difference 0.00021346917929365716
# Round 1, cleint 5, epoch 5, current LR: 0.00125, epoch_accuracy 34.28485576923077, epoch_loss 1.647051141812251
# test loss difference 0.00012843372722803892
# Round 1, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 15.5078125, epoch_loss 2.281774866580963
# test loss difference -0.0006847168310000207
# Round 1, cleint 6, epoch 2, current LR: 0.005, epoch_accuracy 31.71875, epoch_loss 2.228461539745331
# test loss difference 4.21102054586342e-05
# Round 1, cleint 6, epoch 3, current LR: 0.0025, epoch_accuracy 31.71875, epoch_loss 2.1921388030052187
# test loss difference 0.00025512463749377545
# Round 1, cleint 6, epoch 4, current LR: 0.00125, epoch_accuracy 32.5, epoch_loss 2.168559741973877
# test loss difference 0.00021346917929365716
# Round 1, cleint 6, epoch 5, current LR: 0.000625, epoch_accuracy 32.1875, epoch_loss 2.156560492515564
# test loss difference 0.00012843372722803892
# Round 1, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 41.10863095238095, epoch_loss 2.235642989476522
# test loss difference -0.004148222006167046
# Round 1, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 51.413690476190474, epoch_loss 2.0339553980600265
# test loss difference 4.21102054586342e-05
# Round 1, cleint 7, epoch 3, current LR: 0.005, epoch_accuracy 51.674107142857146, epoch_loss 1.675299196016221
# test loss difference 0.00025512463749377545
# Round 1, cleint 7, epoch 4, current LR: 0.0025, epoch_accuracy 51.52529761904762, epoch_loss 1.5503361963090443
# test loss difference 0.00021346917929365716
# Round 1, cleint 7, epoch 5, current LR: 0.00125, epoch_accuracy 51.339285714285715, epoch_loss 1.5242083072662354
# test loss difference 0.00012843372722803892
# Round 1, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 41.9921875, epoch_loss 2.2486371994018555
# test loss difference -0.0017835294095855936
# Round 1, cleint 8, epoch 2, current LR: 0.005, epoch_accuracy 51.513671875, epoch_loss 2.147942394018173
# test loss difference 4.21102054586342e-05
# Round 1, cleint 8, epoch 3, current LR: 0.0025, epoch_accuracy 51.3671875, epoch_loss 2.069331005215645
# test loss difference 0.00025512463749377545
# Round 1, cleint 8, epoch 4, current LR: 0.00125, epoch_accuracy 51.3671875, epoch_loss 2.014496870338917
# test loss difference 0.00021346917929365716
# Round 1, cleint 8, epoch 5, current LR: 0.000625, epoch_accuracy 51.220703125, epoch_loss 1.9833665490150452
# test loss difference 0.00012843372722803892
# Round 1, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 19.80698529411765, epoch_loss 2.2692935046027687
# test loss difference -0.001263494308764379
# Round 1, cleint 9, epoch 2, current LR: 0.005, epoch_accuracy 21.59926470588235, epoch_loss 2.2255345933577595
# test loss difference 4.21102054586342e-05
# Round 1, cleint 9, epoch 3, current LR: 0.0025, epoch_accuracy 24.908088235294116, epoch_loss 2.197982760036693
# test loss difference 0.00025512463749377545
# Round 1, cleint 9, epoch 4, current LR: 0.00125, epoch_accuracy 25.459558823529413, epoch_loss 2.1814800711239086
# test loss difference 0.00021346917929365716
# Round 1, cleint 9, epoch 5, current LR: 0.000625, epoch_accuracy 26.011029411764707, epoch_loss 2.172348373076495
# test loss difference 0.00012843372722803892
# Round 1, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 9.375, epoch_loss 2.300438106060028
# test loss difference -0.00021107585285440322
# Round 1, cleint 10, epoch 2, current LR: 0.005, epoch_accuracy 36.783854166666664, epoch_loss 2.2603996197382608
# test loss difference 4.21102054586342e-05
# Round 1, cleint 10, epoch 3, current LR: 0.0025, epoch_accuracy 38.932291666666664, epoch_loss 2.2398510376612344
# test loss difference 0.00025512463749377545
# Round 1, cleint 10, epoch 4, current LR: 0.00125, epoch_accuracy 39.0625, epoch_loss 2.227467656135559
# test loss difference 0.00021346917929365716
# Round 1, cleint 10, epoch 5, current LR: 0.000625, epoch_accuracy 38.997395833333336, epoch_loss 2.2209197084108987
# test loss difference 0.00012843372722803892
# Round 1, cleint 11, epoch 1, current LR: 0.01, epoch_accuracy 12.03125, epoch_loss 2.2873409748077393
# test loss difference -0.00013273440230010536
# Round 1, cleint 11, epoch 2, current LR: 0.005, epoch_accuracy 15.46875, epoch_loss 2.275892734527588
# test loss difference 4.21102054586342e-05
# Round 1, cleint 11, epoch 3, current LR: 0.0025, epoch_accuracy 21.71875, epoch_loss 2.2704410552978516
# test loss difference 0.00025512463749377545
# Round 1, cleint 11, epoch 4, current LR: 0.00125, epoch_accuracy 20.46875, epoch_loss 2.269488573074341
# test loss difference 0.00021346917929365716
# Round 1, cleint 11, epoch 5, current LR: 0.000625, epoch_accuracy 23.28125, epoch_loss 2.266179990768433
# test loss difference 0.00012843372722803892
# Round 1, cleint 12, epoch 1, current LR: 0.01, epoch_accuracy 23.15340909090909, epoch_loss 2.2639036828821357
# test loss difference -0.000596236116208182
# Round 1, cleint 12, epoch 2, current LR: 0.005, epoch_accuracy 43.60795454545455, epoch_loss 2.2054715806787666
# test loss difference 4.21102054586342e-05
# Round 1, cleint 12, epoch 3, current LR: 0.0025, epoch_accuracy 43.67897727272727, epoch_loss 2.1701259396292945
# test loss difference 0.00025512463749377545
# Round 1, cleint 12, epoch 4, current LR: 0.00125, epoch_accuracy 45.80965909090909, epoch_loss 2.1473997722972524
# test loss difference 0.00021346917929365716
# Round 1, cleint 12, epoch 5, current LR: 0.000625, epoch_accuracy 45.02840909090909, epoch_loss 2.13714675469832
# test loss difference 0.00012843372722803892
# Round 1, cleint 13, epoch 1, current LR: 0.01, epoch_accuracy 15.234375, epoch_loss 2.2997974395751952
# test loss difference 1.2571438432917859e-05
# Round 1, cleint 13, epoch 2, current LR: 0.005, epoch_accuracy 15.46875, epoch_loss 2.291274976730347
# test loss difference 4.21102054586342e-05
# Round 1, cleint 13, epoch 3, current LR: 0.0025, epoch_accuracy 15.625, epoch_loss 2.288162112236023
# test loss difference 0.00025512463749377545
# Round 1, cleint 13, epoch 4, current LR: 0.00125, epoch_accuracy 15.546875, epoch_loss 2.2864389419555664
# test loss difference 0.00021346917929365716
# Round 1, cleint 13, epoch 5, current LR: 0.000625, epoch_accuracy 15.625, epoch_loss 2.2859862089157104
# test loss difference 0.00012843372722803892
# Round 1, cleint 14, epoch 1, current LR: 0.01, epoch_accuracy 22.63454861111111, epoch_loss 2.2747606370184155
# test loss difference -0.0030441825001386036
# Round 1, cleint 14, epoch 2, current LR: 0.01, epoch_accuracy 25.99826388888889, epoch_loss 2.1620087954733105
# test loss difference 4.21102054586342e-05
# Round 1, cleint 14, epoch 3, current LR: 0.005, epoch_accuracy 25.911458333333332, epoch_loss 2.023715717924966
# test loss difference 0.00025512463749377545
# Round 1, cleint 14, epoch 4, current LR: 0.0025, epoch_accuracy 25.889756944444443, epoch_loss 1.9852796859211392
# test loss difference 0.00021346917929365716
# Round 1, cleint 14, epoch 5, current LR: 0.00125, epoch_accuracy 25.93315972222222, epoch_loss 1.970778422223197
# test loss difference 0.00012843372722803892
# Round 1, cleint 15, epoch 1, current LR: 0.01, epoch_accuracy 43.861607142857146, epoch_loss 2.242896948541914
# test loss difference -0.0016849551337978497
# Round 1, cleint 15, epoch 2, current LR: 0.005, epoch_accuracy 44.810267857142854, epoch_loss 2.1693952594484602
# test loss difference 4.21102054586342e-05
# Round 1, cleint 15, epoch 3, current LR: 0.0025, epoch_accuracy 44.754464285714285, epoch_loss 2.1188171420778548
# test loss difference 0.00025512463749377545
# Round 1, cleint 15, epoch 4, current LR: 0.00125, epoch_accuracy 44.754464285714285, epoch_loss 2.0848119599478587
# test loss difference 0.00021346917929365716
# Round 1, cleint 15, epoch 5, current LR: 0.000625, epoch_accuracy 44.810267857142854, epoch_loss 2.065799423626491
# test loss difference 0.00012843372722803892
# Round 1, cleint 16, epoch 1, current LR: 0.01, epoch_accuracy 24.95888157894737, epoch_loss 2.2605307227686833
# test loss difference -0.0011151080695204207
# Round 1, cleint 16, epoch 2, current LR: 0.005, epoch_accuracy 36.22532894736842, epoch_loss 2.1497685783787777
# test loss difference 4.21102054586342e-05
# Round 1, cleint 16, epoch 3, current LR: 0.0025, epoch_accuracy 37.66447368421053, epoch_loss 2.0516318898451957
# test loss difference 0.00025512463749377545
# Round 1, cleint 16, epoch 4, current LR: 0.00125, epoch_accuracy 39.26809210526316, epoch_loss 1.9796487845872577
# test loss difference 0.00021346917929365716
# Round 1, cleint 16, epoch 5, current LR: 0.000625, epoch_accuracy 38.07565789473684, epoch_loss 1.9362939094242297
# test loss difference 0.00012843372722803892
# Round 1, cleint 17, epoch 1, current LR: 0.01, epoch_accuracy 21.770833333333332, epoch_loss 2.2671767552693685
# test loss difference -0.001087251943521217
# Round 1, cleint 17, epoch 2, current LR: 0.005, epoch_accuracy 27.34375, epoch_loss 2.234176747004191
# test loss difference 4.21102054586342e-05
# Round 1, cleint 17, epoch 3, current LR: 0.0025, epoch_accuracy 29.479166666666668, epoch_loss 2.2140824794769287
# test loss difference 0.00025512463749377545
# Round 1, cleint 17, epoch 4, current LR: 0.00125, epoch_accuracy 31.041666666666668, epoch_loss 2.2024079322814942
# test loss difference 0.00021346917929365716
# Round 1, cleint 17, epoch 5, current LR: 0.000625, epoch_accuracy 30.052083333333332, epoch_loss 2.198433430989583
# test loss difference 0.00012843372722803892
# Round 1, cleint 18, epoch 1, current LR: 0.01, epoch_accuracy 23.0219414893617, epoch_loss 2.240634659503369
# test loss difference -0.010789248128287632
# Round 1, cleint 18, epoch 2, current LR: 0.01, epoch_accuracy 28.10837765957447, epoch_loss 1.9162535667419434
# test loss difference 4.21102054586342e-05
# Round 1, cleint 18, epoch 3, current LR: 0.005, epoch_accuracy 28.82313829787234, epoch_loss 1.800939273326955
# test loss difference 0.00025512463749377545
# Round 1, cleint 18, epoch 4, current LR: 0.0025, epoch_accuracy 29.371675531914892, epoch_loss 1.7880577406984695
# test loss difference 0.00021346917929365716
# Round 1, cleint 18, epoch 5, current LR: 0.00125, epoch_accuracy 29.720744680851062, epoch_loss 1.7868649071835456
# test loss difference 0.00012843372722803892
# Round 1, cleint 19, epoch 1, current LR: 0.01, epoch_accuracy 12.8125, epoch_loss 2.292882776260376
# test loss difference 1.0223053514835101e-05
# Round 1, cleint 19, epoch 2, current LR: 0.005, epoch_accuracy 38.4375, epoch_loss 2.267538809776306
# test loss difference 4.21102054586342e-05
# Round 1, cleint 19, epoch 3, current LR: 0.0025, epoch_accuracy 40.15625, epoch_loss 2.2532904863357546
# test loss difference 0.00025512463749377545
# Round 1, cleint 19, epoch 4, current LR: 0.00125, epoch_accuracy 39.921875, epoch_loss 2.2461177825927736
# test loss difference 0.00021346917929365716
# Round 1, cleint 19, epoch 5, current LR: 0.000625, epoch_accuracy 40.625, epoch_loss 2.2405834674835203
# test loss difference 0.00012843372722803892
# Round 1, cleint 20, epoch 1, current LR: 0.01, epoch_accuracy 23.723958333333332, epoch_loss 2.265249220530192
# test loss difference -0.003639240234423635
# Round 1, cleint 20, epoch 2, current LR: 0.01, epoch_accuracy 32.838541666666664, epoch_loss 2.0573213656743365
# test loss difference 4.21102054586342e-05
# Round 1, cleint 20, epoch 3, current LR: 0.005, epoch_accuracy 32.994791666666664, epoch_loss 1.795843787988027
# test loss difference 0.00025512463749377545
# Round 1, cleint 20, epoch 4, current LR: 0.0025, epoch_accuracy 32.786458333333336, epoch_loss 1.7535416722297668
# test loss difference 0.00021346917929365716
# Round 1, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 32.552083333333336, epoch_loss 1.749375061194102
# test loss difference 0.00012843372722803892
# Model's Round: 1, train accuracy of model: 34.29653841793679, train loss of model: 2.028917857611252
#
#
# Model's Round: 1, test accuracy of model: 9.994009584664537, test loss of model: 2.3019908304793386
#
#
# round 1 completed
# Round 2, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 16.927083333333332, epoch_loss 2.2531495571136473
# test loss difference -0.0060688154385113435
# Round 2, cleint 1, epoch 2, current LR: 0.01, epoch_accuracy 20.78125, epoch_loss 2.145113770167033
# test loss difference 4.21102054586342e-05
# Round 2, cleint 1, epoch 3, current LR: 0.005, epoch_accuracy 21.09375, epoch_loss 2.06608825524648
# test loss difference 0.00025512463749377545
# Round 2, cleint 1, epoch 4, current LR: 0.0025, epoch_accuracy 20.625, epoch_loss 2.0395902077356975
# test loss difference 0.00021346917929365716
# Round 2, cleint 1, epoch 5, current LR: 0.00125, epoch_accuracy 21.041666666666668, epoch_loss 2.0326145966847737
# test loss difference 0.00012843372722803892
# Round 2, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 44.270833333333336, epoch_loss 2.0141898949940997
# test loss difference -0.15146582423688493
# Round 2, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 45.885416666666664, epoch_loss 1.511940304438273
# test loss difference 4.21102054586342e-05
# Round 2, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 44.270833333333336, epoch_loss 1.4302404006322225
# test loss difference 0.00025512463749377545
# Round 2, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 44.895833333333336, epoch_loss 1.4168119033177693
# test loss difference 0.00021346917929365716
# Round 2, cleint 2, epoch 5, current LR: 0.00125, epoch_accuracy 45.104166666666664, epoch_loss 1.425128968556722
# test loss difference 0.00012843372722803892
# Round 2, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 22.193287037037038, epoch_loss 2.1638147875114724
# test loss difference -0.09516753403904366
# Round 2, cleint 3, epoch 2, current LR: 0.01, epoch_accuracy 25.086805555555557, epoch_loss 1.8971026296968814
# test loss difference 4.21102054586342e-05
# Round 2, cleint 3, epoch 3, current LR: 0.005, epoch_accuracy 25.28935185185185, epoch_loss 1.8566634699150368
# test loss difference 0.00025512463749377545
# Round 2, cleint 3, epoch 4, current LR: 0.0025, epoch_accuracy 27.17013888888889, epoch_loss 1.8492767545912001
# test loss difference 0.00021346917929365716
# Round 2, cleint 3, epoch 5, current LR: 0.00125, epoch_accuracy 26.90972222222222, epoch_loss 1.8510619622689706
# test loss difference 0.00012843372722803892
# Round 2, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 22.864583333333332, epoch_loss 2.259397252400716
# test loss difference -0.011152973571143754
# Round 2, cleint 4, epoch 2, current LR: 0.01, epoch_accuracy 34.166666666666664, epoch_loss 2.0931973218917848
# test loss difference 4.21102054586342e-05
# Round 2, cleint 4, epoch 3, current LR: 0.005, epoch_accuracy 34.6875, epoch_loss 1.9814979553222656
# test loss difference 0.00025512463749377545
# Round 2, cleint 4, epoch 4, current LR: 0.0025, epoch_accuracy 34.375, epoch_loss 1.9583179076512656
# test loss difference 0.00021346917929365716
# Round 2, cleint 4, epoch 5, current LR: 0.00125, epoch_accuracy 34.375, epoch_loss 1.9505152781804402
# test loss difference 0.00012843372722803892
# Round 2, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 31.34014423076923, epoch_loss 1.9986016062589793
# test loss difference -0.2947563942248066
# Round 2, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 34.07451923076923, epoch_loss 1.6438615505511944
# test loss difference 4.21102054586342e-05
# Round 2, cleint 5, epoch 3, current LR: 0.005, epoch_accuracy 34.40504807692308, epoch_loss 1.6040384402641883
# test loss difference 0.00025512463749377545
# Round 2, cleint 5, epoch 4, current LR: 0.0025, epoch_accuracy 34.79567307692308, epoch_loss 1.604844331741333
# test loss difference 0.00021346917929365716
# Round 2, cleint 5, epoch 5, current LR: 0.00125, epoch_accuracy 34.58533653846154, epoch_loss 1.59491923222175
# test loss difference 0.00012843372722803892
# Round 2, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 26.875, epoch_loss 2.171761727333069
# test loss difference -0.056703462387426296
# Round 2, cleint 6, epoch 2, current LR: 0.01, epoch_accuracy 31.9140625, epoch_loss 1.8763742923736573
# test loss difference 4.21102054586342e-05
# Round 2, cleint 6, epoch 3, current LR: 0.005, epoch_accuracy 32.265625, epoch_loss 1.8047176718711853
# test loss difference 0.00025512463749377545
# Round 2, cleint 6, epoch 4, current LR: 0.0025, epoch_accuracy 33.671875, epoch_loss 1.783901071548462
# test loss difference 0.00021346917929365716
# Round 2, cleint 6, epoch 5, current LR: 0.00125, epoch_accuracy 33.7890625, epoch_loss 1.7852503657341003
# test loss difference 0.00012843372722803892
# Round 2, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 42.410714285714285, epoch_loss 2.038114059539068
# test loss difference -0.24086120867500682
# Round 2, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 51.26488095238095, epoch_loss 1.5198544036774408
# test loss difference 4.21102054586342e-05
# Round 2, cleint 7, epoch 3, current LR: 0.005, epoch_accuracy 51.376488095238095, epoch_loss 1.4447281474158877
# test loss difference 0.00025512463749377545
# Round 2, cleint 7, epoch 4, current LR: 0.0025, epoch_accuracy 51.11607142857143, epoch_loss 1.4361140330632527
# test loss difference 0.00021346917929365716
# Round 2, cleint 7, epoch 5, current LR: 0.00125, epoch_accuracy 51.376488095238095, epoch_loss 1.4325628621237618
# test loss difference 0.00012843372722803892
# Round 2, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 45.458984375, epoch_loss 2.014112986624241
# test loss difference -0.18810647059553354
# Round 2, cleint 8, epoch 2, current LR: 0.01, epoch_accuracy 51.3671875, epoch_loss 1.5953866466879845
# test loss difference 4.21102054586342e-05
# Round 2, cleint 8, epoch 3, current LR: 0.005, epoch_accuracy 51.416015625, epoch_loss 1.5585125237703323
# test loss difference 0.00025512463749377545
# Round 2, cleint 8, epoch 4, current LR: 0.0025, epoch_accuracy 51.26953125, epoch_loss 1.5536038503050804
# test loss difference 0.00021346917929365716
# Round 2, cleint 8, epoch 5, current LR: 0.00125, epoch_accuracy 51.318359375, epoch_loss 1.542245090007782
# test loss difference 0.00012843372722803892
# Round 2, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 23.80514705882353, epoch_loss 2.1676773463978485
# test loss difference -0.044016891394179414
# Round 2, cleint 9, epoch 2, current LR: 0.01, epoch_accuracy 29.779411764705884, epoch_loss 1.9022079495822681
# test loss difference 4.21102054586342e-05
# Round 2, cleint 9, epoch 3, current LR: 0.005, epoch_accuracy 29.090073529411764, epoch_loss 1.8187549464842852
# test loss difference 0.00025512463749377545
# Round 2, cleint 9, epoch 4, current LR: 0.0025, epoch_accuracy 29.27389705882353, epoch_loss 1.8028823417775772
# test loss difference 0.00021346917929365716
# Round 2, cleint 9, epoch 5, current LR: 0.00125, epoch_accuracy 28.768382352941178, epoch_loss 1.795538719962625
# test loss difference 0.00012843372722803892
# Round 2, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 30.2734375, epoch_loss 2.229011078675588
# test loss difference -0.018182033928819674
# Round 2, cleint 10, epoch 2, current LR: 0.01, epoch_accuracy 38.932291666666664, epoch_loss 1.9789648354053497
# test loss difference 4.21102054586342e-05
# Round 2, cleint 10, epoch 3, current LR: 0.005, epoch_accuracy 38.997395833333336, epoch_loss 1.8175532917181652
# test loss difference 0.00025512463749377545
# Round 2, cleint 10, epoch 4, current LR: 0.0025, epoch_accuracy 39.0625, epoch_loss 1.7816911439100902
# test loss difference 0.00021346917929365716
# Round 2, cleint 10, epoch 5, current LR: 0.00125, epoch_accuracy 39.0625, epoch_loss 1.7656594117482503
# test loss difference 0.00012843372722803892
# Round 2, cleint 11, epoch 1, current LR: 0.01, epoch_accuracy 8.90625, epoch_loss 2.314249038696289
# test loss difference 0.0014791884742222372
# Round 2, cleint 11, epoch 2, current LR: 0.005, epoch_accuracy 22.8125, epoch_loss 2.2664740562438963
# test loss difference 4.21102054586342e-05
# Round 2, cleint 11, epoch 3, current LR: 0.0025, epoch_accuracy 26.40625, epoch_loss 2.2459673404693605
# test loss difference 0.00025512463749377545
# Round 2, cleint 11, epoch 4, current LR: 0.00125, epoch_accuracy 25.0, epoch_loss 2.234244632720947
# test loss difference 0.00021346917929365716
# Round 2, cleint 11, epoch 5, current LR: 0.000625, epoch_accuracy 29.21875, epoch_loss 2.225023603439331
# test loss difference 0.00012843372722803892
# Round 2, cleint 12, epoch 1, current LR: 0.01, epoch_accuracy 29.6875, epoch_loss 2.176994193683971
# test loss difference -0.017094372179561557
# Round 2, cleint 12, epoch 2, current LR: 0.01, epoch_accuracy 45.52556818181818, epoch_loss 1.6655677990479902
# test loss difference 4.21102054586342e-05
# Round 2, cleint 12, epoch 3, current LR: 0.005, epoch_accuracy 45.17045454545455, epoch_loss 1.4168440862135454
# test loss difference 0.00025512463749377545
# Round 2, cleint 12, epoch 4, current LR: 0.0025, epoch_accuracy 45.88068181818182, epoch_loss 1.4071543216705322
# test loss difference 0.00021346917929365716
# Round 2, cleint 12, epoch 5, current LR: 0.00125, epoch_accuracy 44.03409090909091, epoch_loss 1.4041341976685957
# test loss difference 0.00012843372722803892
# Round 2, cleint 13, epoch 1, current LR: 0.01, epoch_accuracy 12.265625, epoch_loss 2.2828523397445677
# test loss difference -0.0016039926023148077
# Round 2, cleint 13, epoch 2, current LR: 0.005, epoch_accuracy 18.984375, epoch_loss 2.2513418197631836
# test loss difference 4.21102054586342e-05
# Round 2, cleint 13, epoch 3, current LR: 0.0025, epoch_accuracy 19.375, epoch_loss 2.2352137088775637
# test loss difference 0.00025512463749377545
# Round 2, cleint 13, epoch 4, current LR: 0.00125, epoch_accuracy 19.140625, epoch_loss 2.227942967414856
# test loss difference 0.00021346917929365716
# Round 2, cleint 13, epoch 5, current LR: 0.000625, epoch_accuracy 18.984375, epoch_loss 2.224833106994629
# test loss difference 0.00012843372722803892
# Round 2, cleint 14, epoch 1, current LR: 0.01, epoch_accuracy 25.56423611111111, epoch_loss 2.1137275066640644
# test loss difference -0.19439036168229462
# Round 2, cleint 14, epoch 2, current LR: 0.01, epoch_accuracy 25.130208333333332, epoch_loss 1.967276417546802
# test loss difference 4.21102054586342e-05
# Round 2, cleint 14, epoch 3, current LR: 0.005, epoch_accuracy 25.21701388888889, epoch_loss 1.949647820658154
# test loss difference 0.00025512463749377545
# Round 2, cleint 14, epoch 4, current LR: 0.0025, epoch_accuracy 24.891493055555557, epoch_loss 1.9456351631217532
# test loss difference 0.00021346917929365716
# Round 2, cleint 14, epoch 5, current LR: 0.00125, epoch_accuracy 24.717881944444443, epoch_loss 1.9465861320495605
# test loss difference 0.00012843372722803892
# Round 2, cleint 15, epoch 1, current LR: 0.01, epoch_accuracy 38.002232142857146, epoch_loss 2.1244538766997203
# test loss difference -0.048326862505830626
# Round 2, cleint 15, epoch 2, current LR: 0.01, epoch_accuracy 44.47544642857143, epoch_loss 1.6154268298830305
# test loss difference 4.21102054586342e-05
# Round 2, cleint 15, epoch 3, current LR: 0.005, epoch_accuracy 44.252232142857146, epoch_loss 1.5000372869627816
# test loss difference 0.00025512463749377545
# Round 2, cleint 15, epoch 4, current LR: 0.0025, epoch_accuracy 44.029017857142854, epoch_loss 1.4844540868486678
# test loss difference 0.00021346917929365716
# Round 2, cleint 15, epoch 5, current LR: 0.00125, epoch_accuracy 43.75, epoch_loss 1.4970008816037859
# test loss difference 0.00012843372722803892
# Round 2, cleint 16, epoch 1, current LR: 0.01, epoch_accuracy 34.703947368421055, epoch_loss 1.9854805218546014
# test loss difference -0.25437744966330245
# Round 2, cleint 16, epoch 2, current LR: 0.01, epoch_accuracy 40.5016447368421, epoch_loss 1.5554488269906295
# test loss difference 4.21102054586342e-05
# Round 2, cleint 16, epoch 3, current LR: 0.005, epoch_accuracy 41.735197368421055, epoch_loss 1.514338781959132
# test loss difference 0.00025512463749377545
# Round 2, cleint 16, epoch 4, current LR: 0.0025, epoch_accuracy 41.858552631578945, epoch_loss 1.5169441825465153
# test loss difference 0.00021346917929365716
# Round 2, cleint 16, epoch 5, current LR: 0.00125, epoch_accuracy 44.901315789473685, epoch_loss 1.5020657150368941
# test loss difference 0.00012843372722803892
# Round 2, cleint 17, epoch 1, current LR: 0.01, epoch_accuracy 20.78125, epoch_loss 2.2366775035858155
# test loss difference -0.012824715897679084
# Round 2, cleint 17, epoch 2, current LR: 0.01, epoch_accuracy 31.5625, epoch_loss 2.0193499008814495
# test loss difference 4.21102054586342e-05
# Round 2, cleint 17, epoch 3, current LR: 0.005, epoch_accuracy 32.34375, epoch_loss 1.8734819730122885
# test loss difference 0.00025512463749377545
# Round 2, cleint 17, epoch 4, current LR: 0.0025, epoch_accuracy 30.9375, epoch_loss 1.850752592086792
# test loss difference 0.00021346917929365716
# Round 2, cleint 17, epoch 5, current LR: 0.00125, epoch_accuracy 31.71875, epoch_loss 1.836489446957906
# test loss difference 0.00012843372722803892
# Round 2, cleint 18, epoch 1, current LR: 0.01, epoch_accuracy 26.695478723404257, epoch_loss 1.968237263091067
# test loss difference -0.4643715311544012
# Round 2, cleint 18, epoch 2, current LR: 0.01, epoch_accuracy 30.518617021276597, epoch_loss 1.7817177392066794
# test loss difference 4.21102054586342e-05
# Round 2, cleint 18, epoch 3, current LR: 0.005, epoch_accuracy 33.01196808510638, epoch_loss 1.7558915462899716
# test loss difference 0.00025512463749377545
# Round 2, cleint 18, epoch 4, current LR: 0.0025, epoch_accuracy 33.161569148936174, epoch_loss 1.7394329334827179
# test loss difference 0.00021346917929365716
# Round 2, cleint 18, epoch 5, current LR: 0.00125, epoch_accuracy 34.358377659574465, epoch_loss 1.730471578050167
# test loss difference 0.00012843372722803892
# Round 2, cleint 19, epoch 1, current LR: 0.01, epoch_accuracy 23.671875, epoch_loss 2.2720858573913576
# test loss difference -0.0012213147867221608
# Round 2, cleint 19, epoch 2, current LR: 0.005, epoch_accuracy 39.375, epoch_loss 2.1442585468292235
# test loss difference 4.21102054586342e-05
# Round 2, cleint 19, epoch 3, current LR: 0.0025, epoch_accuracy 40.078125, epoch_loss 2.0653024435043337
# test loss difference 0.00025512463749377545
# Round 2, cleint 19, epoch 4, current LR: 0.00125, epoch_accuracy 40.15625, epoch_loss 2.0273466229438784
# test loss difference 0.00021346917929365716
# Round 2, cleint 19, epoch 5, current LR: 0.000625, epoch_accuracy 39.921875, epoch_loss 2.007483410835266
# test loss difference 0.00012843372722803892
# Round 2, cleint 20, epoch 1, current LR: 0.01, epoch_accuracy 28.385416666666668, epoch_loss 2.03982834815979
# test loss difference -0.32584779178753465
# Round 2, cleint 20, epoch 2, current LR: 0.01, epoch_accuracy 33.203125, epoch_loss 1.751219916343689
# test loss difference 4.21102054586342e-05
# Round 2, cleint 20, epoch 3, current LR: 0.005, epoch_accuracy 32.265625, epoch_loss 1.732156773408254
# test loss difference 0.00025512463749377545
# Round 2, cleint 20, epoch 4, current LR: 0.0025, epoch_accuracy 32.864583333333336, epoch_loss 1.7161767999331157
# test loss difference 0.00021346917929365716
# Round 2, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 32.5, epoch_loss 1.7172593871752422
# test loss difference 0.00012843372722803892
# Model's Round: 2, train accuracy of model: 35.521805035989, train loss of model: 1.7633421973650276
#
#
# Model's Round: 2, test accuracy of model: 10.88258785942492, test loss of model: 2.415868402669986
#
#
# round 2 completed
# Round 3, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 19.010416666666668, epoch_loss 2.0747228066126504
# test loss difference -0.2531712824544208
# Round 3, cleint 1, epoch 2, current LR: 0.01, epoch_accuracy 23.645833333333332, epoch_loss 1.9833553393681844
# test loss difference 4.21102054586342e-05
# Round 3, cleint 1, epoch 3, current LR: 0.005, epoch_accuracy 25.46875, epoch_loss 1.9551978349685668
# test loss difference 0.00025512463749377545
# Round 3, cleint 1, epoch 4, current LR: 0.0025, epoch_accuracy 24.322916666666668, epoch_loss 1.9509630839029948
# test loss difference 0.00021346917929365716
# Round 3, cleint 1, epoch 5, current LR: 0.00125, epoch_accuracy 27.239583333333332, epoch_loss 1.9321222623189291
# test loss difference 0.00012843372722803892
# Round 3, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 39.0625, epoch_loss 1.5743506828943887
# test loss difference -0.8758135771218201
# Round 3, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 43.229166666666664, epoch_loss 1.4171440442403158
# test loss difference 4.21102054586342e-05
# Round 3, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 45.416666666666664, epoch_loss 1.3955453872680663
# test loss difference 0.00025512463749377545
# Round 3, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 46.510416666666664, epoch_loss 1.3812517801920572
# test loss difference 0.00021346917929365716
# Round 3, cleint 2, epoch 5, current LR: 0.00125, epoch_accuracy 45.833333333333336, epoch_loss 1.3833717028299968
# test loss difference 0.00012843372722803892
# Round 3, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 26.27314814814815, epoch_loss 1.9102173822897452
# test loss difference -0.4127242153825854
# Round 3, cleint 3, epoch 2, current LR: 0.01, epoch_accuracy 29.224537037037038, epoch_loss 1.8364378522943567
# test loss difference 4.21102054586342e-05
# Round 3, cleint 3, epoch 3, current LR: 0.005, epoch_accuracy 32.92824074074074, epoch_loss 1.8065759473376803
# test loss difference 0.00025512463749377545
# Round 3, cleint 3, epoch 4, current LR: 0.0025, epoch_accuracy 34.80902777777778, epoch_loss 1.7790234397958826
# test loss difference 0.00021346917929365716
# Round 3, cleint 3, epoch 5, current LR: 0.00125, epoch_accuracy 35.38773148148148, epoch_loss 1.768831001387702
# test loss difference 0.00012843372722803892
# Round 3, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 29.270833333333332, epoch_loss 2.0721630573272707
# test loss difference -0.2737144631699633
# Round 3, cleint 4, epoch 2, current LR: 0.01, epoch_accuracy 33.28125, epoch_loss 1.9403182744979859
# test loss difference 4.21102054586342e-05
# Round 3, cleint 4, epoch 3, current LR: 0.005, epoch_accuracy 33.802083333333336, epoch_loss 1.9171131054560344
# test loss difference 0.00025512463749377545
# Round 3, cleint 4, epoch 4, current LR: 0.0025, epoch_accuracy 33.958333333333336, epoch_loss 1.9168912569681804
# test loss difference 0.00021346917929365716
# Round 3, cleint 4, epoch 5, current LR: 0.00125, epoch_accuracy 33.802083333333336, epoch_loss 1.9112061580022177
# test loss difference 0.00012843372722803892
# Round 3, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 33.38341346153846, epoch_loss 1.678034218458029
# test loss difference -0.773558453629954
# Round 3, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 35.90745192307692, epoch_loss 1.583947310080895
# test loss difference 4.21102054586342e-05
# Round 3, cleint 5, epoch 3, current LR: 0.005, epoch_accuracy 39.39302884615385, epoch_loss 1.5441631262119
# test loss difference 0.00025512463749377545
# Round 3, cleint 5, epoch 4, current LR: 0.0025, epoch_accuracy 40.71514423076923, epoch_loss 1.528180603797619
# test loss difference 0.00021346917929365716
# Round 3, cleint 5, epoch 5, current LR: 0.00125, epoch_accuracy 40.47475961538461, epoch_loss 1.5234884161215563
# test loss difference 0.00012843372722803892
# Round 3, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 32.6953125, epoch_loss 1.8610176026821137
# test loss difference -0.47015875749313807
# Round 3, cleint 6, epoch 2, current LR: 0.01, epoch_accuracy 37.109375, epoch_loss 1.7500934958457948
# test loss difference 4.21102054586342e-05
# Round 3, cleint 6, epoch 3, current LR: 0.005, epoch_accuracy 40.078125, epoch_loss 1.7058559596538543
# test loss difference 0.00025512463749377545
# Round 3, cleint 6, epoch 4, current LR: 0.0025, epoch_accuracy 39.765625, epoch_loss 1.7050635755062102
# test loss difference 0.00021346917929365716
# Round 3, cleint 6, epoch 5, current LR: 0.00125, epoch_accuracy 39.609375, epoch_loss 1.6987110316753387
# test loss difference 0.00012843372722803892
# Round 3, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 46.763392857142854, epoch_loss 1.6015773046584356
# test loss difference -0.9687813196700223
# Round 3, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 50.33482142857143, epoch_loss 1.413473373367673
# test loss difference 4.21102054586342e-05
# Round 3, cleint 7, epoch 3, current LR: 0.005, epoch_accuracy 51.63690476190476, epoch_loss 1.3797482195354642
# test loss difference 0.00025512463749377545
# Round 3, cleint 7, epoch 4, current LR: 0.0025, epoch_accuracy 51.97172619047619, epoch_loss 1.3521929241362072
# test loss difference 0.00021346917929365716
# Round 3, cleint 7, epoch 5, current LR: 0.00125, epoch_accuracy 52.71577380952381, epoch_loss 1.3393359297797793
# test loss difference 0.00012843372722803892
# Round 3, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 49.4140625, epoch_loss 1.6079117506742477
# test loss difference -0.4961454319877747
# Round 3, cleint 8, epoch 2, current LR: 0.01, epoch_accuracy 53.22265625, epoch_loss 1.50605920702219
# test loss difference 4.21102054586342e-05
# Round 3, cleint 8, epoch 3, current LR: 0.005, epoch_accuracy 53.857421875, epoch_loss 1.478720284998417
# test loss difference 0.00025512463749377545
# Round 3, cleint 8, epoch 4, current LR: 0.0025, epoch_accuracy 54.58984375, epoch_loss 1.4745514318346977
# test loss difference 0.00021346917929365716
# Round 3, cleint 8, epoch 5, current LR: 0.00125, epoch_accuracy 54.78515625, epoch_loss 1.458533063530922
# test loss difference 0.00012843372722803892
# Round 3, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 25.965073529411764, epoch_loss 1.890817691298092
# test loss difference -0.5617966362462639
# Round 3, cleint 9, epoch 2, current LR: 0.01, epoch_accuracy 28.676470588235293, epoch_loss 1.7913617316414328
# test loss difference 4.21102054586342e-05
# Round 3, cleint 9, epoch 3, current LR: 0.005, epoch_accuracy 28.033088235294116, epoch_loss 1.7670122805763693
# test loss difference 0.00025512463749377545
# Round 3, cleint 9, epoch 4, current LR: 0.0025, epoch_accuracy 28.63051470588235, epoch_loss 1.7566704469568588
# test loss difference 0.00021346917929365716
# Round 3, cleint 9, epoch 5, current LR: 0.00125, epoch_accuracy 29.825367647058822, epoch_loss 1.7520188373677872
# test loss difference 0.00012843372722803892
# Round 3, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 35.7421875, epoch_loss 1.8991480271021526
# test loss difference -0.5834540140133697
# Round 3, cleint 10, epoch 2, current LR: 0.01, epoch_accuracy 37.5, epoch_loss 1.7414363125960033
# test loss difference 4.21102054586342e-05
# Round 3, cleint 10, epoch 3, current LR: 0.005, epoch_accuracy 39.518229166666664, epoch_loss 1.716287523508072
# test loss difference 0.00025512463749377545
# Round 3, cleint 10, epoch 4, current LR: 0.0025, epoch_accuracy 39.713541666666664, epoch_loss 1.696108837922414
# test loss difference 0.00021346917929365716
# Round 3, cleint 10, epoch 5, current LR: 0.00125, epoch_accuracy 39.713541666666664, epoch_loss 1.6988557080427806
# test loss difference 0.00012843372722803892
# Round 3, cleint 11, epoch 1, current LR: 0.01, epoch_accuracy 18.4375, epoch_loss 2.2943098545074463
# test loss difference -0.1529337910417552
# Round 3, cleint 11, epoch 2, current LR: 0.01, epoch_accuracy 27.65625, epoch_loss 1.9224947214126586
# test loss difference 4.21102054586342e-05
# Round 3, cleint 11, epoch 3, current LR: 0.005, epoch_accuracy 27.34375, epoch_loss 1.8886107921600341
# test loss difference 0.00025512463749377545
# Round 3, cleint 11, epoch 4, current LR: 0.0025, epoch_accuracy 28.90625, epoch_loss 1.8518034934997558
# test loss difference 0.00021346917929365716
# Round 3, cleint 11, epoch 5, current LR: 0.00125, epoch_accuracy 27.96875, epoch_loss 1.8709344625473023
# test loss difference 0.00012843372722803892
# Round 3, cleint 12, epoch 1, current LR: 0.01, epoch_accuracy 39.77272727272727, epoch_loss 1.6389180530201306
# test loss difference -0.790704167308137
# Round 3, cleint 12, epoch 2, current LR: 0.01, epoch_accuracy 49.28977272727273, epoch_loss 1.3295300982215188
# test loss difference 4.21102054586342e-05
# Round 3, cleint 12, epoch 3, current LR: 0.005, epoch_accuracy 50.42613636363637, epoch_loss 1.3134625066410412
# test loss difference 0.00025512463749377545
# Round 3, cleint 12, epoch 4, current LR: 0.0025, epoch_accuracy 54.33238636363637, epoch_loss 1.2657381512902
# test loss difference 0.00021346917929365716
# Round 3, cleint 12, epoch 5, current LR: 0.00125, epoch_accuracy 54.19034090909091, epoch_loss 1.294302831996571
# test loss difference 0.00012843372722803892
# Round 3, cleint 13, epoch 1, current LR: 0.01, epoch_accuracy 17.34375, epoch_loss 2.1867841482162476
# test loss difference -0.15215737674944707
# Round 3, cleint 13, epoch 2, current LR: 0.01, epoch_accuracy 20.234375, epoch_loss 2.092319917678833
# test loss difference 4.21102054586342e-05
# Round 3, cleint 13, epoch 3, current LR: 0.005, epoch_accuracy 22.265625, epoch_loss 2.075750231742859
# test loss difference 0.00025512463749377545
# Round 3, cleint 13, epoch 4, current LR: 0.0025, epoch_accuracy 21.640625, epoch_loss 2.061665749549866
# test loss difference 0.00021346917929365716
# Round 3, cleint 13, epoch 5, current LR: 0.00125, epoch_accuracy 22.5, epoch_loss 2.05223970413208
# test loss difference 0.00012843372722803892
# Round 3, cleint 14, epoch 1, current LR: 0.01, epoch_accuracy 24.24045138888889, epoch_loss 1.9795606268776789
# test loss difference -0.39708220311247144
# Round 3, cleint 14, epoch 2, current LR: 0.01, epoch_accuracy 24.43576388888889, epoch_loss 1.9462513095802731
# test loss difference 4.21102054586342e-05
# Round 3, cleint 14, epoch 3, current LR: 0.005, epoch_accuracy 24.717881944444443, epoch_loss 1.932259241739909
# test loss difference 0.00025512463749377545
# Round 3, cleint 14, epoch 4, current LR: 0.0025, epoch_accuracy 25.065104166666668, epoch_loss 1.9170228375328913
# test loss difference 0.00021346917929365716
# Round 3, cleint 14, epoch 5, current LR: 0.00125, epoch_accuracy 24.739583333333332, epoch_loss 1.9203676879405975
# test loss difference 0.00012843372722803892
# Round 3, cleint 15, epoch 1, current LR: 0.01, epoch_accuracy 38.392857142857146, epoch_loss 1.6739147816385542
# test loss difference -0.6104439493185416
# Round 3, cleint 15, epoch 2, current LR: 0.01, epoch_accuracy 42.801339285714285, epoch_loss 1.496271210057395
# test loss difference 4.21102054586342e-05
# Round 3, cleint 15, epoch 3, current LR: 0.005, epoch_accuracy 42.466517857142854, epoch_loss 1.4783217906951904
# test loss difference 0.00025512463749377545
# Round 3, cleint 15, epoch 4, current LR: 0.0025, epoch_accuracy 42.857142857142854, epoch_loss 1.4707599708012171
# test loss difference 0.00021346917929365716
# Round 3, cleint 15, epoch 5, current LR: 0.00125, epoch_accuracy 43.247767857142854, epoch_loss 1.4748535411698478
# test loss difference 0.00012843372722803892
# Round 3, cleint 16, epoch 1, current LR: 0.01, epoch_accuracy 40.41940789473684, epoch_loss 1.5836667010658665
# test loss difference -0.7461009421668496
# Round 3, cleint 16, epoch 2, current LR: 0.01, epoch_accuracy 45.51809210526316, epoch_loss 1.492124827284562
# test loss difference 4.21102054586342e-05
# Round 3, cleint 16, epoch 3, current LR: 0.005, epoch_accuracy 49.50657894736842, epoch_loss 1.4595556510122198
# test loss difference 0.00025512463749377545
# Round 3, cleint 16, epoch 4, current LR: 0.0025, epoch_accuracy 49.17763157894737, epoch_loss 1.4419979045265598
# test loss difference 0.00021346917929365716
# Round 3, cleint 16, epoch 5, current LR: 0.00125, epoch_accuracy 49.83552631578947, epoch_loss 1.4266615541357743
# test loss difference 0.00012843372722803892
# Round 3, cleint 17, epoch 1, current LR: 0.01, epoch_accuracy 26.5625, epoch_loss 1.9669778108596803
# test loss difference -0.4701160104891744
# Round 3, cleint 17, epoch 2, current LR: 0.01, epoch_accuracy 31.927083333333332, epoch_loss 1.8045238653818767
# test loss difference 4.21102054586342e-05
# Round 3, cleint 17, epoch 3, current LR: 0.005, epoch_accuracy 35.3125, epoch_loss 1.780853525797526
# test loss difference 0.00025512463749377545
# Round 3, cleint 17, epoch 4, current LR: 0.0025, epoch_accuracy 33.125, epoch_loss 1.7702507019042968
# test loss difference 0.00021346917929365716
# Round 3, cleint 17, epoch 5, current LR: 0.00125, epoch_accuracy 35.78125, epoch_loss 1.7535796562830608
# test loss difference 0.00012843372722803892
# Round 3, cleint 18, epoch 1, current LR: 0.01, epoch_accuracy 30.8344414893617, epoch_loss 1.784908951597011
# test loss difference -0.6234489576504254
# Round 3, cleint 18, epoch 2, current LR: 0.01, epoch_accuracy 34.50797872340426, epoch_loss 1.7203702343271134
# test loss difference 4.21102054586342e-05
# Round 3, cleint 18, epoch 3, current LR: 0.005, epoch_accuracy 35.73803191489362, epoch_loss 1.6803320367285546
# test loss difference 0.00025512463749377545
# Round 3, cleint 18, epoch 4, current LR: 0.0025, epoch_accuracy 36.71875, epoch_loss 1.665773259832504
# test loss difference 0.00021346917929365716
# Round 3, cleint 18, epoch 5, current LR: 0.00125, epoch_accuracy 36.96808510638298, epoch_loss 1.6601968471040116
# test loss difference 0.00012843372722803892
# Round 3, cleint 19, epoch 1, current LR: 0.01, epoch_accuracy 34.453125, epoch_loss 2.0654842138290403
# test loss difference -0.18499231490845114
# Round 3, cleint 19, epoch 2, current LR: 0.01, epoch_accuracy 40.15625, epoch_loss 1.8619268178939818
# test loss difference 4.21102054586342e-05
# Round 3, cleint 19, epoch 3, current LR: 0.005, epoch_accuracy 40.15625, epoch_loss 1.8667109608650208
# test loss difference 0.00025512463749377545
# Round 3, cleint 19, epoch 4, current LR: 0.0025, epoch_accuracy 40.3125, epoch_loss 1.8532118439674377
# test loss difference 0.00021346917929365716
# Round 3, cleint 19, epoch 5, current LR: 0.00125, epoch_accuracy 40.78125, epoch_loss 1.8213520050048828
# test loss difference 0.00012843372722803892
# Round 3, cleint 20, epoch 1, current LR: 0.01, epoch_accuracy 31.041666666666668, epoch_loss 1.805213208993276
# test loss difference -0.6869559493689494
# Round 3, cleint 20, epoch 2, current LR: 0.01, epoch_accuracy 32.734375, epoch_loss 1.707918361822764
# test loss difference 4.21102054586342e-05
# Round 3, cleint 20, epoch 3, current LR: 0.005, epoch_accuracy 33.359375, epoch_loss 1.6951148986816407
# test loss difference 0.00025512463749377545
# Round 3, cleint 20, epoch 4, current LR: 0.0025, epoch_accuracy 34.817708333333336, epoch_loss 1.6791422208150228
# test loss difference 0.00021346917929365716
# Round 3, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 34.739583333333336, epoch_loss 1.6596992492675782
# test loss difference 0.00012843372722803892
# Model's Round: 3, train accuracy of model: 38.50694211625942, train loss of model: 1.6700330825319358
#
#
# Model's Round: 3, test accuracy of model: 13.119009584664537, test loss of model: 3.1271105155396386
#
#
# round 3 completed
# Round 4, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 24.479166666666668, epoch_loss 2.4124626795450848
# test loss difference -0.1906385277025997
# Round 4, cleint 1, epoch 2, current LR: 0.01, epoch_accuracy 26.927083333333332, epoch_loss 1.90326775709788
# test loss difference 4.21102054586342e-05
# Round 4, cleint 1, epoch 3, current LR: 0.005, epoch_accuracy 28.59375, epoch_loss 1.8846850713094077
# test loss difference 0.00025512463749377545
# Round 4, cleint 1, epoch 4, current LR: 0.0025, epoch_accuracy 27.604166666666668, epoch_loss 1.8688478867212932
# test loss difference 0.00021346917929365716
# Round 4, cleint 1, epoch 5, current LR: 0.00125, epoch_accuracy 29.635416666666668, epoch_loss 1.866005253791809
# test loss difference 0.00012843372722803892
# Round 4, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 39.0625, epoch_loss 2.1550432125727337
# test loss difference -0.8794702196273563
# Round 4, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 46.458333333333336, epoch_loss 1.3504581848780315
# test loss difference 4.21102054586342e-05
# Round 4, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 46.197916666666664, epoch_loss 1.3523374716440837
# test loss difference 0.00025512463749377545
# Round 4, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 48.645833333333336, epoch_loss 1.3399844725926717
# test loss difference 0.00021346917929365716
# ...
# test loss difference -0.03232282114485985
# Model's Round: 99, train accuracy of model: 93.00559309652056, train loss of model: 0.193394258197975
#
#
# Model's Round: 99, test accuracy of model: 65.72484025559105, test loss of model: 0.9526830540297512
#
#
# round 99 completed
# Round 100, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 78.42261904761905, epoch_loss 0.5455268337613061
# test loss difference 0.8853764387365348
# Round 100, cleint 1, epoch 2, current LR: 0.01, epoch_accuracy 83.33333333333333, epoch_loss 0.3994733159031187
# test loss difference 0.014864399029423936
# Round 100, cleint 1, epoch 3, current LR: 0.01, epoch_accuracy 83.63095238095238, epoch_loss 0.41043081666742054
# test loss difference 0.9918816912288482
# Round 100, cleint 1, epoch 4, current LR: 0.01, epoch_accuracy 85.71428571428571, epoch_loss 0.34101634437129613
# test loss difference 0.22199484791618573
# Round 100, cleint 1, epoch 5, current LR: 0.01, epoch_accuracy 88.69047619047619, epoch_loss 0.3203319836230505
# test loss difference 0.26447960286856453
# Round 100, cleint 1, epoch 6, current LR: 0.01, epoch_accuracy 89.73214285714286, epoch_loss 0.2574984587374188
# test loss difference 0.15022736387892666
# Round 100, cleint 1, epoch 7, current LR: 0.01, epoch_accuracy 91.81547619047619, epoch_loss 0.21571752287092663
# test loss difference 0.15087825117019849
# Round 100, cleint 1, epoch 8, current LR: 0.01, epoch_accuracy 90.77380952380952, epoch_loss 0.24915194511413574
# test loss difference -0.006767111464430542
# Round 100, cleint 1, epoch 9, current LR: 0.01, epoch_accuracy 91.66666666666667, epoch_loss 0.2224503265959876
# test loss difference -0.07493197270475616
# Round 100, cleint 1, epoch 10, current LR: 0.01, epoch_accuracy 91.66666666666667, epoch_loss 0.22651635678041548
# test loss difference -0.03232282114485985
# Round 100, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 88.82978723404256, epoch_loss 0.31393245920697427
# test loss difference 0.24518906689299547
# Round 100, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 91.4561170212766, epoch_loss 0.24022924151033798
# test loss difference 0.014864399029423936
# Round 100, cleint 2, epoch 3, current LR: 0.01, epoch_accuracy 91.82180851063829, epoch_loss 0.22167555108032327
# test loss difference 0.9918816912288482
# Round 100, cleint 2, epoch 4, current LR: 0.01, epoch_accuracy 93.16821808510639, epoch_loss 0.20040413816558553
# test loss difference 0.22199484791618573
# Round 100, cleint 2, epoch 5, current LR: 0.01, epoch_accuracy 93.53390957446808, epoch_loss 0.1815679270496711
# test loss difference 0.26447960286856453
# Round 100, cleint 2, epoch 6, current LR: 0.01, epoch_accuracy 93.51728723404256, epoch_loss 0.17293401261633065
# test loss difference 0.15022736387892666
# Round 100, cleint 2, epoch 7, current LR: 0.01, epoch_accuracy 94.23204787234043, epoch_loss 0.1608325276830967
# test loss difference 0.15087825117019849
# Round 100, cleint 2, epoch 8, current LR: 0.01, epoch_accuracy 94.46476063829788, epoch_loss 0.15830313442076774
# test loss difference -0.006767111464430542
# Round 100, cleint 2, epoch 9, current LR: 0.01, epoch_accuracy 94.61436170212765, epoch_loss 0.15263427648336647
# test loss difference -0.07493197270475616
# Round 100, cleint 2, epoch 10, current LR: 0.01, epoch_accuracy 94.88031914893617, epoch_loss 0.1417928909823457
# test loss difference -0.03232282114485985
# Round 100, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 72.10416666666667, epoch_loss 0.6576036842664083
# test loss difference 0.18686807612641543
# Round 100, cleint 3, epoch 2, current LR: 0.01, epoch_accuracy 76.47916666666667, epoch_loss 0.5577012610435486
# test loss difference 0.014864399029423936
# Round 100, cleint 3, epoch 3, current LR: 0.01, epoch_accuracy 76.64583333333333, epoch_loss 0.5374953254063924
# test loss difference 0.9918816912288482
# Round 100, cleint 3, epoch 4, current LR: 0.01, epoch_accuracy 78.875, epoch_loss 0.5024090061585108
# test loss difference 0.22199484791618573
# Round 100, cleint 3, epoch 5, current LR: 0.01, epoch_accuracy 79.10416666666667, epoch_loss 0.4854635359843572
# test loss difference 0.26447960286856453
# Round 100, cleint 3, epoch 6, current LR: 0.01, epoch_accuracy 81.25, epoch_loss 0.45400695820649467
# test loss difference 0.15022736387892666
# Round 100, cleint 3, epoch 7, current LR: 0.01, epoch_accuracy 81.72916666666667, epoch_loss 0.44498072465260824
# test loss difference 0.15087825117019849
# Round 100, cleint 3, epoch 8, current LR: 0.01, epoch_accuracy 82.10416666666667, epoch_loss 0.4307288187742233
# test loss difference -0.006767111464430542
# Round 100, cleint 3, epoch 9, current LR: 0.01, epoch_accuracy 82.47916666666667, epoch_loss 0.41452979187170663
# test loss difference -0.07493197270475616
# Round 100, cleint 3, epoch 10, current LR: 0.01, epoch_accuracy 82.58333333333333, epoch_loss 0.41096984962622324
# test loss difference -0.03232282114485985
# Round 100, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 92.53289473684211, epoch_loss 0.24920865732588265
# test loss difference -0.04229169893569473
# Round 100, cleint 4, epoch 2, current LR: 0.01, epoch_accuracy 94.53947368421052, epoch_loss 0.1836976588752709
# test loss difference 0.014864399029423936
# Round 100, cleint 4, epoch 3, current LR: 0.01, epoch_accuracy 95.29605263157895, epoch_loss 0.15476120749586506
# test loss difference 0.9918816912288482
# Round 100, cleint 4, epoch 4, current LR: 0.01, epoch_accuracy 95.23026315789474, epoch_loss 0.14698092687482897
# test loss difference 0.22199484791618573
# Round 100, cleint 4, epoch 5, current LR: 0.01, epoch_accuracy 95.39473684210526, epoch_loss 0.1421049510471915
# test loss difference 0.26447960286856453
# Round 100, cleint 4, epoch 6, current LR: 0.01, epoch_accuracy 96.15131578947368, epoch_loss 0.12386532376863454
# test loss difference 0.15022736387892666
# Round 100, cleint 4, epoch 7, current LR: 0.01, epoch_accuracy 96.54605263157895, epoch_loss 0.11832052371709754
# test loss difference 0.15087825117019849
# Round 100, cleint 4, epoch 8, current LR: 0.01, epoch_accuracy 96.41447368421052, epoch_loss 0.10646194870534696
# test loss difference -0.006767111464430542
# Round 100, cleint 4, epoch 9, current LR: 0.01, epoch_accuracy 96.48026315789474, epoch_loss 0.10518631710131701
# test loss difference -0.07493197270475616
# Round 100, cleint 4, epoch 10, current LR: 0.01, epoch_accuracy 97.20394736842105, epoch_loss 0.09026558487921169
# test loss difference -0.03232282114485985
# Round 100, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 90.84002293577981, epoch_loss 0.2603819941879686
# test loss difference -0.9626332079640592
# Round 100, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 93.03325688073394, epoch_loss 0.19513122327283983
# test loss difference 0.014864399029423936
# Round 100, cleint 5, epoch 3, current LR: 0.01, epoch_accuracy 93.92201834862385, epoch_loss 0.17111593501112604
# test loss difference 0.9918816912288482
# Round 100, cleint 5, epoch 4, current LR: 0.01, epoch_accuracy 94.22305045871559, epoch_loss 0.1660590860736343
# test loss difference 0.22199484791618573
# Round 100, cleint 5, epoch 5, current LR: 0.01, epoch_accuracy 94.6961009174312, epoch_loss 0.15101841071603495
# test loss difference 0.26447960286856453
# Round 100, cleint 5, epoch 6, current LR: 0.01, epoch_accuracy 94.89678899082568, epoch_loss 0.14578740060790826
# test loss difference 0.15022736387892666
# Round 100, cleint 5, epoch 7, current LR: 0.01, epoch_accuracy 95.12614678899082, epoch_loss 0.13418297759265801
# test loss difference 0.15087825117019849
# Round 100, cleint 5, epoch 8, current LR: 0.01, epoch_accuracy 95.02580275229357, epoch_loss 0.13991032472017026
# test loss difference -0.006767111464430542
# Round 100, cleint 5, epoch 9, current LR: 0.01, epoch_accuracy 95.3841743119266, epoch_loss 0.12612113308742506
# test loss difference -0.07493197270475616
# Round 100, cleint 5, epoch 10, current LR: 0.01, epoch_accuracy 95.6565366972477, epoch_loss 0.12104564136184684
# test loss difference -0.03232282114485985
# Round 100, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 89.42307692307692, epoch_loss 0.3125806727852577
# test loss difference -0.010302771013765533
# Round 100, cleint 6, epoch 2, current LR: 0.01, epoch_accuracy 91.26602564102564, epoch_loss 0.24797235219142374
# test loss difference 0.014864399029423936
# Round 100, cleint 6, epoch 3, current LR: 0.01, epoch_accuracy 92.3344017094017, epoch_loss 0.2128061776359876
# test loss difference 0.9918816912288482
# Round 100, cleint 6, epoch 4, current LR: 0.01, epoch_accuracy 93.00213675213675, epoch_loss 0.19816345928443801
# test loss difference 0.22199484791618573
# Round 100, cleint 6, epoch 5, current LR: 0.01, epoch_accuracy 93.24252136752136, epoch_loss 0.19431183799209759
# test loss difference 0.26447960286856453
# Round 100, cleint 6, epoch 6, current LR: 0.01, epoch_accuracy 94.31089743589743, epoch_loss 0.172019618921555
# test loss difference 0.15022736387892666
# Round 100, cleint 6, epoch 7, current LR: 0.01, epoch_accuracy 94.17735042735043, epoch_loss 0.16409523996850875
# test loss difference 0.15087825117019849
# Round 100, cleint 6, epoch 8, current LR: 0.01, epoch_accuracy 94.52457264957265, epoch_loss 0.15750767518248823
# test loss difference -0.006767111464430542
# Round 100, cleint 6, epoch 9, current LR: 0.01, epoch_accuracy 94.52457264957265, epoch_loss 0.1469954479740471
# test loss difference -0.07493197270475616
# Round 100, cleint 6, epoch 10, current LR: 0.01, epoch_accuracy 94.65811965811966, epoch_loss 0.1461781165920771
# test loss difference -0.03232282114485985
# Round 100, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 74.15730337078652, epoch_loss 0.7032898540577192
# test loss difference 0.5716749309731748
# Round 100, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 79.03792134831461, epoch_loss 0.571371066436339
# test loss difference 0.014864399029423936
# Round 100, cleint 7, epoch 3, current LR: 0.01, epoch_accuracy 79.98595505617978, epoch_loss 0.5485334764705615
# test loss difference 0.9918816912288482
# Round 100, cleint 7, epoch 4, current LR: 0.01, epoch_accuracy 81.88202247191012, epoch_loss 0.5020952261565776
# test loss difference 0.22199484791618573
# Round 100, cleint 7, epoch 5, current LR: 0.01, epoch_accuracy 83.14606741573034, epoch_loss 0.4624577551410439
# test loss difference 0.26447960286856453
# Round 100, cleint 7, epoch 6, current LR: 0.01, epoch_accuracy 83.28651685393258, epoch_loss 0.45407323941086114
# test loss difference 0.15022736387892666
# Round 100, cleint 7, epoch 7, current LR: 0.01, epoch_accuracy 84.02387640449439, epoch_loss 0.42443359015362986
# test loss difference 0.15087825117019849
# Round 100, cleint 7, epoch 8, current LR: 0.01, epoch_accuracy 85.5688202247191, epoch_loss 0.3932255029343487
# test loss difference -0.006767111464430542
# Round 100, cleint 7, epoch 9, current LR: 0.01, epoch_accuracy 86.34129213483146, epoch_loss 0.39279465544759556
# test loss difference -0.07493197270475616
# Round 100, cleint 7, epoch 10, current LR: 0.01, epoch_accuracy 86.09550561797752, epoch_loss 0.3671819290585732
# test loss difference -0.03232282114485985
# Round 100, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 90.82236842105263, epoch_loss 0.2980393799904146
# test loss difference 0.20864239668312923
# Round 100, cleint 8, epoch 2, current LR: 0.01, epoch_accuracy 93.51973684210526, epoch_loss 0.20243361000167695
# test loss difference 0.014864399029423936
# Round 100, cleint 8, epoch 3, current LR: 0.01, epoch_accuracy 93.38815789473684, epoch_loss 0.20023486904407803
# test loss difference 0.9918816912288482
# Round 100, cleint 8, epoch 4, current LR: 0.01, epoch_accuracy 94.01315789473684, epoch_loss 0.1770410790451263
# test loss difference 0.22199484791618573
# Round 100, cleint 8, epoch 5, current LR: 0.01, epoch_accuracy 94.57236842105263, epoch_loss 0.15265679222188497
# test loss difference 0.26447960286856453
# Round 100, cleint 8, epoch 6, current LR: 0.01, epoch_accuracy 95.0, epoch_loss 0.1437240284328398
# test loss difference 0.15022736387892666
# Round 100, cleint 8, epoch 7, current LR: 0.01, epoch_accuracy 95.29605263157895, epoch_loss 0.1333546948472136
# test loss difference 0.15087825117019849
# Round 100, cleint 8, epoch 8, current LR: 0.01, epoch_accuracy 95.5592105263158, epoch_loss 0.1273066842732461
# test loss difference -0.006767111464430542
# Round 100, cleint 8, epoch 9, current LR: 0.01, epoch_accuracy 95.36184210526316, epoch_loss 0.12499371576858194
# test loss difference -0.07493197270475616
# Round 100, cleint 8, epoch 10, current LR: 0.01, epoch_accuracy 96.34868421052632, epoch_loss 0.11583102599864728
# test loss difference -0.03232282114485985
# Round 100, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 86.62476503759399, epoch_loss 0.36569873016691745
# test loss difference 0.13918892986858244
# Round 100, cleint 9, epoch 2, current LR: 0.01, epoch_accuracy 88.36936090225564, epoch_loss 0.3184500587824032
# test loss difference 0.014864399029423936
# Round 100, cleint 9, epoch 3, current LR: 0.01, epoch_accuracy 89.49130639097744, epoch_loss 0.2933667736422074
# test loss difference 0.9918816912288482
# Round 100, cleint 9, epoch 4, current LR: 0.01, epoch_accuracy 90.26080827067669, epoch_loss 0.2723242758766265
# test loss difference 0.22199484791618573
# Round 100, cleint 9, epoch 5, current LR: 0.01, epoch_accuracy 90.53101503759399, epoch_loss 0.2643397460530575
# test loss difference 0.26447960286856453
# Round 100, cleint 9, epoch 6, current LR: 0.01, epoch_accuracy 91.40625, epoch_loss 0.2431585895583818
# test loss difference 0.15022736387892666
# Round 100, cleint 9, epoch 7, current LR: 0.01, epoch_accuracy 91.24765037593986, epoch_loss 0.24097849204576105
# test loss difference 0.15087825117019849
# Round 100, cleint 9, epoch 8, current LR: 0.01, epoch_accuracy 92.04652255639098, epoch_loss 0.22953699309294834
# test loss difference -0.006767111464430542
# Round 100, cleint 9, epoch 9, current LR: 0.01, epoch_accuracy 92.4577067669173, epoch_loss 0.21051125491696193
# test loss difference -0.07493197270475616
# Round 100, cleint 9, epoch 10, current LR: 0.01, epoch_accuracy 92.44595864661655, epoch_loss 0.2147406357081425
# test loss difference -0.03232282114485985
# Round 100, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 89.66346153846153, epoch_loss 0.32322374108032537
# test loss difference 0.48169585995780784
# Round 100, cleint 10, epoch 2, current LR: 0.01, epoch_accuracy 92.00721153846153, epoch_loss 0.23546130489557981
# test loss difference 0.014864399029423936
# Round 100, cleint 10, epoch 3, current LR: 0.01, epoch_accuracy 93.93028846153847, epoch_loss 0.1968493560114159
# test loss difference 0.9918816912288482
# Round 100, cleint 10, epoch 4, current LR: 0.01, epoch_accuracy 95.13221153846153, epoch_loss 0.1792550404341175
# test loss difference 0.22199484791618573
# Round 100, cleint 10, epoch 5, current LR: 0.01, epoch_accuracy 94.77163461538461, epoch_loss 0.16606105899868104
# test loss difference 0.26447960286856453
# Round 100, cleint 10, epoch 6, current LR: 0.01, epoch_accuracy 95.4326923076923, epoch_loss 0.14617116726003587
# test loss difference 0.15022736387892666
# Round 100, cleint 10, epoch 7, current LR: 0.01, epoch_accuracy 95.49278846153847, epoch_loss 0.13901297769580895
# test loss difference 0.15087825117019849
# Round 100, cleint 10, epoch 8, current LR: 0.01, epoch_accuracy 95.55288461538461, epoch_loss 0.13298547160453522
# test loss difference -0.006767111464430542
# Round 100, cleint 10, epoch 9, current LR: 0.01, epoch_accuracy 95.79326923076923, epoch_loss 0.12559180953898108
# test loss difference -0.07493197270475616
# Round 100, cleint 10, epoch 10, current LR: 0.01, epoch_accuracy 96.81490384615384, epoch_loss 0.0963352990981478
# test loss difference -0.03232282114485985
# Model's Round: 100, train accuracy of model: 92.83539751939989, train loss of model: 0.19308573300856308
#
#
# Model's Round: 100, test accuracy of model: 65.48522364217253, test loss of model: 0.9466701210878147
#
#
# round 100 completed

# %% [markdown]
# # Reuslts

# %%
# Define the folder and file name
folder_name = f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"


# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
folder_name =  f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
