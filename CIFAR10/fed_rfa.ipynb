# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# from sklearn.metrics import confusion_matrix
from torchvision.datasets import CIFAR10
from collections import Counter
import random
import copy
import torch.nn.functional as F
import os
import sys
import time
import pickle
import pandas as pd
from torch import Tensor
from typing import Type
import torchvision.models as models
from torchvision import transforms

# Set font family for plots
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# <H1>Load Dataset</H1>

# %%
# transform = transforms.Compose([
#     transforms.ToTensor(), #This transformation converts a PIL (Python Imaging Library) Image or numpy.ndarray (with shape (H x W x C) in the range [0, 255]) into a PyTorch tensor of shape (C x H x W) in the range [0.0, 1.0]. It essentially rearranges the dimensions of the image data and scales it to a float value between 0 and 1.
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])


# train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# # train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

subset_dataset = torch.load('val_dataset.pth',weights_only=False)
remaining_dataset = torch.load('test_dataset.pth',weights_only=False)

# Create DataLoaders
val_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(remaining_dataset, batch_size=32, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <H1>IID</H1>

# %%
def distribute_dataset_equally(dataset, num_clients):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    # Distribute data
    client_data = [[] for _ in range(num_clients)]
    for label, data in class_data.items():
        data_len = len(data)
        base_size = data_len // num_clients
        remain = data_len - base_size * num_clients

        current_idx = 0
        for i in range(num_clients):
            end_idx = current_idx + base_size + (1 if i < remain else 0)
            client_data[i].extend(data[current_idx:end_idx])
            current_idx = end_idx


    print_iid_distribution(client_data)
    plot_iid_dataset(client_data,num_clients)

    return client_data

# %%
#print client iid_data distribution
def print_iid_distribution(iid_datasets):
    # Check if the distribution is correct
    for i, client_data in enumerate(iid_datasets):
        print(f"Client {i + 1} data size: {len(client_data)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# Plot client iid_data distribution
def plot_iid_dataset(iid_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in iid_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define colors for each class
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")
    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number',labelpad=5)
    ax.set_ylabel('CIFAR-10 Classes',labelpad=15)
    ax.set_zlabel('Fraction of Distribution',labelpad=5)
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], rotation=45)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names, rotation=-60)

    #ax.view_init(elev=40, azim=60)
    ax.view_init(elev=40, azim=10)

    plt.subplots_adjust(left=0.01, right=0.99, bottom=0.01, top=0.99)

    plt.show()

# %% [markdown]
# <H1>non-IID</H1>

# %%
#Print the distribution non IID
def print_distribution(client_data):
    # Check distribution
    for l, client_data_value in enumerate(client_data):
        print(f"Client {l + 1} data size: {len(client_data_value)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data_value:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# #Non IID code
def distribute_dataset_dirichlet(dataset, num_clients, alpha):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    client_data = [[] for _ in range(num_clients)]
    for _, data_list in class_data.items():
        # Shuffle data for randomness
        np.random.shuffle(data_list)

        # Get proportions for data split based on Dirichlet distribution
        proportions = np.random.dirichlet([alpha]*num_clients)
        # print("Proportions: ", proportions)
        total_data = len(data_list)
        # print("total_data: ", total_data)
        data_splits = [int(proportions[i]*total_data) for i in range(num_clients)]
        # print("Data_Split: ", data_splits)

        # Adjust the splits to account for rounding errors
        # print("Before data_split:",data_splits)
        data_splits[-1] += total_data - sum(data_splits)
        print("After data_split:",data_splits)

        start_idx = 0
        for i, split in enumerate(data_splits):
            end_idx = start_idx + split
            client_data[i].extend(data_list[start_idx:end_idx])
            start_idx = end_idx
    print("Client Number: ",num_clients, "Alpha: ", alpha)
    print_distribution(client_data)
    plot_distribution(client_data, num_clients )
    return client_data

# %%
#show the graphs for nonIID
def plot_distribution(client_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in client_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        # print(total_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define distinct colors for classes using a colormap
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # # Generate the 3D bar chart
    # fig = plt.figure(figsize=(18, 12))
    # ax = fig.add_subplot(111, projection='3d')

    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")

    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number')
    ax.set_ylabel('CIFAR-10 Classes')
    ax.set_zlabel('Fraction of Distribution')
    ax.set_title('Distribution of CIFAR-10 Classes across Clients based on Dirichlet Distribution')
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], fontsize=12)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)
        
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Change output to 10 for CIFAR-10 classes

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Train

# %%
def smoothed_weiszfeld(models_dict, weights_alpha, initial_weights_dict, nu=1e-5, R_weiszfeld=10):
    global device
    
    # Ensure all tensors are on the same device and of float type
    v = {k: v.clone().detach().to(device).float() for k, v in initial_weights_dict.items()}
    
    for _ in range(int(R_weiszfeld)):
        # Compute distances between the current aggregated weights and each model's weights
        distances = []
        for model in models_dict:
            # Move model weights to the same device as v and ensure they are of float type
            model = {k: m.to(device).float() for k, m in model.items()}
            distance = sum(
                torch.norm(v[k] - model[k]).item()  # Convert to Python number for easy use
                for k in v.keys()
            )
            distances.append(distance)
        
        distances = torch.tensor(distances, device=device).float()
        
        #print(len(weights_alpha), len(distances))
        
        # Avoid division by zero
        beta = torch.tensor([alpha_i / max(nu, dist) for alpha_i, dist in zip(weights_alpha, distances)], device=device).float()
        
        # Compute weighted sum
        weighted_sum = {k: torch.zeros_like(v[k], device=device).float() for k in v.keys()}
        for beta_i, model in zip(beta, models_dict):
            model = {k: m.to(device).float() for k, m in model.items()}  # Ensure model weights are on the same device and of float type
            for k in weighted_sum.keys():
                weighted_sum[k] += beta_i * model[k]
        
        # Normalize weights
        total_beta = torch.sum(beta)
        for k in weighted_sum.keys():
            weighted_sum[k] /= total_beta
        
        # Update v with the new aggregated weights
        v = weighted_sum
    
    return v

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag):
    global opti
    
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    local_model.train()  # Set the model to training mode

    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        print(f"Round {roun}, cleint {cli+1}, epoch {epoch+1}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")
    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    #print(f"\n Round {roun}, cleint {cli}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    
    
    epoch_rmd=model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data
    
    return epoch_accuracy,epoch_loss, f_weights, epoch_flag

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()  # Assuming a classification task
    #optimizer = torch.optim.SGD(lmodel.parameters(), lr=learning_rate)
    lmodel.load_state_dict(w)
    lmodel.eval()

    #checking the weights
    tw = lmodel.state_dict()
    #Print("Model's before testing the weights in global model",tw)

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    #print("Model's Test accuracy : {:.2f}%".format(test_accuracy))
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_clients_list, participating_client_list
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        models=[]
        weights_alpha = []

        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        all_final_weights={}
        train_accuracy_list=[]
        train_loss_list=[]
        
        # Randomly select clients
        selected_clients = random.sample(total_clients_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
                #train model
                train_accuracy, train_loss, c_f_weights, epoch_flag = train(i_w, E, train_loader, learning_rate, c, r,epoch_flag)

                models.append(c_f_weights)
                weights_alpha.append(1.0) 
            
                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)

                # Accumulate weights for the selected client
                #for param_name, param_grad in c_f_weights.items():
                    #if param_name in all_final_weights:
                        #all_final_weights[param_name] += param_grad
                    #else:
                        #all_final_weights[param_name] = param_grad

            else:
                print(f"client {c+1} is not selectecd")

        all_final_weights = smoothed_weiszfeld(models, weights_alpha, i_w)
        round_epoch=(epoch_flag)
        
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)

        print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

        #for param_name in all_final_weights:
            #all_final_weights[param_name] = all_final_weights[param_name].float() / len(selected_clients)

        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

        #model deviation code
        round_rmd=model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)

        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
        round_results.loc[len(round_results)] = round_data
            
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=20
participating_client=20
epochs=5
learning_rate=0.0001
round_no=30
batch_size=128
distributions = "non_iid" # 'non_iid'
data_class=10
alpha=0.5
opti="sgd" # or SGD

method="fed_rfa"

# List of clients
total_clients_list = list(range(0, client_no))
# print(total_cleints_list)
participating_client_list=[]

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

#===================================loading the saved weight list====================================================
global_model = model().to(device)
# initial_weights={k: v.clone() for k, v in global_model.state_dict().items()}
# Save the initial weights
file_path = "s_cnn.pth"
# torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=True)
Print("Model's initial weights", initial_weights)
# Out:
# Model's initial weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')

# %% [markdown]
# <H1>Divide data among cleints</H1>

# %%
# #=================================loading IID data===========================
# if distributions == 'iid':
#     client_datasets = distribute_dataset_equally(train_dataset,client_no)
    
# elif distributions == 'non_iid':
#     client_datasets = distribute_dataset_dirichlet(train_dataset, client_no, alpha)
# else:
#     print("provide a valid distribution Please")

# %%
# # Save client_datasets to a file
# if distributions == 'iid':
#     with open('client_datasets_IID.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.5:
#     with open('client_datasets_non_IID_0_5.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.125:
#     with open('client_datasets_non_IID_0_125.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)

# print("client_datasets saved successfully.")

# %%
# Load client_datasets from a file
if distributions == 'iid':
    with open('20_client_datasets_IID.pkl', 'rb') as f:
        client_datasets = pickle.load(f)

elif distributions == 'non_iid' and alpha==0.5:
    with open('20_client_datasets_non_IID_0_5.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
    
elif distributions == 'non_iid' and alpha==0.125:
    with open('20_client_datasets_non_IID_0_125.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
        
print("client_datasets loaded successfully.")
print_distribution(client_datasets)
# Out:
# client_datasets loaded successfully.
# Client 1 data size: 1928
# Class distribution: {0: 93, 1: 405, 2: 144, 3: 3, 4: 342, 5: 365, 6: 25, 7: 64, 8: 248, 9: 239}
# Client 2 data size: 1997
# Class distribution: {0: 38, 1: 0, 2: 921, 3: 588, 4: 14, 5: 9, 6: 58, 7: 51, 8: 11, 9: 307}
# Client 3 data size: 3557
# Class distribution: {0: 849, 1: 41, 2: 2, 3: 208, 4: 645, 5: 640, 6: 853, 7: 151, 8: 20, 9: 148}
# Client 4 data size: 1954
# Class distribution: {0: 369, 1: 91, 2: 9, 3: 135, 4: 108, 5: 65, 6: 267, 7: 30, 8: 673, 9: 207}
# Client 5 data size: 3332
# Class distribution: {0: 25, 1: 0, 2: 866, 3: 1163, 4: 6, 5: 194, 6: 13, 7: 375, 8: 61, 9: 629}
# Client 6 data size: 2673
# Class distribution: {0: 241, 1: 643, 2: 161, 3: 26, 4: 2, 5: 861, 6: 65, 7: 182, 8: 462, 9: 30}
# Client 7 data size: 2750
# Class distribution: {0: 161, 1: 0, 2: 503, 3: 26, 4: 184, 5: 443, 6: 6, 7: 6, 8: 1412, 9: 9}
# Client 8 data size: 2071
# Class distribution: {0: 217, 1: 128, 2: 136, 3: 37, 4: 20, 5: 19, 6: 42, 7: 371, 8: 37, 9: 1064}
# Client 9 data size: 2185
# Class distribution: {0: 0, 1: 286, 2: 426, 3: 441, 4: 223, 5: 651, 6: 5, 7: 23, 8: 107, 9: 23}
# Client 10 data size: 1544
# Class distribution: {0: 602, 1: 10, 2: 2, 3: 16, 4: 91, 5: 47, 6: 299, 7: 192, 8: 255, 9: 30}
# Client 11 data size: 681
# Class distribution: {0: 2, 1: 43, 2: 1, 3: 75, 4: 26, 5: 75, 6: 101, 7: 1, 8: 205, 9: 152}
# Client 12 data size: 1524
# Class distribution: {0: 10, 1: 2, 2: 79, 3: 142, 4: 1, 5: 6, 6: 670, 7: 90, 8: 1, 9: 523}
# Client 13 data size: 1346
# Class distribution: {0: 281, 1: 82, 2: 8, 3: 208, 4: 116, 5: 206, 6: 5, 7: 128, 8: 158, 9: 154}
# Client 14 data size: 4708
# Class distribution: {0: 596, 1: 249, 2: 1220, 3: 246, 4: 932, 5: 595, 6: 18, 7: 717, 8: 33, 9: 102}
# Client 15 data size: 1893
# Class distribution: {0: 30, 1: 9, 2: 65, 3: 842, 4: 145, 5: 0, 6: 605, 7: 34, 8: 64, 9: 99}
# Client 16 data size: 2479
# Class distribution: {0: 0, 1: 924, 2: 71, 3: 176, 4: 10, 5: 259, 6: 54, 7: 897, 8: 0, 9: 88}
# Client 17 data size: 2031
# Class distribution: {0: 78, 1: 165, 2: 14, 3: 412, 4: 10, 5: 397, 6: 69, 7: 1, 8: 643, 9: 242}
# Client 18 data size: 6129
# Class distribution: {0: 673, 1: 1721, 2: 41, 3: 127, 4: 1129, 5: 118, 6: 29, 7: 1383, 8: 100, 9: 808}
# Client 19 data size: 1348
# Class distribution: {0: 70, 1: 153, 2: 1, 3: 96, 4: 46, 5: 35, 6: 541, 7: 159, 8: 139, 9: 108}
# Client 20 data size: 3870
# Class distribution: {0: 665, 1: 48, 2: 330, 3: 33, 4: 950, 5: 15, 6: 1275, 7: 145, 8: 371, 9: 38}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for cleints
round_train_accuracy=0
round_train_loss=0

train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True, drop_last=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
round_results.loc[len(round_results)] = round_data

Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')
#
#  train accuracy: 11.265257347518986
#  train_loss: 2.3002289565199807
#  test_accuracy: 10.013977635782748
#  test_loss: 2.3027472800720994

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
# Round 1, cleint 1, epoch 1: epoch_accuracy 2.1875, epoch_loss 2.3071690877278646
# Round 1, cleint 1, epoch 2: epoch_accuracy 1.9791666666666667, epoch_loss 2.3072858174641926
# Round 1, cleint 1, epoch 3: epoch_accuracy 1.9270833333333333, epoch_loss 2.306792736053467
# Round 1, cleint 1, epoch 4: epoch_accuracy 1.6145833333333333, epoch_loss 2.306140089035034
# Round 1, cleint 1, epoch 5: epoch_accuracy 1.6666666666666667, epoch_loss 2.3065494378407796
# Round 1, cleint 2, epoch 1: epoch_accuracy 29.479166666666668, epoch_loss 2.2669203758239744
# Round 1, cleint 2, epoch 2: epoch_accuracy 28.645833333333332, epoch_loss 2.266177034378052
# Round 1, cleint 2, epoch 3: epoch_accuracy 30.15625, epoch_loss 2.2653151671091716
# Round 1, cleint 2, epoch 4: epoch_accuracy 29.635416666666668, epoch_loss 2.2639937241872152
# Round 1, cleint 2, epoch 5: epoch_accuracy 29.114583333333332, epoch_loss 2.2630088965098065
# Round 1, cleint 3, epoch 1: epoch_accuracy 5.237268518518518, epoch_loss 2.3215694074277526
# Round 1, cleint 3, epoch 2: epoch_accuracy 5.208333333333333, epoch_loss 2.3208730397401034
# Round 1, cleint 3, epoch 3: epoch_accuracy 5.324074074074074, epoch_loss 2.319742211589107
# Round 1, cleint 3, epoch 4: epoch_accuracy 5.150462962962963, epoch_loss 2.319126526514689
# Round 1, cleint 3, epoch 5: epoch_accuracy 4.947916666666667, epoch_loss 2.3190552128685846
# Round 1, cleint 4, epoch 1: epoch_accuracy 6.927083333333333, epoch_loss 2.3008351802825926
# Round 1, cleint 4, epoch 2: epoch_accuracy 6.770833333333333, epoch_loss 2.300570821762085
# Round 1, cleint 4, epoch 3: epoch_accuracy 7.083333333333333, epoch_loss 2.3002429326375324
# Round 1, cleint 4, epoch 4: epoch_accuracy 6.71875, epoch_loss 2.299639368057251
# Round 1, cleint 4, epoch 5: epoch_accuracy 7.916666666666667, epoch_loss 2.2992387930552165
# Round 1, cleint 5, epoch 1: epoch_accuracy 32.57211538461539, epoch_loss 2.272855731157156
# Round 1, cleint 5, epoch 2: epoch_accuracy 32.72235576923077, epoch_loss 2.271573616908147
# Round 1, cleint 5, epoch 3: epoch_accuracy 32.63221153846154, epoch_loss 2.270795171077435
# Round 1, cleint 5, epoch 4: epoch_accuracy 32.18149038461539, epoch_loss 2.269857278236976
# Round 1, cleint 5, epoch 5: epoch_accuracy 33.17307692307692, epoch_loss 2.268914369436411
# Round 1, cleint 6, epoch 1: epoch_accuracy 1.484375, epoch_loss 2.30969523191452
# Round 1, cleint 6, epoch 2: epoch_accuracy 1.9140625, epoch_loss 2.308133566379547
# Round 1, cleint 6, epoch 3: epoch_accuracy 1.71875, epoch_loss 2.308454918861389
# Round 1, cleint 6, epoch 4: epoch_accuracy 1.796875, epoch_loss 2.3073233008384704
# Round 1, cleint 6, epoch 5: epoch_accuracy 2.03125, epoch_loss 2.306699883937836
# Round 1, cleint 7, epoch 1: epoch_accuracy 3.7574404761904763, epoch_loss 2.2938822905222573
# Round 1, cleint 7, epoch 2: epoch_accuracy 3.2738095238095237, epoch_loss 2.2929734616052535
# Round 1, cleint 7, epoch 3: epoch_accuracy 5.208333333333333, epoch_loss 2.291283164705549
# Round 1, cleint 7, epoch 4: epoch_accuracy 5.877976190476191, epoch_loss 2.289487498147147
# Round 1, cleint 7, epoch 5: epoch_accuracy 6.063988095238095, epoch_loss 2.2889377049037387
# Round 1, cleint 8, epoch 1: epoch_accuracy 4.78515625, epoch_loss 2.2970149517059326
# Round 1, cleint 8, epoch 2: epoch_accuracy 5.078125, epoch_loss 2.2960423827171326
# Round 1, cleint 8, epoch 3: epoch_accuracy 5.908203125, epoch_loss 2.2953831553459167
# Round 1, cleint 8, epoch 4: epoch_accuracy 6.298828125, epoch_loss 2.294004663825035
# Round 1, cleint 8, epoch 5: epoch_accuracy 6.689453125, epoch_loss 2.293691113591194
# Round 1, cleint 9, epoch 1: epoch_accuracy 18.106617647058822, epoch_loss 2.292926045025096
# Round 1, cleint 9, epoch 2: epoch_accuracy 18.933823529411764, epoch_loss 2.2919721883886
# Round 1, cleint 9, epoch 3: epoch_accuracy 18.658088235294116, epoch_loss 2.2918350836809944
# Round 1, cleint 9, epoch 4: epoch_accuracy 19.209558823529413, epoch_loss 2.290867104249842
# Round 1, cleint 9, epoch 5: epoch_accuracy 18.75, epoch_loss 2.2904122436747834
# Round 1, cleint 10, epoch 1: epoch_accuracy 1.6927083333333333, epoch_loss 2.322406609853109
# Round 1, cleint 10, epoch 2: epoch_accuracy 1.3020833333333333, epoch_loss 2.321731229623159
# Round 1, cleint 10, epoch 3: epoch_accuracy 1.3020833333333333, epoch_loss 2.321507195631663
# Round 1, cleint 10, epoch 4: epoch_accuracy 1.4322916666666667, epoch_loss 2.320449690024058
# Round 1, cleint 10, epoch 5: epoch_accuracy 1.3671875, epoch_loss 2.3197742303212485
# Round 1, cleint 11, epoch 1: epoch_accuracy 9.21875, epoch_loss 2.2898012161254884
# Round 1, cleint 11, epoch 2: epoch_accuracy 10.78125, epoch_loss 2.2901610374450683
# Round 1, cleint 11, epoch 3: epoch_accuracy 11.25, epoch_loss 2.2906131744384766
# Round 1, cleint 11, epoch 4: epoch_accuracy 11.09375, epoch_loss 2.2890971660614015
# Round 1, cleint 11, epoch 5: epoch_accuracy 9.21875, epoch_loss 2.289400243759155
# Round 1, cleint 12, epoch 1: epoch_accuracy 9.090909090909092, epoch_loss 2.296267119320956
# Round 1, cleint 12, epoch 2: epoch_accuracy 9.730113636363637, epoch_loss 2.2953978885303843
# Round 1, cleint 12, epoch 3: epoch_accuracy 10.298295454545455, epoch_loss 2.2937487038699063
# Round 1, cleint 12, epoch 4: epoch_accuracy 9.801136363636363, epoch_loss 2.293251297690652
# Round 1, cleint 12, epoch 5: epoch_accuracy 10.795454545454545, epoch_loss 2.2920341708443384
# Round 1, cleint 13, epoch 1: epoch_accuracy 12.890625, epoch_loss 2.304657793045044
# Round 1, cleint 13, epoch 2: epoch_accuracy 13.59375, epoch_loss 2.3046534299850463
# Round 1, cleint 13, epoch 3: epoch_accuracy 13.59375, epoch_loss 2.3042396068573
# Round 1, cleint 13, epoch 4: epoch_accuracy 13.59375, epoch_loss 2.3049799680709837
# Round 1, cleint 13, epoch 5: epoch_accuracy 13.28125, epoch_loss 2.305130624771118
# Round 1, cleint 14, epoch 1: epoch_accuracy 7.118055555555555, epoch_loss 2.309636288219028
# Round 1, cleint 14, epoch 2: epoch_accuracy 7.877604166666667, epoch_loss 2.3088283869955273
# Round 1, cleint 14, epoch 3: epoch_accuracy 8.485243055555555, epoch_loss 2.3079383969306946
# Round 1, cleint 14, epoch 4: epoch_accuracy 8.723958333333334, epoch_loss 2.307552801238166
# Round 1, cleint 14, epoch 5: epoch_accuracy 8.854166666666666, epoch_loss 2.306725197368198
# Round 1, cleint 15, epoch 1: epoch_accuracy 37.220982142857146, epoch_loss 2.279970850263323
# Round 1, cleint 15, epoch 2: epoch_accuracy 38.560267857142854, epoch_loss 2.279500348227365
# Round 1, cleint 15, epoch 3: epoch_accuracy 39.676339285714285, epoch_loss 2.277536051613944
# Round 1, cleint 15, epoch 4: epoch_accuracy 39.78794642857143, epoch_loss 2.277628779411316
# Round 1, cleint 15, epoch 5: epoch_accuracy 41.015625, epoch_loss 2.276688780103411
# Round 1, cleint 16, epoch 1: epoch_accuracy 6.620065789473684, epoch_loss 2.31144034235101
# Round 1, cleint 16, epoch 2: epoch_accuracy 6.332236842105263, epoch_loss 2.3111627227381657
# Round 1, cleint 16, epoch 3: epoch_accuracy 6.167763157894737, epoch_loss 2.3100179245597436
# Round 1, cleint 16, epoch 4: epoch_accuracy 6.784539473684211, epoch_loss 2.308701276779175
# Round 1, cleint 16, epoch 5: epoch_accuracy 6.949013157894737, epoch_loss 2.307792487897371
# Round 1, cleint 17, epoch 1: epoch_accuracy 17.708333333333332, epoch_loss 2.2872684955596925
# Round 1, cleint 17, epoch 2: epoch_accuracy 19.010416666666668, epoch_loss 2.2864235560099284
# Round 1, cleint 17, epoch 3: epoch_accuracy 18.333333333333332, epoch_loss 2.2867385864257814
# Round 1, cleint 17, epoch 4: epoch_accuracy 17.864583333333332, epoch_loss 2.2858763058980305
# Round 1, cleint 17, epoch 5: epoch_accuracy 18.4375, epoch_loss 2.2856911182403565
# Round 1, cleint 18, epoch 1: epoch_accuracy 2.5764627659574466, epoch_loss 2.315275324151871
# Round 1, cleint 18, epoch 2: epoch_accuracy 2.4268617021276597, epoch_loss 2.3143641441426377
# Round 1, cleint 18, epoch 3: epoch_accuracy 2.77593085106383, epoch_loss 2.3126308410725693
# Round 1, cleint 18, epoch 4: epoch_accuracy 2.925531914893617, epoch_loss 2.311580429685877
# Round 1, cleint 18, epoch 5: epoch_accuracy 3.3743351063829787, epoch_loss 2.310001606636859
# Round 1, cleint 19, epoch 1: epoch_accuracy 6.484375, epoch_loss 2.307871699333191
# Round 1, cleint 19, epoch 2: epoch_accuracy 6.796875, epoch_loss 2.3075921297073365
# Round 1, cleint 19, epoch 3: epoch_accuracy 7.421875, epoch_loss 2.3070801973342894
# Round 1, cleint 19, epoch 4: epoch_accuracy 6.40625, epoch_loss 2.3075998067855834
# Round 1, cleint 19, epoch 5: epoch_accuracy 6.875, epoch_loss 2.3067103147506716
# Round 1, cleint 20, epoch 1: epoch_accuracy 1.796875, epoch_loss 2.3173744281133017
# Round 1, cleint 20, epoch 2: epoch_accuracy 1.953125, epoch_loss 2.316361490885417
# Round 1, cleint 20, epoch 3: epoch_accuracy 2.3177083333333335, epoch_loss 2.3152331988016766
# Round 1, cleint 20, epoch 4: epoch_accuracy 1.9270833333333333, epoch_loss 2.314519413312276
# Round 1, cleint 20, epoch 5: epoch_accuracy 2.3697916666666665, epoch_loss 2.313490358988444
# Model's Round: 1, train accuracy of model: 11.644583755985696, train loss of model: 2.297497339474976
#
#
# Model's Round: 1, test accuracy of model: 10.013977635782748, test loss of model: 2.302742403536178
#
#
# round 1 completed
# Round 2, cleint 1, epoch 1: epoch_accuracy 1.9791666666666667, epoch_loss 2.307724968592326
# Round 2, cleint 1, epoch 2: epoch_accuracy 2.0833333333333335, epoch_loss 2.3078275680541993
# Round 2, cleint 1, epoch 3: epoch_accuracy 1.8229166666666667, epoch_loss 2.306845458348592
# Round 2, cleint 1, epoch 4: epoch_accuracy 1.71875, epoch_loss 2.306812858581543
# Round 2, cleint 1, epoch 5: epoch_accuracy 2.1354166666666665, epoch_loss 2.3065990289052327
# Round 2, cleint 2, epoch 1: epoch_accuracy 29.114583333333332, epoch_loss 2.266714668273926
# Round 2, cleint 2, epoch 2: epoch_accuracy 28.75, epoch_loss 2.2661088943481444
# Round 2, cleint 2, epoch 3: epoch_accuracy 29.84375, epoch_loss 2.265368445714315
# Round 2, cleint 2, epoch 4: epoch_accuracy 31.666666666666668, epoch_loss 2.264217170079549
# Round 2, cleint 2, epoch 5: epoch_accuracy 31.458333333333332, epoch_loss 2.263362661997477
# Round 2, cleint 3, epoch 1: epoch_accuracy 5.005787037037037, epoch_loss 2.3212682141198053
# Round 2, cleint 3, epoch 2: epoch_accuracy 5.208333333333333, epoch_loss 2.32062002464577
# Round 2, cleint 3, epoch 3: epoch_accuracy 5.150462962962963, epoch_loss 2.320209406040333
# Round 2, cleint 3, epoch 4: epoch_accuracy 5.121527777777778, epoch_loss 2.319717557341964
# Round 2, cleint 3, epoch 5: epoch_accuracy 5.237268518518518, epoch_loss 2.3189696382593223
# Round 2, cleint 4, epoch 1: epoch_accuracy 7.239583333333333, epoch_loss 2.3005335648854572
# Round 2, cleint 4, epoch 2: epoch_accuracy 7.03125, epoch_loss 2.301015583674113
# Round 2, cleint 4, epoch 3: epoch_accuracy 7.291666666666667, epoch_loss 2.300007438659668
# Round 2, cleint 4, epoch 4: epoch_accuracy 6.979166666666667, epoch_loss 2.299479945500692
# Round 2, cleint 4, epoch 5: epoch_accuracy 7.135416666666667, epoch_loss 2.298839473724365
# Round 2, cleint 5, epoch 1: epoch_accuracy 33.14302884615385, epoch_loss 2.272767085295457
# Round 2, cleint 5, epoch 2: epoch_accuracy 32.87259615384615, epoch_loss 2.271910007183368
# Round 2, cleint 5, epoch 3: epoch_accuracy 33.203125, epoch_loss 2.2707396562282858
# Round 2, cleint 5, epoch 4: epoch_accuracy 32.99278846153846, epoch_loss 2.2698581585517297
# Round 2, cleint 5, epoch 5: epoch_accuracy 33.203125, epoch_loss 2.269063802865835
# Round 2, cleint 6, epoch 1: epoch_accuracy 2.03125, epoch_loss 2.3090524911880492
# Round 2, cleint 6, epoch 2: epoch_accuracy 1.71875, epoch_loss 2.3086126685142516
# Round 2, cleint 6, epoch 3: epoch_accuracy 2.109375, epoch_loss 2.307714879512787
# Round 2, cleint 6, epoch 4: epoch_accuracy 1.953125, epoch_loss 2.3076377749443053
# Round 2, cleint 6, epoch 5: epoch_accuracy 1.953125, epoch_loss 2.3066092848777773
# Round 2, cleint 7, epoch 1: epoch_accuracy 3.794642857142857, epoch_loss 2.293440727960496
# Round 2, cleint 7, epoch 2: epoch_accuracy 4.092261904761905, epoch_loss 2.292669114612398
# Round 2, cleint 7, epoch 3: epoch_accuracy 4.910714285714286, epoch_loss 2.2909765924726213
# Round 2, cleint 7, epoch 4: epoch_accuracy 5.208333333333333, epoch_loss 2.2897804237547374
# Round 2, cleint 7, epoch 5: epoch_accuracy 6.101190476190476, epoch_loss 2.2884401139758883
# Round 2, cleint 8, epoch 1: epoch_accuracy 4.58984375, epoch_loss 2.297681450843811
# Round 2, cleint 8, epoch 2: epoch_accuracy 5.46875, epoch_loss 2.296261101961136
# Round 2, cleint 8, epoch 3: epoch_accuracy 5.810546875, epoch_loss 2.2955701053142548
# Round 2, cleint 8, epoch 4: epoch_accuracy 7.275390625, epoch_loss 2.2940592020750046
# Round 2, cleint 8, epoch 5: epoch_accuracy 8.447265625, epoch_loss 2.292190134525299
# Round 2, cleint 9, epoch 1: epoch_accuracy 18.887867647058822, epoch_loss 2.2922096112195183
# Round 2, cleint 9, epoch 2: epoch_accuracy 19.209558823529413, epoch_loss 2.29135305741254
# Round 2, cleint 9, epoch 3: epoch_accuracy 17.876838235294116, epoch_loss 2.2918794014874626
# Round 2, cleint 9, epoch 4: epoch_accuracy 19.25551470588235, epoch_loss 2.2906990612254425
# Round 2, cleint 9, epoch 5: epoch_accuracy 18.841911764705884, epoch_loss 2.2906943910262165
# Round 2, cleint 10, epoch 1: epoch_accuracy 1.4973958333333333, epoch_loss 2.3225881457328796
# Round 2, cleint 10, epoch 2: epoch_accuracy 1.2369791666666667, epoch_loss 2.3223156332969666
# Round 2, cleint 10, epoch 3: epoch_accuracy 1.8229166666666667, epoch_loss 2.320874273777008
# Round 2, cleint 10, epoch 4: epoch_accuracy 1.8229166666666667, epoch_loss 2.3209474881490073
# Round 2, cleint 10, epoch 5: epoch_accuracy 1.3671875, epoch_loss 2.320517083009084
# Round 2, cleint 11, epoch 1: epoch_accuracy 12.03125, epoch_loss 2.2894833087921143
# Round 2, cleint 11, epoch 2: epoch_accuracy 11.25, epoch_loss 2.290936803817749
# Round 2, cleint 11, epoch 3: epoch_accuracy 11.09375, epoch_loss 2.289772939682007
# Round 2, cleint 11, epoch 4: epoch_accuracy 10.9375, epoch_loss 2.2889501571655275
# Round 2, cleint 11, epoch 5: epoch_accuracy 11.40625, epoch_loss 2.289171600341797
# Round 2, cleint 12, epoch 1: epoch_accuracy 9.375, epoch_loss 2.2957768223502417
# Round 2, cleint 12, epoch 2: epoch_accuracy 10.511363636363637, epoch_loss 2.294684258374301
# Round 2, cleint 12, epoch 3: epoch_accuracy 11.150568181818182, epoch_loss 2.2935639944943516
# Round 2, cleint 12, epoch 4: epoch_accuracy 9.801136363636363, epoch_loss 2.2928545475006104
# Round 2, cleint 12, epoch 5: epoch_accuracy 10.511363636363637, epoch_loss 2.292814709923484
# Round 2, cleint 13, epoch 1: epoch_accuracy 14.140625, epoch_loss 2.3034504890441894
# Round 2, cleint 13, epoch 2: epoch_accuracy 14.6875, epoch_loss 2.304278588294983
# Round 2, cleint 13, epoch 3: epoch_accuracy 14.375, epoch_loss 2.3043604135513305
# Round 2, cleint 13, epoch 4: epoch_accuracy 13.75, epoch_loss 2.304610800743103
# Round 2, cleint 13, epoch 5: epoch_accuracy 14.21875, epoch_loss 2.3037441968917847
# Round 2, cleint 14, epoch 1: epoch_accuracy 7.009548611111111, epoch_loss 2.3091638485590615
# Round 2, cleint 14, epoch 2: epoch_accuracy 7.595486111111111, epoch_loss 2.308383471435971
# Round 2, cleint 14, epoch 3: epoch_accuracy 7.508680555555555, epoch_loss 2.3084121147791543
# Round 2, cleint 14, epoch 4: epoch_accuracy 8.59375, epoch_loss 2.3073689937591553
# Round 2, cleint 14, epoch 5: epoch_accuracy 8.745659722222221, epoch_loss 2.306719740231832
# Round 2, cleint 15, epoch 1: epoch_accuracy 37.779017857142854, epoch_loss 2.2800626073564803
# Round 2, cleint 15, epoch 2: epoch_accuracy 38.113839285714285, epoch_loss 2.2791665622166226
# Round 2, cleint 15, epoch 3: epoch_accuracy 38.392857142857146, epoch_loss 2.278881345476423
# Round 2, cleint 15, epoch 4: epoch_accuracy 39.453125, epoch_loss 2.2774245057787215
# Round 2, cleint 15, epoch 5: epoch_accuracy 39.229910714285715, epoch_loss 2.2774327312197005
# Round 2, cleint 16, epoch 1: epoch_accuracy 6.743421052631579, epoch_loss 2.3117332207529167
# Round 2, cleint 16, epoch 2: epoch_accuracy 6.620065789473684, epoch_loss 2.310642593785336
# Round 2, cleint 16, epoch 3: epoch_accuracy 6.167763157894737, epoch_loss 2.309841281489322
# Round 2, cleint 16, epoch 4: epoch_accuracy 6.702302631578948, epoch_loss 2.3091989818372225
# Round 2, cleint 16, epoch 5: epoch_accuracy 6.661184210526316, epoch_loss 2.307591287713302
# Round 2, cleint 17, epoch 1: epoch_accuracy 18.125, epoch_loss 2.2869247595469155
# Round 2, cleint 17, epoch 2: epoch_accuracy 17.65625, epoch_loss 2.2864514350891114
# Round 2, cleint 17, epoch 3: epoch_accuracy 18.541666666666668, epoch_loss 2.286020835240682
# Round 2, cleint 17, epoch 4: epoch_accuracy 18.697916666666668, epoch_loss 2.2858819007873534
# Round 2, cleint 17, epoch 5: epoch_accuracy 18.802083333333332, epoch_loss 2.284300963083903
# Round 2, cleint 18, epoch 1: epoch_accuracy 2.376994680851064, epoch_loss 2.315835450557952
# Round 2, cleint 18, epoch 2: epoch_accuracy 2.8756648936170213, epoch_loss 2.31406310771374
# Round 2, cleint 18, epoch 3: epoch_accuracy 2.8091755319148937, epoch_loss 2.3128470765783433
# Round 2, cleint 18, epoch 4: epoch_accuracy 2.942154255319149, epoch_loss 2.311849791952904
# Round 2, cleint 18, epoch 5: epoch_accuracy 3.6735372340425534, epoch_loss 2.310505902513545
# Round 2, cleint 19, epoch 1: epoch_accuracy 6.71875, epoch_loss 2.3077515840530394
# Round 2, cleint 19, epoch 2: epoch_accuracy 6.640625, epoch_loss 2.3073352813720702
# Round 2, cleint 19, epoch 3: epoch_accuracy 6.015625, epoch_loss 2.307507562637329
# Round 2, cleint 19, epoch 4: epoch_accuracy 5.46875, epoch_loss 2.3072193384170534
# Round 2, cleint 19, epoch 5: epoch_accuracy 6.71875, epoch_loss 2.306419825553894
# Round 2, cleint 20, epoch 1: epoch_accuracy 1.6666666666666667, epoch_loss 2.3177352507909137
# Round 2, cleint 20, epoch 2: epoch_accuracy 1.71875, epoch_loss 2.316676553090413
# Round 2, cleint 20, epoch 3: epoch_accuracy 1.640625, epoch_loss 2.315533192952474
# Round 2, cleint 20, epoch 4: epoch_accuracy 2.109375, epoch_loss 2.3144168138504027
# Round 2, cleint 20, epoch 5: epoch_accuracy 2.265625, epoch_loss 2.3128607432047525
# Model's Round: 2, train accuracy of model: 11.905667720092767, train loss of model: 2.2973423656922245
#
#
# Model's Round: 2, test accuracy of model: 10.013977635782748, test loss of model: 2.302737622215344
#
#
# round 2 completed
# Round 3, cleint 1, epoch 1: epoch_accuracy 1.6145833333333333, epoch_loss 2.3068679332733155
# Round 3, cleint 1, epoch 2: epoch_accuracy 1.5104166666666667, epoch_loss 2.306882937749227
# Round 3, cleint 1, epoch 3: epoch_accuracy 2.2395833333333335, epoch_loss 2.3068793455759686
# Round 3, cleint 1, epoch 4: epoch_accuracy 1.5104166666666667, epoch_loss 2.306666437784831
# Round 3, cleint 1, epoch 5: epoch_accuracy 1.9791666666666667, epoch_loss 2.3063978354136148
# Round 3, cleint 2, epoch 1: epoch_accuracy 29.53125, epoch_loss 2.267772610982259
# Round 3, cleint 2, epoch 2: epoch_accuracy 28.697916666666668, epoch_loss 2.266068379084269
# Round 3, cleint 2, epoch 3: epoch_accuracy 29.427083333333332, epoch_loss 2.2651169141133627
# Round 3, cleint 2, epoch 4: epoch_accuracy 30.3125, epoch_loss 2.2641987959543863
# Round 3, cleint 2, epoch 5: epoch_accuracy 31.041666666666668, epoch_loss 2.2633277575174966
# Round 3, cleint 3, epoch 1: epoch_accuracy 4.976851851851852, epoch_loss 2.321204529868232
# Round 3, cleint 3, epoch 2: epoch_accuracy 4.8032407407407405, epoch_loss 2.3209268340358027
# Round 3, cleint 3, epoch 3: epoch_accuracy 4.976851851851852, epoch_loss 2.319966536981088
# Round 3, cleint 3, epoch 4: epoch_accuracy 5.266203703703703, epoch_loss 2.319009648429023
# Round 3, cleint 3, epoch 5: epoch_accuracy 5.46875, epoch_loss 2.3183778568550393
# Round 3, cleint 4, epoch 1: epoch_accuracy 7.291666666666667, epoch_loss 2.3000818252563477
# Round 3, cleint 4, epoch 2: epoch_accuracy 6.614583333333333, epoch_loss 2.3007234573364257
# Round 3, cleint 4, epoch 3: epoch_accuracy 7.5, epoch_loss 2.2998016993204753
# Round 3, cleint 4, epoch 4: epoch_accuracy 7.03125, epoch_loss 2.299057674407959
# Round 3, cleint 4, epoch 5: epoch_accuracy 7.395833333333333, epoch_loss 2.298762146631877
# Round 3, cleint 5, epoch 1: epoch_accuracy 33.02283653846154, epoch_loss 2.2731483166034403
# Round 3, cleint 5, epoch 2: epoch_accuracy 32.69230769230769, epoch_loss 2.2716941925195546
# Round 3, cleint 5, epoch 3: epoch_accuracy 33.203125, epoch_loss 2.2703476594044614
# Round 3, cleint 5, epoch 4: epoch_accuracy 33.17307692307692, epoch_loss 2.2699724527505727
# Round 3, cleint 5, epoch 5: epoch_accuracy 32.90264423076923, epoch_loss 2.2690510016221266
# Round 3, cleint 6, epoch 1: epoch_accuracy 1.796875, epoch_loss 2.308445656299591
# Round 3, cleint 6, epoch 2: epoch_accuracy 1.71875, epoch_loss 2.3086269378662108
# Round 3, cleint 6, epoch 3: epoch_accuracy 2.265625, epoch_loss 2.307678210735321
# Round 3, cleint 6, epoch 4: epoch_accuracy 1.875, epoch_loss 2.3076770067214967
# Round 3, cleint 6, epoch 5: epoch_accuracy 2.2265625, epoch_loss 2.3065425038337706
# Round 3, cleint 7, epoch 1: epoch_accuracy 3.3482142857142856, epoch_loss 2.293226752962385
# Round 3, cleint 7, epoch 2: epoch_accuracy 3.794642857142857, epoch_loss 2.2920093763442266
# Round 3, cleint 7, epoch 3: epoch_accuracy 3.5714285714285716, epoch_loss 2.291326182229178
# Round 3, cleint 7, epoch 4: epoch_accuracy 5.729166666666667, epoch_loss 2.2892872038341703
# Round 3, cleint 7, epoch 5: epoch_accuracy 5.282738095238095, epoch_loss 2.288071030662173
# Round 3, cleint 8, epoch 1: epoch_accuracy 5.029296875, epoch_loss 2.297957733273506
# Round 3, cleint 8, epoch 2: epoch_accuracy 5.224609375, epoch_loss 2.2961084693670273
# Round 3, cleint 8, epoch 3: epoch_accuracy 6.005859375, epoch_loss 2.296018347144127
# Round 3, cleint 8, epoch 4: epoch_accuracy 7.6171875, epoch_loss 2.294138938188553
# Round 3, cleint 8, epoch 5: epoch_accuracy 7.91015625, epoch_loss 2.292893201112747
# Round 3, cleint 9, epoch 1: epoch_accuracy 19.577205882352942, epoch_loss 2.2916838421541104
# Round 3, cleint 9, epoch 2: epoch_accuracy 18.014705882352942, epoch_loss 2.2918934261097625
# Round 3, cleint 9, epoch 3: epoch_accuracy 18.795955882352942, epoch_loss 2.2912083794088924
# Round 3, cleint 9, epoch 4: epoch_accuracy 18.47426470588235, epoch_loss 2.290771750842824
# Round 3, cleint 9, epoch 5: epoch_accuracy 19.02573529411765, epoch_loss 2.290635627858779
# Round 3, cleint 10, epoch 1: epoch_accuracy 1.1067708333333333, epoch_loss 2.321844776471456
# Round 3, cleint 10, epoch 2: epoch_accuracy 1.3671875, epoch_loss 2.321546455224355
# Round 3, cleint 10, epoch 3: epoch_accuracy 1.4322916666666667, epoch_loss 2.3208136359850564
# Round 3, cleint 10, epoch 4: epoch_accuracy 1.5625, epoch_loss 2.3198129733403525
# Round 3, cleint 10, epoch 5: epoch_accuracy 1.8229166666666667, epoch_loss 2.320725599924723
# Round 3, cleint 11, epoch 1: epoch_accuracy 11.71875, epoch_loss 2.2902825832366944
# Round 3, cleint 11, epoch 2: epoch_accuracy 8.90625, epoch_loss 2.290771818161011
# Round 3, cleint 11, epoch 3: epoch_accuracy 10.3125, epoch_loss 2.2896143913269045
# Round 3, cleint 11, epoch 4: epoch_accuracy 10.46875, epoch_loss 2.2901214122772218
# Round 3, cleint 11, epoch 5: epoch_accuracy 10.15625, epoch_loss 2.2898208141326903
# Round 3, cleint 12, epoch 1: epoch_accuracy 9.375, epoch_loss 2.2958603338761763
# Round 3, cleint 12, epoch 2: epoch_accuracy 10.369318181818182, epoch_loss 2.294952219182795
# Round 3, cleint 12, epoch 3: epoch_accuracy 10.582386363636363, epoch_loss 2.293378938328136
# Round 3, cleint 12, epoch 4: epoch_accuracy 10.369318181818182, epoch_loss 2.2924193902449175
# Round 3, cleint 12, epoch 5: epoch_accuracy 10.653409090909092, epoch_loss 2.2926631407304243
# Round 3, cleint 13, epoch 1: epoch_accuracy 13.4375, epoch_loss 2.3049328088760377
# Round 3, cleint 13, epoch 2: epoch_accuracy 13.359375, epoch_loss 2.3051695585250855
# Round 3, cleint 13, epoch 3: epoch_accuracy 14.6875, epoch_loss 2.3037016868591307
# Round 3, cleint 13, epoch 4: epoch_accuracy 12.734375, epoch_loss 2.3057426691055296
# Round 3, cleint 13, epoch 5: epoch_accuracy 14.53125, epoch_loss 2.3039669752120973
# Round 3, cleint 14, epoch 1: epoch_accuracy 6.749131944444445, epoch_loss 2.309981928931342
# Round 3, cleint 14, epoch 2: epoch_accuracy 7.595486111111111, epoch_loss 2.3088005118899875
# Round 3, cleint 14, epoch 3: epoch_accuracy 7.2265625, epoch_loss 2.308474520842234
# Round 3, cleint 14, epoch 4: epoch_accuracy 7.747395833333333, epoch_loss 2.3078719907336764
# Round 3, cleint 14, epoch 5: epoch_accuracy 9.114583333333334, epoch_loss 2.307005842526754
# Round 3, cleint 15, epoch 1: epoch_accuracy 38.28125, epoch_loss 2.279266119003296
# Round 3, cleint 15, epoch 2: epoch_accuracy 38.783482142857146, epoch_loss 2.2793189116886685
# Round 3, cleint 15, epoch 3: epoch_accuracy 39.39732142857143, epoch_loss 2.278067009789603
# Round 3, cleint 15, epoch 4: epoch_accuracy 39.39732142857143, epoch_loss 2.2781351634434293
# Round 3, cleint 15, epoch 5: epoch_accuracy 39.78794642857143, epoch_loss 2.2771303483418057
# Round 3, cleint 16, epoch 1: epoch_accuracy 6.167763157894737, epoch_loss 2.312016148316233
# Round 3, cleint 16, epoch 2: epoch_accuracy 6.25, epoch_loss 2.311798848603901
# Round 3, cleint 16, epoch 3: epoch_accuracy 6.4144736842105265, epoch_loss 2.3109921279706453
# Round 3, cleint 16, epoch 4: epoch_accuracy 7.1957236842105265, epoch_loss 2.308733664060894
# Round 3, cleint 16, epoch 5: epoch_accuracy 6.784539473684211, epoch_loss 2.307697522012811
# Round 3, cleint 17, epoch 1: epoch_accuracy 18.4375, epoch_loss 2.2856927076975504
# Round 3, cleint 17, epoch 2: epoch_accuracy 18.75, epoch_loss 2.28556227684021
# Round 3, cleint 17, epoch 3: epoch_accuracy 17.96875, epoch_loss 2.2866051038106283
# Round 3, cleint 17, epoch 4: epoch_accuracy 17.864583333333332, epoch_loss 2.2850023110707602
# Round 3, cleint 17, epoch 5: epoch_accuracy 18.802083333333332, epoch_loss 2.2843969027201334
# Round 3, cleint 18, epoch 1: epoch_accuracy 2.34375, epoch_loss 2.3158448249735732
# Round 3, cleint 18, epoch 2: epoch_accuracy 2.7593085106382977, epoch_loss 2.313849423794036
# Round 3, cleint 18, epoch 3: epoch_accuracy 3.257978723404255, epoch_loss 2.312598649491655
# Round 3, cleint 18, epoch 4: epoch_accuracy 2.859042553191489, epoch_loss 2.31209715376509
# Round 3, cleint 18, epoch 5: epoch_accuracy 3.4242021276595747, epoch_loss 2.3103529696768903
# Round 3, cleint 19, epoch 1: epoch_accuracy 6.40625, epoch_loss 2.3080920934677125
# Round 3, cleint 19, epoch 2: epoch_accuracy 6.640625, epoch_loss 2.3080410242080687
# Round 3, cleint 19, epoch 3: epoch_accuracy 6.40625, epoch_loss 2.307655119895935
# Round 3, cleint 19, epoch 4: epoch_accuracy 6.015625, epoch_loss 2.3066991329193116
# Round 3, cleint 19, epoch 5: epoch_accuracy 7.109375, epoch_loss 2.3062839984893797
# Round 3, cleint 20, epoch 1: epoch_accuracy 1.7708333333333333, epoch_loss 2.3181309620539348
# Round 3, cleint 20, epoch 2: epoch_accuracy 1.9010416666666667, epoch_loss 2.3161984364191692
# Round 3, cleint 20, epoch 3: epoch_accuracy 1.796875, epoch_loss 2.3154553095499675
# Round 3, cleint 20, epoch 4: epoch_accuracy 1.640625, epoch_loss 2.3141438166300454
# Round 3, cleint 20, epoch 5: epoch_accuracy 1.9010416666666667, epoch_loss 2.3130903005599976
# Model's Round: 3, train accuracy of model: 11.866042507880797, train loss of model: 2.2973596687917666
#
#
# Model's Round: 3, test accuracy of model: 10.013977635782748, test loss of model: 2.302732911734535
#
#
# round 3 completed
# Round 4, cleint 1, epoch 1: epoch_accuracy 1.6145833333333333, epoch_loss 2.3071834882100424
# Round 4, cleint 1, epoch 2: epoch_accuracy 1.8229166666666667, epoch_loss 2.3067283630371094
# Round 4, cleint 1, epoch 3: epoch_accuracy 1.9791666666666667, epoch_loss 2.306431802113851
# Round 4, cleint 1, epoch 4: epoch_accuracy 1.7708333333333333, epoch_loss 2.3072383244832357
# Round 4, cleint 1, epoch 5: epoch_accuracy 1.5104166666666667, epoch_loss 2.306450303395589
# Round 4, cleint 2, epoch 1: epoch_accuracy 27.96875, epoch_loss 2.2676423231760663
# Round 4, cleint 2, epoch 2: epoch_accuracy 30.0, epoch_loss 2.2655678113301594
# Round 4, cleint 2, epoch 3: epoch_accuracy 28.75, epoch_loss 2.2657351970672606
# Round 4, cleint 2, epoch 4: epoch_accuracy 31.041666666666668, epoch_loss 2.264065901438395
# Round 4, cleint 2, epoch 5: epoch_accuracy 29.895833333333332, epoch_loss 2.263846842447917
# Round 4, cleint 3, epoch 1: epoch_accuracy 5.005787037037037, epoch_loss 2.32125476554588
# Round 4, cleint 3, epoch 2: epoch_accuracy 5.208333333333333, epoch_loss 2.320339564923887
# Round 4, cleint 3, epoch 3: epoch_accuracy 5.758101851851852, epoch_loss 2.3193529623526112
# Round 4, cleint 3, epoch 4: epoch_accuracy 5.208333333333333, epoch_loss 2.3191134929656982
# Round 4, cleint 3, epoch 5: epoch_accuracy 5.295138888888889, epoch_loss 2.3186081515418158
# Round 4, cleint 4, epoch 1: epoch_accuracy 7.083333333333333, epoch_loss 2.299979654947917
# Round 4, cleint 4, epoch 2: epoch_accuracy 7.03125, epoch_loss 2.2994636058807374
# Round 4, cleint 4, epoch 3: epoch_accuracy 6.5625, epoch_loss 2.2998339811960857
# Round 4, cleint 4, epoch 4: epoch_accuracy 7.34375, epoch_loss 2.2984606424967446
# Round 4, cleint 4, epoch 5: epoch_accuracy 7.760416666666667, epoch_loss 2.298536427815755
# Round 4, cleint 5, epoch 1: epoch_accuracy 32.57211538461539, epoch_loss 2.272515296936035
# Round 4, cleint 5, epoch 2: epoch_accuracy 32.72235576923077, epoch_loss 2.271784883279067
# Round 4, cleint 5, epoch 3: epoch_accuracy 32.33173076923077, epoch_loss 2.2713276056142955
# Round 4, cleint 5, epoch 4: epoch_accuracy 33.71394230769231, epoch_loss 2.2697218381441555
# Round 4, cleint 5, epoch 5: epoch_accuracy 32.99278846153846, epoch_loss 2.2690507632035475
# Round 4, cleint 6, epoch 1: epoch_accuracy 2.1484375, epoch_loss 2.308869254589081
# Round 4, cleint 6, epoch 2: epoch_accuracy 1.953125, epoch_loss 2.3083431005477903
# Round 4, cleint 6, epoch 3: epoch_accuracy 1.640625, epoch_loss 2.3079668283462524
# Round 4, cleint 6, epoch 4: epoch_accuracy 1.7578125, epoch_loss 2.307189929485321
# Round 4, cleint 6, epoch 5: epoch_accuracy 1.9921875, epoch_loss 2.3066284894943236
# Round 4, cleint 7, epoch 1: epoch_accuracy 3.869047619047619, epoch_loss 2.2929978484199163
# Round 4, cleint 7, epoch 2: epoch_accuracy 4.9851190476190474, epoch_loss 2.291820389883859
# Round 4, cleint 7, epoch 3: epoch_accuracy 5.096726190476191, epoch_loss 2.2907077925545827
# Round 4, cleint 7, epoch 4: epoch_accuracy 5.580357142857143, epoch_loss 2.2892398720695857
# Round 4, cleint 7, epoch 5: epoch_accuracy 6.361607142857143, epoch_loss 2.2884887740725564
# Round 4, cleint 8, epoch 1: epoch_accuracy 4.638671875, epoch_loss 2.2966955453157425
# Round 4, cleint 8, epoch 2: epoch_accuracy 5.6640625, epoch_loss 2.2958514392375946
# Round 4, cleint 8, epoch 3: epoch_accuracy 6.689453125, epoch_loss 2.294961556792259
# Round 4, cleint 8, epoch 4: epoch_accuracy 6.494140625, epoch_loss 2.294158160686493
# Round 4, cleint 8, epoch 5: epoch_accuracy 8.740234375, epoch_loss 2.2930641174316406
# Round 4, cleint 9, epoch 1: epoch_accuracy 19.25551470588235, epoch_loss 2.2922052916358497
# Round 4, cleint 9, epoch 2: epoch_accuracy 19.02573529411765, epoch_loss 2.2920774431789623
# Round 4, cleint 9, epoch 3: epoch_accuracy 18.658088235294116, epoch_loss 2.292094455045812
# Round 4, cleint 9, epoch 4: epoch_accuracy 19.11764705882353, epoch_loss 2.290551816715914
# Round 4, cleint 9, epoch 5: epoch_accuracy 19.347426470588236, epoch_loss 2.290367463055779
# Round 4, cleint 10, epoch 1: epoch_accuracy 1.3671875, epoch_loss 2.323080519835154
# Round 4, cleint 10, epoch 2: epoch_accuracy 1.4322916666666667, epoch_loss 2.3211710254351297
# Round 4, cleint 10, epoch 3: epoch_accuracy 1.2369791666666667, epoch_loss 2.3214202721913657
# Round 4, cleint 10, epoch 4: epoch_accuracy 1.171875, epoch_loss 2.320726970831553
# Round 4, cleint 10, epoch 5: epoch_accuracy 1.3020833333333333, epoch_loss 2.3200716773668923
# Round 4, cleint 11, epoch 1: epoch_accuracy 10.9375, epoch_loss 2.2897790908813476
# Round 4, cleint 11, epoch 2: epoch_accuracy 11.25, epoch_loss 2.2893635272979735
# Round 4, cleint 11, epoch 3: epoch_accuracy 10.46875, epoch_loss 2.290030336380005
# Round 4, cleint 11, epoch 4: epoch_accuracy 11.25, epoch_loss 2.2897600650787355
# Round 4, cleint 11, epoch 5: epoch_accuracy 9.53125, epoch_loss 2.289359426498413
# Round 4, cleint 12, epoch 1: epoch_accuracy 9.303977272727273, epoch_loss 2.295293829657815
# Round 4, cleint 12, epoch 2: epoch_accuracy 10.298295454545455, epoch_loss 2.2951244007457388
# Round 4, cleint 12, epoch 3: epoch_accuracy 9.801136363636363, epoch_loss 2.294250813397494
# Round 4, cleint 12, epoch 4: epoch_accuracy 11.434659090909092, epoch_loss 2.2924947305159136
# Round 4, cleint 12, epoch 5: epoch_accuracy 10.9375, epoch_loss 2.2912421226501465
# Round 4, cleint 13, epoch 1: epoch_accuracy 12.96875, epoch_loss 2.304644250869751
# Round 4, cleint 13, epoch 2: epoch_accuracy 14.140625, epoch_loss 2.304944944381714
# Round 4, cleint 13, epoch 3: epoch_accuracy 13.984375, epoch_loss 2.3044764518737795
# Round 4, cleint 13, epoch 4: epoch_accuracy 14.609375, epoch_loss 2.3030569553375244
# Round 4, cleint 13, epoch 5: epoch_accuracy 13.28125, epoch_loss 2.3047794103622437
# Round 4, cleint 14, epoch 1: epoch_accuracy 6.792534722222222, epoch_loss 2.309724635548062
# Round 4, cleint 14, epoch 2: epoch_accuracy 7.486979166666667, epoch_loss 2.3094489640659757
# Round 4, cleint 14, epoch 3: epoch_accuracy 7.8125, epoch_loss 2.308879600630866
# Round 4, cleint 14, epoch 4: epoch_accuracy 7.8125, epoch_loss 2.3079966571595936
# Round 4, cleint 14, epoch 5: epoch_accuracy 8.311631944444445, epoch_loss 2.3077145086394415
# Round 4, cleint 15, epoch 1: epoch_accuracy 38.002232142857146, epoch_loss 2.2792656932558333
# Round 4, cleint 15, epoch 2: epoch_accuracy 38.839285714285715, epoch_loss 2.2788277012961253
# Round 4, cleint 15, epoch 3: epoch_accuracy 39.564732142857146, epoch_loss 2.277921199798584
# Round 4, cleint 15, epoch 4: epoch_accuracy 40.56919642857143, epoch_loss 2.276981677327837
# Round 4, cleint 15, epoch 5: epoch_accuracy 40.011160714285715, epoch_loss 2.2768552814211165
# Round 4, cleint 16, epoch 1: epoch_accuracy 6.743421052631579, epoch_loss 2.312147491856625
# Round 4, cleint 16, epoch 2: epoch_accuracy 6.620065789473684, epoch_loss 2.3112253766310844
# Round 4, cleint 16, epoch 3: epoch_accuracy 6.702302631578948, epoch_loss 2.309820212815937
# Round 4, cleint 16, epoch 4: epoch_accuracy 6.4555921052631575, epoch_loss 2.30901184834932
# Round 4, cleint 16, epoch 5: epoch_accuracy 6.8256578947368425, epoch_loss 2.3082548568123267
# Round 4, cleint 17, epoch 1: epoch_accuracy 18.697916666666668, epoch_loss 2.2857943058013914
# Round 4, cleint 17, epoch 2: epoch_accuracy 18.90625, epoch_loss 2.28576668103536
# Round 4, cleint 17, epoch 3: epoch_accuracy 19.427083333333332, epoch_loss 2.2855836391448974
# Round 4, cleint 17, epoch 4: epoch_accuracy 19.0625, epoch_loss 2.284779659907023
# Round 4, cleint 17, epoch 5: epoch_accuracy 18.854166666666668, epoch_loss 2.2848883152008055
# Round 4, cleint 18, epoch 1: epoch_accuracy 2.4933510638297873, epoch_loss 2.3156176222131606
# Round 4, cleint 18, epoch 2: epoch_accuracy 2.8756648936170213, epoch_loss 2.3142750871942397
# Round 4, cleint 18, epoch 3: epoch_accuracy 2.7094414893617023, epoch_loss 2.3129593818745713
# Round 4, cleint 18, epoch 4: epoch_accuracy 3.6236702127659575, epoch_loss 2.311892159441684
# Round 4, cleint 18, epoch 5: epoch_accuracy 3.390957446808511, epoch_loss 2.3106104718877916
# Round 4, cleint 19, epoch 1: epoch_accuracy 6.328125, epoch_loss 2.3070934534072878
# Round 4, cleint 19, epoch 2: epoch_accuracy 6.640625, epoch_loss 2.3074077367782593
# Round 4, cleint 19, epoch 3: epoch_accuracy 6.953125, epoch_loss 2.3071279525756836
# Round 4, cleint 19, epoch 4: epoch_accuracy 6.875, epoch_loss 2.3068299770355223
# Round 4, cleint 19, epoch 5: epoch_accuracy 6.71875, epoch_loss 2.3063503980636595
# Round 4, cleint 20, epoch 1: epoch_accuracy 1.6666666666666667, epoch_loss 2.3171416918436685
# Round 4, cleint 20, epoch 2: epoch_accuracy 1.7708333333333333, epoch_loss 2.316535973548889
# Round 4, cleint 20, epoch 3: epoch_accuracy 2.2916666666666665, epoch_loss 2.315427279472351
# Round 4, cleint 20, epoch 4: epoch_accuracy 1.953125, epoch_loss 2.3141777992248533
# Round 4, cleint 20, epoch 5: epoch_accuracy 1.5625, epoch_loss 2.3132402976353963
# Model's Round: 4, train accuracy of model: 11.731147875290745, train loss of model: 2.297420404949858
#
#
# Model's Round: 4, test accuracy of model: 10.013977635782748, test loss of model: 2.3027283071329037
#
#
# round 4 completed
# Round 5, cleint 1, epoch 1: epoch_accuracy 1.7708333333333333, epoch_loss 2.3074658075968424
# Round 5, cleint 1, epoch 2: epoch_accuracy 1.9270833333333333, epoch_loss 2.306326421101888
# Round 5, cleint 1, epoch 3: epoch_accuracy 1.5625, epoch_loss 2.3065391222635907
# Round 5, cleint 1, epoch 4: epoch_accuracy 1.9791666666666667, epoch_loss 2.306856409708659
# Round 5, cleint 1, epoch 5: epoch_accuracy 1.71875, epoch_loss 2.3061501661936443
# Round 5, cleint 2, epoch 1: epoch_accuracy 29.427083333333332, epoch_loss 2.267314354578654
# Round 5, cleint 2, epoch 2: epoch_accuracy 29.322916666666668, epoch_loss 2.266594966252645
# Round 5, cleint 2, epoch 3: epoch_accuracy 31.770833333333332, epoch_loss 2.2650545597076417
# Round 5, cleint 2, epoch 4: epoch_accuracy 30.885416666666668, epoch_loss 2.2644075552622476
# Round 5, cleint 2, epoch 5: epoch_accuracy 30.46875, epoch_loss 2.2638706525166827
# Round 5, cleint 3, epoch 1: epoch_accuracy 5.266203703703703, epoch_loss 2.3212600813971624
# Round 5, cleint 3, epoch 2: epoch_accuracy 4.918981481481482, epoch_loss 2.320538785722521
# Round 5, cleint 3, epoch 3: epoch_accuracy 5.324074074074074, epoch_loss 2.3193849192725287
# Round 5, cleint 3, epoch 4: epoch_accuracy 5.266203703703703, epoch_loss 2.319156796843917
# Round 5, cleint 3, epoch 5: epoch_accuracy 5.063657407407407, epoch_loss 2.318313130625972
# Round 5, cleint 4, epoch 1: epoch_accuracy 7.291666666666667, epoch_loss 2.2998213291168215
# Round 5, cleint 4, epoch 2: epoch_accuracy 7.604166666666667, epoch_loss 2.2993812402089437
# Round 5, cleint 4, epoch 3: epoch_accuracy 7.760416666666667, epoch_loss 2.2996670722961428
# Round 5, cleint 4, epoch 4: epoch_accuracy 7.96875, epoch_loss 2.298128779729207
# Round 5, cleint 4, epoch 5: epoch_accuracy 7.291666666666667, epoch_loss 2.298803186416626
# Round 5, cleint 5, epoch 1: epoch_accuracy 32.51201923076923, epoch_loss 2.2731353594706607
# Round 5, cleint 5, epoch 2: epoch_accuracy 33.26322115384615, epoch_loss 2.272087518985455
# Round 5, cleint 5, epoch 3: epoch_accuracy 33.14302884615385, epoch_loss 2.2710047501784105
# Round 5, cleint 5, epoch 4: epoch_accuracy 34.10456730769231, epoch_loss 2.269505638342637
# Round 5, cleint 5, epoch 5: epoch_accuracy 33.14302884615385, epoch_loss 2.269189165188716
# Round 5, cleint 6, epoch 1: epoch_accuracy 2.0703125, epoch_loss 2.30877103805542
# Round 5, cleint 6, epoch 2: epoch_accuracy 2.1484375, epoch_loss 2.3081404089927675
# Round 5, cleint 6, epoch 3: epoch_accuracy 2.03125, epoch_loss 2.307457721233368
# Round 5, cleint 6, epoch 4: epoch_accuracy 2.03125, epoch_loss 2.3067718505859376
# Round 5, cleint 6, epoch 5: epoch_accuracy 1.875, epoch_loss 2.306784915924072
# Round 5, cleint 7, epoch 1: epoch_accuracy 3.6830357142857144, epoch_loss 2.2930836223420643
# Round 5, cleint 7, epoch 2: epoch_accuracy 4.315476190476191, epoch_loss 2.2914855366661433
# Round 5, cleint 7, epoch 3: epoch_accuracy 4.6875, epoch_loss 2.2906526838030135
# Round 5, cleint 7, epoch 4: epoch_accuracy 5.133928571428571, epoch_loss 2.288714533760434
# Round 5, cleint 7, epoch 5: epoch_accuracy 6.212797619047619, epoch_loss 2.2880867208753313
# Round 5, cleint 8, epoch 1: epoch_accuracy 4.78515625, epoch_loss 2.2972395420074463
# Round 5, cleint 8, epoch 2: epoch_accuracy 6.4453125, epoch_loss 2.2962031811475754
# Round 5, cleint 8, epoch 3: epoch_accuracy 5.615234375, epoch_loss 2.295186936855316
# Round 5, cleint 8, epoch 4: epoch_accuracy 6.494140625, epoch_loss 2.293797329068184
# Round 5, cleint 8, epoch 5: epoch_accuracy 7.958984375, epoch_loss 2.2929670363664627
# Round 5, cleint 9, epoch 1: epoch_accuracy 19.02573529411765, epoch_loss 2.2919711505665497
# Round 5, cleint 9, epoch 2: epoch_accuracy 19.209558823529413, epoch_loss 2.291993688134586
# Round 5, cleint 9, epoch 3: epoch_accuracy 19.623161764705884, epoch_loss 2.2911559974446014
# Round 5, cleint 9, epoch 4: epoch_accuracy 19.347426470588236, epoch_loss 2.2909789646373078
# Round 5, cleint 9, epoch 5: epoch_accuracy 19.02573529411765, epoch_loss 2.2902974942151237
# Round 5, cleint 10, epoch 1: epoch_accuracy 1.2369791666666667, epoch_loss 2.3227660059928894
# Round 5, cleint 10, epoch 2: epoch_accuracy 1.4322916666666667, epoch_loss 2.3224163254102073
# Round 5, cleint 10, epoch 3: epoch_accuracy 1.3020833333333333, epoch_loss 2.3212226827939353
# Round 5, cleint 10, epoch 4: epoch_accuracy 1.4322916666666667, epoch_loss 2.321083188056946
# Round 5, cleint 10, epoch 5: epoch_accuracy 1.4973958333333333, epoch_loss 2.3201823234558105
# Round 5, cleint 11, epoch 1: epoch_accuracy 11.40625, epoch_loss 2.289114475250244
# Round 5, cleint 11, epoch 2: epoch_accuracy 11.875, epoch_loss 2.2895033836364744
# Round 5, cleint 11, epoch 3: epoch_accuracy 12.03125, epoch_loss 2.288675308227539
# Round 5, cleint 11, epoch 4: epoch_accuracy 11.71875, epoch_loss 2.2892375946044923
# Round 5, cleint 11, epoch 5: epoch_accuracy 11.09375, epoch_loss 2.2889877796173095
# Round 5, cleint 12, epoch 1: epoch_accuracy 9.943181818181818, epoch_loss 2.2954564528031782
# Round 5, cleint 12, epoch 2: epoch_accuracy 9.659090909090908, epoch_loss 2.2940495447679
# Round 5, cleint 12, epoch 3: epoch_accuracy 9.303977272727273, epoch_loss 2.294217738238248
# Round 5, cleint 12, epoch 4: epoch_accuracy 9.303977272727273, epoch_loss 2.2932431481101294
# Round 5, cleint 12, epoch 5: epoch_accuracy 10.014204545454545, epoch_loss 2.292633793570779
# Round 5, cleint 13, epoch 1: epoch_accuracy 13.90625, epoch_loss 2.304905319213867
# Round 5, cleint 13, epoch 2: epoch_accuracy 13.90625, epoch_loss 2.3044381618499754
# Round 5, cleint 13, epoch 3: epoch_accuracy 14.0625, epoch_loss 2.304026794433594
# Round 5, cleint 13, epoch 4: epoch_accuracy 14.375, epoch_loss 2.303605794906616
# Round 5, cleint 13, epoch 5: epoch_accuracy 13.59375, epoch_loss 2.304406929016113
# Round 5, cleint 14, epoch 1: epoch_accuracy 7.052951388888889, epoch_loss 2.310634824964735
# Round 5, cleint 14, epoch 2: epoch_accuracy 7.508680555555555, epoch_loss 2.3092479242218866
# Round 5, cleint 14, epoch 3: epoch_accuracy 7.074652777777778, epoch_loss 2.3090234200159707
# Round 5, cleint 14, epoch 4: epoch_accuracy 7.552083333333333, epoch_loss 2.3083255290985107
# Round 5, cleint 14, epoch 5: epoch_accuracy 8.919270833333334, epoch_loss 2.30684714184867
# Round 5, cleint 15, epoch 1: epoch_accuracy 38.113839285714285, epoch_loss 2.2798497336251393
# Round 5, cleint 15, epoch 2: epoch_accuracy 39.341517857142854, epoch_loss 2.278594442776271
# Round 5, cleint 15, epoch 3: epoch_accuracy 38.560267857142854, epoch_loss 2.2783719982419695
# Round 5, cleint 15, epoch 4: epoch_accuracy 40.345982142857146, epoch_loss 2.277389509337289
# Round 5, cleint 15, epoch 5: epoch_accuracy 41.294642857142854, epoch_loss 2.2766289029802596
# Round 5, cleint 16, epoch 1: epoch_accuracy 6.0444078947368425, epoch_loss 2.3124893213573254
# Round 5, cleint 16, epoch 2: epoch_accuracy 6.702302631578948, epoch_loss 2.3110218048095703
# Round 5, cleint 16, epoch 3: epoch_accuracy 6.784539473684211, epoch_loss 2.3099857631482577
# Round 5, cleint 16, epoch 4: epoch_accuracy 6.990131578947368, epoch_loss 2.3090108695783114
# Round 5, cleint 16, epoch 5: epoch_accuracy 6.578947368421052, epoch_loss 2.3086475196637606
# Round 5, cleint 17, epoch 1: epoch_accuracy 18.229166666666668, epoch_loss 2.2856135845184324
# Round 5, cleint 17, epoch 2: epoch_accuracy 18.59375, epoch_loss 2.286749744415283
# Round 5, cleint 17, epoch 3: epoch_accuracy 18.958333333333332, epoch_loss 2.285170062383016
# Round 5, cleint 17, epoch 4: epoch_accuracy 18.59375, epoch_loss 2.2847281297047934
# Round 5, cleint 17, epoch 5: epoch_accuracy 18.177083333333332, epoch_loss 2.2844024658203126
# Round 5, cleint 18, epoch 1: epoch_accuracy 2.7593085106382977, epoch_loss 2.3159251669619945
# Round 5, cleint 18, epoch 2: epoch_accuracy 2.7094414893617023, epoch_loss 2.3145375606861522
# Round 5, cleint 18, epoch 3: epoch_accuracy 2.958776595744681, epoch_loss 2.3128837423121675
# Round 5, cleint 18, epoch 4: epoch_accuracy 3.141622340425532, epoch_loss 2.312271407309999
# Round 5, cleint 18, epoch 5: epoch_accuracy 3.4075797872340425, epoch_loss 2.3103890621915775
# Round 5, cleint 19, epoch 1: epoch_accuracy 6.40625, epoch_loss 2.3078784942626953
# Round 5, cleint 19, epoch 2: epoch_accuracy 6.640625, epoch_loss 2.306815576553345
# Round 5, cleint 19, epoch 3: epoch_accuracy 7.1875, epoch_loss 2.3068689584732054
# Round 5, cleint 19, epoch 4: epoch_accuracy 6.25, epoch_loss 2.3069090366363527
# Round 5, cleint 19, epoch 5: epoch_accuracy 6.796875, epoch_loss 2.3065293550491335
# Round 5, cleint 20, epoch 1: epoch_accuracy 1.796875, epoch_loss 2.317206557591756
# Round 5, cleint 20, epoch 2: epoch_accuracy 1.9010416666666667, epoch_loss 2.316600275039673
# Round 5, cleint 20, epoch 3: epoch_accuracy 1.8489583333333333, epoch_loss 2.315852499008179
# Round 5, cleint 20, epoch 4: epoch_accuracy 1.875, epoch_loss 2.314632201194763
# Round 5, cleint 20, epoch 5: epoch_accuracy 2.1354166666666665, epoch_loss 2.3134944836298623
# Model's Round: 5, train accuracy of model: 11.813364321665617, train loss of model: 2.297380611258311
#
#
# Model's Round: 5, test accuracy of model: 10.013977635782748, test loss of model: 2.3027237604220456
#
#
# round 5 completed
# Round 6, cleint 1, epoch 1: epoch_accuracy 2.0833333333333335, epoch_loss 2.307604503631592
# Round 6, cleint 1, epoch 2: epoch_accuracy 1.875, epoch_loss 2.3064313252766926
# Round 6, cleint 1, epoch 3: epoch_accuracy 1.7708333333333333, epoch_loss 2.3072657426198324
# Round 6, cleint 1, epoch 4: epoch_accuracy 1.8229166666666667, epoch_loss 2.3065945307413735
# Round 6, cleint 1, epoch 5: epoch_accuracy 1.9791666666666667, epoch_loss 2.3066187540690106
# Round 6, cleint 2, epoch 1: epoch_accuracy 30.208333333333332, epoch_loss 2.2673712253570555
# Round 6, cleint 2, epoch 2: epoch_accuracy 29.270833333333332, epoch_loss 2.2668042818705243
# Round 6, cleint 2, epoch 3: epoch_accuracy 28.958333333333332, epoch_loss 2.2663424491882322
# Round 6, cleint 2, epoch 4: epoch_accuracy 29.583333333333332, epoch_loss 2.26499613126119
# Round 6, cleint 2, epoch 5: epoch_accuracy 29.322916666666668, epoch_loss 2.264758888880412
# Round 6, cleint 3, epoch 1: epoch_accuracy 5.324074074074074, epoch_loss 2.320879547684281
# Round 6, cleint 3, epoch 2: epoch_accuracy 5.121527777777778, epoch_loss 2.320279739521168
# Round 6, cleint 3, epoch 3: epoch_accuracy 5.179398148148148, epoch_loss 2.3202142892060458
# Round 6, cleint 3, epoch 4: epoch_accuracy 5.034722222222222, epoch_loss 2.319222097043638
# Round 6, cleint 3, epoch 5: epoch_accuracy 5.324074074074074, epoch_loss 2.3184661776931197
# Round 6, cleint 4, epoch 1: epoch_accuracy 7.239583333333333, epoch_loss 2.2997356096903485
# Round 6, cleint 4, epoch 2: epoch_accuracy 6.927083333333333, epoch_loss 2.2995285193125405
# Round 6, cleint 4, epoch 3: epoch_accuracy 7.708333333333333, epoch_loss 2.299380079905192
# Round 6, cleint 4, epoch 4: epoch_accuracy 7.1875, epoch_loss 2.298454682032267
# Round 6, cleint 4, epoch 5: epoch_accuracy 7.760416666666667, epoch_loss 2.2980901559193927
# Round 6, cleint 5, epoch 1: epoch_accuracy 32.72235576923077, epoch_loss 2.273212643770071
# ...
# Round 29, cleint 7, epoch 1: epoch_accuracy 5.431547619047619, epoch_loss 2.288352512177967
# Round 29, cleint 7, epoch 2: epoch_accuracy 6.026785714285714, epoch_loss 2.286551975068592
# Round 29, cleint 7, epoch 3: epoch_accuracy 8.258928571428571, epoch_loss 2.285946391877674
# Round 29, cleint 7, epoch 4: epoch_accuracy 8.258928571428571, epoch_loss 2.284752811704363
# Round 29, cleint 7, epoch 5: epoch_accuracy 9.598214285714286, epoch_loss 2.2831231980096724
# Round 29, cleint 8, epoch 1: epoch_accuracy 5.95703125, epoch_loss 2.296729162335396
# Round 29, cleint 8, epoch 2: epoch_accuracy 5.615234375, epoch_loss 2.295746475458145
# Round 29, cleint 8, epoch 3: epoch_accuracy 7.32421875, epoch_loss 2.2950615733861923
# Round 29, cleint 8, epoch 4: epoch_accuracy 8.154296875, epoch_loss 2.293835937976837
# Round 29, cleint 8, epoch 5: epoch_accuracy 9.27734375, epoch_loss 2.292756125330925
# Round 29, cleint 9, epoch 1: epoch_accuracy 17.55514705882353, epoch_loss 2.2934031626757454
# Round 29, cleint 9, epoch 2: epoch_accuracy 18.24448529411765, epoch_loss 2.2925209017360912
# Round 29, cleint 9, epoch 3: epoch_accuracy 18.38235294117647, epoch_loss 2.2914429412168613
# Round 29, cleint 9, epoch 4: epoch_accuracy 18.060661764705884, epoch_loss 2.292034107096055
# Round 29, cleint 9, epoch 5: epoch_accuracy 17.922794117647058, epoch_loss 2.291622554554659
# Round 29, cleint 10, epoch 1: epoch_accuracy 2.5390625, epoch_loss 2.3194011052449546
# Round 29, cleint 10, epoch 2: epoch_accuracy 2.4739583333333335, epoch_loss 2.3193726738293967
# Round 29, cleint 10, epoch 3: epoch_accuracy 2.6692708333333335, epoch_loss 2.3188495437304177
# Round 29, cleint 10, epoch 4: epoch_accuracy 1.953125, epoch_loss 2.31913161277771
# Round 29, cleint 10, epoch 5: epoch_accuracy 2.4739583333333335, epoch_loss 2.318281352519989
# Round 29, cleint 11, epoch 1: epoch_accuracy 12.1875, epoch_loss 2.2841136932373045
# Round 29, cleint 11, epoch 2: epoch_accuracy 12.5, epoch_loss 2.2836594581604004
# Round 29, cleint 11, epoch 3: epoch_accuracy 13.59375, epoch_loss 2.282253789901733
# Round 29, cleint 11, epoch 4: epoch_accuracy 11.875, epoch_loss 2.2837178707122803
# Round 29, cleint 11, epoch 5: epoch_accuracy 11.09375, epoch_loss 2.2843177795410154
# Round 29, cleint 12, epoch 1: epoch_accuracy 10.369318181818182, epoch_loss 2.2912905649705366
# Round 29, cleint 12, epoch 2: epoch_accuracy 10.440340909090908, epoch_loss 2.2908537821336226
# Round 29, cleint 12, epoch 3: epoch_accuracy 11.363636363636363, epoch_loss 2.2902943654493852
# Round 29, cleint 12, epoch 4: epoch_accuracy 9.659090909090908, epoch_loss 2.288579962470315
# Round 29, cleint 12, epoch 5: epoch_accuracy 11.576704545454545, epoch_loss 2.2884486588564785
# Round 29, cleint 13, epoch 1: epoch_accuracy 14.453125, epoch_loss 2.3025902032852175
# Round 29, cleint 13, epoch 2: epoch_accuracy 14.375, epoch_loss 2.303707718849182
# Round 29, cleint 13, epoch 3: epoch_accuracy 14.21875, epoch_loss 2.303124737739563
# Round 29, cleint 13, epoch 4: epoch_accuracy 14.453125, epoch_loss 2.3029825925827025
# Round 29, cleint 13, epoch 5: epoch_accuracy 15.234375, epoch_loss 2.302088165283203
# Round 29, cleint 14, epoch 1: epoch_accuracy 5.316840277777778, epoch_loss 2.3149890303611755
# Round 29, cleint 14, epoch 2: epoch_accuracy 5.316840277777778, epoch_loss 2.3140854438145957
# Round 29, cleint 14, epoch 3: epoch_accuracy 5.186631944444445, epoch_loss 2.313863866859012
# Round 29, cleint 14, epoch 4: epoch_accuracy 5.6640625, epoch_loss 2.3130069573720298
# Round 29, cleint 14, epoch 5: epoch_accuracy 6.163194444444445, epoch_loss 2.3122653232680426
# Round 29, cleint 15, epoch 1: epoch_accuracy 37.83482142857143, epoch_loss 2.2770814895629883
# Round 29, cleint 15, epoch 2: epoch_accuracy 39.174107142857146, epoch_loss 2.276556270463126
# Round 29, cleint 15, epoch 3: epoch_accuracy 40.066964285714285, epoch_loss 2.276240178516933
# Round 29, cleint 15, epoch 4: epoch_accuracy 40.29017857142857, epoch_loss 2.274725948061262
# Round 29, cleint 15, epoch 5: epoch_accuracy 40.401785714285715, epoch_loss 2.27377382346562
# Round 29, cleint 16, epoch 1: epoch_accuracy 6.003289473684211, epoch_loss 2.3172644439496493
# Round 29, cleint 16, epoch 2: epoch_accuracy 6.537828947368421, epoch_loss 2.3150957007157174
# Round 29, cleint 16, epoch 3: epoch_accuracy 6.373355263157895, epoch_loss 2.3145574644992224
# Round 29, cleint 16, epoch 4: epoch_accuracy 6.208881578947368, epoch_loss 2.3134590701053015
# Round 29, cleint 16, epoch 5: epoch_accuracy 6.702302631578948, epoch_loss 2.3121684852399325
# Round 29, cleint 17, epoch 1: epoch_accuracy 20.677083333333332, epoch_loss 2.2802117824554444
# Round 29, cleint 17, epoch 2: epoch_accuracy 20.625, epoch_loss 2.279810365041097
# Round 29, cleint 17, epoch 3: epoch_accuracy 20.833333333333332, epoch_loss 2.2787238438924153
# Round 29, cleint 17, epoch 4: epoch_accuracy 20.78125, epoch_loss 2.2791497230529787
# Round 29, cleint 17, epoch 5: epoch_accuracy 20.729166666666668, epoch_loss 2.278224007288615
# Round 29, cleint 18, epoch 1: epoch_accuracy 2.8091755319148937, epoch_loss 2.319694569770326
# Round 29, cleint 18, epoch 2: epoch_accuracy 2.8756648936170213, epoch_loss 2.318175990530785
# Round 29, cleint 18, epoch 3: epoch_accuracy 2.859042553191489, epoch_loss 2.317102518487484
# Round 29, cleint 18, epoch 4: epoch_accuracy 3.3577127659574466, epoch_loss 2.315730815238141
# Round 29, cleint 18, epoch 5: epoch_accuracy 3.889627659574468, epoch_loss 2.3141378240382418
# Round 29, cleint 19, epoch 1: epoch_accuracy 7.5, epoch_loss 2.3048745155334474
# Round 29, cleint 19, epoch 2: epoch_accuracy 7.578125, epoch_loss 2.303550434112549
# Round 29, cleint 19, epoch 3: epoch_accuracy 7.578125, epoch_loss 2.3039294958114622
# Round 29, cleint 19, epoch 4: epoch_accuracy 7.65625, epoch_loss 2.3035681009292603
# Round 29, cleint 19, epoch 5: epoch_accuracy 6.953125, epoch_loss 2.3031996965408323
# Round 29, cleint 20, epoch 1: epoch_accuracy 1.6666666666666667, epoch_loss 2.3167346715927124
# Round 29, cleint 20, epoch 2: epoch_accuracy 1.8489583333333333, epoch_loss 2.3157278140385946
# Round 29, cleint 20, epoch 3: epoch_accuracy 2.03125, epoch_loss 2.314962395032247
# Round 29, cleint 20, epoch 4: epoch_accuracy 2.34375, epoch_loss 2.313061507542928
# Round 29, cleint 20, epoch 5: epoch_accuracy 1.9270833333333333, epoch_loss 2.312681770324707
# Model's Round: 29, train accuracy of model: 12.265858952164319, train loss of model: 2.296319451947732
#
#
# Model's Round: 29, test accuracy of model: 10.013977635782748, test loss of model: 2.302636926547407
#
#
# round 29 completed
# Round 30, cleint 1, epoch 1: epoch_accuracy 2.4479166666666665, epoch_loss 2.307458209991455
# Round 30, cleint 1, epoch 2: epoch_accuracy 2.0833333333333335, epoch_loss 2.306179920832316
# Round 30, cleint 1, epoch 3: epoch_accuracy 2.2916666666666665, epoch_loss 2.306787141164144
# Round 30, cleint 1, epoch 4: epoch_accuracy 2.7083333333333335, epoch_loss 2.3067740917205812
# Round 30, cleint 1, epoch 5: epoch_accuracy 2.7604166666666665, epoch_loss 2.3061227321624758
# Round 30, cleint 2, epoch 1: epoch_accuracy 26.09375, epoch_loss 2.2724829355875653
# Round 30, cleint 2, epoch 2: epoch_accuracy 27.239583333333332, epoch_loss 2.271196492513021
# Round 30, cleint 2, epoch 3: epoch_accuracy 27.8125, epoch_loss 2.270124355951945
# Round 30, cleint 2, epoch 4: epoch_accuracy 28.229166666666668, epoch_loss 2.2691953659057615
# Round 30, cleint 2, epoch 5: epoch_accuracy 27.447916666666668, epoch_loss 2.269194730122884
# Round 30, cleint 3, epoch 1: epoch_accuracy 5.237268518518518, epoch_loss 2.3194484269177473
# Round 30, cleint 3, epoch 2: epoch_accuracy 5.092592592592593, epoch_loss 2.3186711823498762
# Round 30, cleint 3, epoch 3: epoch_accuracy 5.41087962962963, epoch_loss 2.3179747793409557
# Round 30, cleint 3, epoch 4: epoch_accuracy 5.52662037037037, epoch_loss 2.3177817044434725
# Round 30, cleint 3, epoch 5: epoch_accuracy 5.237268518518518, epoch_loss 2.316364562069928
# Round 30, cleint 4, epoch 1: epoch_accuracy 9.322916666666666, epoch_loss 2.2944107055664062
# Round 30, cleint 4, epoch 2: epoch_accuracy 9.6875, epoch_loss 2.2946108182271323
# Round 30, cleint 4, epoch 3: epoch_accuracy 9.791666666666666, epoch_loss 2.2933449745178223
# Round 30, cleint 4, epoch 4: epoch_accuracy 10.104166666666666, epoch_loss 2.2935510158538817
# Round 30, cleint 4, epoch 5: epoch_accuracy 10.260416666666666, epoch_loss 2.292953634262085
# Round 30, cleint 5, epoch 1: epoch_accuracy 31.310096153846153, epoch_loss 2.2749576018406796
# Round 30, cleint 5, epoch 2: epoch_accuracy 31.400240384615383, epoch_loss 2.274571501291715
# Round 30, cleint 5, epoch 3: epoch_accuracy 31.73076923076923, epoch_loss 2.2732257476219764
# Round 30, cleint 5, epoch 4: epoch_accuracy 32.72235576923077, epoch_loss 2.272165371821477
# Round 30, cleint 5, epoch 5: epoch_accuracy 33.74399038461539, epoch_loss 2.271114257665781
# Round 30, cleint 6, epoch 1: epoch_accuracy 2.3046875, epoch_loss 2.3066008567810057
# Round 30, cleint 6, epoch 2: epoch_accuracy 2.5390625, epoch_loss 2.3057077527046204
# Round 30, cleint 6, epoch 3: epoch_accuracy 2.734375, epoch_loss 2.3048808097839357
# Round 30, cleint 6, epoch 4: epoch_accuracy 2.6953125, epoch_loss 2.304283320903778
# Round 30, cleint 6, epoch 5: epoch_accuracy 2.9296875, epoch_loss 2.304229700565338
# Round 30, cleint 7, epoch 1: epoch_accuracy 5.46875, epoch_loss 2.2884310200100852
# Round 30, cleint 7, epoch 2: epoch_accuracy 6.5476190476190474, epoch_loss 2.286794140225365
# Round 30, cleint 7, epoch 3: epoch_accuracy 8.444940476190476, epoch_loss 2.2861029988243464
# Round 30, cleint 7, epoch 4: epoch_accuracy 10.044642857142858, epoch_loss 2.28418839545477
# Round 30, cleint 7, epoch 5: epoch_accuracy 10.602678571428571, epoch_loss 2.282969383966355
# Round 30, cleint 8, epoch 1: epoch_accuracy 5.2734375, epoch_loss 2.297106295824051
# Round 30, cleint 8, epoch 2: epoch_accuracy 5.95703125, epoch_loss 2.296189561486244
# Round 30, cleint 8, epoch 3: epoch_accuracy 8.447265625, epoch_loss 2.2948867976665497
# Round 30, cleint 8, epoch 4: epoch_accuracy 8.349609375, epoch_loss 2.2939364165067673
# Round 30, cleint 8, epoch 5: epoch_accuracy 10.205078125, epoch_loss 2.2934897989034653
# Round 30, cleint 9, epoch 1: epoch_accuracy 17.55514705882353, epoch_loss 2.2924805248484894
# Round 30, cleint 9, epoch 2: epoch_accuracy 17.96875, epoch_loss 2.292427623973173
# Round 30, cleint 9, epoch 3: epoch_accuracy 18.152573529411764, epoch_loss 2.291658443563125
# Round 30, cleint 9, epoch 4: epoch_accuracy 18.24448529411765, epoch_loss 2.2912711536183075
# Round 30, cleint 9, epoch 5: epoch_accuracy 18.704044117647058, epoch_loss 2.2913101420683017
# Round 30, cleint 10, epoch 1: epoch_accuracy 2.0833333333333335, epoch_loss 2.319737414518992
# Round 30, cleint 10, epoch 2: epoch_accuracy 2.34375, epoch_loss 2.319176733493805
# Round 30, cleint 10, epoch 3: epoch_accuracy 2.734375, epoch_loss 2.317879299322764
# Round 30, cleint 10, epoch 4: epoch_accuracy 2.0833333333333335, epoch_loss 2.3190497557322183
# Round 30, cleint 10, epoch 5: epoch_accuracy 2.2786458333333335, epoch_loss 2.3177754084269204
# Round 30, cleint 11, epoch 1: epoch_accuracy 13.75, epoch_loss 2.28334527015686
# Round 30, cleint 11, epoch 2: epoch_accuracy 12.96875, epoch_loss 2.2841588497161864
# Round 30, cleint 11, epoch 3: epoch_accuracy 12.8125, epoch_loss 2.2831742763519287
# Round 30, cleint 11, epoch 4: epoch_accuracy 13.90625, epoch_loss 2.2815710067749024
# Round 30, cleint 11, epoch 5: epoch_accuracy 12.65625, epoch_loss 2.2815203189849855
# Round 30, cleint 12, epoch 1: epoch_accuracy 10.653409090909092, epoch_loss 2.289997165853327
# Round 30, cleint 12, epoch 2: epoch_accuracy 9.801136363636363, epoch_loss 2.290585084394975
# Round 30, cleint 12, epoch 3: epoch_accuracy 9.019886363636363, epoch_loss 2.2912295081398706
# Round 30, cleint 12, epoch 4: epoch_accuracy 10.085227272727273, epoch_loss 2.2894037420099433
# Round 30, cleint 12, epoch 5: epoch_accuracy 10.724431818181818, epoch_loss 2.2885351181030273
# Round 30, cleint 13, epoch 1: epoch_accuracy 15.390625, epoch_loss 2.302426266670227
# Round 30, cleint 13, epoch 2: epoch_accuracy 13.90625, epoch_loss 2.3033886432647703
# Round 30, cleint 13, epoch 3: epoch_accuracy 14.609375, epoch_loss 2.3019615173339845
# Round 30, cleint 13, epoch 4: epoch_accuracy 14.921875, epoch_loss 2.302953314781189
# Round 30, cleint 13, epoch 5: epoch_accuracy 13.828125, epoch_loss 2.3030486345291137
# Round 30, cleint 14, epoch 1: epoch_accuracy 4.774305555555555, epoch_loss 2.3151535987854004
# Round 30, cleint 14, epoch 2: epoch_accuracy 5.164930555555555, epoch_loss 2.3142950932184854
# Round 30, cleint 14, epoch 3: epoch_accuracy 5.381944444444445, epoch_loss 2.313932995001475
# Round 30, cleint 14, epoch 4: epoch_accuracy 5.164930555555555, epoch_loss 2.313528663582272
# Round 30, cleint 14, epoch 5: epoch_accuracy 5.642361111111111, epoch_loss 2.3122767210006714
# Round 30, cleint 15, epoch 1: epoch_accuracy 38.392857142857146, epoch_loss 2.277516041483198
# Round 30, cleint 15, epoch 2: epoch_accuracy 38.504464285714285, epoch_loss 2.276946152959551
# Round 30, cleint 15, epoch 3: epoch_accuracy 38.783482142857146, epoch_loss 2.2755968400410245
# Round 30, cleint 15, epoch 4: epoch_accuracy 39.285714285714285, epoch_loss 2.2753202404294695
# Round 30, cleint 15, epoch 5: epoch_accuracy 39.50892857142857, epoch_loss 2.2740668739591325
# Round 30, cleint 16, epoch 1: epoch_accuracy 6.291118421052632, epoch_loss 2.3164073542544714
# Round 30, cleint 16, epoch 2: epoch_accuracy 6.291118421052632, epoch_loss 2.3162018123425936
# Round 30, cleint 16, epoch 3: epoch_accuracy 6.702302631578948, epoch_loss 2.314360593494616
# Round 30, cleint 16, epoch 4: epoch_accuracy 6.496710526315789, epoch_loss 2.313694690403185
# Round 30, cleint 16, epoch 5: epoch_accuracy 6.496710526315789, epoch_loss 2.312385270470067
# Round 30, cleint 17, epoch 1: epoch_accuracy 19.895833333333332, epoch_loss 2.2801986853281657
# Round 30, cleint 17, epoch 2: epoch_accuracy 20.677083333333332, epoch_loss 2.27945761680603
# Round 30, cleint 17, epoch 3: epoch_accuracy 20.052083333333332, epoch_loss 2.2794273217519123
# Round 30, cleint 17, epoch 4: epoch_accuracy 20.729166666666668, epoch_loss 2.2781168778737384
# Round 30, cleint 17, epoch 5: epoch_accuracy 20.78125, epoch_loss 2.2789347171783447
# Round 30, cleint 18, epoch 1: epoch_accuracy 2.7925531914893615, epoch_loss 2.319968593881485
# Round 30, cleint 18, epoch 2: epoch_accuracy 2.958776595744681, epoch_loss 2.3183150646534374
# Round 30, cleint 18, epoch 3: epoch_accuracy 3.2247340425531914, epoch_loss 2.3171807907997293
# Round 30, cleint 18, epoch 4: epoch_accuracy 3.5405585106382977, epoch_loss 2.3161228159640697
# Round 30, cleint 18, epoch 5: epoch_accuracy 3.740026595744681, epoch_loss 2.3142559223986687
# Round 30, cleint 19, epoch 1: epoch_accuracy 7.5, epoch_loss 2.304612874984741
# Round 30, cleint 19, epoch 2: epoch_accuracy 7.8125, epoch_loss 2.304775619506836
# Round 30, cleint 19, epoch 3: epoch_accuracy 7.109375, epoch_loss 2.3035828351974486
# Round 30, cleint 19, epoch 4: epoch_accuracy 7.65625, epoch_loss 2.3028735876083375
# Round 30, cleint 19, epoch 5: epoch_accuracy 6.953125, epoch_loss 2.303265929222107
# Round 30, cleint 20, epoch 1: epoch_accuracy 2.03125, epoch_loss 2.31680158774058
# Round 30, cleint 20, epoch 2: epoch_accuracy 2.0833333333333335, epoch_loss 2.315653403600057
# Round 30, cleint 20, epoch 3: epoch_accuracy 2.109375, epoch_loss 2.3146549065907798
# Round 30, cleint 20, epoch 4: epoch_accuracy 2.109375, epoch_loss 2.3136228561401366
# Round 30, cleint 20, epoch 5: epoch_accuracy 2.2395833333333335, epoch_loss 2.3129355748494467
# Model's Round: 30, train accuracy of model: 12.337046750332908, train loss of model: 2.296337471545455
#
#
# Model's Round: 30, test accuracy of model: 10.013977635782748, test loss of model: 2.3026339794500186
#
#
# round 30 completed

# %% [markdown]
# # Reuslts

# %%
# Define the folder and file name
folder_name = f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"


# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
folder_name =  f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
