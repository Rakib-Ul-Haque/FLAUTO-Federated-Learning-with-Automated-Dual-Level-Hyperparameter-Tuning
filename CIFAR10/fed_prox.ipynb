# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# from sklearn.metrics import confusion_matrix
from torchvision.datasets import CIFAR10
from collections import Counter
import random
import copy
import torch.nn.functional as F
import os
import sys
import time
import pickle
import pandas as pd
from torch import Tensor
from typing import Type
import torchvision.models as models
from torchvision import transforms

# Set font family for plots
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# <H1>Load Dataset</H1>

# %%
# transform = transforms.Compose([
#     transforms.ToTensor(), #This transformation converts a PIL (Python Imaging Library) Image or numpy.ndarray (with shape (H x W x C) in the range [0, 255]) into a PyTorch tensor of shape (C x H x W) in the range [0.0, 1.0]. It essentially rearranges the dimensions of the image data and scales it to a float value between 0 and 1.
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])


# train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# # train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)
subset_dataset = torch.load('val_dataset.pth',weights_only=False)
remaining_dataset = torch.load('test_dataset.pth',weights_only=False)

# Create DataLoaders
val_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(remaining_dataset, batch_size=32, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <H1>IID</H1>

# %%
def distribute_dataset_equally(dataset, num_clients):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    # Distribute data
    client_data = [[] for _ in range(num_clients)]
    for label, data in class_data.items():
        data_len = len(data)
        base_size = data_len // num_clients
        remain = data_len - base_size * num_clients

        current_idx = 0
        for i in range(num_clients):
            end_idx = current_idx + base_size + (1 if i < remain else 0)
            client_data[i].extend(data[current_idx:end_idx])
            current_idx = end_idx


    print_iid_distribution(client_data)
    plot_iid_dataset(client_data,num_clients)

    return client_data

# %%
#print client iid_data distribution
def print_iid_distribution(iid_datasets):
    # Check if the distribution is correct
    for i, client_data in enumerate(iid_datasets):
        print(f"Client {i + 1} data size: {len(client_data)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# Plot client iid_data distribution
def plot_iid_dataset(iid_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in iid_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define colors for each class
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")
    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number',labelpad=5)
    ax.set_ylabel('CIFAR-10 Classes',labelpad=15)
    ax.set_zlabel('Fraction of Distribution',labelpad=5)
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], rotation=45)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names, rotation=-60)

    #ax.view_init(elev=40, azim=60)
    ax.view_init(elev=40, azim=10)

    plt.subplots_adjust(left=0.01, right=0.99, bottom=0.01, top=0.99)

    plt.show()

# %% [markdown]
# <H1>non-IID</H1>

# %%
#Print the distribution non IID
def print_distribution(client_data):
    # Check distribution
    for l, client_data_value in enumerate(client_data):
        print(f"Client {l + 1} data size: {len(client_data_value)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data_value:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# #Non IID code
def distribute_dataset_dirichlet(dataset, num_clients, alpha):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    client_data = [[] for _ in range(num_clients)]
    for _, data_list in class_data.items():
        # Shuffle data for randomness
        np.random.shuffle(data_list)

        # Get proportions for data split based on Dirichlet distribution
        proportions = np.random.dirichlet([alpha]*num_clients)
        # print("Proportions: ", proportions)
        total_data = len(data_list)
        # print("total_data: ", total_data)
        data_splits = [int(proportions[i]*total_data) for i in range(num_clients)]
        # print("Data_Split: ", data_splits)

        # Adjust the splits to account for rounding errors
        # print("Before data_split:",data_splits)
        data_splits[-1] += total_data - sum(data_splits)
        print("After data_split:",data_splits)

        start_idx = 0
        for i, split in enumerate(data_splits):
            end_idx = start_idx + split
            client_data[i].extend(data_list[start_idx:end_idx])
            start_idx = end_idx
    print("Client Number: ",num_clients, "Alpha: ", alpha)
    print_distribution(client_data)
    plot_distribution(client_data, num_clients )
    return client_data

# %%
#show the graphs for nonIID
def plot_distribution(client_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in client_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        # print(total_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define distinct colors for classes using a colormap
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # # Generate the 3D bar chart
    # fig = plt.figure(figsize=(18, 12))
    # ax = fig.add_subplot(111, projection='3d')

    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")

    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number')
    ax.set_ylabel('CIFAR-10 Classes')
    ax.set_zlabel('Fraction of Distribution')
    ax.set_title('Distribution of CIFAR-10 Classes across Clients based on Dirichlet Distribution')
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], fontsize=12)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)
        
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Change output to 10 for CIFAR-10 classes

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Train

# %%
#averaging the weihgts

def average_weights_function(dicts):
    # Initialize an empty dictionary to store the summed weights
    summed_weights = {}
    
    # Initialize an empty dictionary to keep track of how many times each key is seen
    key_occurrences = {}
    
    # Iterate through all the dictionaries
    for d in dicts:
        for key, value in d.items():
            if key in summed_weights:
                summed_weights[key] += value
                key_occurrences[key] += 1
            else:
                summed_weights[key] = value
                key_occurrences[key] = 1
    
    # Create a dictionary to store the final averaged weights
    averaged_weights = {}
    
    # Iterate through the summed weights and divide by the number of occurrences for each key
    for key, value in summed_weights.items():
        if key_occurrences[key] > 1:
            averaged_weights[key] = value / key_occurrences[key]
        else:
            averaged_weights[key] = value  # If only present in one dict, keep as is
    
    return averaged_weights

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag, mu=0.001):
    global opti
    
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    local_model.train()  # Set the model to training mode

    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        print(f"Round {roun}, cleint {cli+1}, epoch {epoch+1}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")
    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    #print(f"\n Round {roun}, cleint {cli}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    
    
    epoch_rmd=model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data

    for name in f_weights.keys():
        # Ensure final_weights are also on the correct device
        f_weights[name] = f_weights[name].to(device)
        # Apply the proximal term: w_new = w - mu * (w - w_t)
        f_weights[name] = f_weights[name] - mu * (f_weights[name] - i_weights[name])
    
    return epoch_accuracy,epoch_loss, f_weights, epoch_flag

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()  # Assuming a classification task
    #optimizer = torch.optim.SGD(lmodel.parameters(), lr=learning_rate)
    lmodel.load_state_dict(w)
    lmodel.eval()

    #checking the weights
    tw = lmodel.state_dict()
    #Print("Model's before testing the weights in global model",tw)

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    #print("Model's Test accuracy : {:.2f}%".format(test_accuracy))
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_clients_list, participating_client_list
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        models=[]
        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        all_final_weights={}
        train_accuracy_list=[]
        train_loss_list=[]
        
        # Randomly select clients
        selected_clients = random.sample(total_clients_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
                #train model
                train_accuracy, train_loss, c_f_weights, epoch_flag = train(i_w, E, train_loader, learning_rate, c, r,epoch_flag)
                
                models.append(c_f_weights)
                
                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)

                # Accumulate weights for the selected client
                #for param_name, param_grad in c_f_weights.items():
                    #if param_name in all_final_weights:
                        #all_final_weights[param_name] += param_grad
                    #else:
                        #all_final_weights[param_name] = param_grad

            else:
                print(f"client {c+1} is not selectecd")
        
        round_epoch=(epoch_flag)
        all_final_weights=average_weights_function(models)
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)
        
        print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

        #for param_name in all_final_weights:
            #all_final_weights[param_name] = all_final_weights[param_name].float() / len(selected_clients)

        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

        #model deviation code
        round_rmd=model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)

        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
        round_results.loc[len(round_results)] = round_data
            
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=20
participating_client=20
epochs=5
learning_rate=0.0001
round_no=30
batch_size=128
distributions = "non_iid" # 'non_iid'
data_class=10
alpha=0.5
opti="sgd" # or SGD

method="fed_prox"

# List of clients
total_clients_list = list(range(0, client_no))
# print(total_cleints_list)
participating_client_list=[]

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

#===================================loading the saved weight list====================================================
global_model = model().to(device)
# initial_weights={k: v.clone() for k, v in global_model.state_dict().items()}
# Save the initial weights
file_path = "s_cnn.pth"
# torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=True)
Print("Model's initial weights", initial_weights)
# Out:
# Model's initial weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')

# %% [markdown]
# <H1>Divide data among cleints</H1>

# %%
# #=================================loading IID data===========================
# if distributions == 'iid':
#     client_datasets = distribute_dataset_equally(train_dataset,client_no)
    
# elif distributions == 'non_iid':
#     client_datasets = distribute_dataset_dirichlet(train_dataset, client_no, alpha)
# else:
#     print("provide a valid distribution Please")

# %%
# # Save client_datasets to a file
# if distributions == 'iid':
#     with open('client_datasets_IID.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.5:
#     with open('client_datasets_non_IID_0_5.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.125:
#     with open('client_datasets_non_IID_0_125.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)

# print("client_datasets saved successfully.")

# %%
# Load client_datasets from a file
if distributions == 'iid':
    with open('20_client_datasets_IID.pkl', 'rb') as f:
        client_datasets = pickle.load(f)

elif distributions == 'non_iid' and alpha==0.5:
    with open('20_client_datasets_non_IID_0_5.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
    
elif distributions == 'non_iid' and alpha==0.125:
    with open('20_client_datasets_non_IID_0_125.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
        
print("client_datasets loaded successfully.")
print_distribution(client_datasets)
# Out:
# client_datasets loaded successfully.
# Client 1 data size: 1928
# Class distribution: {0: 93, 1: 405, 2: 144, 3: 3, 4: 342, 5: 365, 6: 25, 7: 64, 8: 248, 9: 239}
# Client 2 data size: 1997
# Class distribution: {0: 38, 1: 0, 2: 921, 3: 588, 4: 14, 5: 9, 6: 58, 7: 51, 8: 11, 9: 307}
# Client 3 data size: 3557
# Class distribution: {0: 849, 1: 41, 2: 2, 3: 208, 4: 645, 5: 640, 6: 853, 7: 151, 8: 20, 9: 148}
# Client 4 data size: 1954
# Class distribution: {0: 369, 1: 91, 2: 9, 3: 135, 4: 108, 5: 65, 6: 267, 7: 30, 8: 673, 9: 207}
# Client 5 data size: 3332
# Class distribution: {0: 25, 1: 0, 2: 866, 3: 1163, 4: 6, 5: 194, 6: 13, 7: 375, 8: 61, 9: 629}
# Client 6 data size: 2673
# Class distribution: {0: 241, 1: 643, 2: 161, 3: 26, 4: 2, 5: 861, 6: 65, 7: 182, 8: 462, 9: 30}
# Client 7 data size: 2750
# Class distribution: {0: 161, 1: 0, 2: 503, 3: 26, 4: 184, 5: 443, 6: 6, 7: 6, 8: 1412, 9: 9}
# Client 8 data size: 2071
# Class distribution: {0: 217, 1: 128, 2: 136, 3: 37, 4: 20, 5: 19, 6: 42, 7: 371, 8: 37, 9: 1064}
# Client 9 data size: 2185
# Class distribution: {0: 0, 1: 286, 2: 426, 3: 441, 4: 223, 5: 651, 6: 5, 7: 23, 8: 107, 9: 23}
# Client 10 data size: 1544
# Class distribution: {0: 602, 1: 10, 2: 2, 3: 16, 4: 91, 5: 47, 6: 299, 7: 192, 8: 255, 9: 30}
# Client 11 data size: 681
# Class distribution: {0: 2, 1: 43, 2: 1, 3: 75, 4: 26, 5: 75, 6: 101, 7: 1, 8: 205, 9: 152}
# Client 12 data size: 1524
# Class distribution: {0: 10, 1: 2, 2: 79, 3: 142, 4: 1, 5: 6, 6: 670, 7: 90, 8: 1, 9: 523}
# Client 13 data size: 1346
# Class distribution: {0: 281, 1: 82, 2: 8, 3: 208, 4: 116, 5: 206, 6: 5, 7: 128, 8: 158, 9: 154}
# Client 14 data size: 4708
# Class distribution: {0: 596, 1: 249, 2: 1220, 3: 246, 4: 932, 5: 595, 6: 18, 7: 717, 8: 33, 9: 102}
# Client 15 data size: 1893
# Class distribution: {0: 30, 1: 9, 2: 65, 3: 842, 4: 145, 5: 0, 6: 605, 7: 34, 8: 64, 9: 99}
# Client 16 data size: 2479
# Class distribution: {0: 0, 1: 924, 2: 71, 3: 176, 4: 10, 5: 259, 6: 54, 7: 897, 8: 0, 9: 88}
# Client 17 data size: 2031
# Class distribution: {0: 78, 1: 165, 2: 14, 3: 412, 4: 10, 5: 397, 6: 69, 7: 1, 8: 643, 9: 242}
# Client 18 data size: 6129
# Class distribution: {0: 673, 1: 1721, 2: 41, 3: 127, 4: 1129, 5: 118, 6: 29, 7: 1383, 8: 100, 9: 808}
# Client 19 data size: 1348
# Class distribution: {0: 70, 1: 153, 2: 1, 3: 96, 4: 46, 5: 35, 6: 541, 7: 159, 8: 139, 9: 108}
# Client 20 data size: 3870
# Class distribution: {0: 665, 1: 48, 2: 330, 3: 33, 4: 950, 5: 15, 6: 1275, 7: 145, 8: 371, 9: 38}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for cleints
round_train_accuracy=0
round_train_loss=0

train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True, drop_last=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
round_results.loc[len(round_results)] = round_data

Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')
#
#  train accuracy: 11.184571359262506
#  train_loss: 2.3003227259353514
#  test_accuracy: 10.013977635782748
#  test_loss: 2.3027472800720994

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
# Round 1, cleint 1, epoch 1: epoch_accuracy 1.9270833333333333, epoch_loss 2.30700839360555
# Round 1, cleint 1, epoch 2: epoch_accuracy 1.9791666666666667, epoch_loss 2.307120752334595
# Round 1, cleint 1, epoch 3: epoch_accuracy 1.9791666666666667, epoch_loss 2.306822188695272
# Round 1, cleint 1, epoch 4: epoch_accuracy 2.1354166666666665, epoch_loss 2.3066508928934732
# Round 1, cleint 1, epoch 5: epoch_accuracy 2.1875, epoch_loss 2.306426779429118
# Round 1, cleint 2, epoch 1: epoch_accuracy 29.427083333333332, epoch_loss 2.2670952796936037
# Round 1, cleint 2, epoch 2: epoch_accuracy 29.21875, epoch_loss 2.265919542312622
# Round 1, cleint 2, epoch 3: epoch_accuracy 31.09375, epoch_loss 2.265126593907674
# Round 1, cleint 2, epoch 4: epoch_accuracy 30.104166666666668, epoch_loss 2.263952652613322
# Round 1, cleint 2, epoch 5: epoch_accuracy 30.677083333333332, epoch_loss 2.2630923271179197
# Round 1, cleint 3, epoch 1: epoch_accuracy 5.092592592592593, epoch_loss 2.321618989661888
# Round 1, cleint 3, epoch 2: epoch_accuracy 5.092592592592593, epoch_loss 2.3201737845385515
# Round 1, cleint 3, epoch 3: epoch_accuracy 4.890046296296297, epoch_loss 2.3204165476339833
# Round 1, cleint 3, epoch 4: epoch_accuracy 5.063657407407407, epoch_loss 2.319295556456954
# Round 1, cleint 3, epoch 5: epoch_accuracy 5.295138888888889, epoch_loss 2.3187206232989275
# Round 1, cleint 4, epoch 1: epoch_accuracy 6.927083333333333, epoch_loss 2.3009851455688475
# Round 1, cleint 4, epoch 2: epoch_accuracy 6.875, epoch_loss 2.3004621346791585
# Round 1, cleint 4, epoch 3: epoch_accuracy 7.291666666666667, epoch_loss 2.3000899155934653
# Round 1, cleint 4, epoch 4: epoch_accuracy 6.770833333333333, epoch_loss 2.2997382799784343
# Round 1, cleint 4, epoch 5: epoch_accuracy 6.979166666666667, epoch_loss 2.299173386891683
# Round 1, cleint 5, epoch 1: epoch_accuracy 33.08293269230769, epoch_loss 2.2728187487675595
# Round 1, cleint 5, epoch 2: epoch_accuracy 32.69230769230769, epoch_loss 2.2715103717950673
# Round 1, cleint 5, epoch 3: epoch_accuracy 32.60216346153846, epoch_loss 2.270644939862765
# Round 1, cleint 5, epoch 4: epoch_accuracy 33.59375, epoch_loss 2.269650000792283
# Round 1, cleint 5, epoch 5: epoch_accuracy 33.32331730769231, epoch_loss 2.268318460537837
# Round 1, cleint 6, epoch 1: epoch_accuracy 2.2265625, epoch_loss 2.3091418862342836
# Round 1, cleint 6, epoch 2: epoch_accuracy 2.03125, epoch_loss 2.308301043510437
# Round 1, cleint 6, epoch 3: epoch_accuracy 1.7578125, epoch_loss 2.3078870296478273
# Round 1, cleint 6, epoch 4: epoch_accuracy 1.8359375, epoch_loss 2.307480490207672
# Round 1, cleint 6, epoch 5: epoch_accuracy 2.109375, epoch_loss 2.3069374799728393
# Round 1, cleint 7, epoch 1: epoch_accuracy 3.5714285714285716, epoch_loss 2.2936476866404214
# Round 1, cleint 7, epoch 2: epoch_accuracy 3.90625, epoch_loss 2.2928220885140553
# Round 1, cleint 7, epoch 3: epoch_accuracy 5.096726190476191, epoch_loss 2.2911399886721657
# Round 1, cleint 7, epoch 4: epoch_accuracy 5.357142857142857, epoch_loss 2.290004162561326
# Round 1, cleint 7, epoch 5: epoch_accuracy 5.989583333333333, epoch_loss 2.288827816645304
# Round 1, cleint 8, epoch 1: epoch_accuracy 4.345703125, epoch_loss 2.297507792711258
# Round 1, cleint 8, epoch 2: epoch_accuracy 4.931640625, epoch_loss 2.295840173959732
# Round 1, cleint 8, epoch 3: epoch_accuracy 5.908203125, epoch_loss 2.295475497841835
# Round 1, cleint 8, epoch 4: epoch_accuracy 6.884765625, epoch_loss 2.294059455394745
# Round 1, cleint 8, epoch 5: epoch_accuracy 7.71484375, epoch_loss 2.2932231575250626
# Round 1, cleint 9, epoch 1: epoch_accuracy 19.577205882352942, epoch_loss 2.2921070491566375
# Round 1, cleint 9, epoch 2: epoch_accuracy 18.612132352941178, epoch_loss 2.2911151156705967
# Round 1, cleint 9, epoch 3: epoch_accuracy 18.704044117647058, epoch_loss 2.2914684099309586
# Round 1, cleint 9, epoch 4: epoch_accuracy 18.704044117647058, epoch_loss 2.291863609762753
# Round 1, cleint 9, epoch 5: epoch_accuracy 18.704044117647058, epoch_loss 2.290903357898488
# Round 1, cleint 10, epoch 1: epoch_accuracy 1.171875, epoch_loss 2.3234023451805115
# Round 1, cleint 10, epoch 2: epoch_accuracy 1.171875, epoch_loss 2.3225000699361167
# Round 1, cleint 10, epoch 3: epoch_accuracy 1.4973958333333333, epoch_loss 2.3220963875452676
# Round 1, cleint 10, epoch 4: epoch_accuracy 1.4973958333333333, epoch_loss 2.3212093512217202
# Round 1, cleint 10, epoch 5: epoch_accuracy 1.3020833333333333, epoch_loss 2.3203196128209433
# Round 1, cleint 11, epoch 1: epoch_accuracy 9.6875, epoch_loss 2.2903302669525147
# Round 1, cleint 11, epoch 2: epoch_accuracy 10.78125, epoch_loss 2.291405963897705
# Round 1, cleint 11, epoch 3: epoch_accuracy 10.78125, epoch_loss 2.2907617568969725
# Round 1, cleint 11, epoch 4: epoch_accuracy 10.625, epoch_loss 2.290483331680298
# Round 1, cleint 11, epoch 5: epoch_accuracy 9.21875, epoch_loss 2.290448713302612
# Round 1, cleint 12, epoch 1: epoch_accuracy 9.517045454545455, epoch_loss 2.295573212883689
# Round 1, cleint 12, epoch 2: epoch_accuracy 9.872159090909092, epoch_loss 2.295621546831998
# Round 1, cleint 12, epoch 3: epoch_accuracy 9.446022727272727, epoch_loss 2.2941939397291704
# Round 1, cleint 12, epoch 4: epoch_accuracy 9.303977272727273, epoch_loss 2.293839151209051
# Round 1, cleint 12, epoch 5: epoch_accuracy 10.724431818181818, epoch_loss 2.292527675628662
# Round 1, cleint 13, epoch 1: epoch_accuracy 13.59375, epoch_loss 2.304923963546753
# Round 1, cleint 13, epoch 2: epoch_accuracy 13.671875, epoch_loss 2.3049116134643555
# Round 1, cleint 13, epoch 3: epoch_accuracy 13.4375, epoch_loss 2.3050069570541383
# Round 1, cleint 13, epoch 4: epoch_accuracy 13.359375, epoch_loss 2.305067801475525
# Round 1, cleint 13, epoch 5: epoch_accuracy 14.53125, epoch_loss 2.3050389766693113
# Round 1, cleint 14, epoch 1: epoch_accuracy 7.508680555555555, epoch_loss 2.308902601401011
# Round 1, cleint 14, epoch 2: epoch_accuracy 7.638888888888889, epoch_loss 2.3087207211388483
# Round 1, cleint 14, epoch 3: epoch_accuracy 7.921006944444445, epoch_loss 2.3076097236739264
# Round 1, cleint 14, epoch 4: epoch_accuracy 8.441840277777779, epoch_loss 2.307280957698822
# Round 1, cleint 14, epoch 5: epoch_accuracy 8.940972222222221, epoch_loss 2.307294878694746
# Round 1, cleint 15, epoch 1: epoch_accuracy 37.779017857142854, epoch_loss 2.280022536005293
# Round 1, cleint 15, epoch 2: epoch_accuracy 38.33705357142857, epoch_loss 2.279623167855399
# Round 1, cleint 15, epoch 3: epoch_accuracy 39.39732142857143, epoch_loss 2.2781442744391307
# Round 1, cleint 15, epoch 4: epoch_accuracy 39.564732142857146, epoch_loss 2.277502179145813
# Round 1, cleint 15, epoch 5: epoch_accuracy 39.732142857142854, epoch_loss 2.2772933585303172
# Round 1, cleint 16, epoch 1: epoch_accuracy 6.0855263157894735, epoch_loss 2.312452529606066
# Round 1, cleint 16, epoch 2: epoch_accuracy 6.291118421052632, epoch_loss 2.310906485507363
# Round 1, cleint 16, epoch 3: epoch_accuracy 6.4555921052631575, epoch_loss 2.3096354384171334
# Round 1, cleint 16, epoch 4: epoch_accuracy 6.743421052631579, epoch_loss 2.30934076560171
# Round 1, cleint 16, epoch 5: epoch_accuracy 6.743421052631579, epoch_loss 2.307264340551276
# Round 1, cleint 17, epoch 1: epoch_accuracy 17.96875, epoch_loss 2.2877012411753337
# Round 1, cleint 17, epoch 2: epoch_accuracy 17.864583333333332, epoch_loss 2.2872091134389243
# Round 1, cleint 17, epoch 3: epoch_accuracy 18.020833333333332, epoch_loss 2.2864399274190266
# Round 1, cleint 17, epoch 4: epoch_accuracy 18.541666666666668, epoch_loss 2.2858322938283284
# Round 1, cleint 17, epoch 5: epoch_accuracy 19.010416666666668, epoch_loss 2.285592492421468
# Round 1, cleint 18, epoch 1: epoch_accuracy 2.6595744680851063, epoch_loss 2.315797729695097
# Round 1, cleint 18, epoch 2: epoch_accuracy 2.293882978723404, epoch_loss 2.3142352560733226
# Round 1, cleint 18, epoch 3: epoch_accuracy 3.0252659574468086, epoch_loss 2.3128177409476423
# Round 1, cleint 18, epoch 4: epoch_accuracy 2.6429521276595747, epoch_loss 2.3116357732326427
# Round 1, cleint 18, epoch 5: epoch_accuracy 3.3743351063829787, epoch_loss 2.3103860895684423
# Round 1, cleint 19, epoch 1: epoch_accuracy 6.5625, epoch_loss 2.308850622177124
# Round 1, cleint 19, epoch 2: epoch_accuracy 6.71875, epoch_loss 2.306909680366516
# Round 1, cleint 19, epoch 3: epoch_accuracy 6.171875, epoch_loss 2.3069204568862913
# Round 1, cleint 19, epoch 4: epoch_accuracy 6.484375, epoch_loss 2.3064106702804565
# Round 1, cleint 19, epoch 5: epoch_accuracy 5.390625, epoch_loss 2.3066466093063354
# Round 1, cleint 20, epoch 1: epoch_accuracy 1.4322916666666667, epoch_loss 2.3177143573760985
# Round 1, cleint 20, epoch 2: epoch_accuracy 1.796875, epoch_loss 2.316541345914205
# Round 1, cleint 20, epoch 3: epoch_accuracy 2.2916666666666665, epoch_loss 2.3150207440058392
# Round 1, cleint 20, epoch 4: epoch_accuracy 1.9010416666666667, epoch_loss 2.314191484451294
# Round 1, cleint 20, epoch 5: epoch_accuracy 1.71875, epoch_loss 2.3134677012761435
# Model's Round: 1, train accuracy of model: 11.683361522706152, train loss of model: 2.297595191904372
#
#
# Model's Round: 1, test accuracy of model: 10.013977635782748, test loss of model: 2.302737342663847
#
#
# round 1 completed
# Round 2, cleint 1, epoch 1: epoch_accuracy 1.8229166666666667, epoch_loss 2.3074342886606853
# Round 2, cleint 1, epoch 2: epoch_accuracy 1.71875, epoch_loss 2.3073874950408935
# Round 2, cleint 1, epoch 3: epoch_accuracy 2.03125, epoch_loss 2.3073290983835855
# Round 2, cleint 1, epoch 4: epoch_accuracy 2.1354166666666665, epoch_loss 2.305959955851237
# Round 2, cleint 1, epoch 5: epoch_accuracy 1.6666666666666667, epoch_loss 2.306000248591105
# Round 2, cleint 2, epoch 1: epoch_accuracy 30.572916666666668, epoch_loss 2.2666649341583254
# Round 2, cleint 2, epoch 2: epoch_accuracy 29.270833333333332, epoch_loss 2.265487813949585
# Round 2, cleint 2, epoch 3: epoch_accuracy 30.104166666666668, epoch_loss 2.265131775538127
# Round 2, cleint 2, epoch 4: epoch_accuracy 30.260416666666668, epoch_loss 2.264027198155721
# Round 2, cleint 2, epoch 5: epoch_accuracy 29.84375, epoch_loss 2.2637791792551676
# Round 2, cleint 3, epoch 1: epoch_accuracy 5.063657407407407, epoch_loss 2.321445588712339
# Round 2, cleint 3, epoch 2: epoch_accuracy 4.976851851851852, epoch_loss 2.321033415970979
# Round 2, cleint 3, epoch 3: epoch_accuracy 5.295138888888889, epoch_loss 2.319979464566266
# Round 2, cleint 3, epoch 4: epoch_accuracy 5.3530092592592595, epoch_loss 2.3192794411270707
# Round 2, cleint 3, epoch 5: epoch_accuracy 5.063657407407407, epoch_loss 2.318885017324377
# Round 2, cleint 4, epoch 1: epoch_accuracy 7.083333333333333, epoch_loss 2.3011838595072427
# Round 2, cleint 4, epoch 2: epoch_accuracy 7.708333333333333, epoch_loss 2.3008822441101073
# Round 2, cleint 4, epoch 3: epoch_accuracy 6.875, epoch_loss 2.3009578227996825
# Round 2, cleint 4, epoch 4: epoch_accuracy 6.666666666666667, epoch_loss 2.3001073201497397
# Round 2, cleint 4, epoch 5: epoch_accuracy 7.916666666666667, epoch_loss 2.2998618443806964
# Round 2, cleint 5, epoch 1: epoch_accuracy 32.66225961538461, epoch_loss 2.2724747382677517
# Round 2, cleint 5, epoch 2: epoch_accuracy 32.75240384615385, epoch_loss 2.2720197714292087
# Round 2, cleint 5, epoch 3: epoch_accuracy 33.17307692307692, epoch_loss 2.270329612952012
# Round 2, cleint 5, epoch 4: epoch_accuracy 33.62379807692308, epoch_loss 2.2694618701934814
# Round 2, cleint 5, epoch 5: epoch_accuracy 32.96274038461539, epoch_loss 2.268845420617324
# Round 2, cleint 6, epoch 1: epoch_accuracy 2.1875, epoch_loss 2.309078240394592
# Round 2, cleint 6, epoch 2: epoch_accuracy 2.0703125, epoch_loss 2.308445680141449
# Round 2, cleint 6, epoch 3: epoch_accuracy 1.875, epoch_loss 2.3080491423606873
# Round 2, cleint 6, epoch 4: epoch_accuracy 2.0703125, epoch_loss 2.307225263118744
# Round 2, cleint 6, epoch 5: epoch_accuracy 2.109375, epoch_loss 2.306533968448639
# Round 2, cleint 7, epoch 1: epoch_accuracy 3.7574404761904763, epoch_loss 2.293505929765247
# Round 2, cleint 7, epoch 2: epoch_accuracy 3.943452380952381, epoch_loss 2.2926991326468333
# Round 2, cleint 7, epoch 3: epoch_accuracy 4.501488095238095, epoch_loss 2.2917280991872153
# Round 2, cleint 7, epoch 4: epoch_accuracy 4.613095238095238, epoch_loss 2.2900557972135998
# Round 2, cleint 7, epoch 5: epoch_accuracy 6.25, epoch_loss 2.2893484887622653
# Round 2, cleint 8, epoch 1: epoch_accuracy 4.150390625, epoch_loss 2.297501638531685
# Round 2, cleint 8, epoch 2: epoch_accuracy 5.078125, epoch_loss 2.2960725724697113
# Round 2, cleint 8, epoch 3: epoch_accuracy 6.298828125, epoch_loss 2.2954414784908295
# Round 2, cleint 8, epoch 4: epoch_accuracy 6.591796875, epoch_loss 2.2943199425935745
# Round 2, cleint 8, epoch 5: epoch_accuracy 7.080078125, epoch_loss 2.293115124106407
# Round 2, cleint 9, epoch 1: epoch_accuracy 18.887867647058822, epoch_loss 2.2925792581894817
# Round 2, cleint 9, epoch 2: epoch_accuracy 19.53125, epoch_loss 2.2922211675082935
# Round 2, cleint 9, epoch 3: epoch_accuracy 19.02573529411765, epoch_loss 2.2914943835314583
# Round 2, cleint 9, epoch 4: epoch_accuracy 20.03676470588235, epoch_loss 2.2912297809825226
# Round 2, cleint 9, epoch 5: epoch_accuracy 19.439338235294116, epoch_loss 2.290065148297478
# Round 2, cleint 10, epoch 1: epoch_accuracy 1.171875, epoch_loss 2.3218624194463096
# Round 2, cleint 10, epoch 2: epoch_accuracy 1.2369791666666667, epoch_loss 2.3215768337249756
# Round 2, cleint 10, epoch 3: epoch_accuracy 1.4973958333333333, epoch_loss 2.3220255374908447
# Round 2, cleint 10, epoch 4: epoch_accuracy 1.3020833333333333, epoch_loss 2.320823013782501
# Round 2, cleint 10, epoch 5: epoch_accuracy 1.4322916666666667, epoch_loss 2.320158302783966
# Round 2, cleint 11, epoch 1: epoch_accuracy 11.09375, epoch_loss 2.290360164642334
# Round 2, cleint 11, epoch 2: epoch_accuracy 12.03125, epoch_loss 2.2889310836791994
# Round 2, cleint 11, epoch 3: epoch_accuracy 11.25, epoch_loss 2.290148448944092
# Round 2, cleint 11, epoch 4: epoch_accuracy 10.0, epoch_loss 2.290440225601196
# Round 2, cleint 11, epoch 5: epoch_accuracy 10.625, epoch_loss 2.2912328243255615
# Round 2, cleint 12, epoch 1: epoch_accuracy 11.008522727272727, epoch_loss 2.294749628413807
# Round 2, cleint 12, epoch 2: epoch_accuracy 10.511363636363637, epoch_loss 2.294707038185813
# Round 2, cleint 12, epoch 3: epoch_accuracy 10.014204545454545, epoch_loss 2.293668335134333
# Round 2, cleint 12, epoch 4: epoch_accuracy 10.15625, epoch_loss 2.2933717424219306
# Round 2, cleint 12, epoch 5: epoch_accuracy 10.227272727272727, epoch_loss 2.2927886789495293
# Round 2, cleint 13, epoch 1: epoch_accuracy 14.0625, epoch_loss 2.304289960861206
# Round 2, cleint 13, epoch 2: epoch_accuracy 13.515625, epoch_loss 2.3053476095199583
# Round 2, cleint 13, epoch 3: epoch_accuracy 12.65625, epoch_loss 2.305308127403259
# Round 2, cleint 13, epoch 4: epoch_accuracy 14.296875, epoch_loss 2.303773617744446
# Round 2, cleint 13, epoch 5: epoch_accuracy 13.125, epoch_loss 2.3045167922973633
# Round 2, cleint 14, epoch 1: epoch_accuracy 7.096354166666667, epoch_loss 2.3093187941445246
# Round 2, cleint 14, epoch 2: epoch_accuracy 7.573784722222222, epoch_loss 2.308636393811968
# Round 2, cleint 14, epoch 3: epoch_accuracy 8.203125, epoch_loss 2.3078011870384216
# Round 2, cleint 14, epoch 4: epoch_accuracy 8.57204861111111, epoch_loss 2.3076127568880715
# Round 2, cleint 14, epoch 5: epoch_accuracy 9.244791666666666, epoch_loss 2.306883136431376
# Round 2, cleint 15, epoch 1: epoch_accuracy 37.276785714285715, epoch_loss 2.280576263155256
# Round 2, cleint 15, epoch 2: epoch_accuracy 37.16517857142857, epoch_loss 2.279794761112758
# Round 2, cleint 15, epoch 3: epoch_accuracy 38.61607142857143, epoch_loss 2.27826041834695
# Round 2, cleint 15, epoch 4: epoch_accuracy 38.560267857142854, epoch_loss 2.2777617147990634
# Round 2, cleint 15, epoch 5: epoch_accuracy 40.848214285714285, epoch_loss 2.276139668055943
# Round 2, cleint 16, epoch 1: epoch_accuracy 6.4555921052631575, epoch_loss 2.3121361857966374
# Round 2, cleint 16, epoch 2: epoch_accuracy 6.743421052631579, epoch_loss 2.310606002807617
# Round 2, cleint 16, epoch 3: epoch_accuracy 6.126644736842105, epoch_loss 2.3094913081118933
# Round 2, cleint 16, epoch 4: epoch_accuracy 6.702302631578948, epoch_loss 2.3086396016572652
# Round 2, cleint 16, epoch 5: epoch_accuracy 6.743421052631579, epoch_loss 2.3071610300164473
# Round 2, cleint 17, epoch 1: epoch_accuracy 17.395833333333332, epoch_loss 2.287199878692627
# Round 2, cleint 17, epoch 2: epoch_accuracy 18.4375, epoch_loss 2.2868886470794676
# Round 2, cleint 17, epoch 3: epoch_accuracy 18.645833333333332, epoch_loss 2.28592529296875
# Round 2, cleint 17, epoch 4: epoch_accuracy 18.072916666666668, epoch_loss 2.286330540974935
# Round 2, cleint 17, epoch 5: epoch_accuracy 18.59375, epoch_loss 2.285883665084839
# Round 2, cleint 18, epoch 1: epoch_accuracy 2.6595744680851063, epoch_loss 2.3153751302272716
# Round 2, cleint 18, epoch 2: epoch_accuracy 2.376994680851064, epoch_loss 2.3141630406075335
# Round 2, cleint 18, epoch 3: epoch_accuracy 3.125, epoch_loss 2.312816234345132
# Round 2, cleint 18, epoch 4: epoch_accuracy 3.4906914893617023, epoch_loss 2.311287925598469
# Round 2, cleint 18, epoch 5: epoch_accuracy 3.690159574468085, epoch_loss 2.310015414623504
# Round 2, cleint 19, epoch 1: epoch_accuracy 6.484375, epoch_loss 2.3078361988067626
# Round 2, cleint 19, epoch 2: epoch_accuracy 6.09375, epoch_loss 2.308710503578186
# Round 2, cleint 19, epoch 3: epoch_accuracy 6.25, epoch_loss 2.307558560371399
# Round 2, cleint 19, epoch 4: epoch_accuracy 5.390625, epoch_loss 2.3071299314498903
# Round 2, cleint 19, epoch 5: epoch_accuracy 6.796875, epoch_loss 2.3068541526794433
# Round 2, cleint 20, epoch 1: epoch_accuracy 1.5364583333333333, epoch_loss 2.317746305465698
# Round 2, cleint 20, epoch 2: epoch_accuracy 1.71875, epoch_loss 2.3161343336105347
# Round 2, cleint 20, epoch 3: epoch_accuracy 2.0052083333333335, epoch_loss 2.314971160888672
# Round 2, cleint 20, epoch 4: epoch_accuracy 1.7708333333333333, epoch_loss 2.3143884420394896
# Round 2, cleint 20, epoch 5: epoch_accuracy 2.1354166666666665, epoch_loss 2.313251233100891
# Model's Round: 2, train accuracy of model: 11.789723256286845, train loss of model: 2.297565966906616
#
#
# Model's Round: 2, test accuracy of model: 10.013977635782748, test loss of model: 2.302727387736019
#
#
# round 2 completed
# Round 3, cleint 1, epoch 1: epoch_accuracy 2.1875, epoch_loss 2.3063587665557863
# Round 3, cleint 1, epoch 2: epoch_accuracy 2.0833333333333335, epoch_loss 2.3073105971018473
# Round 3, cleint 1, epoch 3: epoch_accuracy 1.9270833333333333, epoch_loss 2.3068291982014975
# Round 3, cleint 1, epoch 4: epoch_accuracy 1.5625, epoch_loss 2.3068754196166994
# Round 3, cleint 1, epoch 5: epoch_accuracy 2.0833333333333335, epoch_loss 2.3061474164326987
# Round 3, cleint 2, epoch 1: epoch_accuracy 30.208333333333332, epoch_loss 2.2667173544565835
# Round 3, cleint 2, epoch 2: epoch_accuracy 30.15625, epoch_loss 2.266248575846354
# Round 3, cleint 2, epoch 3: epoch_accuracy 30.0, epoch_loss 2.2652318159739178
# Round 3, cleint 2, epoch 4: epoch_accuracy 31.197916666666668, epoch_loss 2.263772217432658
# Round 3, cleint 2, epoch 5: epoch_accuracy 30.0, epoch_loss 2.2631813367207845
# Round 3, cleint 3, epoch 1: epoch_accuracy 5.237268518518518, epoch_loss 2.3211436095061124
# Round 3, cleint 3, epoch 2: epoch_accuracy 5.005787037037037, epoch_loss 2.3208362879576505
# Round 3, cleint 3, epoch 3: epoch_accuracy 5.295138888888889, epoch_loss 2.319831856974849
# Round 3, cleint 3, epoch 4: epoch_accuracy 5.179398148148148, epoch_loss 2.319151410350093
# Round 3, cleint 3, epoch 5: epoch_accuracy 5.121527777777778, epoch_loss 2.318579223420885
# Round 3, cleint 4, epoch 1: epoch_accuracy 6.875, epoch_loss 2.3006216367085774
# Round 3, cleint 4, epoch 2: epoch_accuracy 6.875, epoch_loss 2.300241804122925
# Round 3, cleint 4, epoch 3: epoch_accuracy 7.447916666666667, epoch_loss 2.299736579259237
# Round 3, cleint 4, epoch 4: epoch_accuracy 7.5, epoch_loss 2.2995941638946533
# Round 3, cleint 4, epoch 5: epoch_accuracy 7.083333333333333, epoch_loss 2.298983176549276
# Round 3, cleint 5, epoch 1: epoch_accuracy 32.78245192307692, epoch_loss 2.2726804659916806
# Round 3, cleint 5, epoch 2: epoch_accuracy 33.08293269230769, epoch_loss 2.271469006171593
# Round 3, cleint 5, epoch 3: epoch_accuracy 32.39182692307692, epoch_loss 2.270749752338116
# Round 3, cleint 5, epoch 4: epoch_accuracy 33.08293269230769, epoch_loss 2.269577439014728
# Round 3, cleint 5, epoch 5: epoch_accuracy 33.53365384615385, epoch_loss 2.2684409068180966
# Round 3, cleint 6, epoch 1: epoch_accuracy 1.6015625, epoch_loss 2.3087289571762084
# Round 3, cleint 6, epoch 2: epoch_accuracy 1.484375, epoch_loss 2.3092734813690186
# Round 3, cleint 6, epoch 3: epoch_accuracy 1.640625, epoch_loss 2.308226132392883
# Round 3, cleint 6, epoch 4: epoch_accuracy 1.6015625, epoch_loss 2.306968367099762
# Round 3, cleint 6, epoch 5: epoch_accuracy 1.8359375, epoch_loss 2.3070436835289003
# Round 3, cleint 7, epoch 1: epoch_accuracy 3.4598214285714284, epoch_loss 2.293750592640468
# Round 3, cleint 7, epoch 2: epoch_accuracy 3.794642857142857, epoch_loss 2.292275144940331
# Round 3, cleint 7, epoch 3: epoch_accuracy 4.910714285714286, epoch_loss 2.2913198130471364
# Round 3, cleint 7, epoch 4: epoch_accuracy 5.580357142857143, epoch_loss 2.289889029094151
# Round 3, cleint 7, epoch 5: epoch_accuracy 6.398809523809524, epoch_loss 2.2885689848945256
# Round 3, cleint 8, epoch 1: epoch_accuracy 5.56640625, epoch_loss 2.296899825334549
# Round 3, cleint 8, epoch 2: epoch_accuracy 4.443359375, epoch_loss 2.2962051033973694
# Round 3, cleint 8, epoch 3: epoch_accuracy 5.322265625, epoch_loss 2.29583640396595
# Round 3, cleint 8, epoch 4: epoch_accuracy 6.787109375, epoch_loss 2.2947311103343964
# Round 3, cleint 8, epoch 5: epoch_accuracy 8.935546875, epoch_loss 2.2930754125118256
# Round 3, cleint 9, epoch 1: epoch_accuracy 18.658088235294116, epoch_loss 2.29284564186545
# Round 3, cleint 9, epoch 2: epoch_accuracy 19.301470588235293, epoch_loss 2.2917387625750374
# Round 3, cleint 9, epoch 3: epoch_accuracy 19.071691176470587, epoch_loss 2.2914793912102196
# Round 3, cleint 9, epoch 4: epoch_accuracy 19.990808823529413, epoch_loss 2.2907813296598545
# Round 3, cleint 9, epoch 5: epoch_accuracy 19.347426470588236, epoch_loss 2.290093281689812
# Round 3, cleint 10, epoch 1: epoch_accuracy 1.0416666666666667, epoch_loss 2.322498639424642
# Round 3, cleint 10, epoch 2: epoch_accuracy 1.2369791666666667, epoch_loss 2.3208290735880532
# Round 3, cleint 10, epoch 3: epoch_accuracy 1.171875, epoch_loss 2.3207886020342507
# Round 3, cleint 10, epoch 4: epoch_accuracy 1.4973958333333333, epoch_loss 2.32132879892985
# Round 3, cleint 10, epoch 5: epoch_accuracy 1.3671875, epoch_loss 2.320515433947245
# Round 3, cleint 11, epoch 1: epoch_accuracy 10.78125, epoch_loss 2.2911314010620116
# Round 3, cleint 11, epoch 2: epoch_accuracy 10.78125, epoch_loss 2.290152835845947
# Round 3, cleint 11, epoch 3: epoch_accuracy 10.46875, epoch_loss 2.2901352405548097
# Round 3, cleint 11, epoch 4: epoch_accuracy 10.9375, epoch_loss 2.289988470077515
# Round 3, cleint 11, epoch 5: epoch_accuracy 9.6875, epoch_loss 2.2899961471557617
# Round 3, cleint 12, epoch 1: epoch_accuracy 9.801136363636363, epoch_loss 2.29545166275718
# Round 3, cleint 12, epoch 2: epoch_accuracy 10.227272727272727, epoch_loss 2.2947884039445356
# Round 3, cleint 12, epoch 3: epoch_accuracy 9.943181818181818, epoch_loss 2.2952109466899526
# Round 3, cleint 12, epoch 4: epoch_accuracy 10.582386363636363, epoch_loss 2.294185161590576
# Round 3, cleint 12, epoch 5: epoch_accuracy 11.434659090909092, epoch_loss 2.2918399680744517
# Round 3, cleint 13, epoch 1: epoch_accuracy 13.90625, epoch_loss 2.3050029039382935
# Round 3, cleint 13, epoch 2: epoch_accuracy 13.59375, epoch_loss 2.3051219940185548
# Round 3, cleint 13, epoch 3: epoch_accuracy 14.609375, epoch_loss 2.3047005891799928
# Round 3, cleint 13, epoch 4: epoch_accuracy 13.984375, epoch_loss 2.3045597791671755
# Round 3, cleint 13, epoch 5: epoch_accuracy 13.75, epoch_loss 2.3044986486434937
# Round 3, cleint 14, epoch 1: epoch_accuracy 7.921006944444445, epoch_loss 2.309406187799242
# Round 3, cleint 14, epoch 2: epoch_accuracy 7.573784722222222, epoch_loss 2.309161259068383
# Round 3, cleint 14, epoch 3: epoch_accuracy 8.02951388888889, epoch_loss 2.3081194162368774
# Round 3, cleint 14, epoch 4: epoch_accuracy 8.76736111111111, epoch_loss 2.307508561346266
# Round 3, cleint 14, epoch 5: epoch_accuracy 9.35329861111111, epoch_loss 2.3064244058397083
# Round 3, cleint 15, epoch 1: epoch_accuracy 37.276785714285715, epoch_loss 2.2805612768445696
# Round 3, cleint 15, epoch 2: epoch_accuracy 38.72767857142857, epoch_loss 2.278516786439078
# Round 3, cleint 15, epoch 3: epoch_accuracy 38.392857142857146, epoch_loss 2.279127631868635
# Round 3, cleint 15, epoch 4: epoch_accuracy 39.341517857142854, epoch_loss 2.2778037445885793
# Round 3, cleint 15, epoch 5: epoch_accuracy 40.401785714285715, epoch_loss 2.2765573263168335
# Round 3, cleint 16, epoch 1: epoch_accuracy 6.537828947368421, epoch_loss 2.3116571652261833
# Round 3, cleint 16, epoch 2: epoch_accuracy 6.4144736842105265, epoch_loss 2.310674416391473
# Round 3, cleint 16, epoch 3: epoch_accuracy 6.8256578947368425, epoch_loss 2.3097088713394966
# Round 3, cleint 16, epoch 4: epoch_accuracy 6.496710526315789, epoch_loss 2.308441249947799
# Round 3, cleint 16, epoch 5: epoch_accuracy 6.784539473684211, epoch_loss 2.3072655326441716
# Round 3, cleint 17, epoch 1: epoch_accuracy 18.802083333333332, epoch_loss 2.2867488225301105
# Round 3, cleint 17, epoch 2: epoch_accuracy 18.333333333333332, epoch_loss 2.2863210678100585
# Round 3, cleint 17, epoch 3: epoch_accuracy 18.489583333333332, epoch_loss 2.285279401143392
# Round 3, cleint 17, epoch 4: epoch_accuracy 18.28125, epoch_loss 2.2862877368927004
# Round 3, cleint 17, epoch 5: epoch_accuracy 18.75, epoch_loss 2.286055866877238
# Round 3, cleint 18, epoch 1: epoch_accuracy 2.4601063829787235, epoch_loss 2.315661044830972
# Round 3, cleint 18, epoch 2: epoch_accuracy 2.69281914893617, epoch_loss 2.3138584786273064
# Round 3, cleint 18, epoch 3: epoch_accuracy 2.958776595744681, epoch_loss 2.312584161758423
# Round 3, cleint 18, epoch 4: epoch_accuracy 3.1914893617021276, epoch_loss 2.311068793560596
# Round 3, cleint 18, epoch 5: epoch_accuracy 3.873005319148936, epoch_loss 2.3095957776333425
# Round 3, cleint 19, epoch 1: epoch_accuracy 6.09375, epoch_loss 2.3073559999465942
# Round 3, cleint 19, epoch 2: epoch_accuracy 6.015625, epoch_loss 2.308791899681091
# Round 3, cleint 19, epoch 3: epoch_accuracy 6.015625, epoch_loss 2.3070078134536742
# Round 3, cleint 19, epoch 4: epoch_accuracy 6.5625, epoch_loss 2.307283878326416
# Round 3, cleint 19, epoch 5: epoch_accuracy 6.484375, epoch_loss 2.306933641433716
# Round 3, cleint 20, epoch 1: epoch_accuracy 2.0052083333333335, epoch_loss 2.3176244258880616
# Round 3, cleint 20, epoch 2: epoch_accuracy 1.8229166666666667, epoch_loss 2.316333301862081
# Round 3, cleint 20, epoch 3: epoch_accuracy 2.2916666666666665, epoch_loss 2.3149963140487673
# Round 3, cleint 20, epoch 4: epoch_accuracy 1.9791666666666667, epoch_loss 2.3142220258712767
# Round 3, cleint 20, epoch 5: epoch_accuracy 2.3958333333333335, epoch_loss 2.3129856824874877
# Model's Round: 3, train accuracy of model: 11.931087635123422, train loss of model: 2.2973390926810127
#
#
# Model's Round: 3, test accuracy of model: 10.013977635782748, test loss of model: 2.302717496792729
#
#
# round 3 completed
# Round 4, cleint 1, epoch 1: epoch_accuracy 1.6666666666666667, epoch_loss 2.3078511397043866
# Round 4, cleint 1, epoch 2: epoch_accuracy 1.71875, epoch_loss 2.307692797978719
# Round 4, cleint 1, epoch 3: epoch_accuracy 1.9791666666666667, epoch_loss 2.3066723982493085
# Round 4, cleint 1, epoch 4: epoch_accuracy 1.9791666666666667, epoch_loss 2.3069234689076743
# Round 4, cleint 1, epoch 5: epoch_accuracy 2.0833333333333335, epoch_loss 2.305976661046346
# Round 4, cleint 2, epoch 1: epoch_accuracy 29.53125, epoch_loss 2.26737904548645
# Round 4, cleint 2, epoch 2: epoch_accuracy 30.520833333333332, epoch_loss 2.2654815038045246
# Round 4, cleint 2, epoch 3: epoch_accuracy 29.84375, epoch_loss 2.265569003423055
# Round 4, cleint 2, epoch 4: epoch_accuracy 29.84375, epoch_loss 2.2646049817403155
# Round 4, cleint 2, epoch 5: epoch_accuracy 29.635416666666668, epoch_loss 2.2635525544484456
# Round 4, cleint 3, epoch 1: epoch_accuracy 5.063657407407407, epoch_loss 2.3212019072638617
# Round 4, cleint 3, epoch 2: epoch_accuracy 5.092592592592593, epoch_loss 2.3207583162519665
# Round 4, cleint 3, epoch 3: epoch_accuracy 4.890046296296297, epoch_loss 2.3200844570442483
# Round 4, cleint 3, epoch 4: epoch_accuracy 5.121527777777778, epoch_loss 2.31925540500217
# Round 4, cleint 3, epoch 5: epoch_accuracy 5.381944444444445, epoch_loss 2.3179866207970514
# Round 4, cleint 4, epoch 1: epoch_accuracy 7.552083333333333, epoch_loss 2.3005273818969725
# Round 4, cleint 4, epoch 2: epoch_accuracy 6.5625, epoch_loss 2.301045068105062
# Round 4, cleint 4, epoch 3: epoch_accuracy 6.614583333333333, epoch_loss 2.3005910873413087
# Round 4, cleint 4, epoch 4: epoch_accuracy 7.083333333333333, epoch_loss 2.2998165130615233
# Round 4, cleint 4, epoch 5: epoch_accuracy 7.8125, epoch_loss 2.2989118734995526
# Round 4, cleint 5, epoch 1: epoch_accuracy 32.69230769230769, epoch_loss 2.2721744775772095
# Round 4, cleint 5, epoch 2: epoch_accuracy 32.99278846153846, epoch_loss 2.271759968537551
# Round 4, cleint 5, epoch 3: epoch_accuracy 33.65384615384615, epoch_loss 2.270418350513165
# Round 4, cleint 5, epoch 4: epoch_accuracy 33.08293269230769, epoch_loss 2.269374187176044
# Round 4, cleint 5, epoch 5: epoch_accuracy 33.92427884615385, epoch_loss 2.268610349068275
# Round 4, cleint 6, epoch 1: epoch_accuracy 1.953125, epoch_loss 2.3093383431434633
# Round 4, cleint 6, epoch 2: epoch_accuracy 1.875, epoch_loss 2.3083625435829163
# Round 4, cleint 6, epoch 3: epoch_accuracy 2.3828125, epoch_loss 2.3079286336898805
# Round 4, cleint 6, epoch 4: epoch_accuracy 2.0703125, epoch_loss 2.3065940618515013
# Round 4, cleint 6, epoch 5: epoch_accuracy 1.9921875, epoch_loss 2.3066745162010194
# Round 4, cleint 7, epoch 1: epoch_accuracy 3.5342261904761907, epoch_loss 2.294000966208322
# Round 4, cleint 7, epoch 2: epoch_accuracy 3.5342261904761907, epoch_loss 2.2930735633486794
# Round 4, cleint 7, epoch 3: epoch_accuracy 4.538690476190476, epoch_loss 2.2912142163231257
# Round 4, cleint 7, epoch 4: epoch_accuracy 5.394345238095238, epoch_loss 2.2902295475914363
# Round 4, cleint 7, epoch 5: epoch_accuracy 5.46875, epoch_loss 2.2891394864945185
# Round 4, cleint 8, epoch 1: epoch_accuracy 4.4921875, epoch_loss 2.2970872819423676
# Round 4, cleint 8, epoch 2: epoch_accuracy 5.712890625, epoch_loss 2.295971781015396
# Round 4, cleint 8, epoch 3: epoch_accuracy 5.419921875, epoch_loss 2.2947855293750763
# Round 4, cleint 8, epoch 4: epoch_accuracy 7.177734375, epoch_loss 2.294472649693489
# Round 4, cleint 8, epoch 5: epoch_accuracy 7.421875, epoch_loss 2.2932453602552414
# Round 4, cleint 9, epoch 1: epoch_accuracy 19.209558823529413, epoch_loss 2.292577827678007
# Round 4, cleint 9, epoch 2: epoch_accuracy 18.933823529411764, epoch_loss 2.2922971108380485
# Round 4, cleint 9, epoch 3: epoch_accuracy 18.106617647058822, epoch_loss 2.291813850402832
# Round 4, cleint 9, epoch 4: epoch_accuracy 19.11764705882353, epoch_loss 2.291209473329432
# Round 4, cleint 9, epoch 5: epoch_accuracy 19.11764705882353, epoch_loss 2.2900983445784626
# Round 4, cleint 10, epoch 1: epoch_accuracy 1.4322916666666667, epoch_loss 2.322606166203817
# Round 4, cleint 10, epoch 2: epoch_accuracy 1.2369791666666667, epoch_loss 2.3216394186019897
# Round 4, cleint 10, epoch 3: epoch_accuracy 1.6927083333333333, epoch_loss 2.3213075598080954
# Round 4, cleint 10, epoch 4: epoch_accuracy 1.4322916666666667, epoch_loss 2.3209685484568277
# Round 4, cleint 10, epoch 5: epoch_accuracy 1.7578125, epoch_loss 2.3204690416653952
# Round 4, cleint 11, epoch 1: epoch_accuracy 10.78125, epoch_loss 2.2919074058532716
# Round 4, cleint 11, epoch 2: epoch_accuracy 10.78125, epoch_loss 2.290411853790283
# Round 4, cleint 11, epoch 3: epoch_accuracy 10.9375, epoch_loss 2.2903393268585206
# Round 4, cleint 11, epoch 4: epoch_accuracy 9.6875, epoch_loss 2.291345453262329
# Round 4, cleint 11, epoch 5: epoch_accuracy 12.03125, epoch_loss 2.2912627696990966
# Round 4, cleint 12, epoch 1: epoch_accuracy 9.730113636363637, epoch_loss 2.295637759295377
# Round 4, cleint 12, epoch 2: epoch_accuracy 9.801136363636363, epoch_loss 2.294288331812078
# Round 4, cleint 12, epoch 3: epoch_accuracy 10.582386363636363, epoch_loss 2.2932551340623335
# Round 4, cleint 12, epoch 4: epoch_accuracy 10.369318181818182, epoch_loss 2.2937904704700816
# Round 4, cleint 12, epoch 5: epoch_accuracy 10.9375, epoch_loss 2.292360956018621
# Round 4, cleint 13, epoch 1: epoch_accuracy 13.515625, epoch_loss 2.304526996612549
# Round 4, cleint 13, epoch 2: epoch_accuracy 13.515625, epoch_loss 2.3055159568786623
# Round 4, cleint 13, epoch 3: epoch_accuracy 13.359375, epoch_loss 2.305134630203247
# Round 4, cleint 13, epoch 4: epoch_accuracy 14.296875, epoch_loss 2.3042925357818604
# Round 4, cleint 13, epoch 5: epoch_accuracy 13.90625, epoch_loss 2.3041337013244627
# Round 4, cleint 14, epoch 1: epoch_accuracy 6.922743055555555, epoch_loss 2.3095649878184
# Round 4, cleint 14, epoch 2: epoch_accuracy 7.660590277777778, epoch_loss 2.3085303174124823
# Round 4, cleint 14, epoch 3: epoch_accuracy 8.3984375, epoch_loss 2.307824340131548
# Round 4, cleint 14, epoch 4: epoch_accuracy 8.485243055555555, epoch_loss 2.3072918918397693
# Round 4, cleint 14, epoch 5: epoch_accuracy 9.15798611111111, epoch_loss 2.3065214819378324
# Round 4, cleint 15, epoch 1: epoch_accuracy 36.830357142857146, epoch_loss 2.2800096784319197
# Round 4, cleint 15, epoch 2: epoch_accuracy 37.5, epoch_loss 2.2802455765860423
# Round 4, cleint 15, epoch 3: epoch_accuracy 38.783482142857146, epoch_loss 2.278187768799918
# Round 4, cleint 15, epoch 4: epoch_accuracy 38.895089285714285, epoch_loss 2.2778801918029785
# Round 4, cleint 15, epoch 5: epoch_accuracy 40.17857142857143, epoch_loss 2.276457905769348
# Round 4, cleint 16, epoch 1: epoch_accuracy 6.373355263157895, epoch_loss 2.3118558933860376
# Round 4, cleint 16, epoch 2: epoch_accuracy 6.620065789473684, epoch_loss 2.3096608111732886
# Round 4, cleint 16, epoch 3: epoch_accuracy 6.4555921052631575, epoch_loss 2.3094842559412907
# Round 4, cleint 16, epoch 4: epoch_accuracy 6.661184210526316, epoch_loss 2.308581929457815
# Round 4, cleint 16, epoch 5: epoch_accuracy 6.373355263157895, epoch_loss 2.307084183943899
# Round 4, cleint 17, epoch 1: epoch_accuracy 18.072916666666668, epoch_loss 2.2870327949523928
# Round 4, cleint 17, epoch 2: epoch_accuracy 18.28125, epoch_loss 2.2869959672292075
# Round 4, cleint 17, epoch 3: epoch_accuracy 18.333333333333332, epoch_loss 2.2865323702494305
# Round 4, cleint 17, epoch 4: epoch_accuracy 17.708333333333332, epoch_loss 2.2871761957804364
# Round 4, cleint 17, epoch 5: epoch_accuracy 18.333333333333332, epoch_loss 2.285151720046997
# Round 4, cleint 18, epoch 1: epoch_accuracy 2.8424202127659575, epoch_loss 2.315041334071058
# Round 4, cleint 18, epoch 2: epoch_accuracy 3.0585106382978724, epoch_loss 2.313918042690196
# Round 4, cleint 18, epoch 3: epoch_accuracy 2.859042553191489, epoch_loss 2.3126989019677993
# Round 4, cleint 18, epoch 4: epoch_accuracy 3.174867021276596, epoch_loss 2.3111817836761475
# Round 4, cleint 18, epoch 5: epoch_accuracy 3.4906914893617023, epoch_loss 2.310097207414343
# Round 4, cleint 19, epoch 1: epoch_accuracy 6.640625, epoch_loss 2.3082836866378784
# Round 4, cleint 19, epoch 2: epoch_accuracy 6.5625, epoch_loss 2.307435178756714
# Round 4, cleint 19, epoch 3: epoch_accuracy 6.796875, epoch_loss 2.3067105770111085
# Round 4, cleint 19, epoch 4: epoch_accuracy 5.546875, epoch_loss 2.306917691230774
# Round 4, cleint 19, epoch 5: epoch_accuracy 6.40625, epoch_loss 2.3065431356430053
# Round 4, cleint 20, epoch 1: epoch_accuracy 1.6927083333333333, epoch_loss 2.3175487756729125
# Round 4, cleint 20, epoch 2: epoch_accuracy 1.6927083333333333, epoch_loss 2.3163116375605264
# Round 4, cleint 20, epoch 3: epoch_accuracy 1.9010416666666667, epoch_loss 2.3155024369557697
# Round 4, cleint 20, epoch 4: epoch_accuracy 1.9270833333333333, epoch_loss 2.314163335164388
# Round 4, cleint 20, epoch 5: epoch_accuracy 1.9010416666666667, epoch_loss 2.3138428846995036
# Model's Round: 4, train accuracy of model: 11.865598732081198, train loss of model: 2.297406037727571
#
#
# Model's Round: 4, test accuracy of model: 10.013977635782748, test loss of model: 2.3027076827832302
#
#
# round 4 completed
# Round 5, cleint 1, epoch 1: epoch_accuracy 2.6041666666666665, epoch_loss 2.3075908184051515
# Round 5, cleint 1, epoch 2: epoch_accuracy 1.6145833333333333, epoch_loss 2.3072663942972818
# Round 5, cleint 1, epoch 3: epoch_accuracy 1.40625, epoch_loss 2.3070998827616376
# Round 5, cleint 1, epoch 4: epoch_accuracy 2.2395833333333335, epoch_loss 2.30584929784139
# Round 5, cleint 1, epoch 5: epoch_accuracy 1.71875, epoch_loss 2.306103531519572
# Round 5, cleint 2, epoch 1: epoch_accuracy 30.3125, epoch_loss 2.265981419881185
# Round 5, cleint 2, epoch 2: epoch_accuracy 30.625, epoch_loss 2.265633153915405
# Round 5, cleint 2, epoch 3: epoch_accuracy 30.364583333333332, epoch_loss 2.2651917616526287
# Round 5, cleint 2, epoch 4: epoch_accuracy 29.427083333333332, epoch_loss 2.265120506286621
# Round 5, cleint 2, epoch 5: epoch_accuracy 30.15625, epoch_loss 2.263402239481608
# Round 5, cleint 3, epoch 1: epoch_accuracy 5.063657407407407, epoch_loss 2.3211358741477683
# Round 5, cleint 3, epoch 2: epoch_accuracy 5.324074074074074, epoch_loss 2.320127699110243
# Round 5, cleint 3, epoch 3: epoch_accuracy 5.005787037037037, epoch_loss 2.319351107985885
# Round 5, cleint 3, epoch 4: epoch_accuracy 5.3530092592592595, epoch_loss 2.3187276434015343
# Round 5, cleint 3, epoch 5: epoch_accuracy 5.005787037037037, epoch_loss 2.3183789871357106
# Round 5, cleint 4, epoch 1: epoch_accuracy 6.875, epoch_loss 2.3005787054697673
# Round 5, cleint 4, epoch 2: epoch_accuracy 6.614583333333333, epoch_loss 2.300544198354085
# Round 5, cleint 4, epoch 3: epoch_accuracy 7.5, epoch_loss 2.300246572494507
# Round 5, cleint 4, epoch 4: epoch_accuracy 7.135416666666667, epoch_loss 2.300316747029622
# Round 5, cleint 4, epoch 5: epoch_accuracy 7.083333333333333, epoch_loss 2.299599059422811
# Round 5, cleint 5, epoch 1: epoch_accuracy 32.87259615384615, epoch_loss 2.272798226429866
# Round 5, cleint 5, epoch 2: epoch_accuracy 32.87259615384615, epoch_loss 2.2717159436299252
# Round 5, cleint 5, epoch 3: epoch_accuracy 33.44350961538461, epoch_loss 2.2706725964179406
# Round 5, cleint 5, epoch 4: epoch_accuracy 32.78245192307692, epoch_loss 2.270000622822688
# Round 5, cleint 5, epoch 5: epoch_accuracy 32.96274038461539, epoch_loss 2.268645222370441
# Round 5, cleint 6, epoch 1: epoch_accuracy 1.9140625, epoch_loss 2.3092209100723267
# Round 5, cleint 6, epoch 2: epoch_accuracy 1.8359375, epoch_loss 2.3085355162620544
# Round 5, cleint 6, epoch 3: epoch_accuracy 2.1875, epoch_loss 2.307836413383484
# Round 5, cleint 6, epoch 4: epoch_accuracy 1.875, epoch_loss 2.3069984793663023
# Round 5, cleint 6, epoch 5: epoch_accuracy 1.9921875, epoch_loss 2.3069732069969175
# Round 5, cleint 7, epoch 1: epoch_accuracy 3.6086309523809526, epoch_loss 2.294578813371204
# Round 5, cleint 7, epoch 2: epoch_accuracy 4.017857142857143, epoch_loss 2.2927378018697104
# Round 5, cleint 7, epoch 3: epoch_accuracy 4.873511904761905, epoch_loss 2.2914022491091774
# Round 5, cleint 7, epoch 4: epoch_accuracy 6.287202380952381, epoch_loss 2.2903268791380382
# Round 5, cleint 7, epoch 5: epoch_accuracy 5.877976190476191, epoch_loss 2.2891091278621127
# Round 5, cleint 8, epoch 1: epoch_accuracy 5.615234375, epoch_loss 2.29701729118824
# Round 5, cleint 8, epoch 2: epoch_accuracy 6.25, epoch_loss 2.2953910678625107
# Round 5, cleint 8, epoch 3: epoch_accuracy 5.859375, epoch_loss 2.295240819454193
# Round 5, cleint 8, epoch 4: epoch_accuracy 7.2265625, epoch_loss 2.293875426054001
# Round 5, cleint 8, epoch 5: epoch_accuracy 8.349609375, epoch_loss 2.2926910519599915
# Round 5, cleint 9, epoch 1: epoch_accuracy 18.428308823529413, epoch_loss 2.2924913658815274
# Round 5, cleint 9, epoch 2: epoch_accuracy 18.841911764705884, epoch_loss 2.292157958535587
# Round 5, cleint 9, epoch 3: epoch_accuracy 18.658088235294116, epoch_loss 2.291270382264081
# Round 5, cleint 9, epoch 4: epoch_accuracy 18.795955882352942, epoch_loss 2.2911119601305794
# Round 5, cleint 9, epoch 5: epoch_accuracy 18.841911764705884, epoch_loss 2.290284311070162
# Round 5, cleint 10, epoch 1: epoch_accuracy 1.5625, epoch_loss 2.3216832478841147
# Round 5, cleint 10, epoch 2: epoch_accuracy 1.3671875, epoch_loss 2.321863293647766
# Round 5, cleint 10, epoch 3: epoch_accuracy 1.3020833333333333, epoch_loss 2.3213155468304953
# Round 5, cleint 10, epoch 4: epoch_accuracy 1.3671875, epoch_loss 2.3206642270088196
# Round 5, cleint 10, epoch 5: epoch_accuracy 1.2369791666666667, epoch_loss 2.319927752017975
# Round 5, cleint 11, epoch 1: epoch_accuracy 10.625, epoch_loss 2.2911773681640626
# Round 5, cleint 11, epoch 2: epoch_accuracy 10.0, epoch_loss 2.290232944488525
# Round 5, cleint 11, epoch 3: epoch_accuracy 10.9375, epoch_loss 2.290421152114868
# Round 5, cleint 11, epoch 4: epoch_accuracy 10.625, epoch_loss 2.2904317378997803
# Round 5, cleint 11, epoch 5: epoch_accuracy 11.40625, epoch_loss 2.289100408554077
# Round 5, cleint 12, epoch 1: epoch_accuracy 10.014204545454545, epoch_loss 2.2950599410317163
# Round 5, cleint 12, epoch 2: epoch_accuracy 9.517045454545455, epoch_loss 2.2954238544810903
# Round 5, cleint 12, epoch 3: epoch_accuracy 9.943181818181818, epoch_loss 2.294162858616222
# Round 5, cleint 12, epoch 4: epoch_accuracy 10.653409090909092, epoch_loss 2.2930595007809726
# Round 5, cleint 12, epoch 5: epoch_accuracy 10.653409090909092, epoch_loss 2.292694633657282
# Round 5, cleint 13, epoch 1: epoch_accuracy 12.96875, epoch_loss 2.3056647062301634
# Round 5, cleint 13, epoch 2: epoch_accuracy 14.375, epoch_loss 2.3039077281951905
# Round 5, cleint 13, epoch 3: epoch_accuracy 14.296875, epoch_loss 2.304351282119751
# Round 5, cleint 13, epoch 4: epoch_accuracy 14.0625, epoch_loss 2.305020785331726
# Round 5, cleint 13, epoch 5: epoch_accuracy 13.359375, epoch_loss 2.3047215700149537
# Round 5, cleint 14, epoch 1: epoch_accuracy 7.378472222222222, epoch_loss 2.309544093079037
# Round 5, cleint 14, epoch 2: epoch_accuracy 7.508680555555555, epoch_loss 2.3084713882870145
# Round 5, cleint 14, epoch 3: epoch_accuracy 7.942708333333333, epoch_loss 2.30810139576594
# Round 5, cleint 14, epoch 4: epoch_accuracy 8.832465277777779, epoch_loss 2.306900872124566
# Round 5, cleint 14, epoch 5: epoch_accuracy 9.635416666666666, epoch_loss 2.3059666885270014
# Round 5, cleint 15, epoch 1: epoch_accuracy 36.830357142857146, epoch_loss 2.2802655015672957
# Round 5, cleint 15, epoch 2: epoch_accuracy 37.44419642857143, epoch_loss 2.2795914241245816
# Round 5, cleint 15, epoch 3: epoch_accuracy 38.783482142857146, epoch_loss 2.2788262707846507
# Round 5, cleint 15, epoch 4: epoch_accuracy 40.122767857142854, epoch_loss 2.2775397641318187
# Round 5, cleint 15, epoch 5: epoch_accuracy 40.625, epoch_loss 2.2769529138292586
# Round 5, cleint 16, epoch 1: epoch_accuracy 6.578947368421052, epoch_loss 2.311332790475143
# Round 5, cleint 16, epoch 2: epoch_accuracy 6.496710526315789, epoch_loss 2.3101845540498434
# Round 5, cleint 16, epoch 3: epoch_accuracy 6.784539473684211, epoch_loss 2.309076095882215
# Round 5, cleint 16, epoch 4: epoch_accuracy 6.537828947368421, epoch_loss 2.3082934680737948
# Round 5, cleint 16, epoch 5: epoch_accuracy 6.4555921052631575, epoch_loss 2.30741948830454
# Round 5, cleint 17, epoch 1: epoch_accuracy 19.21875, epoch_loss 2.286962127685547
# Round 5, cleint 17, epoch 2: epoch_accuracy 18.28125, epoch_loss 2.287063233057658
# Round 5, cleint 17, epoch 3: epoch_accuracy 18.125, epoch_loss 2.2865920702616376
# Round 5, cleint 17, epoch 4: epoch_accuracy 18.59375, epoch_loss 2.2860553582509358
# Round 5, cleint 17, epoch 5: epoch_accuracy 18.125, epoch_loss 2.2859224637349445
# Round 5, cleint 18, epoch 1: epoch_accuracy 2.5930851063829787, epoch_loss 2.315242310787769
# Round 5, cleint 18, epoch 2: epoch_accuracy 2.8756648936170213, epoch_loss 2.3137017057297076
# Round 5, cleint 18, epoch 3: epoch_accuracy 2.8922872340425534, epoch_loss 2.3122995102659183
# Round 5, cleint 18, epoch 4: epoch_accuracy 3.174867021276596, epoch_loss 2.3111291692612017
# Round 5, cleint 18, epoch 5: epoch_accuracy 3.158244680851064, epoch_loss 2.3104148519800063
# Round 5, cleint 19, epoch 1: epoch_accuracy 6.328125, epoch_loss 2.308765172958374
# Round 5, cleint 19, epoch 2: epoch_accuracy 6.484375, epoch_loss 2.307675528526306
# Round 5, cleint 19, epoch 3: epoch_accuracy 5.78125, epoch_loss 2.3080132722854616
# Round 5, cleint 19, epoch 4: epoch_accuracy 7.109375, epoch_loss 2.306769299507141
# Round 5, cleint 19, epoch 5: epoch_accuracy 6.171875, epoch_loss 2.3067327976226806
# Round 5, cleint 20, epoch 1: epoch_accuracy 1.875, epoch_loss 2.3173030376434327
# Round 5, cleint 20, epoch 2: epoch_accuracy 1.9791666666666667, epoch_loss 2.316164422035217
# Round 5, cleint 20, epoch 3: epoch_accuracy 1.71875, epoch_loss 2.3154739777247113
# Round 5, cleint 20, epoch 4: epoch_accuracy 2.2916666666666665, epoch_loss 2.3143665075302122
# Round 5, cleint 20, epoch 5: epoch_accuracy 2.1875, epoch_loss 2.31302060286204
# Model's Round: 5, train accuracy of model: 11.750159364776223, train loss of model: 2.297403045446204
#
#
# Model's Round: 5, test accuracy of model: 10.013977635782748, test loss of model: 2.302697634925477
#
#
# round 5 completed
# Round 6, cleint 1, epoch 1: epoch_accuracy 1.8229166666666667, epoch_loss 2.307051960627238
# Round 6, cleint 1, epoch 2: epoch_accuracy 1.6666666666666667, epoch_loss 2.3068182945251463
# Round 6, cleint 1, epoch 3: epoch_accuracy 2.1354166666666665, epoch_loss 2.307031202316284
# Round 6, cleint 1, epoch 4: epoch_accuracy 2.0833333333333335, epoch_loss 2.3064406236012776
# Round 6, cleint 1, epoch 5: epoch_accuracy 1.71875, epoch_loss 2.306221278508504
# Round 6, cleint 2, epoch 1: epoch_accuracy 29.010416666666668, epoch_loss 2.267743396759033
# Round 6, cleint 2, epoch 2: epoch_accuracy 30.572916666666668, epoch_loss 2.2660654067993162
# Round 6, cleint 2, epoch 3: epoch_accuracy 29.635416666666668, epoch_loss 2.265701405207316
# Round 6, cleint 2, epoch 4: epoch_accuracy 29.0625, epoch_loss 2.2643199443817137
# Round 6, cleint 2, epoch 5: epoch_accuracy 30.208333333333332, epoch_loss 2.2630656401316327
# Round 6, cleint 3, epoch 1: epoch_accuracy 5.381944444444445, epoch_loss 2.3208407207771584
# Round 6, cleint 3, epoch 2: epoch_accuracy 5.381944444444445, epoch_loss 2.3202505111694336
# Round 6, cleint 3, epoch 3: epoch_accuracy 5.150462962962963, epoch_loss 2.319282399283515
# Round 6, cleint 3, epoch 4: epoch_accuracy 5.381944444444445, epoch_loss 2.3196363802309388
# Round 6, cleint 3, epoch 5: epoch_accuracy 5.063657407407407, epoch_loss 2.318455422366107
# Round 6, cleint 4, epoch 1: epoch_accuracy 7.083333333333333, epoch_loss 2.300525156656901
# Round 6, cleint 4, epoch 2: epoch_accuracy 7.03125, epoch_loss 2.3008718967437742
# Round 6, cleint 4, epoch 3: epoch_accuracy 7.135416666666667, epoch_loss 2.3004408836364747
# Round 6, cleint 4, epoch 4: epoch_accuracy 7.1875, epoch_loss 2.2996668020884194
# Round 6, cleint 4, epoch 5: epoch_accuracy 7.760416666666667, epoch_loss 2.29933287302653
# Round 6, cleint 5, epoch 1: epoch_accuracy 32.72235576923077, epoch_loss 2.2730372227155247
# ...
# Round 29, cleint 7, epoch 1: epoch_accuracy 3.6458333333333335, epoch_loss 2.2952184790656682
# Round 29, cleint 7, epoch 2: epoch_accuracy 3.831845238095238, epoch_loss 2.2944287118457614
# Round 29, cleint 7, epoch 3: epoch_accuracy 5.022321428571429, epoch_loss 2.292833226067679
# Round 29, cleint 7, epoch 4: epoch_accuracy 5.282738095238095, epoch_loss 2.2915251822698686
# Round 29, cleint 7, epoch 5: epoch_accuracy 6.510416666666667, epoch_loss 2.2907599153972806
# Round 29, cleint 8, epoch 1: epoch_accuracy 5.76171875, epoch_loss 2.2962561547756195
# Round 29, cleint 8, epoch 2: epoch_accuracy 5.712890625, epoch_loss 2.2950705140829086
# Round 29, cleint 8, epoch 3: epoch_accuracy 8.447265625, epoch_loss 2.293665587902069
# Round 29, cleint 8, epoch 4: epoch_accuracy 8.203125, epoch_loss 2.293365478515625
# Round 29, cleint 8, epoch 5: epoch_accuracy 8.0078125, epoch_loss 2.2926946878433228
# Round 29, cleint 9, epoch 1: epoch_accuracy 18.106617647058822, epoch_loss 2.2929932089412914
# Round 29, cleint 9, epoch 2: epoch_accuracy 18.33639705882353, epoch_loss 2.2926293401157154
# Round 29, cleint 9, epoch 3: epoch_accuracy 19.439338235294116, epoch_loss 2.2917435309466194
# Round 29, cleint 9, epoch 4: epoch_accuracy 18.290441176470587, epoch_loss 2.2917919579674217
# Round 29, cleint 9, epoch 5: epoch_accuracy 18.33639705882353, epoch_loss 2.290833178688498
# Round 29, cleint 10, epoch 1: epoch_accuracy 1.1067708333333333, epoch_loss 2.3218839963277182
# Round 29, cleint 10, epoch 2: epoch_accuracy 1.3020833333333333, epoch_loss 2.3212504188219705
# Round 29, cleint 10, epoch 3: epoch_accuracy 1.1067708333333333, epoch_loss 2.3209996819496155
# Round 29, cleint 10, epoch 4: epoch_accuracy 1.0416666666666667, epoch_loss 2.3205355207125344
# Round 29, cleint 10, epoch 5: epoch_accuracy 1.7578125, epoch_loss 2.319280286629995
# Round 29, cleint 11, epoch 1: epoch_accuracy 11.25, epoch_loss 2.2904006481170653
# Round 29, cleint 11, epoch 2: epoch_accuracy 10.78125, epoch_loss 2.291711616516113
# Round 29, cleint 11, epoch 3: epoch_accuracy 10.15625, epoch_loss 2.291258430480957
# Round 29, cleint 11, epoch 4: epoch_accuracy 10.46875, epoch_loss 2.2904218673706054
# Round 29, cleint 11, epoch 5: epoch_accuracy 11.71875, epoch_loss 2.290458345413208
# Round 29, cleint 12, epoch 1: epoch_accuracy 10.866477272727273, epoch_loss 2.2950253703377466
# Round 29, cleint 12, epoch 2: epoch_accuracy 10.15625, epoch_loss 2.2945255799727007
# Round 29, cleint 12, epoch 3: epoch_accuracy 10.866477272727273, epoch_loss 2.2928112853657114
# Round 29, cleint 12, epoch 4: epoch_accuracy 9.943181818181818, epoch_loss 2.2928693944757637
# Round 29, cleint 12, epoch 5: epoch_accuracy 10.014204545454545, epoch_loss 2.2921887094324287
# Round 29, cleint 13, epoch 1: epoch_accuracy 13.59375, epoch_loss 2.3051286697387696
# Round 29, cleint 13, epoch 2: epoch_accuracy 14.0625, epoch_loss 2.303363561630249
# Round 29, cleint 13, epoch 3: epoch_accuracy 13.90625, epoch_loss 2.3039175271987915
# Round 29, cleint 13, epoch 4: epoch_accuracy 14.0625, epoch_loss 2.3046584606170653
# Round 29, cleint 13, epoch 5: epoch_accuracy 12.578125, epoch_loss 2.304366636276245
# Round 29, cleint 14, epoch 1: epoch_accuracy 7.465277777777778, epoch_loss 2.308695455392202
# Round 29, cleint 14, epoch 2: epoch_accuracy 7.508680555555555, epoch_loss 2.308071964316898
# Round 29, cleint 14, epoch 3: epoch_accuracy 8.441840277777779, epoch_loss 2.3075890408621893
# Round 29, cleint 14, epoch 4: epoch_accuracy 8.96267361111111, epoch_loss 2.306998093922933
# Round 29, cleint 14, epoch 5: epoch_accuracy 9.049479166666666, epoch_loss 2.3063537610901728
# Round 29, cleint 15, epoch 1: epoch_accuracy 37.388392857142854, epoch_loss 2.2816519226346696
# Round 29, cleint 15, epoch 2: epoch_accuracy 37.55580357142857, epoch_loss 2.28100734097617
# Round 29, cleint 15, epoch 3: epoch_accuracy 39.39732142857143, epoch_loss 2.2795626606260027
# Round 29, cleint 15, epoch 4: epoch_accuracy 39.11830357142857, epoch_loss 2.2784482070377896
# Round 29, cleint 15, epoch 5: epoch_accuracy 39.50892857142857, epoch_loss 2.2772409915924072
# Round 29, cleint 16, epoch 1: epoch_accuracy 6.702302631578948, epoch_loss 2.3099364983408073
# Round 29, cleint 16, epoch 2: epoch_accuracy 6.702302631578948, epoch_loss 2.3087554228933236
# Round 29, cleint 16, epoch 3: epoch_accuracy 6.496710526315789, epoch_loss 2.3076262850510445
# Round 29, cleint 16, epoch 4: epoch_accuracy 6.784539473684211, epoch_loss 2.3063733201277885
# Round 29, cleint 16, epoch 5: epoch_accuracy 6.990131578947368, epoch_loss 2.3053386838812577
# Round 29, cleint 17, epoch 1: epoch_accuracy 18.125, epoch_loss 2.288103453318278
# Round 29, cleint 17, epoch 2: epoch_accuracy 18.020833333333332, epoch_loss 2.287350638707479
# Round 29, cleint 17, epoch 3: epoch_accuracy 18.854166666666668, epoch_loss 2.2871498584747316
# Round 29, cleint 17, epoch 4: epoch_accuracy 18.333333333333332, epoch_loss 2.2865901629130048
# Round 29, cleint 17, epoch 5: epoch_accuracy 17.916666666666668, epoch_loss 2.286852995554606
# Round 29, cleint 18, epoch 1: epoch_accuracy 2.742686170212766, epoch_loss 2.3136325592690326
# Round 29, cleint 18, epoch 2: epoch_accuracy 2.742686170212766, epoch_loss 2.3123270501481725
# Round 29, cleint 18, epoch 3: epoch_accuracy 3.5738031914893615, epoch_loss 2.310785582725038
# Round 29, cleint 18, epoch 4: epoch_accuracy 3.6070478723404253, epoch_loss 2.309642365638246
# Round 29, cleint 18, epoch 5: epoch_accuracy 4.17220744680851, epoch_loss 2.3080237013228397
# Round 29, cleint 19, epoch 1: epoch_accuracy 7.265625, epoch_loss 2.3066024780273438
# Round 29, cleint 19, epoch 2: epoch_accuracy 6.953125, epoch_loss 2.3072184324264526
# Round 29, cleint 19, epoch 3: epoch_accuracy 6.328125, epoch_loss 2.306857705116272
# Round 29, cleint 19, epoch 4: epoch_accuracy 6.328125, epoch_loss 2.3060881376266478
# Round 29, cleint 19, epoch 5: epoch_accuracy 6.5625, epoch_loss 2.3063284158706665
# Round 29, cleint 20, epoch 1: epoch_accuracy 1.8229166666666667, epoch_loss 2.3164854923884075
# Round 29, cleint 20, epoch 2: epoch_accuracy 2.2135416666666665, epoch_loss 2.3155173778533937
# Round 29, cleint 20, epoch 3: epoch_accuracy 1.9010416666666667, epoch_loss 2.314631470044454
# Round 29, cleint 20, epoch 4: epoch_accuracy 2.34375, epoch_loss 2.3131391445795697
# Round 29, cleint 20, epoch 5: epoch_accuracy 2.0833333333333335, epoch_loss 2.3128960927327475
# Model's Round: 29, train accuracy of model: 11.846147769189935, train loss of model: 2.2974456323988584
#
#
# Model's Round: 29, test accuracy of model: 10.013977635782748, test loss of model: 2.302459576640266
#
#
# round 29 completed
# Round 30, cleint 1, epoch 1: epoch_accuracy 1.9791666666666667, epoch_loss 2.3058597087860107
# Round 30, cleint 1, epoch 2: epoch_accuracy 1.9791666666666667, epoch_loss 2.306588570276896
# Round 30, cleint 1, epoch 3: epoch_accuracy 1.9791666666666667, epoch_loss 2.306909958521525
# Round 30, cleint 1, epoch 4: epoch_accuracy 2.65625, epoch_loss 2.305907948811849
# Round 30, cleint 1, epoch 5: epoch_accuracy 1.6666666666666667, epoch_loss 2.3064286867777506
# Round 30, cleint 2, epoch 1: epoch_accuracy 29.166666666666668, epoch_loss 2.2689258575439455
# Round 30, cleint 2, epoch 2: epoch_accuracy 30.364583333333332, epoch_loss 2.268382199605306
# Round 30, cleint 2, epoch 3: epoch_accuracy 30.416666666666668, epoch_loss 2.267484521865845
# Round 30, cleint 2, epoch 4: epoch_accuracy 29.53125, epoch_loss 2.266676648457845
# Round 30, cleint 2, epoch 5: epoch_accuracy 30.052083333333332, epoch_loss 2.26591051419576
# Round 30, cleint 3, epoch 1: epoch_accuracy 5.150462962962963, epoch_loss 2.3206457826826306
# Round 30, cleint 3, epoch 2: epoch_accuracy 5.439814814814815, epoch_loss 2.3191563376673945
# Round 30, cleint 3, epoch 3: epoch_accuracy 5.266203703703703, epoch_loss 2.3187088701460095
# Round 30, cleint 3, epoch 4: epoch_accuracy 5.324074074074074, epoch_loss 2.3178705197793468
# Round 30, cleint 3, epoch 5: epoch_accuracy 4.890046296296297, epoch_loss 2.3177955327210604
# Round 30, cleint 4, epoch 1: epoch_accuracy 7.03125, epoch_loss 2.301786279678345
# Round 30, cleint 4, epoch 2: epoch_accuracy 6.875, epoch_loss 2.3006450653076174
# Round 30, cleint 4, epoch 3: epoch_accuracy 7.135416666666667, epoch_loss 2.300620969136556
# Round 30, cleint 4, epoch 4: epoch_accuracy 7.1875, epoch_loss 2.3002472241719563
# Round 30, cleint 4, epoch 5: epoch_accuracy 7.8125, epoch_loss 2.300265979766846
# Round 30, cleint 5, epoch 1: epoch_accuracy 33.14302884615385, epoch_loss 2.2736341678179226
# Round 30, cleint 5, epoch 2: epoch_accuracy 32.54206730769231, epoch_loss 2.272608995437622
# Round 30, cleint 5, epoch 3: epoch_accuracy 31.73076923076923, epoch_loss 2.2722433438667884
# Round 30, cleint 5, epoch 4: epoch_accuracy 33.26322115384615, epoch_loss 2.270925595210149
# Round 30, cleint 5, epoch 5: epoch_accuracy 33.23317307692308, epoch_loss 2.2699502339729896
# Round 30, cleint 6, epoch 1: epoch_accuracy 2.0703125, epoch_loss 2.3083474159240724
# Round 30, cleint 6, epoch 2: epoch_accuracy 2.1875, epoch_loss 2.307710826396942
# Round 30, cleint 6, epoch 3: epoch_accuracy 1.7578125, epoch_loss 2.307708191871643
# Round 30, cleint 6, epoch 4: epoch_accuracy 1.71875, epoch_loss 2.3066340923309325
# Round 30, cleint 6, epoch 5: epoch_accuracy 1.7578125, epoch_loss 2.306088364124298
# Round 30, cleint 7, epoch 1: epoch_accuracy 3.5342261904761907, epoch_loss 2.2954244386582148
# Round 30, cleint 7, epoch 2: epoch_accuracy 4.6875, epoch_loss 2.293967905498686
# Round 30, cleint 7, epoch 3: epoch_accuracy 4.799107142857143, epoch_loss 2.2930281048729304
# Round 30, cleint 7, epoch 4: epoch_accuracy 5.394345238095238, epoch_loss 2.291206166857765
# Round 30, cleint 7, epoch 5: epoch_accuracy 5.617559523809524, epoch_loss 2.290913922446115
# Round 30, cleint 8, epoch 1: epoch_accuracy 5.810546875, epoch_loss 2.296830892562866
# Round 30, cleint 8, epoch 2: epoch_accuracy 6.15234375, epoch_loss 2.295258492231369
# Round 30, cleint 8, epoch 3: epoch_accuracy 7.568359375, epoch_loss 2.2945673763751984
# Round 30, cleint 8, epoch 4: epoch_accuracy 8.154296875, epoch_loss 2.293331876397133
# Round 30, cleint 8, epoch 5: epoch_accuracy 9.423828125, epoch_loss 2.292192429304123
# Round 30, cleint 9, epoch 1: epoch_accuracy 18.979779411764707, epoch_loss 2.2929008147295784
# Round 30, cleint 9, epoch 2: epoch_accuracy 18.658088235294116, epoch_loss 2.292274839737836
# Round 30, cleint 9, epoch 3: epoch_accuracy 18.795955882352942, epoch_loss 2.2914295336779427
# Round 30, cleint 9, epoch 4: epoch_accuracy 18.520220588235293, epoch_loss 2.291563637116376
# Round 30, cleint 9, epoch 5: epoch_accuracy 18.198529411764707, epoch_loss 2.2920049218570484
# Round 30, cleint 10, epoch 1: epoch_accuracy 1.4973958333333333, epoch_loss 2.320745329062144
# Round 30, cleint 10, epoch 2: epoch_accuracy 1.3020833333333333, epoch_loss 2.3209986289342246
# Round 30, cleint 10, epoch 3: epoch_accuracy 1.6276041666666667, epoch_loss 2.320389211177826
# Round 30, cleint 10, epoch 4: epoch_accuracy 1.6276041666666667, epoch_loss 2.320957064628601
# Round 30, cleint 10, epoch 5: epoch_accuracy 1.6276041666666667, epoch_loss 2.3193286458651223
# Round 30, cleint 11, epoch 1: epoch_accuracy 9.6875, epoch_loss 2.2921517372131346
# Round 30, cleint 11, epoch 2: epoch_accuracy 12.03125, epoch_loss 2.291532373428345
# Round 30, cleint 11, epoch 3: epoch_accuracy 10.625, epoch_loss 2.289828634262085
# Round 30, cleint 11, epoch 4: epoch_accuracy 12.96875, epoch_loss 2.29024977684021
# Round 30, cleint 11, epoch 5: epoch_accuracy 12.1875, epoch_loss 2.2896228790283204
# Round 30, cleint 12, epoch 1: epoch_accuracy 9.872159090909092, epoch_loss 2.2948967760259453
# Round 30, cleint 12, epoch 2: epoch_accuracy 9.943181818181818, epoch_loss 2.2947218851609663
# Round 30, cleint 12, epoch 3: epoch_accuracy 10.795454545454545, epoch_loss 2.293853911486539
# Round 30, cleint 12, epoch 4: epoch_accuracy 9.943181818181818, epoch_loss 2.293310057033192
# Round 30, cleint 12, epoch 5: epoch_accuracy 10.085227272727273, epoch_loss 2.292835755781694
# Round 30, cleint 13, epoch 1: epoch_accuracy 12.96875, epoch_loss 2.305149221420288
# Round 30, cleint 13, epoch 2: epoch_accuracy 13.90625, epoch_loss 2.3048577070236207
# Round 30, cleint 13, epoch 3: epoch_accuracy 13.984375, epoch_loss 2.3037155151367186
# Round 30, cleint 13, epoch 4: epoch_accuracy 13.671875, epoch_loss 2.304982566833496
# Round 30, cleint 13, epoch 5: epoch_accuracy 13.359375, epoch_loss 2.3049119234085085
# Round 30, cleint 14, epoch 1: epoch_accuracy 7.2265625, epoch_loss 2.3085615634918213
# Round 30, cleint 14, epoch 2: epoch_accuracy 7.421875, epoch_loss 2.30827354060279
# Round 30, cleint 14, epoch 3: epoch_accuracy 8.116319444444445, epoch_loss 2.307681620121002
# Round 30, cleint 14, epoch 4: epoch_accuracy 8.289930555555555, epoch_loss 2.3072533276345997
# Round 30, cleint 14, epoch 5: epoch_accuracy 9.092881944444445, epoch_loss 2.3067281709776983
# Round 30, cleint 15, epoch 1: epoch_accuracy 36.886160714285715, epoch_loss 2.2818998779569353
# Round 30, cleint 15, epoch 2: epoch_accuracy 36.66294642857143, epoch_loss 2.281422972679138
# Round 30, cleint 15, epoch 3: epoch_accuracy 37.55580357142857, epoch_loss 2.280186210359846
# Round 30, cleint 15, epoch 4: epoch_accuracy 38.671875, epoch_loss 2.278500505856105
# Round 30, cleint 15, epoch 5: epoch_accuracy 40.122767857142854, epoch_loss 2.2776149000440324
# Round 30, cleint 16, epoch 1: epoch_accuracy 6.661184210526316, epoch_loss 2.3095727217824837
# Round 30, cleint 16, epoch 2: epoch_accuracy 6.496710526315789, epoch_loss 2.3087562259874845
# Round 30, cleint 16, epoch 3: epoch_accuracy 6.496710526315789, epoch_loss 2.307339404758654
# Round 30, cleint 16, epoch 4: epoch_accuracy 6.949013157894737, epoch_loss 2.3061874289261666
# Round 30, cleint 16, epoch 5: epoch_accuracy 7.2368421052631575, epoch_loss 2.3046091104808606
# Round 30, cleint 17, epoch 1: epoch_accuracy 18.28125, epoch_loss 2.287969875335693
# Round 30, cleint 17, epoch 2: epoch_accuracy 18.75, epoch_loss 2.2870184262593587
# Round 30, cleint 17, epoch 3: epoch_accuracy 17.916666666666668, epoch_loss 2.2874034722646077
# Round 30, cleint 17, epoch 4: epoch_accuracy 17.864583333333332, epoch_loss 2.2870235125223797
# Round 30, cleint 17, epoch 5: epoch_accuracy 17.864583333333332, epoch_loss 2.2863390763600666
# Round 30, cleint 18, epoch 1: epoch_accuracy 2.8257978723404253, epoch_loss 2.313471220909281
# Round 30, cleint 18, epoch 2: epoch_accuracy 2.9753989361702127, epoch_loss 2.312239723002657
# Round 30, cleint 18, epoch 3: epoch_accuracy 3.2413563829787235, epoch_loss 2.3114792184626802
# Round 30, cleint 18, epoch 4: epoch_accuracy 3.7566489361702127, epoch_loss 2.3091422801322126
# Round 30, cleint 18, epoch 5: epoch_accuracy 4.0724734042553195, epoch_loss 2.3081312382474857
# Round 30, cleint 19, epoch 1: epoch_accuracy 6.5625, epoch_loss 2.307286190986633
# Round 30, cleint 19, epoch 2: epoch_accuracy 6.875, epoch_loss 2.3060379028320312
# Round 30, cleint 19, epoch 3: epoch_accuracy 6.25, epoch_loss 2.3064911127090455
# Round 30, cleint 19, epoch 4: epoch_accuracy 6.796875, epoch_loss 2.3058400392532348
# Round 30, cleint 19, epoch 5: epoch_accuracy 6.875, epoch_loss 2.305582785606384
# Round 30, cleint 20, epoch 1: epoch_accuracy 1.8229166666666667, epoch_loss 2.316580128669739
# Round 30, cleint 20, epoch 2: epoch_accuracy 2.1875, epoch_loss 2.315718905131022
# Round 30, cleint 20, epoch 3: epoch_accuracy 1.953125, epoch_loss 2.3146379788716636
# Round 30, cleint 20, epoch 4: epoch_accuracy 1.875, epoch_loss 2.3137550195058187
# Round 30, cleint 20, epoch 5: epoch_accuracy 2.0052083333333335, epoch_loss 2.3126792748769125
# Model's Round: 30, train accuracy of model: 11.859083117548, train loss of model: 2.297496717292154
#
#
# Model's Round: 30, test accuracy of model: 10.013977635782748, test loss of model: 2.302449646849221
#
#
# round 30 completed

# %% [markdown]
# # Reuslts

# %%
# Define the folder and file name
folder_name = f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"


# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
folder_name =  f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
