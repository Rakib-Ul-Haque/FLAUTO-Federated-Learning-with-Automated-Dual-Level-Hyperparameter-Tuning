# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# from sklearn.metrics import confusion_matrix
from torchvision.datasets import CIFAR10
from collections import Counter
import random
import copy
import torch.nn.functional as F
import os
import sys
import time
import pickle
import pandas as pd
from torch import Tensor
from typing import Type
import torchvision.models as models
from torchvision import transforms
from copy import deepcopy

# Set font family for plots
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# <H1>Load Dataset</H1>

# %%
# transform = transforms.Compose([
#     transforms.ToTensor(), #This transformation converts a PIL (Python Imaging Library) Image or numpy.ndarray (with shape (H x W x C) in the range [0, 255]) into a PyTorch tensor of shape (C x H x W) in the range [0.0, 1.0]. It essentially rearranges the dimensions of the image data and scales it to a float value between 0 and 1.
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])


# train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# # train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)
subset_dataset = torch.load('val_dataset.pth',weights_only=False)
remaining_dataset = torch.load('test_dataset.pth',weights_only=False)

# Create DataLoaders
val_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(remaining_dataset, batch_size=32, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <H1>IID</H1>

# %%
def distribute_dataset_equally(dataset, num_clients):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    # Distribute data
    client_data = [[] for _ in range(num_clients)]
    for label, data in class_data.items():
        data_len = len(data)
        base_size = data_len // num_clients
        remain = data_len - base_size * num_clients

        current_idx = 0
        for i in range(num_clients):
            end_idx = current_idx + base_size + (1 if i < remain else 0)
            client_data[i].extend(data[current_idx:end_idx])
            current_idx = end_idx


    print_iid_distribution(client_data)
    plot_iid_dataset(client_data,num_clients)

    return client_data

# %%
#print client iid_data distribution
def print_iid_distribution(iid_datasets):
    # Check if the distribution is correct
    for i, client_data in enumerate(iid_datasets):
        print(f"Client {i + 1} data size: {len(client_data)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# Plot client iid_data distribution
def plot_iid_dataset(iid_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in iid_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define colors for each class
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")
    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number',labelpad=5)
    ax.set_ylabel('CIFAR-10 Classes',labelpad=15)
    ax.set_zlabel('Fraction of Distribution',labelpad=5)
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], rotation=45)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names, rotation=-60)

    #ax.view_init(elev=40, azim=60)
    ax.view_init(elev=40, azim=10)

    plt.subplots_adjust(left=0.01, right=0.99, bottom=0.01, top=0.99)

    plt.show()

# %% [markdown]
# <H1>non-IID</H1>

# %%
#Print the distribution non IID
def print_distribution(client_data):
    # Check distribution
    for l, client_data_value in enumerate(client_data):
        print(f"Client {l + 1} data size: {len(client_data_value)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data_value:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# #Non IID code
def distribute_dataset_dirichlet(dataset, num_clients, alpha):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    client_data = [[] for _ in range(num_clients)]
    for _, data_list in class_data.items():
        # Shuffle data for randomness
        np.random.shuffle(data_list)

        # Get proportions for data split based on Dirichlet distribution
        proportions = np.random.dirichlet([alpha]*num_clients)
        # print("Proportions: ", proportions)
        total_data = len(data_list)
        # print("total_data: ", total_data)
        data_splits = [int(proportions[i]*total_data) for i in range(num_clients)]
        # print("Data_Split: ", data_splits)

        # Adjust the splits to account for rounding errors
        # print("Before data_split:",data_splits)
        data_splits[-1] += total_data - sum(data_splits)
        print("After data_split:",data_splits)

        start_idx = 0
        for i, split in enumerate(data_splits):
            end_idx = start_idx + split
            client_data[i].extend(data_list[start_idx:end_idx])
            start_idx = end_idx
    print("Client Number: ",num_clients, "Alpha: ", alpha)
    print_distribution(client_data)
    plot_distribution(client_data, num_clients )
    return client_data

# %%
#show the graphs for nonIID
def plot_distribution(client_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in client_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        # print(total_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define distinct colors for classes using a colormap
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # # Generate the 3D bar chart
    # fig = plt.figure(figsize=(18, 12))
    # ax = fig.add_subplot(111, projection='3d')

    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")

    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number')
    ax.set_ylabel('CIFAR-10 Classes')
    ax.set_zlabel('Fraction of Distribution')
    ax.set_title('Distribution of CIFAR-10 Classes across Clients based on Dirichlet Distribution')
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], fontsize=12)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)
        
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Change output to 10 for CIFAR-10 classes

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Train

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag):
    global opti
    
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate,  weight_decay=0.004)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate, weight_decay=0.004)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    local_model.train()  # Set the model to training mode

    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        print(f"Round {roun}, cleint {cli+1}, epoch {epoch+1}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")
    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    #print(f"\n Round {roun}, cleint {cli}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    
    
    epoch_rmd=model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data
    
    model_update = {}
    for key in local_model.state_dict():
        model_update[key] = torch.sub(i_weights[key], f_weights[key])
    
    return epoch_accuracy,epoch_loss, epoch_flag, model_update

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()  # Assuming a classification task
    #optimizer = torch.optim.SGD(lmodel.parameters(), lr=learning_rate)
    lmodel.load_state_dict(w)
    lmodel.eval()

    #checking the weights
    tw = lmodel.state_dict()
    #Print("Model's before testing the weights in global model",tw)

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    #print("Model's Test accuracy : {:.2f}%".format(test_accuracy))
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
def average_updates(w, n_k):
    w_avg = deepcopy(w[0])
    for key in w_avg.keys():
        w_avg[key] = torch.mul(w_avg[key], n_k[0])
        for i in range(1, len(w)):
            w_avg[key] = torch.add(w_avg[key], w[i][key], alpha=n_k[i])
        w_avg[key] = torch.div(w_avg[key], sum(n_k))
    return w_avg

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size, epsilon=1e-8):
    
    global total_clients_list, participating_client_list, G
    
    global_model.load_state_dict(i_w)
    
    # Initialize accumulated squared gradient for Adagrad
    G = None

    # loop for round
    for r in range(1, R+1):
        round_train_accuracy = 0
        round_train_loss = 0
        round_test_accuracy = 0
        round_test_loss = 0
        epoch_flag = 0

        # Saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}

        # Collecting weights and results
        data_size = []
        all_clients_updates = []
        train_accuracy_list = []
        train_loss_list = []
        
        # Randomly select clients
        selected_clients = random.sample(total_clients_list, P)
        participating_client_list.append(selected_clients)

        # Loop for client
        for c, data in enumerate(data_client):
            if c in selected_clients:
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
                # Train model
                train_accuracy, train_loss, epoch_flag, model_update = train(i_w, E, train_loader, learning_rate, c, r, epoch_flag)

                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)
                
                all_clients_updates.append(model_update)
                data_size.append(len(train_loader))
            else:
                print(f"Client {c+1} is not selected")
        
        round_epoch = epoch_flag
        round_train_loss = sum(train_loss_list) / len(train_loss_list)
        round_train_accuracy = sum(train_accuracy_list) / len(train_accuracy_list)
        print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

        # Aggregate the updates using a weighted average
        update_avg = average_updates(all_clients_updates, data_size)

        # Initialize the sum of squares for Adagrad if not done
        if G is None:
            G = {key: torch.zeros_like(param) for key, param in update_avg.items()}

        # Adagrad update rule for each parameter
        for key in i_w:
            # Accumulate the sum of squares of gradients
            G[key] += update_avg[key] ** 2

            # Update weights using Adagrad rule
            i_w[key] -= learning_rate * update_avg[key] / (torch.sqrt(G[key]) + epsilon)

        # Test the model on global test set
        round_test_accuracy, round_test_loss = test(i_w, test_loader)
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

        # Model deviation calculation
        round_rmd = model_deviation_function(i_w, global_model.state_dict())
        
        # Save data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, epoch_flag]
        round_results.loc[len(round_results)] = round_data

        # Load the updated weights into the global model
        global_model.load_state_dict(i_w)
        print("Round", r, "completed")

# %%
# def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
#     global total_cleints_list, participating_client_list, v
    
#     global_model.load_state_dict(i_w)
#     #Print("Model's initial weights", i_w)

#     #loop for round
#     for r in range(1,R+1):
#         round_train_accuracy=0
#         round_train_loss=0
#         round_test_accuracy=0
#         round_test_loss=0
#         epoch_flag=0

#         #saving initial weights for spiking model
#         i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
#         #Print("Model's initial weights", i_w)
        
#         #colleting weights and results
#         data_size=[]
#         all_final_weights={}
#         all_cleints_updates=[]
#         train_accuracy_list=[]
#         train_loss_list=[]
        
#         # Randomly select clients
#         selected_clients = random.sample(total_cleints_list, P)
#         participating_client_list.append(selected_clients)

#         #loop for client
#         for c, data in enumerate(data_client):
            
#             if(c in selected_clients):
                
#                 train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
#                 #train model
#                 train_accuracy, train_loss, epoch_flag, model_update = train(i_w, E, train_loader, learning_rate, c, r,epoch_flag)

#                 train_accuracy_list.append(train_accuracy)
#                 train_loss_list.append(train_loss)
                
#                 all_cleints_updates.append(model_update)

#                 data_size.append(len(train_loader))
                
                
#                 # Accumulate weights for the selected client
#                 # for param_name, param_grad in c_f_weights.items():
#                 #     if param_name in all_final_weights:
#                 #         all_final_weights[param_name] += param_grad
#                 #     else:
#                 #         all_final_weights[param_name] = param_grad

#             else:
#                 print(f"client {c} is not selectecd")
        
#         round_epoch=(epoch_flag)
#         #print("Total number of selected clients is", client_counter)
#         round_train_loss=sum(train_loss_list)/len(train_loss_list)
#         round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)
#         print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

#         update_avg = average_updates( all_cleints_updates, data_size)

#         if v is None:
#             v = deepcopy(update_avg)
#         else:
#             for key in v.keys():
#                 v[key] = update_avg[key] + (v[key] * 0.99)
                
#         for key in i_w:
#             all_final_weights[key]=i_w[key] - (v[key] * 1)

#         # for param_name in all_final_weights:
#         #     all_final_weights[param_name] = all_final_weights[param_name].float() / len(selected_clients)

#         round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)
#         print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

#         #model deviation code
#         round_rmd=model_deviation_function(i_w, all_final_weights)
#         #print("Model deviation values: ", model_deviation)

#         #saving data into dataframe
#         round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
#         round_results.loc[len(round_results)] = round_data
            
#         global_model.load_state_dict(all_final_weights)
#         print("round", r, "completed")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=20
participating_client=20
epochs=5
learning_rate=0.0001
round_no=30
batch_size=128
distributions = "non_iid" # 'non_iid'
data_class=10
alpha= 0.5 #"infinity"
opti="sgd" # or sgd or adam
# v=None
# m=None
G = None
# t=0
method="fed_adagrade"

# List of clients
total_clients_list = list(range(0, client_no))
# print(total_cleints_list)
participating_client_list=[]

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

#===================================loading the saved weight list====================================================
global_model = model().to(device)
# initial_weights={k: v.clone() for k, v in global_model.state_dict().items()}
# Save the initial weights
file_path = "s_cnn.pth"
# torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=True)
Print("Model's initial weights", initial_weights)
# Out:
# Model's initial weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')

# %% [markdown]
# <H1>Divide data among cleints</H1>

# %%
# #=================================loading IID data===========================
# if distributions == 'iid':
#     client_datasets = distribute_dataset_equally(train_dataset,client_no)
    
# elif distributions == 'non_iid':
#     client_datasets = distribute_dataset_dirichlet(train_dataset, client_no, alpha)
# else:
#     print("provide a valid distribution Please")

# %%
# # Save client_datasets to a file
# if distributions == 'iid':
#     with open('client_datasets_IID.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.5:
#     with open('client_datasets_non_IID_0_5.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.125:
#     with open('client_datasets_non_IID_0_125.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)

# print("client_datasets saved successfully.")

# %%
# Load client_datasets from a file
if distributions == 'iid':
    with open('20_client_datasets_IID.pkl', 'rb') as f:
        client_datasets = pickle.load(f)

elif distributions == 'non_iid' and alpha==0.5:
    with open('20_client_datasets_non_IID_0_5.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
    
elif distributions == 'non_iid' and alpha==0.125:
    with open('20_client_datasets_non_IID_0_125.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
        
print("client_datasets loaded successfully.")
print_distribution(client_datasets)
# Out:
# client_datasets loaded successfully.
# Client 1 data size: 1928
# Class distribution: {0: 93, 1: 405, 2: 144, 3: 3, 4: 342, 5: 365, 6: 25, 7: 64, 8: 248, 9: 239}
# Client 2 data size: 1997
# Class distribution: {0: 38, 1: 0, 2: 921, 3: 588, 4: 14, 5: 9, 6: 58, 7: 51, 8: 11, 9: 307}
# Client 3 data size: 3557
# Class distribution: {0: 849, 1: 41, 2: 2, 3: 208, 4: 645, 5: 640, 6: 853, 7: 151, 8: 20, 9: 148}
# Client 4 data size: 1954
# Class distribution: {0: 369, 1: 91, 2: 9, 3: 135, 4: 108, 5: 65, 6: 267, 7: 30, 8: 673, 9: 207}
# Client 5 data size: 3332
# Class distribution: {0: 25, 1: 0, 2: 866, 3: 1163, 4: 6, 5: 194, 6: 13, 7: 375, 8: 61, 9: 629}
# Client 6 data size: 2673
# Class distribution: {0: 241, 1: 643, 2: 161, 3: 26, 4: 2, 5: 861, 6: 65, 7: 182, 8: 462, 9: 30}
# Client 7 data size: 2750
# Class distribution: {0: 161, 1: 0, 2: 503, 3: 26, 4: 184, 5: 443, 6: 6, 7: 6, 8: 1412, 9: 9}
# Client 8 data size: 2071
# Class distribution: {0: 217, 1: 128, 2: 136, 3: 37, 4: 20, 5: 19, 6: 42, 7: 371, 8: 37, 9: 1064}
# Client 9 data size: 2185
# Class distribution: {0: 0, 1: 286, 2: 426, 3: 441, 4: 223, 5: 651, 6: 5, 7: 23, 8: 107, 9: 23}
# Client 10 data size: 1544
# Class distribution: {0: 602, 1: 10, 2: 2, 3: 16, 4: 91, 5: 47, 6: 299, 7: 192, 8: 255, 9: 30}
# Client 11 data size: 681
# Class distribution: {0: 2, 1: 43, 2: 1, 3: 75, 4: 26, 5: 75, 6: 101, 7: 1, 8: 205, 9: 152}
# Client 12 data size: 1524
# Class distribution: {0: 10, 1: 2, 2: 79, 3: 142, 4: 1, 5: 6, 6: 670, 7: 90, 8: 1, 9: 523}
# Client 13 data size: 1346
# Class distribution: {0: 281, 1: 82, 2: 8, 3: 208, 4: 116, 5: 206, 6: 5, 7: 128, 8: 158, 9: 154}
# Client 14 data size: 4708
# Class distribution: {0: 596, 1: 249, 2: 1220, 3: 246, 4: 932, 5: 595, 6: 18, 7: 717, 8: 33, 9: 102}
# Client 15 data size: 1893
# Class distribution: {0: 30, 1: 9, 2: 65, 3: 842, 4: 145, 5: 0, 6: 605, 7: 34, 8: 64, 9: 99}
# Client 16 data size: 2479
# Class distribution: {0: 0, 1: 924, 2: 71, 3: 176, 4: 10, 5: 259, 6: 54, 7: 897, 8: 0, 9: 88}
# Client 17 data size: 2031
# Class distribution: {0: 78, 1: 165, 2: 14, 3: 412, 4: 10, 5: 397, 6: 69, 7: 1, 8: 643, 9: 242}
# Client 18 data size: 6129
# Class distribution: {0: 673, 1: 1721, 2: 41, 3: 127, 4: 1129, 5: 118, 6: 29, 7: 1383, 8: 100, 9: 808}
# Client 19 data size: 1348
# Class distribution: {0: 70, 1: 153, 2: 1, 3: 96, 4: 46, 5: 35, 6: 541, 7: 159, 8: 139, 9: 108}
# Client 20 data size: 3870
# Class distribution: {0: 665, 1: 48, 2: 330, 3: 33, 4: 950, 5: 15, 6: 1275, 7: 145, 8: 371, 9: 38}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for cleints
round_train_accuracy=0
round_train_loss=0

train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True, drop_last=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
round_results.loc[len(round_results)] = round_data

Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')
#
#  train accuracy: 11.255979334200955
#  train_loss: 2.3002562651039957
#  test_accuracy: 10.013977635782748
#  test_loss: 2.3027472800720994

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
# Round 1, cleint 1, epoch 1: epoch_accuracy 1.8229166666666667, epoch_loss 2.3076149463653564
# Round 1, cleint 1, epoch 2: epoch_accuracy 1.5625, epoch_loss 2.3066256205240885
# Round 1, cleint 1, epoch 3: epoch_accuracy 1.5104166666666667, epoch_loss 2.3070501486460366
# Round 1, cleint 1, epoch 4: epoch_accuracy 1.8229166666666667, epoch_loss 2.3071343898773193
# Round 1, cleint 1, epoch 5: epoch_accuracy 2.5520833333333335, epoch_loss 2.3059964179992676
# Round 1, cleint 2, epoch 1: epoch_accuracy 30.15625, epoch_loss 2.2664058367411295
# Round 1, cleint 2, epoch 2: epoch_accuracy 29.739583333333332, epoch_loss 2.2658321380615236
# Round 1, cleint 2, epoch 3: epoch_accuracy 29.6875, epoch_loss 2.264799722035726
# Round 1, cleint 2, epoch 4: epoch_accuracy 30.104166666666668, epoch_loss 2.2640762011210125
# Round 1, cleint 2, epoch 5: epoch_accuracy 29.84375, epoch_loss 2.2631865978240966
# Round 1, cleint 3, epoch 1: epoch_accuracy 4.947916666666667, epoch_loss 2.321708643877948
# Round 1, cleint 3, epoch 2: epoch_accuracy 5.208333333333333, epoch_loss 2.320742925008138
# Round 1, cleint 3, epoch 3: epoch_accuracy 5.092592592592593, epoch_loss 2.3198679111622
# Round 1, cleint 3, epoch 4: epoch_accuracy 5.208333333333333, epoch_loss 2.3195550000226057
# Round 1, cleint 3, epoch 5: epoch_accuracy 5.121527777777778, epoch_loss 2.3188688490125866
# Round 1, cleint 4, epoch 1: epoch_accuracy 7.34375, epoch_loss 2.3002661228179933
# Round 1, cleint 4, epoch 2: epoch_accuracy 7.083333333333333, epoch_loss 2.3000085671742756
# Round 1, cleint 4, epoch 3: epoch_accuracy 7.03125, epoch_loss 2.3000175952911377
# Round 1, cleint 4, epoch 4: epoch_accuracy 7.552083333333333, epoch_loss 2.2996037642161054
# Round 1, cleint 4, epoch 5: epoch_accuracy 6.927083333333333, epoch_loss 2.2992121537526446
# Round 1, cleint 5, epoch 1: epoch_accuracy 32.27163461538461, epoch_loss 2.272784627400912
# Round 1, cleint 5, epoch 2: epoch_accuracy 33.44350961538461, epoch_loss 2.2710933685302734
# Round 1, cleint 5, epoch 3: epoch_accuracy 33.11298076923077, epoch_loss 2.270586059643672
# Round 1, cleint 5, epoch 4: epoch_accuracy 33.62379807692308, epoch_loss 2.2697328604184666
# Round 1, cleint 5, epoch 5: epoch_accuracy 32.57211538461539, epoch_loss 2.268790630193857
# Round 1, cleint 6, epoch 1: epoch_accuracy 1.8359375, epoch_loss 2.3096890330314634
# Round 1, cleint 6, epoch 2: epoch_accuracy 1.9921875, epoch_loss 2.308703100681305
# Round 1, cleint 6, epoch 3: epoch_accuracy 2.5, epoch_loss 2.307507073879242
# Round 1, cleint 6, epoch 4: epoch_accuracy 2.4609375, epoch_loss 2.307673919200897
# Round 1, cleint 6, epoch 5: epoch_accuracy 2.1875, epoch_loss 2.307111883163452
# Round 1, cleint 7, epoch 1: epoch_accuracy 4.017857142857143, epoch_loss 2.293247279666719
# Round 1, cleint 7, epoch 2: epoch_accuracy 4.166666666666667, epoch_loss 2.293365410396031
# Round 1, cleint 7, epoch 3: epoch_accuracy 4.501488095238095, epoch_loss 2.291105928875151
# Round 1, cleint 7, epoch 4: epoch_accuracy 5.431547619047619, epoch_loss 2.2902383463723317
# Round 1, cleint 7, epoch 5: epoch_accuracy 5.580357142857143, epoch_loss 2.289487395967756
# Round 1, cleint 8, epoch 1: epoch_accuracy 4.443359375, epoch_loss 2.2972381114959717
# Round 1, cleint 8, epoch 2: epoch_accuracy 5.6640625, epoch_loss 2.295854836702347
# Round 1, cleint 8, epoch 3: epoch_accuracy 6.34765625, epoch_loss 2.2954550087451935
# Round 1, cleint 8, epoch 4: epoch_accuracy 6.494140625, epoch_loss 2.294001579284668
# Round 1, cleint 8, epoch 5: epoch_accuracy 7.275390625, epoch_loss 2.2925998866558075
# Round 1, cleint 9, epoch 1: epoch_accuracy 18.933823529411764, epoch_loss 2.2922041977153107
# Round 1, cleint 9, epoch 2: epoch_accuracy 18.520220588235293, epoch_loss 2.2912849818958954
# Round 1, cleint 9, epoch 3: epoch_accuracy 18.152573529411764, epoch_loss 2.2910938964170566
# Round 1, cleint 9, epoch 4: epoch_accuracy 19.761029411764707, epoch_loss 2.291023787330179
# Round 1, cleint 9, epoch 5: epoch_accuracy 18.933823529411764, epoch_loss 2.2907340386334587
# Round 1, cleint 10, epoch 1: epoch_accuracy 1.0416666666666667, epoch_loss 2.3222301801045737
# Round 1, cleint 10, epoch 2: epoch_accuracy 1.1067708333333333, epoch_loss 2.322605013847351
# Round 1, cleint 10, epoch 3: epoch_accuracy 1.1067708333333333, epoch_loss 2.3212724924087524
# Round 1, cleint 10, epoch 4: epoch_accuracy 1.1067708333333333, epoch_loss 2.3213985562324524
# Round 1, cleint 10, epoch 5: epoch_accuracy 1.7578125, epoch_loss 2.3203828732172647
# Round 1, cleint 11, epoch 1: epoch_accuracy 11.875, epoch_loss 2.2901050090789794
# Round 1, cleint 11, epoch 2: epoch_accuracy 9.6875, epoch_loss 2.2922096729278563
# Round 1, cleint 11, epoch 3: epoch_accuracy 11.875, epoch_loss 2.2883620262145996
# Round 1, cleint 11, epoch 4: epoch_accuracy 10.46875, epoch_loss 2.290438413619995
# Round 1, cleint 11, epoch 5: epoch_accuracy 10.9375, epoch_loss 2.289719295501709
# Round 1, cleint 12, epoch 1: epoch_accuracy 9.517045454545455, epoch_loss 2.295931729403409
# Round 1, cleint 12, epoch 2: epoch_accuracy 10.511363636363637, epoch_loss 2.2948390353809702
# Round 1, cleint 12, epoch 3: epoch_accuracy 9.943181818181818, epoch_loss 2.2942173914475874
# Round 1, cleint 12, epoch 4: epoch_accuracy 9.801136363636363, epoch_loss 2.293804732235995
# Round 1, cleint 12, epoch 5: epoch_accuracy 10.085227272727273, epoch_loss 2.2927803126248447
# Round 1, cleint 13, epoch 1: epoch_accuracy 13.90625, epoch_loss 2.3044792652130126
# Round 1, cleint 13, epoch 2: epoch_accuracy 14.140625, epoch_loss 2.3048420667648317
# Round 1, cleint 13, epoch 3: epoch_accuracy 13.4375, epoch_loss 2.3049500226974486
# Round 1, cleint 13, epoch 4: epoch_accuracy 13.515625, epoch_loss 2.3048580169677733
# Round 1, cleint 13, epoch 5: epoch_accuracy 13.75, epoch_loss 2.3038928747177123
# Round 1, cleint 14, epoch 1: epoch_accuracy 7.725694444444445, epoch_loss 2.3089459207322864
# Round 1, cleint 14, epoch 2: epoch_accuracy 7.204861111111111, epoch_loss 2.3090247313181558
# Round 1, cleint 14, epoch 3: epoch_accuracy 8.289930555555555, epoch_loss 2.307896819379595
# Round 1, cleint 14, epoch 4: epoch_accuracy 8.289930555555555, epoch_loss 2.307318111260732
# Round 1, cleint 14, epoch 5: epoch_accuracy 9.244791666666666, epoch_loss 2.3067652384440103
# Round 1, cleint 15, epoch 1: epoch_accuracy 38.392857142857146, epoch_loss 2.2800233704703197
# Round 1, cleint 15, epoch 2: epoch_accuracy 38.058035714285715, epoch_loss 2.279752561024257
# Round 1, cleint 15, epoch 3: epoch_accuracy 38.895089285714285, epoch_loss 2.2792747701917375
# Round 1, cleint 15, epoch 4: epoch_accuracy 39.00669642857143, epoch_loss 2.2779102495738437
# Round 1, cleint 15, epoch 5: epoch_accuracy 39.564732142857146, epoch_loss 2.277311393192836
# Round 1, cleint 16, epoch 1: epoch_accuracy 6.784539473684211, epoch_loss 2.311282107704564
# Round 1, cleint 16, epoch 2: epoch_accuracy 6.907894736842105, epoch_loss 2.3101217997701546
# Round 1, cleint 16, epoch 3: epoch_accuracy 6.8667763157894735, epoch_loss 2.309375148070486
# Round 1, cleint 16, epoch 4: epoch_accuracy 6.990131578947368, epoch_loss 2.3087677579177055
# Round 1, cleint 16, epoch 5: epoch_accuracy 6.661184210526316, epoch_loss 2.3074834095804313
# Round 1, cleint 17, epoch 1: epoch_accuracy 18.333333333333332, epoch_loss 2.2867358207702635
# Round 1, cleint 17, epoch 2: epoch_accuracy 18.333333333333332, epoch_loss 2.2868795871734617
# Round 1, cleint 17, epoch 3: epoch_accuracy 17.5, epoch_loss 2.2865238189697266
# Round 1, cleint 17, epoch 4: epoch_accuracy 18.75, epoch_loss 2.285164244969686
# Round 1, cleint 17, epoch 5: epoch_accuracy 18.802083333333332, epoch_loss 2.285321108500163
# Round 1, cleint 18, epoch 1: epoch_accuracy 2.4601063829787235, epoch_loss 2.315364193409047
# Round 1, cleint 18, epoch 2: epoch_accuracy 2.5764627659574466, epoch_loss 2.31450839245573
# Round 1, cleint 18, epoch 3: epoch_accuracy 3.091755319148936, epoch_loss 2.31243571322015
# Round 1, cleint 18, epoch 4: epoch_accuracy 3.0585106382978724, epoch_loss 2.3114323514573116
# Round 1, cleint 18, epoch 5: epoch_accuracy 3.2746010638297873, epoch_loss 2.3102672049339783
# Round 1, cleint 19, epoch 1: epoch_accuracy 6.640625, epoch_loss 2.3074553489685057
# Round 1, cleint 19, epoch 2: epoch_accuracy 6.328125, epoch_loss 2.3073259592056274
# Round 1, cleint 19, epoch 3: epoch_accuracy 6.796875, epoch_loss 2.308295226097107
# Round 1, cleint 19, epoch 4: epoch_accuracy 6.71875, epoch_loss 2.3063820123672487
# Round 1, cleint 19, epoch 5: epoch_accuracy 6.09375, epoch_loss 2.306863880157471
# Round 1, cleint 20, epoch 1: epoch_accuracy 1.6927083333333333, epoch_loss 2.3172523895899455
# Round 1, cleint 20, epoch 2: epoch_accuracy 1.9010416666666667, epoch_loss 2.316818435986837
# Round 1, cleint 20, epoch 3: epoch_accuracy 1.9270833333333333, epoch_loss 2.315269716580709
# Round 1, cleint 20, epoch 4: epoch_accuracy 2.0572916666666665, epoch_loss 2.3137402375539144
# Round 1, cleint 20, epoch 5: epoch_accuracy 1.9270833333333333, epoch_loss 2.313154665629069
# Model's Round: 1, train accuracy of model: 11.65461983248013, train loss of model: 2.2974965054851206
#
#
# Model's Round: 1, test accuracy of model: 11.481629392971247, test loss of model: 2.3018367419989345
#
#
# Round 1 completed
# Round 2, cleint 1, epoch 1: epoch_accuracy 13.90625, epoch_loss 2.2999086380004883
# Round 2, cleint 1, epoch 2: epoch_accuracy 13.75, epoch_loss 2.299802827835083
# Round 2, cleint 1, epoch 3: epoch_accuracy 13.854166666666666, epoch_loss 2.3002074559529624
# Round 2, cleint 1, epoch 4: epoch_accuracy 14.479166666666666, epoch_loss 2.299855279922485
# Round 2, cleint 1, epoch 5: epoch_accuracy 14.6875, epoch_loss 2.2991124471028646
# Round 2, cleint 2, epoch 1: epoch_accuracy 14.6875, epoch_loss 2.280207554499308
# Round 2, cleint 2, epoch 2: epoch_accuracy 17.239583333333332, epoch_loss 2.278455368677775
# Round 2, cleint 2, epoch 3: epoch_accuracy 16.927083333333332, epoch_loss 2.2778103987375897
# Round 2, cleint 2, epoch 4: epoch_accuracy 18.4375, epoch_loss 2.2772894382476805
# Round 2, cleint 2, epoch 5: epoch_accuracy 22.5, epoch_loss 2.2752119223276774
# Round 2, cleint 3, epoch 1: epoch_accuracy 2.7488425925925926, epoch_loss 2.321781361544574
# Round 2, cleint 3, epoch 2: epoch_accuracy 2.488425925925926, epoch_loss 2.3203072547912598
# Round 2, cleint 3, epoch 3: epoch_accuracy 2.8356481481481484, epoch_loss 2.3196223223650896
# Round 2, cleint 3, epoch 4: epoch_accuracy 2.7199074074074074, epoch_loss 2.318868539951466
# Round 2, cleint 3, epoch 5: epoch_accuracy 2.8645833333333335, epoch_loss 2.3183385796017117
# Round 2, cleint 4, epoch 1: epoch_accuracy 4.21875, epoch_loss 2.318291346232096
# Round 2, cleint 4, epoch 2: epoch_accuracy 4.479166666666667, epoch_loss 2.318035364151001
# Round 2, cleint 4, epoch 3: epoch_accuracy 4.427083333333333, epoch_loss 2.317147143681844
# Round 2, cleint 4, epoch 4: epoch_accuracy 4.583333333333333, epoch_loss 2.3164216836293536
# Round 2, cleint 4, epoch 5: epoch_accuracy 4.53125, epoch_loss 2.316738478342692
# Round 2, cleint 5, epoch 1: epoch_accuracy 14.002403846153847, epoch_loss 2.2825746719653788
# Round 2, cleint 5, epoch 2: epoch_accuracy 14.242788461538462, epoch_loss 2.2823081566737247
# Round 2, cleint 5, epoch 3: epoch_accuracy 15.655048076923077, epoch_loss 2.2811139088410597
# Round 2, cleint 5, epoch 4: epoch_accuracy 16.58653846153846, epoch_loss 2.280421119469863
# Round 2, cleint 5, epoch 5: epoch_accuracy 17.1875, epoch_loss 2.279744716791006
# Round 2, cleint 6, epoch 1: epoch_accuracy 14.4921875, epoch_loss 2.3086543440818788
# Round 2, cleint 6, epoch 2: epoch_accuracy 15.0390625, epoch_loss 2.308002734184265
# Round 2, cleint 6, epoch 3: epoch_accuracy 15.4296875, epoch_loss 2.3074304819107057
# Round 2, cleint 6, epoch 4: epoch_accuracy 15.859375, epoch_loss 2.307166862487793
# Round 2, cleint 6, epoch 5: epoch_accuracy 16.4453125, epoch_loss 2.3063555002212524
# Round 2, cleint 7, epoch 1: epoch_accuracy 4.315476190476191, epoch_loss 2.3180499417441234
# Round 2, cleint 7, epoch 2: epoch_accuracy 4.427083333333333, epoch_loss 2.3175008183433894
# Round 2, cleint 7, epoch 3: epoch_accuracy 5.46875, epoch_loss 2.3160488605499268
# Round 2, cleint 7, epoch 4: epoch_accuracy 5.208333333333333, epoch_loss 2.3147966975257512
# Round 2, cleint 7, epoch 5: epoch_accuracy 5.729166666666667, epoch_loss 2.3131615547906783
# Round 2, cleint 8, epoch 1: epoch_accuracy 8.49609375, epoch_loss 2.2901488542556763
# Round 2, cleint 8, epoch 2: epoch_accuracy 8.740234375, epoch_loss 2.2887177765369415
# Round 2, cleint 8, epoch 3: epoch_accuracy 9.912109375, epoch_loss 2.287757471203804
# Round 2, cleint 8, epoch 4: epoch_accuracy 12.548828125, epoch_loss 2.2863483130931854
# Round 2, cleint 8, epoch 5: epoch_accuracy 13.916015625, epoch_loss 2.2848400473594666
# Round 2, cleint 9, epoch 1: epoch_accuracy 15.027573529411764, epoch_loss 2.29827057614046
# Round 2, cleint 9, epoch 2: epoch_accuracy 13.648897058823529, epoch_loss 2.29778790473938
# Round 2, cleint 9, epoch 3: epoch_accuracy 13.511029411764707, epoch_loss 2.2973133115207447
# Round 2, cleint 9, epoch 4: epoch_accuracy 14.705882352941176, epoch_loss 2.296353171853458
# Round 2, cleint 9, epoch 5: epoch_accuracy 13.970588235294118, epoch_loss 2.29638513396768
# Round 2, cleint 10, epoch 1: epoch_accuracy 2.0182291666666665, epoch_loss 2.322403291861216
# Round 2, cleint 10, epoch 2: epoch_accuracy 2.2786458333333335, epoch_loss 2.321893334388733
# Round 2, cleint 10, epoch 3: epoch_accuracy 2.7994791666666665, epoch_loss 2.3215012749036155
# Round 2, cleint 10, epoch 4: epoch_accuracy 2.4739583333333335, epoch_loss 2.3211482167243958
# Round 2, cleint 10, epoch 5: epoch_accuracy 2.0833333333333335, epoch_loss 2.3206227819124856
# Round 2, cleint 11, epoch 1: epoch_accuracy 6.09375, epoch_loss 2.31345534324646
# Round 2, cleint 11, epoch 2: epoch_accuracy 6.875, epoch_loss 2.313080835342407
# Round 2, cleint 11, epoch 3: epoch_accuracy 6.09375, epoch_loss 2.3122541904449463
# Round 2, cleint 11, epoch 4: epoch_accuracy 4.84375, epoch_loss 2.3140139102935793
# Round 2, cleint 11, epoch 5: epoch_accuracy 6.25, epoch_loss 2.3133809089660646
# Round 2, cleint 12, epoch 1: epoch_accuracy 5.681818181818182, epoch_loss 2.3122663497924805
# Round 2, cleint 12, epoch 2: epoch_accuracy 5.113636363636363, epoch_loss 2.310449708591808
# Round 2, cleint 12, epoch 3: epoch_accuracy 5.752840909090909, epoch_loss 2.3104455254294654
# Round 2, cleint 12, epoch 4: epoch_accuracy 5.184659090909091, epoch_loss 2.3093473477797075
# Round 2, cleint 12, epoch 5: epoch_accuracy 5.255681818181818, epoch_loss 2.309392820705067
# Round 2, cleint 13, epoch 1: epoch_accuracy 7.109375, epoch_loss 2.3048843145370483
# Round 2, cleint 13, epoch 2: epoch_accuracy 6.796875, epoch_loss 2.3067288637161254
# Round 2, cleint 13, epoch 3: epoch_accuracy 7.65625, epoch_loss 2.306096649169922
# Round 2, cleint 13, epoch 4: epoch_accuracy 6.171875, epoch_loss 2.3067980289459227
# Round 2, cleint 13, epoch 5: epoch_accuracy 8.046875, epoch_loss 2.3063381195068358
# Round 2, cleint 14, epoch 1: epoch_accuracy 11.414930555555555, epoch_loss 2.2941862609651356
# Round 2, cleint 14, epoch 2: epoch_accuracy 12.543402777777779, epoch_loss 2.29344234863917
# Round 2, cleint 14, epoch 3: epoch_accuracy 14.149305555555555, epoch_loss 2.2923814720577664
# Round 2, cleint 14, epoch 4: epoch_accuracy 13.25954861111111, epoch_loss 2.292191379600101
# Round 2, cleint 14, epoch 5: epoch_accuracy 14.366319444444445, epoch_loss 2.2912679579522877
# Round 2, cleint 15, epoch 1: epoch_accuracy 8.984375, epoch_loss 2.3033967188426425
# Round 2, cleint 15, epoch 2: epoch_accuracy 7.924107142857143, epoch_loss 2.302472404071263
# Round 2, cleint 15, epoch 3: epoch_accuracy 9.151785714285714, epoch_loss 2.3023633616311208
# Round 2, cleint 15, epoch 4: epoch_accuracy 10.993303571428571, epoch_loss 2.3014325073787143
# Round 2, cleint 15, epoch 5: epoch_accuracy 10.323660714285714, epoch_loss 2.3002542427607944
# Round 2, cleint 16, epoch 1: epoch_accuracy 24.588815789473685, epoch_loss 2.2799822154798006
# Round 2, cleint 16, epoch 2: epoch_accuracy 25.32894736842105, epoch_loss 2.277865924333271
# Round 2, cleint 16, epoch 3: epoch_accuracy 28.16611842105263, epoch_loss 2.276631154512104
# Round 2, cleint 16, epoch 4: epoch_accuracy 27.79605263157895, epoch_loss 2.2762316904569926
# Round 2, cleint 16, epoch 5: epoch_accuracy 29.893092105263158, epoch_loss 2.274526420392488
# Round 2, cleint 17, epoch 1: epoch_accuracy 8.229166666666666, epoch_loss 2.310747162501017
# Round 2, cleint 17, epoch 2: epoch_accuracy 7.760416666666667, epoch_loss 2.3107362588246665
# Round 2, cleint 17, epoch 3: epoch_accuracy 9.270833333333334, epoch_loss 2.3102087497711183
# Round 2, cleint 17, epoch 4: epoch_accuracy 8.59375, epoch_loss 2.3094029585520426
# Round 2, cleint 17, epoch 5: epoch_accuracy 7.96875, epoch_loss 2.3088088194529215
# Round 2, cleint 18, epoch 1: epoch_accuracy 18.75, epoch_loss 2.2843447796841887
# Round 2, cleint 18, epoch 2: epoch_accuracy 20.511968085106382, epoch_loss 2.283058318685978
# Round 2, cleint 18, epoch 3: epoch_accuracy 20.74468085106383, epoch_loss 2.281795806073128
# Round 2, cleint 18, epoch 4: epoch_accuracy 23.45412234042553, epoch_loss 2.2797366456782564
# Round 2, cleint 18, epoch 5: epoch_accuracy 23.96941489361702, epoch_loss 2.278466042051924
# Round 2, cleint 19, epoch 1: epoch_accuracy 8.90625, epoch_loss 2.3142208576202394
# Round 2, cleint 19, epoch 2: epoch_accuracy 9.0625, epoch_loss 2.3134682416915893
# Round 2, cleint 19, epoch 3: epoch_accuracy 8.671875, epoch_loss 2.3133748531341554
# Round 2, cleint 19, epoch 4: epoch_accuracy 9.296875, epoch_loss 2.3130253553390503
# Round 2, cleint 19, epoch 5: epoch_accuracy 8.671875, epoch_loss 2.312583804130554
# Round 2, cleint 20, epoch 1: epoch_accuracy 4.088541666666667, epoch_loss 2.3173729817072553
# Round 2, cleint 20, epoch 2: epoch_accuracy 3.9322916666666665, epoch_loss 2.316313362121582
# Round 2, cleint 20, epoch 3: epoch_accuracy 4.114583333333333, epoch_loss 2.3152945121129354
# Round 2, cleint 20, epoch 4: epoch_accuracy 4.270833333333333, epoch_loss 2.3139862219492593
# Round 2, cleint 20, epoch 5: epoch_accuracy 4.505208333333333, epoch_loss 2.3127575238545734
# Model's Round: 2, train accuracy of model: 11.658306350137646, train loss of model: 2.3009143911095515
#
#
# Model's Round: 2, test accuracy of model: 9.994009584664537, test loss of model: 2.3012246003927896
#
#
# Round 2 completed
# Round 3, cleint 1, epoch 1: epoch_accuracy 15.416666666666666, epoch_loss 2.2947043895721437
# Round 3, cleint 1, epoch 2: epoch_accuracy 15.833333333333334, epoch_loss 2.2955599149068195
# Round 3, cleint 1, epoch 3: epoch_accuracy 16.40625, epoch_loss 2.2937626520792644
# Round 3, cleint 1, epoch 4: epoch_accuracy 17.864583333333332, epoch_loss 2.293539269765218
# Round 3, cleint 1, epoch 5: epoch_accuracy 17.604166666666668, epoch_loss 2.2926528294881185
# Round 3, cleint 2, epoch 1: epoch_accuracy 2.65625, epoch_loss 2.2899447123209637
# Round 3, cleint 2, epoch 2: epoch_accuracy 3.9583333333333335, epoch_loss 2.287772544225057
# Round 3, cleint 2, epoch 3: epoch_accuracy 4.479166666666667, epoch_loss 2.2864391167958575
# Round 3, cleint 2, epoch 4: epoch_accuracy 4.583333333333333, epoch_loss 2.2865735212961833
# Round 3, cleint 2, epoch 5: epoch_accuracy 4.947916666666667, epoch_loss 2.2840541203816733
# Round 3, cleint 3, epoch 1: epoch_accuracy 2.980324074074074, epoch_loss 2.321660032978764
# Round 3, cleint 3, epoch 2: epoch_accuracy 3.443287037037037, epoch_loss 2.320703621263857
# Round 3, cleint 3, epoch 3: epoch_accuracy 2.980324074074074, epoch_loss 2.3197468916575112
# Round 3, cleint 3, epoch 4: epoch_accuracy 3.6168981481481484, epoch_loss 2.3185698721143932
# Round 3, cleint 3, epoch 5: epoch_accuracy 3.3854166666666665, epoch_loss 2.3188095092773438
# Round 3, cleint 4, epoch 1: epoch_accuracy 3.6458333333333335, epoch_loss 2.332047208150228
# Round 3, cleint 4, epoch 2: epoch_accuracy 4.010416666666667, epoch_loss 2.3318208853403726
# Round 3, cleint 4, epoch 3: epoch_accuracy 3.9583333333333335, epoch_loss 2.3304903666178385
# Round 3, cleint 4, epoch 4: epoch_accuracy 3.4375, epoch_loss 2.3305975437164306
# Round 3, cleint 4, epoch 5: epoch_accuracy 4.21875, epoch_loss 2.3310232480367024
# Round 3, cleint 5, epoch 1: epoch_accuracy 4.537259615384615, epoch_loss 2.2912913927665124
# Round 3, cleint 5, epoch 2: epoch_accuracy 4.597355769230769, epoch_loss 2.290056723814744
# Round 3, cleint 5, epoch 3: epoch_accuracy 5.1983173076923075, epoch_loss 2.289451479911804
# Round 3, cleint 5, epoch 4: epoch_accuracy 6.310096153846154, epoch_loss 2.287158654286311
# Round 3, cleint 5, epoch 5: epoch_accuracy 5.7391826923076925, epoch_loss 2.286042671937209
# Round 3, cleint 6, epoch 1: epoch_accuracy 18.0859375, epoch_loss 2.308796191215515
# Round 3, cleint 6, epoch 2: epoch_accuracy 18.75, epoch_loss 2.3081904292106628
# Round 3, cleint 6, epoch 3: epoch_accuracy 18.90625, epoch_loss 2.307426226139069
# Round 3, cleint 6, epoch 4: epoch_accuracy 18.59375, epoch_loss 2.3068762183189393
# Round 3, cleint 6, epoch 5: epoch_accuracy 19.0234375, epoch_loss 2.305550765991211
# Round 3, cleint 7, epoch 1: epoch_accuracy 1.6369047619047619, epoch_loss 2.3372242677779425
# Round 3, cleint 7, epoch 2: epoch_accuracy 1.0416666666666667, epoch_loss 2.336133525485084
# Round 3, cleint 7, epoch 3: epoch_accuracy 1.9345238095238095, epoch_loss 2.334051007316226
# Round 3, cleint 7, epoch 4: epoch_accuracy 1.8973214285714286, epoch_loss 2.3326825073787143
# Round 3, cleint 7, epoch 5: epoch_accuracy 2.1949404761904763, epoch_loss 2.3305567673274448
# Round 3, cleint 8, epoch 1: epoch_accuracy 9.423828125, epoch_loss 2.285743236541748
# Round 3, cleint 8, epoch 2: epoch_accuracy 9.86328125, epoch_loss 2.284171998500824
# Round 3, cleint 8, epoch 3: epoch_accuracy 10.546875, epoch_loss 2.2830024510622025
# Round 3, cleint 8, epoch 4: epoch_accuracy 10.107421875, epoch_loss 2.2812578231096268
# Round 3, cleint 8, epoch 5: epoch_accuracy 9.716796875, epoch_loss 2.2797392904758453
# Round 3, cleint 9, epoch 1: epoch_accuracy 10.202205882352942, epoch_loss 2.3006342018351837
# Round 3, cleint 9, epoch 2: epoch_accuracy 10.431985294117647, epoch_loss 2.3005252445445343
# Round 3, cleint 9, epoch 3: epoch_accuracy 10.018382352941176, epoch_loss 2.299482555950389
# Round 3, cleint 9, epoch 4: epoch_accuracy 10.891544117647058, epoch_loss 2.2992277706370636
# Round 3, cleint 9, epoch 5: epoch_accuracy 11.488970588235293, epoch_loss 2.2976682466619156
# Round 3, cleint 10, epoch 1: epoch_accuracy 4.296875, epoch_loss 2.324425677458445
# Round 3, cleint 10, epoch 2: epoch_accuracy 4.231770833333333, epoch_loss 2.323151429494222
# Round 3, cleint 10, epoch 3: epoch_accuracy 5.013020833333333, epoch_loss 2.3228553533554077
# Round 3, cleint 10, epoch 4: epoch_accuracy 4.1015625, epoch_loss 2.322817007700602
# Round 3, cleint 10, epoch 5: epoch_accuracy 4.8828125, epoch_loss 2.3223661184310913
# Round 3, cleint 11, epoch 1: epoch_accuracy 3.90625, epoch_loss 2.3296125888824464
# Round 3, cleint 11, epoch 2: epoch_accuracy 3.75, epoch_loss 2.3304679870605467
# Round 3, cleint 11, epoch 3: epoch_accuracy 5.3125, epoch_loss 2.3301884651184084
# Round 3, cleint 11, epoch 4: epoch_accuracy 5.15625, epoch_loss 2.3290256023406983
# Round 3, cleint 11, epoch 5: epoch_accuracy 4.84375, epoch_loss 2.329050397872925
# Round 3, cleint 12, epoch 1: epoch_accuracy 2.2017045454545454, epoch_loss 2.3251201672987505
# Round 3, cleint 12, epoch 2: epoch_accuracy 1.7755681818181819, epoch_loss 2.3231363079764624
# Round 3, cleint 12, epoch 3: epoch_accuracy 2.34375, epoch_loss 2.3220485773953525
# Round 3, cleint 12, epoch 4: epoch_accuracy 2.059659090909091, epoch_loss 2.3214398297396572
# Round 3, cleint 12, epoch 5: epoch_accuracy 2.9829545454545454, epoch_loss 2.3203307498585093
# Round 3, cleint 13, epoch 1: epoch_accuracy 7.96875, epoch_loss 2.3070970296859743
# Round 3, cleint 13, epoch 2: epoch_accuracy 7.1875, epoch_loss 2.3070669889450075
# Round 3, cleint 13, epoch 3: epoch_accuracy 7.96875, epoch_loss 2.3072211503982545
# Round 3, cleint 13, epoch 4: epoch_accuracy 7.578125, epoch_loss 2.306235337257385
# Round 3, cleint 13, epoch 5: epoch_accuracy 7.734375, epoch_loss 2.3064350843429566
# Round 3, cleint 14, epoch 1: epoch_accuracy 10.52517361111111, epoch_loss 2.2836057941118875
# Round 3, cleint 14, epoch 2: epoch_accuracy 11.436631944444445, epoch_loss 2.2817073000801935
# Round 3, cleint 14, epoch 3: epoch_accuracy 10.785590277777779, epoch_loss 2.2819060683250427
# Round 3, cleint 14, epoch 4: epoch_accuracy 11.458333333333334, epoch_loss 2.2802159123950534
# Round 3, cleint 14, epoch 5: epoch_accuracy 12.109375, epoch_loss 2.279608349005381
# Round 3, cleint 15, epoch 1: epoch_accuracy 1.2834821428571428, epoch_loss 2.319849814687456
# Round 3, cleint 15, epoch 2: epoch_accuracy 1.6183035714285714, epoch_loss 2.3193917274475098
# Round 3, cleint 15, epoch 3: epoch_accuracy 1.8973214285714286, epoch_loss 2.31743175642831
# Round 3, cleint 15, epoch 4: epoch_accuracy 1.6741071428571428, epoch_loss 2.3174681152616228
# Round 3, cleint 15, epoch 5: epoch_accuracy 1.2834821428571428, epoch_loss 2.3168280124664307
# Round 3, cleint 16, epoch 1: epoch_accuracy 34.33388157894737, epoch_loss 2.2564371008622017
# Round 3, cleint 16, epoch 2: epoch_accuracy 35.32072368421053, epoch_loss 2.2541052416751257
# Round 3, cleint 16, epoch 3: epoch_accuracy 36.55427631578947, epoch_loss 2.251897560922723
# Round 3, cleint 16, epoch 4: epoch_accuracy 35.608552631578945, epoch_loss 2.2520103203622917
# Round 3, cleint 16, epoch 5: epoch_accuracy 37.129934210526315, epoch_loss 2.2501042516607987
# Round 3, cleint 17, epoch 1: epoch_accuracy 5.520833333333333, epoch_loss 2.329272715250651
# Round 3, cleint 17, epoch 2: epoch_accuracy 6.25, epoch_loss 2.3275378227233885
# Round 3, cleint 17, epoch 3: epoch_accuracy 5.885416666666667, epoch_loss 2.327585236231486
# Round 3, cleint 17, epoch 4: epoch_accuracy 5.9375, epoch_loss 2.3260165055592856
# Round 3, cleint 17, epoch 5: epoch_accuracy 5.885416666666667, epoch_loss 2.3272120157877603
# Round 3, cleint 18, epoch 1: epoch_accuracy 26.62898936170213, epoch_loss 2.2621056729174676
# Round 3, cleint 18, epoch 2: epoch_accuracy 26.446143617021278, epoch_loss 2.2602623320640403
# Round 3, cleint 18, epoch 3: epoch_accuracy 25.88098404255319, epoch_loss 2.2589041882372918
# Round 3, cleint 18, epoch 4: epoch_accuracy 26.5625, epoch_loss 2.2570755430992615
# Round 3, cleint 18, epoch 5: epoch_accuracy 26.82845744680851, epoch_loss 2.255161554255384
# Round 3, cleint 19, epoch 1: epoch_accuracy 10.859375, epoch_loss 2.3188790559768675
# Round 3, cleint 19, epoch 2: epoch_accuracy 11.484375, epoch_loss 2.3197036504745485
# Round 3, cleint 19, epoch 3: epoch_accuracy 10.625, epoch_loss 2.3201100826263428
# Round 3, cleint 19, epoch 4: epoch_accuracy 11.015625, epoch_loss 2.318761706352234
# Round 3, cleint 19, epoch 5: epoch_accuracy 10.546875, epoch_loss 2.3182573318481445
# Round 3, cleint 20, epoch 1: epoch_accuracy 3.828125, epoch_loss 2.318981726964315
# Round 3, cleint 20, epoch 2: epoch_accuracy 4.427083333333333, epoch_loss 2.3175665378570556
# Round 3, cleint 20, epoch 3: epoch_accuracy 4.427083333333333, epoch_loss 2.3163086652755736
# Round 3, cleint 20, epoch 4: epoch_accuracy 4.739583333333333, epoch_loss 2.314235711097717
# Round 3, cleint 20, epoch 5: epoch_accuracy 5.052083333333333, epoch_loss 2.3134979486465452
# Model's Round: 3, train accuracy of model: 9.879954698868998, train loss of model: 2.3032474631876694
#
#
# Model's Round: 3, test accuracy of model: 9.994009584664537, test loss of model: 2.3005848075635136
#
#
# Round 3 completed
# Round 4, cleint 1, epoch 1: epoch_accuracy 15.260416666666666, epoch_loss 2.2898768901824953
# Round 4, cleint 1, epoch 2: epoch_accuracy 16.40625, epoch_loss 2.2899521668752034
# Round 4, cleint 1, epoch 3: epoch_accuracy 15.78125, epoch_loss 2.288622029622396
# Round 4, cleint 1, epoch 4: epoch_accuracy 15.677083333333334, epoch_loss 2.2894336223602294
# Round 4, cleint 1, epoch 5: epoch_accuracy 16.145833333333332, epoch_loss 2.28899401028951
# Round 4, cleint 2, epoch 1: epoch_accuracy 1.25, epoch_loss 2.3002760887145994
# Round 4, cleint 2, epoch 2: epoch_accuracy 1.09375, epoch_loss 2.2981903394063314
# Round 4, cleint 2, epoch 3: epoch_accuracy 1.1979166666666667, epoch_loss 2.2980637550354004
# Round 4, cleint 2, epoch 4: epoch_accuracy 1.1979166666666667, epoch_loss 2.294268274307251
# Round 4, cleint 2, epoch 5: epoch_accuracy 1.71875, epoch_loss 2.2931938648223875
# Round 4, cleint 3, epoch 1: epoch_accuracy 4.427083333333333, epoch_loss 2.32069515298914
# Round 4, cleint 3, epoch 2: epoch_accuracy 4.0219907407407405, epoch_loss 2.320708751678467
# Round 4, cleint 3, epoch 3: epoch_accuracy 4.774305555555555, epoch_loss 2.318884090141014
# Round 4, cleint 3, epoch 4: epoch_accuracy 4.62962962962963, epoch_loss 2.3196912076738148
# Round 4, cleint 3, epoch 5: epoch_accuracy 4.947916666666667, epoch_loss 2.3184296643292464
# Round 4, cleint 4, epoch 1: epoch_accuracy 3.90625, epoch_loss 2.344447199503581
# Round 4, cleint 4, epoch 2: epoch_accuracy 4.010416666666667, epoch_loss 2.3451422214508058
# Round 4, cleint 4, epoch 3: epoch_accuracy 4.114583333333333, epoch_loss 2.3430694103240968
# Round 4, cleint 4, epoch 4: epoch_accuracy 3.6458333333333335, epoch_loss 2.342993720372518
# Round 4, cleint 4, epoch 5: epoch_accuracy 4.0625, epoch_loss 2.342615540822347
# Round 4, cleint 5, epoch 1: epoch_accuracy 4.236778846153846, epoch_loss 2.2997925831721377
# Round 4, cleint 5, epoch 2: epoch_accuracy 4.5673076923076925, epoch_loss 2.297859971339886
# Round 4, cleint 5, epoch 3: epoch_accuracy 4.837740384615385, epoch_loss 2.297263585604154
# Round 4, cleint 5, epoch 4: epoch_accuracy 5.288461538461538, epoch_loss 2.294792028573843
# Round 4, cleint 5, epoch 5: epoch_accuracy 4.987980769230769, epoch_loss 2.292030545381399
# Round 4, cleint 6, epoch 1: epoch_accuracy 17.109375, epoch_loss 2.3089699149131775
# Round 4, cleint 6, epoch 2: epoch_accuracy 16.5625, epoch_loss 2.3086421966552733
# Round 4, cleint 6, epoch 3: epoch_accuracy 18.7109375, epoch_loss 2.3064374566078185
# Round 4, cleint 6, epoch 4: epoch_accuracy 17.734375, epoch_loss 2.305448818206787
# Round 4, cleint 6, epoch 5: epoch_accuracy 18.59375, epoch_loss 2.3036511898040772
# Round 4, cleint 7, epoch 1: epoch_accuracy 0.7440476190476191, epoch_loss 2.356459583554949
# Round 4, cleint 7, epoch 2: epoch_accuracy 0.9672619047619048, epoch_loss 2.3541189715975808
# Round 4, cleint 7, epoch 3: epoch_accuracy 1.0416666666666667, epoch_loss 2.3518822079613093
# Round 4, cleint 7, epoch 4: epoch_accuracy 1.0416666666666667, epoch_loss 2.3493789037068686
# Round 4, cleint 7, epoch 5: epoch_accuracy 1.0416666666666667, epoch_loss 2.348327091761998
# Round 4, cleint 8, epoch 1: epoch_accuracy 9.912109375, epoch_loss 2.2824635952711105
# Round 4, cleint 8, epoch 2: epoch_accuracy 9.9609375, epoch_loss 2.2804227471351624
# Round 4, cleint 8, epoch 3: epoch_accuracy 11.5234375, epoch_loss 2.2791297137737274
# Round 4, cleint 8, epoch 4: epoch_accuracy 10.15625, epoch_loss 2.2767232060432434
# Round 4, cleint 8, epoch 5: epoch_accuracy 10.498046875, epoch_loss 2.276838317513466
# Round 4, cleint 9, epoch 1: epoch_accuracy 9.145220588235293, epoch_loss 2.3045395542593563
# Round 4, cleint 9, epoch 2: epoch_accuracy 9.834558823529411, epoch_loss 2.3035188422483555
# Round 4, cleint 9, epoch 3: epoch_accuracy 9.972426470588236, epoch_loss 2.3012687178219067
# Round 4, cleint 9, epoch 4: epoch_accuracy 10.431985294117647, epoch_loss 2.3012715227463665
# Round 4, cleint 9, epoch 5: epoch_accuracy 9.788602941176471, epoch_loss 2.301338784834918
# Round 4, cleint 10, epoch 1: epoch_accuracy 5.533854166666667, epoch_loss 2.327554921309153
# Round 4, cleint 10, epoch 2: epoch_accuracy 5.143229166666667, epoch_loss 2.326617737611135
# Round 4, cleint 10, epoch 3: epoch_accuracy 6.705729166666667, epoch_loss 2.32365483045578
# Round 4, cleint 10, epoch 4: epoch_accuracy 4.427083333333333, epoch_loss 2.3255282839139304
# Round 4, cleint 10, epoch 5: epoch_accuracy 5.598958333333333, epoch_loss 2.3242112199465432
# Round 4, cleint 11, epoch 1: epoch_accuracy 3.75, epoch_loss 2.349437189102173
# Round 4, cleint 11, epoch 2: epoch_accuracy 5.625, epoch_loss 2.345020818710327
# Round 4, cleint 11, epoch 3: epoch_accuracy 4.0625, epoch_loss 2.3459388256072997
# Round 4, cleint 11, epoch 4: epoch_accuracy 2.8125, epoch_loss 2.345151090621948
# Round 4, cleint 11, epoch 5: epoch_accuracy 5.15625, epoch_loss 2.3460752964019775
# Round 4, cleint 12, epoch 1: epoch_accuracy 2.059659090909091, epoch_loss 2.338243766264482
# Round 4, cleint 12, epoch 2: epoch_accuracy 2.1306818181818183, epoch_loss 2.334455966949463
# Round 4, cleint 12, epoch 3: epoch_accuracy 1.9886363636363635, epoch_loss 2.3317623138427734
# Round 4, cleint 12, epoch 4: epoch_accuracy 2.272727272727273, epoch_loss 2.3311738100918857
# Round 4, cleint 12, epoch 5: epoch_accuracy 2.272727272727273, epoch_loss 2.331539652564309
# Round 4, cleint 13, epoch 1: epoch_accuracy 7.1875, epoch_loss 2.3098798513412477
# Round 4, cleint 13, epoch 2: epoch_accuracy 8.28125, epoch_loss 2.3092395067214966
# Round 4, cleint 13, epoch 3: epoch_accuracy 7.8125, epoch_loss 2.309412956237793
# Round 4, cleint 13, epoch 4: epoch_accuracy 7.65625, epoch_loss 2.307918334007263
# Round 4, cleint 13, epoch 5: epoch_accuracy 7.5, epoch_loss 2.3083204507827757
# Round 4, cleint 14, epoch 1: epoch_accuracy 10.7421875, epoch_loss 2.2743726041581898
# Round 4, cleint 14, epoch 2: epoch_accuracy 11.024305555555555, epoch_loss 2.2731641928354898
# Round 4, cleint 14, epoch 3: epoch_accuracy 10.872395833333334, epoch_loss 2.2726425197389393
# Round 4, cleint 14, epoch 4: epoch_accuracy 11.393229166666666, epoch_loss 2.271657837761773
# Round 4, cleint 14, epoch 5: epoch_accuracy 11.653645833333334, epoch_loss 2.271136608388689
# Round 4, cleint 15, epoch 1: epoch_accuracy 1.8973214285714286, epoch_loss 2.335173010826111
# Round 4, cleint 15, epoch 2: epoch_accuracy 1.953125, epoch_loss 2.336311970438276
# Round 4, cleint 15, epoch 3: epoch_accuracy 1.7299107142857142, epoch_loss 2.332169839314052
# Round 4, cleint 15, epoch 4: epoch_accuracy 1.2834821428571428, epoch_loss 2.3314826829092845
# Round 4, cleint 15, epoch 5: epoch_accuracy 1.6183035714285714, epoch_loss 2.3309339455195834
# Round 4, cleint 16, epoch 1: epoch_accuracy 35.89638157894737, epoch_loss 2.2334128555498625
# Round 4, cleint 16, epoch 2: epoch_accuracy 35.15625, epoch_loss 2.2329282133202804
# Round 4, cleint 16, epoch 3: epoch_accuracy 35.69078947368421, epoch_loss 2.2310598649476705
# Round 4, cleint 16, epoch 4: epoch_accuracy 37.29440789473684, epoch_loss 2.228644433774446
# Round 4, cleint 16, epoch 5: epoch_accuracy 38.1578947368421, epoch_loss 2.2272117137908936
# Round 4, cleint 17, epoch 1: epoch_accuracy 5.572916666666667, epoch_loss 2.3443021615346273
# Round 4, cleint 17, epoch 2: epoch_accuracy 5.052083333333333, epoch_loss 2.3452643553415933
# Round 4, cleint 17, epoch 3: epoch_accuracy 5.15625, epoch_loss 2.342776807149251
# Round 4, cleint 17, epoch 4: epoch_accuracy 5.416666666666667, epoch_loss 2.343215004603068
# Round 4, cleint 17, epoch 5: epoch_accuracy 5.208333333333333, epoch_loss 2.342316404978434
# Round 4, cleint 18, epoch 1: epoch_accuracy 26.1469414893617, epoch_loss 2.2410362578452903
# Round 4, cleint 18, epoch 2: epoch_accuracy 26.84507978723404, epoch_loss 2.2390512912831406
# Round 4, cleint 18, epoch 3: epoch_accuracy 26.961436170212767, epoch_loss 2.236849084813544
# Round 4, cleint 18, epoch 4: epoch_accuracy 26.878324468085108, epoch_loss 2.234319321652676
# Round 4, cleint 18, epoch 5: epoch_accuracy 27.227393617021278, epoch_loss 2.2326043768131987
# Round 4, cleint 19, epoch 1: epoch_accuracy 11.09375, epoch_loss 2.325702261924744
# Round 4, cleint 19, epoch 2: epoch_accuracy 11.71875, epoch_loss 2.325018072128296
# Round 4, cleint 19, epoch 3: epoch_accuracy 12.265625, epoch_loss 2.3240575790405273
# Round 4, cleint 19, epoch 4: epoch_accuracy 11.5625, epoch_loss 2.322661519050598
# Round 4, cleint 19, epoch 5: epoch_accuracy 10.78125, epoch_loss 2.324299669265747
# Round 4, cleint 20, epoch 1: epoch_accuracy 5.078125, epoch_loss 2.3205667893091837
# Round 4, cleint 20, epoch 2: epoch_accuracy 4.661458333333333, epoch_loss 2.3175374984741213
# Round 4, cleint 20, epoch 3: epoch_accuracy 5.182291666666667, epoch_loss 2.3168990214665732
# Round 4, cleint 20, epoch 4: epoch_accuracy 6.380208333333333, epoch_loss 2.3143813769022623
# Round 4, cleint 20, epoch 5: epoch_accuracy 6.197916666666667, epoch_loss 2.313948694864909
# Model's Round: 4, train accuracy of model: 9.65788603083799, train loss of model: 2.3059008521438207
#
#
# Model's Round: 4, test accuracy of model: 10.213658146964857, test loss of model: 2.299852458813701
#
#
# Round 4 completed
# Round 5, cleint 1, epoch 1: epoch_accuracy 15.260416666666666, epoch_loss 2.285704819361369
# Round 5, cleint 1, epoch 2: epoch_accuracy 15.78125, epoch_loss 2.2839095910390217
# Round 5, cleint 1, epoch 3: epoch_accuracy 16.770833333333332, epoch_loss 2.2842615922292073
# Round 5, cleint 1, epoch 4: epoch_accuracy 16.979166666666668, epoch_loss 2.284375206629435
# Round 5, cleint 1, epoch 5: epoch_accuracy 16.666666666666668, epoch_loss 2.2844117164611815
# Round 5, cleint 2, epoch 1: epoch_accuracy 1.0416666666666667, epoch_loss 2.309499406814575
# Round 5, cleint 2, epoch 2: epoch_accuracy 1.09375, epoch_loss 2.308674764633179
# Round 5, cleint 2, epoch 3: epoch_accuracy 1.25, epoch_loss 2.3068705876668294
# Round 5, cleint 2, epoch 4: epoch_accuracy 1.3541666666666667, epoch_loss 2.3065247535705566
# Round 5, cleint 2, epoch 5: epoch_accuracy 0.8854166666666666, epoch_loss 2.3021271387736
# Round 5, cleint 3, epoch 1: epoch_accuracy 4.74537037037037, epoch_loss 2.322007497151693
# Round 5, cleint 3, epoch 2: epoch_accuracy 4.62962962962963, epoch_loss 2.3195452248608626
# Round 5, cleint 3, epoch 3: epoch_accuracy 4.282407407407407, epoch_loss 2.3188094474651195
# Round 5, cleint 3, epoch 4: epoch_accuracy 4.832175925925926, epoch_loss 2.317495663960775
# Round 5, cleint 3, epoch 5: epoch_accuracy 4.861111111111111, epoch_loss 2.3161349914692066
# Round 5, cleint 4, epoch 1: epoch_accuracy 4.166666666666667, epoch_loss 2.356156333287557
# Round 5, cleint 4, epoch 2: epoch_accuracy 4.322916666666667, epoch_loss 2.356067689259847
# Round 5, cleint 4, epoch 3: epoch_accuracy 3.3333333333333335, epoch_loss 2.354792515436808
# Round 5, cleint 4, epoch 4: epoch_accuracy 4.53125, epoch_loss 2.3532113234202066
# Round 5, cleint 4, epoch 5: epoch_accuracy 4.0625, epoch_loss 2.3522444566090903
# Round 5, cleint 5, epoch 1: epoch_accuracy 4.627403846153846, epoch_loss 2.3068386499698343
# Round 5, cleint 5, epoch 2: epoch_accuracy 4.597355769230769, epoch_loss 2.305679733936603
# Round 5, cleint 5, epoch 3: epoch_accuracy 4.507211538461538, epoch_loss 2.303725141745347
# Round 5, cleint 5, epoch 4: epoch_accuracy 4.4170673076923075, epoch_loss 2.302632212638855
# Round 5, cleint 5, epoch 5: epoch_accuracy 4.9579326923076925, epoch_loss 2.300435176262489
# Round 5, cleint 6, epoch 1: epoch_accuracy 18.0859375, epoch_loss 2.3071800231933595
# Round 5, cleint 6, epoch 2: epoch_accuracy 17.03125, epoch_loss 2.306604266166687
# Round 5, cleint 6, epoch 3: epoch_accuracy 16.875, epoch_loss 2.3059205770492555
# Round 5, cleint 6, epoch 4: epoch_accuracy 17.890625, epoch_loss 2.3048880815505983
# Round 5, cleint 6, epoch 5: epoch_accuracy 18.9453125, epoch_loss 2.302280938625336
# Round 5, cleint 7, epoch 1: epoch_accuracy 0.8928571428571429, epoch_loss 2.3735562846774148
# Round 5, cleint 7, epoch 2: epoch_accuracy 0.78125, epoch_loss 2.37027603104001
# Round 5, cleint 7, epoch 3: epoch_accuracy 0.7068452380952381, epoch_loss 2.368950503213065
# Round 5, cleint 7, epoch 4: epoch_accuracy 0.5208333333333334, epoch_loss 2.3661129020509266
# Round 5, cleint 7, epoch 5: epoch_accuracy 1.1160714285714286, epoch_loss 2.362418015797933
# Round 5, cleint 8, epoch 1: epoch_accuracy 10.791015625, epoch_loss 2.278871402144432
# Round 5, cleint 8, epoch 2: epoch_accuracy 10.791015625, epoch_loss 2.2775783985853195
# Round 5, cleint 8, epoch 3: epoch_accuracy 10.83984375, epoch_loss 2.2754963487386703
# Round 5, cleint 8, epoch 4: epoch_accuracy 11.03515625, epoch_loss 2.2728295773267746
# Round 5, cleint 8, epoch 5: epoch_accuracy 11.181640625, epoch_loss 2.2708270251750946
# Round 5, cleint 9, epoch 1: epoch_accuracy 9.145220588235293, epoch_loss 2.3079436105840347
# Round 5, cleint 9, epoch 2: epoch_accuracy 9.834558823529411, epoch_loss 2.3052737993352554
# Round 5, cleint 9, epoch 3: epoch_accuracy 9.788602941176471, epoch_loss 2.3060668777017033
# Round 5, cleint 9, epoch 4: epoch_accuracy 9.053308823529411, epoch_loss 2.3051691616282746
# Round 5, cleint 9, epoch 5: epoch_accuracy 9.466911764705882, epoch_loss 2.304751718745512
# Round 5, cleint 10, epoch 1: epoch_accuracy 6.119791666666667, epoch_loss 2.328102429707845
# Round 5, cleint 10, epoch 2: epoch_accuracy 6.770833333333333, epoch_loss 2.328447937965393
# Round 5, cleint 10, epoch 3: epoch_accuracy 6.25, epoch_loss 2.3280548254648843
# Round 5, cleint 10, epoch 4: epoch_accuracy 5.6640625, epoch_loss 2.326431612173716
# Round 5, cleint 10, epoch 5: epoch_accuracy 7.03125, epoch_loss 2.3235061963399253
# Round 5, cleint 11, epoch 1: epoch_accuracy 4.84375, epoch_loss 2.356967639923096
# Round 5, cleint 11, epoch 2: epoch_accuracy 4.0625, epoch_loss 2.36227707862854
# Round 5, cleint 11, epoch 3: epoch_accuracy 3.75, epoch_loss 2.359086036682129
# Round 5, cleint 11, epoch 4: epoch_accuracy 3.75, epoch_loss 2.358359527587891
# Round 5, cleint 11, epoch 5: epoch_accuracy 3.4375, epoch_loss 2.3576990604400634
# Round 5, cleint 12, epoch 1: epoch_accuracy 2.4857954545454546, epoch_loss 2.3457262732765893
# Round 5, cleint 12, epoch 2: epoch_accuracy 2.4857954545454546, epoch_loss 2.342940027063543
# Round 5, cleint 12, epoch 3: epoch_accuracy 2.272727272727273, epoch_loss 2.3417731631885874
# Round 5, cleint 12, epoch 4: epoch_accuracy 1.9176136363636365, epoch_loss 2.3405769521539863
# Round 5, cleint 12, epoch 5: epoch_accuracy 1.9886363636363635, epoch_loss 2.339916554364291
# Round 5, cleint 13, epoch 1: epoch_accuracy 8.28125, epoch_loss 2.309740734100342
# Round 5, cleint 13, epoch 2: epoch_accuracy 8.984375, epoch_loss 2.310443663597107
# Round 5, cleint 13, epoch 3: epoch_accuracy 9.0625, epoch_loss 2.3095941066741945
# Round 5, cleint 13, epoch 4: epoch_accuracy 8.4375, epoch_loss 2.30985803604126
# Round 5, cleint 13, epoch 5: epoch_accuracy 7.8125, epoch_loss 2.3084245204925535
# Round 5, cleint 14, epoch 1: epoch_accuracy 10.807291666666666, epoch_loss 2.2685349583625793
# Round 5, cleint 14, epoch 2: epoch_accuracy 11.610243055555555, epoch_loss 2.2658105227682324
# Round 5, cleint 14, epoch 3: epoch_accuracy 12.152777777777779, epoch_loss 2.265556216239929
# Round 5, cleint 14, epoch 4: epoch_accuracy 11.783854166666666, epoch_loss 2.264450920952691
# Round 5, cleint 14, epoch 5: epoch_accuracy 12.586805555555555, epoch_loss 2.2624694572554693
# Round 5, cleint 15, epoch 1: epoch_accuracy 1.2834821428571428, epoch_loss 2.3478667054857527
# Round 5, cleint 15, epoch 2: epoch_accuracy 1.953125, epoch_loss 2.3480024337768555
# Round 5, cleint 15, epoch 3: epoch_accuracy 1.5066964285714286, epoch_loss 2.3463938406535556
# Round 5, cleint 15, epoch 4: epoch_accuracy 1.6741071428571428, epoch_loss 2.343976753098624
# Round 5, cleint 15, epoch 5: epoch_accuracy 1.5066964285714286, epoch_loss 2.3430648701531545
# Round 5, cleint 16, epoch 1: epoch_accuracy 36.10197368421053, epoch_loss 2.2160340108369527
# Round 5, cleint 16, epoch 2: epoch_accuracy 35.608552631578945, epoch_loss 2.2145719151747856
# Round 5, cleint 16, epoch 3: epoch_accuracy 37.129934210526315, epoch_loss 2.2126501359437643
# Round 5, cleint 16, epoch 4: epoch_accuracy 36.71875, epoch_loss 2.210260842975817
# Round 5, cleint 16, epoch 5: epoch_accuracy 37.3766447368421, epoch_loss 2.2080317923897193
# Round 5, cleint 17, epoch 1: epoch_accuracy 5.104166666666667, epoch_loss 2.359154446919759
# Round 5, cleint 17, epoch 2: epoch_accuracy 4.635416666666667, epoch_loss 2.359053595860799
# Round 5, cleint 17, epoch 3: epoch_accuracy 5.260416666666667, epoch_loss 2.3593924840291343
# Round 5, cleint 17, epoch 4: epoch_accuracy 5.520833333333333, epoch_loss 2.358317502339681
# Round 5, cleint 17, epoch 5: epoch_accuracy 5.052083333333333, epoch_loss 2.35611310005188
# Round 5, cleint 18, epoch 1: epoch_accuracy 26.47938829787234, epoch_loss 2.2234030936626676
# Round 5, cleint 18, epoch 2: epoch_accuracy 26.66223404255319, epoch_loss 2.2212724533486874
# Round 5, cleint 18, epoch 3: epoch_accuracy 26.72872340425532, epoch_loss 2.2181004108266626
# Round 5, cleint 18, epoch 4: epoch_accuracy 26.878324468085108, epoch_loss 2.215429351684895
# Round 5, cleint 18, epoch 5: epoch_accuracy 27.293882978723403, epoch_loss 2.2121531811166317
# Round 5, cleint 19, epoch 1: epoch_accuracy 11.5625, epoch_loss 2.3291574001312254
# Round 5, cleint 19, epoch 2: epoch_accuracy 11.40625, epoch_loss 2.328001856803894
# Round 5, cleint 19, epoch 3: epoch_accuracy 11.328125, epoch_loss 2.327048921585083
# Round 5, cleint 19, epoch 4: epoch_accuracy 12.890625, epoch_loss 2.325659084320068
# Round 5, cleint 19, epoch 5: epoch_accuracy 12.03125, epoch_loss 2.3246802568435667
# Round 5, cleint 20, epoch 1: epoch_accuracy 4.84375, epoch_loss 2.320010471343994
# Round 5, cleint 20, epoch 2: epoch_accuracy 5.651041666666667, epoch_loss 2.31755629380544
# Round 5, cleint 20, epoch 3: epoch_accuracy 5.625, epoch_loss 2.3170271078745523
# Round 5, cleint 20, epoch 4: epoch_accuracy 6.197916666666667, epoch_loss 2.315144642194112
# Round 5, cleint 20, epoch 5: epoch_accuracy 7.473958333333333, epoch_loss 2.312024148305257
# Model's Round: 5, train accuracy of model: 9.786738559251248, train loss of model: 2.3071857157835978
#
#
# Model's Round: 5, test accuracy of model: 10.64297124600639, test loss of model: 2.299017131519013
#
#
# Round 5 completed
# Round 6, cleint 1, epoch 1: epoch_accuracy 16.302083333333332, epoch_loss 2.280149968465169
# Round 6, cleint 1, epoch 2: epoch_accuracy 15.3125, epoch_loss 2.281126038233439
# Round 6, cleint 1, epoch 3: epoch_accuracy 16.354166666666668, epoch_loss 2.2811683177948
# Round 6, cleint 1, epoch 4: epoch_accuracy 15.46875, epoch_loss 2.2811729113260903
# Round 6, cleint 1, epoch 5: epoch_accuracy 16.770833333333332, epoch_loss 2.2802989641825357
# Round 6, cleint 2, epoch 1: epoch_accuracy 1.09375, epoch_loss 2.3198721408843994
# Round 6, cleint 2, epoch 2: epoch_accuracy 0.8854166666666666, epoch_loss 2.3174304485321047
# Round 6, cleint 2, epoch 3: epoch_accuracy 1.1458333333333333, epoch_loss 2.314448928833008
# Round 6, cleint 2, epoch 4: epoch_accuracy 1.4583333333333333, epoch_loss 2.314371601740519
# Round 6, cleint 2, epoch 5: epoch_accuracy 0.9375, epoch_loss 2.3106016635894777
# Round 6, cleint 3, epoch 1: epoch_accuracy 4.542824074074074, epoch_loss 2.320628634205571
# Round 6, cleint 3, epoch 2: epoch_accuracy 4.658564814814815, epoch_loss 2.319837976385046
# Round 6, cleint 3, epoch 3: epoch_accuracy 5.960648148148148, epoch_loss 2.3171860376993814
# Round 6, cleint 3, epoch 4: epoch_accuracy 4.8032407407407405, epoch_loss 2.316705067952474
# Round 6, cleint 3, epoch 5: epoch_accuracy 6.105324074074074, epoch_loss 2.3149914564909757
# Round 6, cleint 4, epoch 1: epoch_accuracy 4.010416666666667, epoch_loss 2.364552640914917
# Round 6, cleint 4, epoch 2: epoch_accuracy 4.322916666666667, epoch_loss 2.365381940205892
# Round 6, cleint 4, epoch 3: epoch_accuracy 4.84375, epoch_loss 2.3630547523498535
# Round 6, cleint 4, epoch 4: epoch_accuracy 3.8020833333333335, epoch_loss 2.3643181641896565
# Round 6, cleint 4, epoch 5: epoch_accuracy 3.75, epoch_loss 2.362525796890259
# Round 6, cleint 5, epoch 1: epoch_accuracy 4.146634615384615, epoch_loss 2.3151251077651978
# ...
# Round 29, cleint 7, epoch 1: epoch_accuracy 6.175595238095238, epoch_loss 2.3416796071188792
# Round 29, cleint 7, epoch 2: epoch_accuracy 6.361607142857143, epoch_loss 2.3271534783499583
# Round 29, cleint 7, epoch 3: epoch_accuracy 6.436011904761905, epoch_loss 2.312847932179769
# Round 29, cleint 7, epoch 4: epoch_accuracy 7.254464285714286, epoch_loss 2.2955999147324335
# Round 29, cleint 7, epoch 5: epoch_accuracy 6.845238095238095, epoch_loss 2.2819710686093284
# Round 29, cleint 8, epoch 1: epoch_accuracy 17.724609375, epoch_loss 2.1585008949041367
# Round 29, cleint 8, epoch 2: epoch_accuracy 18.45703125, epoch_loss 2.149315670132637
# Round 29, cleint 8, epoch 3: epoch_accuracy 21.923828125, epoch_loss 2.130090221762657
# Round 29, cleint 8, epoch 4: epoch_accuracy 21.142578125, epoch_loss 2.1244371831417084
# Round 29, cleint 8, epoch 5: epoch_accuracy 23.33984375, epoch_loss 2.1125709414482117
# Round 29, cleint 9, epoch 1: epoch_accuracy 12.454044117647058, epoch_loss 2.26069676174837
# Round 29, cleint 9, epoch 2: epoch_accuracy 12.637867647058824, epoch_loss 2.258032335954554
# Round 29, cleint 9, epoch 3: epoch_accuracy 12.959558823529411, epoch_loss 2.2525067189160515
# Round 29, cleint 9, epoch 4: epoch_accuracy 14.154411764705882, epoch_loss 2.2416524326100067
# Round 29, cleint 9, epoch 5: epoch_accuracy 13.419117647058824, epoch_loss 2.2432093199561622
# Round 29, cleint 10, epoch 1: epoch_accuracy 24.869791666666668, epoch_loss 2.2199610273043313
# Round 29, cleint 10, epoch 2: epoch_accuracy 26.497395833333332, epoch_loss 2.21342404683431
# Round 29, cleint 10, epoch 3: epoch_accuracy 26.627604166666668, epoch_loss 2.2049983541170755
# Round 29, cleint 10, epoch 4: epoch_accuracy 28.059895833333332, epoch_loss 2.197991132736206
# Round 29, cleint 10, epoch 5: epoch_accuracy 28.3203125, epoch_loss 2.1861631870269775
# Round 29, cleint 11, epoch 1: epoch_accuracy 7.5, epoch_loss 2.313228130340576
# Round 29, cleint 11, epoch 2: epoch_accuracy 7.03125, epoch_loss 2.31146183013916
# Round 29, cleint 11, epoch 3: epoch_accuracy 6.5625, epoch_loss 2.310008192062378
# Round 29, cleint 11, epoch 4: epoch_accuracy 7.5, epoch_loss 2.3096285820007325
# Round 29, cleint 11, epoch 5: epoch_accuracy 6.71875, epoch_loss 2.3025386333465576
# Round 29, cleint 12, epoch 1: epoch_accuracy 4.900568181818182, epoch_loss 2.2725342403758657
# Round 29, cleint 12, epoch 2: epoch_accuracy 5.042613636363637, epoch_loss 2.2703759887001733
# Round 29, cleint 12, epoch 3: epoch_accuracy 5.894886363636363, epoch_loss 2.250313867222179
# Round 29, cleint 12, epoch 4: epoch_accuracy 6.392045454545454, epoch_loss 2.2442397421056572
# Round 29, cleint 12, epoch 5: epoch_accuracy 6.747159090909091, epoch_loss 2.2279809604991567
# Round 29, cleint 13, epoch 1: epoch_accuracy 23.28125, epoch_loss 2.216568112373352
# Round 29, cleint 13, epoch 2: epoch_accuracy 21.71875, epoch_loss 2.212789273262024
# Round 29, cleint 13, epoch 3: epoch_accuracy 20.9375, epoch_loss 2.2135645389556884
# Round 29, cleint 13, epoch 4: epoch_accuracy 22.890625, epoch_loss 2.2113657236099242
# Round 29, cleint 13, epoch 5: epoch_accuracy 21.640625, epoch_loss 2.2124187707901
# Round 29, cleint 14, epoch 1: epoch_accuracy 23.4375, epoch_loss 2.173825866646237
# Round 29, cleint 14, epoch 2: epoch_accuracy 23.524305555555557, epoch_loss 2.1663056876924305
# Round 29, cleint 14, epoch 3: epoch_accuracy 24.153645833333332, epoch_loss 2.1617903643184238
# Round 29, cleint 14, epoch 4: epoch_accuracy 23.719618055555557, epoch_loss 2.1582920021480985
# Round 29, cleint 14, epoch 5: epoch_accuracy 25.43402777777778, epoch_loss 2.150588552157084
# Round 29, cleint 15, epoch 1: epoch_accuracy 5.357142857142857, epoch_loss 2.3332315513065884
# Round 29, cleint 15, epoch 2: epoch_accuracy 5.524553571428571, epoch_loss 2.320697511945452
# Round 29, cleint 15, epoch 3: epoch_accuracy 6.138392857142857, epoch_loss 2.3171184233256747
# Round 29, cleint 15, epoch 4: epoch_accuracy 5.691964285714286, epoch_loss 2.2973405803952898
# Round 29, cleint 15, epoch 5: epoch_accuracy 5.301339285714286, epoch_loss 2.286654455321176
# Round 29, cleint 16, epoch 1: epoch_accuracy 35.85526315789474, epoch_loss 2.0833078183625875
# Round 29, cleint 16, epoch 2: epoch_accuracy 37.58223684210526, epoch_loss 2.071229570790341
# Round 29, cleint 16, epoch 3: epoch_accuracy 39.88486842105263, epoch_loss 2.059610417014674
# Round 29, cleint 16, epoch 4: epoch_accuracy 42.96875, epoch_loss 2.038978570385983
# Round 29, cleint 16, epoch 5: epoch_accuracy 43.95559210526316, epoch_loss 2.029500572304977
# Round 29, cleint 17, epoch 1: epoch_accuracy 7.604166666666667, epoch_loss 2.335350672403971
# Round 29, cleint 17, epoch 2: epoch_accuracy 7.65625, epoch_loss 2.3323686758677167
# Round 29, cleint 17, epoch 3: epoch_accuracy 7.760416666666667, epoch_loss 2.325270748138428
# Round 29, cleint 17, epoch 4: epoch_accuracy 7.864583333333333, epoch_loss 2.316893720626831
# Round 29, cleint 17, epoch 5: epoch_accuracy 8.489583333333334, epoch_loss 2.3127029577891034
# Round 29, cleint 18, epoch 1: epoch_accuracy 38.2313829787234, epoch_loss 2.0608325207487064
# Round 29, cleint 18, epoch 2: epoch_accuracy 37.849069148936174, epoch_loss 2.0477227936399744
# Round 29, cleint 18, epoch 3: epoch_accuracy 38.77992021276596, epoch_loss 2.031299644328178
# Round 29, cleint 18, epoch 4: epoch_accuracy 38.2313829787234, epoch_loss 2.0148250752307
# Round 29, cleint 18, epoch 5: epoch_accuracy 38.746675531914896, epoch_loss 1.9987146600763848
# Round 29, cleint 19, epoch 1: epoch_accuracy 13.203125, epoch_loss 2.252403903007507
# Round 29, cleint 19, epoch 2: epoch_accuracy 13.90625, epoch_loss 2.253722095489502
# Round 29, cleint 19, epoch 3: epoch_accuracy 15.390625, epoch_loss 2.2436296224594114
# Round 29, cleint 19, epoch 4: epoch_accuracy 15.078125, epoch_loss 2.2362424612045286
# Round 29, cleint 19, epoch 5: epoch_accuracy 13.984375, epoch_loss 2.2371252298355104
# Round 29, cleint 20, epoch 1: epoch_accuracy 21.328125, epoch_loss 2.213494865099589
# Round 29, cleint 20, epoch 2: epoch_accuracy 22.369791666666668, epoch_loss 2.1979311386744182
# Round 29, cleint 20, epoch 3: epoch_accuracy 22.942708333333332, epoch_loss 2.185040275255839
# Round 29, cleint 20, epoch 4: epoch_accuracy 24.348958333333332, epoch_loss 2.1720017274220784
# Round 29, cleint 20, epoch 5: epoch_accuracy 25.234375, epoch_loss 2.1624173482259113
# Model's Round: 29, train accuracy of model: 18.526950777085545, train loss of model: 2.2026134766293555
#
#
# Model's Round: 29, test accuracy of model: 21.236022364217252, test loss of model: 2.206865945944009
#
#
# Round 29 completed
# Round 30, cleint 1, epoch 1: epoch_accuracy 23.489583333333332, epoch_loss 2.16773575146993
# Round 30, cleint 1, epoch 2: epoch_accuracy 25.260416666666668, epoch_loss 2.1615055720011394
# Round 30, cleint 1, epoch 3: epoch_accuracy 25.052083333333332, epoch_loss 2.155824327468872
# Round 30, cleint 1, epoch 4: epoch_accuracy 24.947916666666668, epoch_loss 2.1564613342285157
# Round 30, cleint 1, epoch 5: epoch_accuracy 25.208333333333332, epoch_loss 2.1554393927256266
# Round 30, cleint 2, epoch 1: epoch_accuracy 3.125, epoch_loss 2.3044986883799234
# Round 30, cleint 2, epoch 2: epoch_accuracy 3.5416666666666665, epoch_loss 2.2945196628570557
# Round 30, cleint 2, epoch 3: epoch_accuracy 4.0625, epoch_loss 2.2822352250417075
# Round 30, cleint 2, epoch 4: epoch_accuracy 4.895833333333333, epoch_loss 2.2714905897776285
# Round 30, cleint 2, epoch 5: epoch_accuracy 5.208333333333333, epoch_loss 2.2637344201405845
# Round 30, cleint 3, epoch 1: epoch_accuracy 23.408564814814813, epoch_loss 2.197060973555953
# Round 30, cleint 3, epoch 2: epoch_accuracy 24.16087962962963, epoch_loss 2.1886692488635027
# Round 30, cleint 3, epoch 3: epoch_accuracy 24.421296296296298, epoch_loss 2.17859066857232
# Round 30, cleint 3, epoch 4: epoch_accuracy 25.23148148148148, epoch_loss 2.1703404585520425
# Round 30, cleint 3, epoch 5: epoch_accuracy 25.318287037037038, epoch_loss 2.1679377997363054
# Round 30, cleint 4, epoch 1: epoch_accuracy 16.145833333333332, epoch_loss 2.279375505447388
# Round 30, cleint 4, epoch 2: epoch_accuracy 14.84375, epoch_loss 2.273241949081421
# Round 30, cleint 4, epoch 3: epoch_accuracy 17.083333333333332, epoch_loss 2.260663890838623
# Round 30, cleint 4, epoch 4: epoch_accuracy 15.833333333333334, epoch_loss 2.2610771020253497
# Round 30, cleint 4, epoch 5: epoch_accuracy 16.5625, epoch_loss 2.255173174540202
# Round 30, cleint 5, epoch 1: epoch_accuracy 6.310096153846154, epoch_loss 2.2820058969350963
# Round 30, cleint 5, epoch 2: epoch_accuracy 7.091346153846154, epoch_loss 2.269739710367643
# Round 30, cleint 5, epoch 3: epoch_accuracy 8.29326923076923, epoch_loss 2.2582702269920936
# Round 30, cleint 5, epoch 4: epoch_accuracy 8.653846153846153, epoch_loss 2.2478418258520274
# Round 30, cleint 5, epoch 5: epoch_accuracy 9.615384615384615, epoch_loss 2.2360878540919376
# Round 30, cleint 6, epoch 1: epoch_accuracy 21.3671875, epoch_loss 2.2087208151817324
# Round 30, cleint 6, epoch 2: epoch_accuracy 21.953125, epoch_loss 2.2053689479827883
# Round 30, cleint 6, epoch 3: epoch_accuracy 22.3828125, epoch_loss 2.196144962310791
# Round 30, cleint 6, epoch 4: epoch_accuracy 23.90625, epoch_loss 2.189185678958893
# Round 30, cleint 6, epoch 5: epoch_accuracy 24.140625, epoch_loss 2.1841177701950074
# Round 30, cleint 7, epoch 1: epoch_accuracy 6.659226190476191, epoch_loss 2.337383497328985
# Round 30, cleint 7, epoch 2: epoch_accuracy 7.03125, epoch_loss 2.3159034819830033
# Round 30, cleint 7, epoch 3: epoch_accuracy 7.254464285714286, epoch_loss 2.3040515922364735
# Round 30, cleint 7, epoch 4: epoch_accuracy 7.291666666666667, epoch_loss 2.2838056541624523
# Round 30, cleint 7, epoch 5: epoch_accuracy 7.477678571428571, epoch_loss 2.2698166710989818
# Round 30, cleint 8, epoch 1: epoch_accuracy 18.408203125, epoch_loss 2.1500523686408997
# Round 30, cleint 8, epoch 2: epoch_accuracy 19.677734375, epoch_loss 2.1357687562704086
# Round 30, cleint 8, epoch 3: epoch_accuracy 21.728515625, epoch_loss 2.124933138489723
# Round 30, cleint 8, epoch 4: epoch_accuracy 23.53515625, epoch_loss 2.1130480021238327
# Round 30, cleint 8, epoch 5: epoch_accuracy 27.001953125, epoch_loss 2.099760890007019
# Round 30, cleint 9, epoch 1: epoch_accuracy 12.270220588235293, epoch_loss 2.260954870897181
# Round 30, cleint 9, epoch 2: epoch_accuracy 13.832720588235293, epoch_loss 2.2526386906118954
# Round 30, cleint 9, epoch 3: epoch_accuracy 12.959558823529411, epoch_loss 2.2453420442693375
# Round 30, cleint 9, epoch 4: epoch_accuracy 13.786764705882353, epoch_loss 2.2395787098828484
# Round 30, cleint 9, epoch 5: epoch_accuracy 14.705882352941176, epoch_loss 2.231849992976469
# Round 30, cleint 10, epoch 1: epoch_accuracy 25.651041666666668, epoch_loss 2.209662059942881
# Round 30, cleint 10, epoch 2: epoch_accuracy 26.5625, epoch_loss 2.204598824183146
# Round 30, cleint 10, epoch 3: epoch_accuracy 28.776041666666668, epoch_loss 2.198614994684855
# Round 30, cleint 10, epoch 4: epoch_accuracy 28.125, epoch_loss 2.1909119884173074
# Round 30, cleint 10, epoch 5: epoch_accuracy 29.557291666666668, epoch_loss 2.1824661095937095
# Round 30, cleint 11, epoch 1: epoch_accuracy 7.8125, epoch_loss 2.3061511516571045
# Round 30, cleint 11, epoch 2: epoch_accuracy 6.875, epoch_loss 2.3088499546051025
# Round 30, cleint 11, epoch 3: epoch_accuracy 8.28125, epoch_loss 2.306975221633911
# Round 30, cleint 11, epoch 4: epoch_accuracy 7.03125, epoch_loss 2.3005489349365233
# Round 30, cleint 11, epoch 5: epoch_accuracy 5.9375, epoch_loss 2.3137587547302245
# Round 30, cleint 12, epoch 1: epoch_accuracy 5.610795454545454, epoch_loss 2.265028108250011
# Round 30, cleint 12, epoch 2: epoch_accuracy 5.681818181818182, epoch_loss 2.250005982138894
# Round 30, cleint 12, epoch 3: epoch_accuracy 6.676136363636363, epoch_loss 2.2408345612612637
# Round 30, cleint 12, epoch 4: epoch_accuracy 6.676136363636363, epoch_loss 2.2390022494576196
# Round 30, cleint 12, epoch 5: epoch_accuracy 7.386363636363637, epoch_loss 2.2246948372234
# Round 30, cleint 13, epoch 1: epoch_accuracy 21.875, epoch_loss 2.2083092451095583
# Round 30, cleint 13, epoch 2: epoch_accuracy 21.328125, epoch_loss 2.2069015979766844
# Round 30, cleint 13, epoch 3: epoch_accuracy 23.75, epoch_loss 2.2012086391448973
# Round 30, cleint 13, epoch 4: epoch_accuracy 23.125, epoch_loss 2.2011246919631957
# Round 30, cleint 13, epoch 5: epoch_accuracy 21.796875, epoch_loss 2.198470950126648
# Round 30, cleint 14, epoch 1: epoch_accuracy 23.6328125, epoch_loss 2.1705996725294323
# Round 30, cleint 14, epoch 2: epoch_accuracy 24.39236111111111, epoch_loss 2.1640144652790494
# Round 30, cleint 14, epoch 3: epoch_accuracy 25.086805555555557, epoch_loss 2.155336790614658
# Round 30, cleint 14, epoch 4: epoch_accuracy 25.108506944444443, epoch_loss 2.1493818958600364
# Round 30, cleint 14, epoch 5: epoch_accuracy 24.95659722222222, epoch_loss 2.142322580019633
# Round 30, cleint 15, epoch 1: epoch_accuracy 5.357142857142857, epoch_loss 2.32611038003649
# Round 30, cleint 15, epoch 2: epoch_accuracy 5.915178571428571, epoch_loss 2.315065622329712
# Round 30, cleint 15, epoch 3: epoch_accuracy 6.361607142857143, epoch_loss 2.301866786820548
# Round 30, cleint 15, epoch 4: epoch_accuracy 6.138392857142857, epoch_loss 2.2940866265978133
# Round 30, cleint 15, epoch 5: epoch_accuracy 6.584821428571429, epoch_loss 2.276671154158456
# Round 30, cleint 16, epoch 1: epoch_accuracy 35.11513157894737, epoch_loss 2.081926007019846
# Round 30, cleint 16, epoch 2: epoch_accuracy 38.52796052631579, epoch_loss 2.0696724465018823
# Round 30, cleint 16, epoch 3: epoch_accuracy 39.1858552631579, epoch_loss 2.0530058333748267
# Round 30, cleint 16, epoch 4: epoch_accuracy 41.32401315789474, epoch_loss 2.033813765174464
# Round 30, cleint 16, epoch 5: epoch_accuracy 44.53125, epoch_loss 2.0206044033954016
# Round 30, cleint 17, epoch 1: epoch_accuracy 7.8125, epoch_loss 2.335264730453491
# Round 30, cleint 17, epoch 2: epoch_accuracy 8.4375, epoch_loss 2.3221874872843427
# Round 30, cleint 17, epoch 3: epoch_accuracy 8.177083333333334, epoch_loss 2.3148955504099527
# Round 30, cleint 17, epoch 4: epoch_accuracy 7.864583333333333, epoch_loss 2.312552642822266
# Round 30, cleint 17, epoch 5: epoch_accuracy 8.958333333333334, epoch_loss 2.305554469426473
# Round 30, cleint 18, epoch 1: epoch_accuracy 38.630319148936174, epoch_loss 2.0582670861102166
# Round 30, cleint 18, epoch 2: epoch_accuracy 37.78257978723404, epoch_loss 2.0417174253057926
# Round 30, cleint 18, epoch 3: epoch_accuracy 37.5498670212766, epoch_loss 2.02748567500013
# Round 30, cleint 18, epoch 4: epoch_accuracy 38.430851063829785, epoch_loss 2.007439372387338
# Round 30, cleint 18, epoch 5: epoch_accuracy 38.89627659574468, epoch_loss 1.991200530782659
# Round 30, cleint 19, epoch 1: epoch_accuracy 14.609375, epoch_loss 2.251291799545288
# Round 30, cleint 19, epoch 2: epoch_accuracy 13.671875, epoch_loss 2.240611124038696
# Round 30, cleint 19, epoch 3: epoch_accuracy 13.4375, epoch_loss 2.240478539466858
# Round 30, cleint 19, epoch 4: epoch_accuracy 14.84375, epoch_loss 2.236975336074829
# Round 30, cleint 19, epoch 5: epoch_accuracy 14.765625, epoch_loss 2.2295607566833495
# Round 30, cleint 20, epoch 1: epoch_accuracy 22.057291666666668, epoch_loss 2.204442087809245
# Round 30, cleint 20, epoch 2: epoch_accuracy 22.1875, epoch_loss 2.188916794459025
# Round 30, cleint 20, epoch 3: epoch_accuracy 23.984375, epoch_loss 2.178677479426066
# Round 30, cleint 20, epoch 4: epoch_accuracy 25.0, epoch_loss 2.1649763584136963
# Round 30, cleint 20, epoch 5: epoch_accuracy 25.807291666666668, epoch_loss 2.1521944204966226
# Model's Round: 30, train accuracy of model: 19.220860145901334, train loss of model: 2.1950708466074356
#
#
# Model's Round: 30, test accuracy of model: 21.615415335463258, test loss of model: 2.201134283321734
#
#
# Round 30 completed

# %% [markdown]
# # Reuslts

# %%
# Define the folder and file name
folder_name = f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"


# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
folder_name =  f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
