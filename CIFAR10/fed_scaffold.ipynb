# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# from sklearn.metrics import confusion_matrix
from torchvision.datasets import CIFAR10
from collections import Counter
import random
import copy
import torch.nn.functional as F
import os
import sys
import time
import pickle
import pandas as pd
from torch import Tensor
from typing import Type
import torchvision.models as models
from torchvision import transforms

# Set font family for plots
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# <H1>Load Dataset</H1>

# %%
# transform = transforms.Compose([
#     transforms.ToTensor(), #This transformation converts a PIL (Python Imaging Library) Image or numpy.ndarray (with shape (H x W x C) in the range [0, 255]) into a PyTorch tensor of shape (C x H x W) in the range [0.0, 1.0]. It essentially rearranges the dimensions of the image data and scales it to a float value between 0 and 1.
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])


# train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# # train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

subset_dataset = torch.load('val_dataset.pth',weights_only=False)
remaining_dataset = torch.load('test_dataset.pth',weights_only=False)

# Create DataLoaders
val_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(remaining_dataset, batch_size=32, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <H1>IID</H1>

# %%
def distribute_dataset_equally(dataset, num_clients):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    # Distribute data
    client_data = [[] for _ in range(num_clients)]
    for label, data in class_data.items():
        data_len = len(data)
        base_size = data_len // num_clients
        remain = data_len - base_size * num_clients

        current_idx = 0
        for i in range(num_clients):
            end_idx = current_idx + base_size + (1 if i < remain else 0)
            client_data[i].extend(data[current_idx:end_idx])
            current_idx = end_idx


    print_iid_distribution(client_data)
    plot_iid_dataset(client_data,num_clients)

    return client_data

# %%
#print client iid_data distribution
def print_iid_distribution(iid_datasets):
    # Check if the distribution is correct
    for i, client_data in enumerate(iid_datasets):
        print(f"Client {i + 1} data size: {len(client_data)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# Plot client iid_data distribution
def plot_iid_dataset(iid_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in iid_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define colors for each class
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")
    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number',labelpad=5)
    ax.set_ylabel('CIFAR-10 Classes',labelpad=15)
    ax.set_zlabel('Fraction of Distribution',labelpad=5)
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], rotation=45)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names, rotation=-60)

    #ax.view_init(elev=40, azim=60)
    ax.view_init(elev=40, azim=10)

    plt.subplots_adjust(left=0.01, right=0.99, bottom=0.01, top=0.99)

    plt.show()

# %% [markdown]
# <H1>non-IID</H1>

# %%
#Print the distribution non IID
def print_distribution(client_data):
    # Check distribution
    for l, client_data_value in enumerate(client_data):
        print(f"Client {l + 1} data size: {len(client_data_value)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data_value:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# #Non IID code
def distribute_dataset_dirichlet(dataset, num_clients, alpha):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    client_data = [[] for _ in range(num_clients)]
    for _, data_list in class_data.items():
        # Shuffle data for randomness
        np.random.shuffle(data_list)

        # Get proportions for data split based on Dirichlet distribution
        proportions = np.random.dirichlet([alpha]*num_clients)
        # print("Proportions: ", proportions)
        total_data = len(data_list)
        # print("total_data: ", total_data)
        data_splits = [int(proportions[i]*total_data) for i in range(num_clients)]
        # print("Data_Split: ", data_splits)

        # Adjust the splits to account for rounding errors
        # print("Before data_split:",data_splits)
        data_splits[-1] += total_data - sum(data_splits)
        print("After data_split:",data_splits)

        start_idx = 0
        for i, split in enumerate(data_splits):
            end_idx = start_idx + split
            client_data[i].extend(data_list[start_idx:end_idx])
            start_idx = end_idx
    print("Client Number: ",num_clients, "Alpha: ", alpha)
    print_distribution(client_data)
    plot_distribution(client_data, num_clients )
    return client_data

# %%
#show the graphs for nonIID
def plot_distribution(client_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in client_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        # print(total_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define distinct colors for classes using a colormap
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # # Generate the 3D bar chart
    # fig = plt.figure(figsize=(18, 12))
    # ax = fig.add_subplot(111, projection='3d')

    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")

    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number')
    ax.set_ylabel('CIFAR-10 Classes')
    ax.set_zlabel('Fraction of Distribution')
    ax.set_title('Distribution of CIFAR-10 Classes across Clients based on Dirichlet Distribution')
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], fontsize=12)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)
        
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Change output to 10 for CIFAR-10 classes

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Train

# %%
def average_weights_function(dicts):
    # Initialize an empty dictionary to store the summed weights
    summed_weights = {}
    
    # Initialize an empty dictionary to keep track of how many times each key is seen
    key_occurrences = {}
    
    # Iterate through all the dictionaries
    for d in dicts:
        for key, value in d.items():
            if key in summed_weights:
                summed_weights[key] += value
                key_occurrences[key] += 1
            else:
                summed_weights[key] = value
                key_occurrences[key] = 1
    
    # Create a dictionary to store the final averaged weights
    averaged_weights = {}
    
    # Iterate through the summed weights and divide by the number of occurrences for each key
    for key, value in summed_weights.items():
        if key_occurrences[key] > 1:
            averaged_weights[key] = value / key_occurrences[key]
        else:
            averaged_weights[key] = value  # If only present in one dict, keep as is
    
    return averaged_weights

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag, ci,c):
    global opti
    
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    # Initialize local model with the global model weights
    yi = {k: v.clone().float().to(device) for k, v in i_weights.items()}
    # Ensure control variates are float
    ci = {k: v.float().to(device) for k, v in ci.items()}
    c = {k: v.float().to(device) for k, v in c.items()}
    
    # Adjust gradients with control variate (c - ci)
    with torch.no_grad():  # Ensure no gradient tracking for this operation
        for k in local_model.state_dict().keys():
            param = local_model.state_dict()[k].float()
            local_model.state_dict()[k] = param - (ci[k] - c[k])

    local_model.train()  # Set the model to training mode

    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        print(f"Round {roun}, cleint {cli+1}, epoch {epoch+1}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")
    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    #print(f"\n Round {roun}, cleint {cli}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    
    
    epoch_rmd=model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data

    # Update client control variate ci using Option II
    new_ci = {
        k: ci[k] - c[k] + (1 / (epochs * le_rate)) * (i_weights[k].float() - f_weights[k])
        for k in ci.keys()
    }
    return epoch_accuracy,epoch_loss, f_weights, epoch_flag, new_ci

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()  # Assuming a classification task
    #optimizer = torch.optim.SGD(lmodel.parameters(), lr=learning_rate)
    lmodel.load_state_dict(w)
    lmodel.eval()

    #checking the weights
    tw = lmodel.state_dict()
    #Print("Model's before testing the weights in global model",tw)

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    #print("Model's Test accuracy : {:.2f}%".format(test_accuracy))
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_clients_list, participating_client_list
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)

    c_list = {k: torch.zeros_like(v, dtype=torch.float).to(device) for k, v in i_w.items()}  # Initialize global control variate to zero
    ci_list = [{k: torch.zeros_like(v, dtype=torch.float).to(device) for k, v in i_w.items()} for _ in range(C)]  # Initialize client control variates to zero

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        models = []

        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        all_final_weights={}
        train_accuracy_list=[]
        train_loss_list=[]
        
        # Randomly select clients
        selected_clients = random.sample(total_clients_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                
                c_i = ci_list[c] 
                
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
                #train model
                train_accuracy, train_loss, c_f_weights, epoch_flag, new_ci = train(i_w, E, train_loader, learning_rate, c, r,epoch_flag, c_i, c_list)

                models.append( c_f_weights)

                ci_list[c] = new_ci

                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)

                # Accumulate weights for the selected client
                #for param_name, param_grad in c_f_weights.items():
                    #if param_name in all_final_weights:
                        #all_final_weights[param_name] += param_grad
                    #else:
                        #all_final_weights[param_name] = param_grad

            else:
                print(f"client {c+1} is not selectecd")
                
        all_final_weights = average_weights_function(models)
        
        round_epoch=(epoch_flag)

        for k in c_list.keys():
            # Convert to float before summing and assigning
            ci_sum = sum([ci_list[n_no][k].float() for n_no in range(C)])
            c_list[k] += (1 / C) * ci_sum
        
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)

        print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

        #for param_name in all_final_weights:
            #all_final_weights[param_name] = all_final_weights[param_name].float() / len(selected_clients)

        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

        #model deviation code
        round_rmd=model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)

        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
        round_results.loc[len(round_results)] = round_data
            
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=20
participating_client=20
epochs=5
learning_rate=0.0001
round_no=30
batch_size=128
distributions = "non_iid" # 'non_iid'
data_class=10
alpha=0.5
opti="sgd" # or SGD

method="fed_scaffold"

# List of clients
total_clients_list = list(range(0, client_no))
# print(total_cleints_list)
participating_client_list=[]

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

#===================================loading the saved weight list====================================================
global_model = model().to(device)
# initial_weights={k: v.clone() for k, v in global_model.state_dict().items()}
# Save the initial weights
file_path = "s_cnn.pth"
# torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=True)
Print("Model's initial weights", initial_weights)
# Out:
# Model's initial weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')

# %% [markdown]
# <H1>Divide data among cleints</H1>

# %%
# #=================================loading IID data===========================
# if distributions == 'iid':
#     client_datasets = distribute_dataset_equally(train_dataset,client_no)
    
# elif distributions == 'non_iid':
#     client_datasets = distribute_dataset_dirichlet(train_dataset, client_no, alpha)
# else:
#     print("provide a valid distribution Please")

# %%
# # Save client_datasets to a file
# if distributions == 'iid':
#     with open('client_datasets_IID.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.5:
#     with open('client_datasets_non_IID_0_5.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.125:
#     with open('client_datasets_non_IID_0_125.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)

# print("client_datasets saved successfully.")

# %%
# Load client_datasets from a file
if distributions == 'iid':
    with open('20_client_datasets_IID.pkl', 'rb') as f:
        client_datasets = pickle.load(f)

elif distributions == 'non_iid' and alpha==0.5:
    with open('20_client_datasets_non_IID_0_5.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
    
elif distributions == 'non_iid' and alpha==0.125:
    with open('20_client_datasets_non_IID_0_125.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
        
print("client_datasets loaded successfully.")
print_distribution(client_datasets)
# Out:
# client_datasets loaded successfully.
# Client 1 data size: 1928
# Class distribution: {0: 93, 1: 405, 2: 144, 3: 3, 4: 342, 5: 365, 6: 25, 7: 64, 8: 248, 9: 239}
# Client 2 data size: 1997
# Class distribution: {0: 38, 1: 0, 2: 921, 3: 588, 4: 14, 5: 9, 6: 58, 7: 51, 8: 11, 9: 307}
# Client 3 data size: 3557
# Class distribution: {0: 849, 1: 41, 2: 2, 3: 208, 4: 645, 5: 640, 6: 853, 7: 151, 8: 20, 9: 148}
# Client 4 data size: 1954
# Class distribution: {0: 369, 1: 91, 2: 9, 3: 135, 4: 108, 5: 65, 6: 267, 7: 30, 8: 673, 9: 207}
# Client 5 data size: 3332
# Class distribution: {0: 25, 1: 0, 2: 866, 3: 1163, 4: 6, 5: 194, 6: 13, 7: 375, 8: 61, 9: 629}
# Client 6 data size: 2673
# Class distribution: {0: 241, 1: 643, 2: 161, 3: 26, 4: 2, 5: 861, 6: 65, 7: 182, 8: 462, 9: 30}
# Client 7 data size: 2750
# Class distribution: {0: 161, 1: 0, 2: 503, 3: 26, 4: 184, 5: 443, 6: 6, 7: 6, 8: 1412, 9: 9}
# Client 8 data size: 2071
# Class distribution: {0: 217, 1: 128, 2: 136, 3: 37, 4: 20, 5: 19, 6: 42, 7: 371, 8: 37, 9: 1064}
# Client 9 data size: 2185
# Class distribution: {0: 0, 1: 286, 2: 426, 3: 441, 4: 223, 5: 651, 6: 5, 7: 23, 8: 107, 9: 23}
# Client 10 data size: 1544
# Class distribution: {0: 602, 1: 10, 2: 2, 3: 16, 4: 91, 5: 47, 6: 299, 7: 192, 8: 255, 9: 30}
# Client 11 data size: 681
# Class distribution: {0: 2, 1: 43, 2: 1, 3: 75, 4: 26, 5: 75, 6: 101, 7: 1, 8: 205, 9: 152}
# Client 12 data size: 1524
# Class distribution: {0: 10, 1: 2, 2: 79, 3: 142, 4: 1, 5: 6, 6: 670, 7: 90, 8: 1, 9: 523}
# Client 13 data size: 1346
# Class distribution: {0: 281, 1: 82, 2: 8, 3: 208, 4: 116, 5: 206, 6: 5, 7: 128, 8: 158, 9: 154}
# Client 14 data size: 4708
# Class distribution: {0: 596, 1: 249, 2: 1220, 3: 246, 4: 932, 5: 595, 6: 18, 7: 717, 8: 33, 9: 102}
# Client 15 data size: 1893
# Class distribution: {0: 30, 1: 9, 2: 65, 3: 842, 4: 145, 5: 0, 6: 605, 7: 34, 8: 64, 9: 99}
# Client 16 data size: 2479
# Class distribution: {0: 0, 1: 924, 2: 71, 3: 176, 4: 10, 5: 259, 6: 54, 7: 897, 8: 0, 9: 88}
# Client 17 data size: 2031
# Class distribution: {0: 78, 1: 165, 2: 14, 3: 412, 4: 10, 5: 397, 6: 69, 7: 1, 8: 643, 9: 242}
# Client 18 data size: 6129
# Class distribution: {0: 673, 1: 1721, 2: 41, 3: 127, 4: 1129, 5: 118, 6: 29, 7: 1383, 8: 100, 9: 808}
# Client 19 data size: 1348
# Class distribution: {0: 70, 1: 153, 2: 1, 3: 96, 4: 46, 5: 35, 6: 541, 7: 159, 8: 139, 9: 108}
# Client 20 data size: 3870
# Class distribution: {0: 665, 1: 48, 2: 330, 3: 33, 4: 950, 5: 15, 6: 1275, 7: 145, 8: 371, 9: 38}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for cleints
round_train_accuracy=0
round_train_loss=0

train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True, drop_last=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
round_results.loc[len(round_results)] = round_data

Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')
#
#  train accuracy: 11.202316706095846
#  train_loss: 2.300268226845141
#  test_accuracy: 10.013977635782748
#  test_loss: 2.3027472800720994

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
# Round 1, cleint 1, epoch 1: epoch_accuracy 1.9270833333333333, epoch_loss 2.3075278759002686
# Round 1, cleint 1, epoch 2: epoch_accuracy 2.1354166666666665, epoch_loss 2.3073696454366046
# Round 1, cleint 1, epoch 3: epoch_accuracy 1.8229166666666667, epoch_loss 2.3071299393971763
# Round 1, cleint 1, epoch 4: epoch_accuracy 1.6145833333333333, epoch_loss 2.306867520014445
# Round 1, cleint 1, epoch 5: epoch_accuracy 1.6666666666666667, epoch_loss 2.3066601276397707
# Round 1, cleint 2, epoch 1: epoch_accuracy 28.958333333333332, epoch_loss 2.2672160466512046
# Round 1, cleint 2, epoch 2: epoch_accuracy 29.739583333333332, epoch_loss 2.265491278966268
# Round 1, cleint 2, epoch 3: epoch_accuracy 30.104166666666668, epoch_loss 2.2653316974639894
# Round 1, cleint 2, epoch 4: epoch_accuracy 30.416666666666668, epoch_loss 2.264072545369466
# Round 1, cleint 2, epoch 5: epoch_accuracy 30.15625, epoch_loss 2.2639458815256757
# Round 1, cleint 3, epoch 1: epoch_accuracy 5.3530092592592595, epoch_loss 2.3205680405652083
# Round 1, cleint 3, epoch 2: epoch_accuracy 5.005787037037037, epoch_loss 2.321106610474763
# Round 1, cleint 3, epoch 3: epoch_accuracy 5.092592592592593, epoch_loss 2.3198533058166504
# Round 1, cleint 3, epoch 4: epoch_accuracy 5.092592592592593, epoch_loss 2.3194418836522988
# Round 1, cleint 3, epoch 5: epoch_accuracy 5.034722222222222, epoch_loss 2.319293675599275
# Round 1, cleint 4, epoch 1: epoch_accuracy 7.291666666666667, epoch_loss 2.3006566842397054
# Round 1, cleint 4, epoch 2: epoch_accuracy 6.666666666666667, epoch_loss 2.300867033004761
# Round 1, cleint 4, epoch 3: epoch_accuracy 6.71875, epoch_loss 2.300751066207886
# Round 1, cleint 4, epoch 4: epoch_accuracy 6.666666666666667, epoch_loss 2.2997265497843427
# Round 1, cleint 4, epoch 5: epoch_accuracy 7.5, epoch_loss 2.298869514465332
# Round 1, cleint 5, epoch 1: epoch_accuracy 33.05288461538461, epoch_loss 2.2727291859113254
# Round 1, cleint 5, epoch 2: epoch_accuracy 33.05288461538461, epoch_loss 2.2715209814218373
# Round 1, cleint 5, epoch 3: epoch_accuracy 33.56370192307692, epoch_loss 2.270560521345872
# Round 1, cleint 5, epoch 4: epoch_accuracy 32.09134615384615, epoch_loss 2.2698905559686513
# Round 1, cleint 5, epoch 5: epoch_accuracy 33.17307692307692, epoch_loss 2.2686216556108914
# Round 1, cleint 6, epoch 1: epoch_accuracy 2.0703125, epoch_loss 2.3091815233230593
# Round 1, cleint 6, epoch 2: epoch_accuracy 1.7578125, epoch_loss 2.3083447217941284
# Round 1, cleint 6, epoch 3: epoch_accuracy 1.7578125, epoch_loss 2.3082045793533323
# Round 1, cleint 6, epoch 4: epoch_accuracy 2.3046875, epoch_loss 2.306996190547943
# Round 1, cleint 6, epoch 5: epoch_accuracy 2.03125, epoch_loss 2.30732798576355
# Round 1, cleint 7, epoch 1: epoch_accuracy 3.7574404761904763, epoch_loss 2.2941323461986722
# Round 1, cleint 7, epoch 2: epoch_accuracy 4.427083333333333, epoch_loss 2.2924056393759593
# Round 1, cleint 7, epoch 3: epoch_accuracy 4.352678571428571, epoch_loss 2.291447571345738
# Round 1, cleint 7, epoch 4: epoch_accuracy 5.282738095238095, epoch_loss 2.289659397942679
# Round 1, cleint 7, epoch 5: epoch_accuracy 5.989583333333333, epoch_loss 2.2886501720973422
# Round 1, cleint 8, epoch 1: epoch_accuracy 5.078125, epoch_loss 2.296973407268524
# Round 1, cleint 8, epoch 2: epoch_accuracy 5.37109375, epoch_loss 2.2962902784347534
# Round 1, cleint 8, epoch 3: epoch_accuracy 5.6640625, epoch_loss 2.29505056142807
# Round 1, cleint 8, epoch 4: epoch_accuracy 6.25, epoch_loss 2.294251263141632
# Round 1, cleint 8, epoch 5: epoch_accuracy 8.0078125, epoch_loss 2.2927364259958267
# Round 1, cleint 9, epoch 1: epoch_accuracy 19.347426470588236, epoch_loss 2.292762321584365
# Round 1, cleint 9, epoch 2: epoch_accuracy 19.11764705882353, epoch_loss 2.291612274506513
# Round 1, cleint 9, epoch 3: epoch_accuracy 19.16360294117647, epoch_loss 2.2913164531483368
# Round 1, cleint 9, epoch 4: epoch_accuracy 19.485294117647058, epoch_loss 2.2911962761598477
# Round 1, cleint 9, epoch 5: epoch_accuracy 19.347426470588236, epoch_loss 2.2906531586366543
# Round 1, cleint 10, epoch 1: epoch_accuracy 1.5625, epoch_loss 2.3223618070284524
# Round 1, cleint 10, epoch 2: epoch_accuracy 1.0416666666666667, epoch_loss 2.3221062223116555
# Round 1, cleint 10, epoch 3: epoch_accuracy 1.2369791666666667, epoch_loss 2.321946064631144
# Round 1, cleint 10, epoch 4: epoch_accuracy 1.3671875, epoch_loss 2.320798953374227
# Round 1, cleint 10, epoch 5: epoch_accuracy 1.4322916666666667, epoch_loss 2.32062820593516
# Round 1, cleint 11, epoch 1: epoch_accuracy 10.15625, epoch_loss 2.2903332233428957
# Round 1, cleint 11, epoch 2: epoch_accuracy 9.84375, epoch_loss 2.2907993316650392
# Round 1, cleint 11, epoch 3: epoch_accuracy 11.5625, epoch_loss 2.290543556213379
# Round 1, cleint 11, epoch 4: epoch_accuracy 12.03125, epoch_loss 2.2889984130859373
# Round 1, cleint 11, epoch 5: epoch_accuracy 10.9375, epoch_loss 2.2897902488708497
# Round 1, cleint 12, epoch 1: epoch_accuracy 9.446022727272727, epoch_loss 2.2954623699188232
# Round 1, cleint 12, epoch 2: epoch_accuracy 9.730113636363637, epoch_loss 2.2944514101201836
# Round 1, cleint 12, epoch 3: epoch_accuracy 10.440340909090908, epoch_loss 2.294164462523027
# Round 1, cleint 12, epoch 4: epoch_accuracy 10.511363636363637, epoch_loss 2.2940543348138984
# Round 1, cleint 12, epoch 5: epoch_accuracy 11.008522727272727, epoch_loss 2.2928523150357334
# Round 1, cleint 13, epoch 1: epoch_accuracy 13.359375, epoch_loss 2.305814790725708
# Round 1, cleint 13, epoch 2: epoch_accuracy 13.515625, epoch_loss 2.3046658277511596
# Round 1, cleint 13, epoch 3: epoch_accuracy 13.59375, epoch_loss 2.3047324657440185
# Round 1, cleint 13, epoch 4: epoch_accuracy 13.59375, epoch_loss 2.304630756378174
# Round 1, cleint 13, epoch 5: epoch_accuracy 14.21875, epoch_loss 2.3049543857574464
# Round 1, cleint 14, epoch 1: epoch_accuracy 6.597222222222222, epoch_loss 2.3095092640982733
# Round 1, cleint 14, epoch 2: epoch_accuracy 7.747395833333333, epoch_loss 2.308691097630395
# Round 1, cleint 14, epoch 3: epoch_accuracy 8.441840277777779, epoch_loss 2.3079773518774243
# Round 1, cleint 14, epoch 4: epoch_accuracy 8.984375, epoch_loss 2.3069757885403104
# Round 1, cleint 14, epoch 5: epoch_accuracy 9.114583333333334, epoch_loss 2.306568556361728
# Round 1, cleint 15, epoch 1: epoch_accuracy 38.895089285714285, epoch_loss 2.27972902570452
# Round 1, cleint 15, epoch 2: epoch_accuracy 37.779017857142854, epoch_loss 2.2795827388763428
# Round 1, cleint 15, epoch 3: epoch_accuracy 38.22544642857143, epoch_loss 2.278957486152649
# Round 1, cleint 15, epoch 4: epoch_accuracy 39.732142857142854, epoch_loss 2.2766982998166765
# Round 1, cleint 15, epoch 5: epoch_accuracy 40.17857142857143, epoch_loss 2.2766771657126292
# Round 1, cleint 16, epoch 1: epoch_accuracy 6.4555921052631575, epoch_loss 2.311345000016062
# Round 1, cleint 16, epoch 2: epoch_accuracy 6.990131578947368, epoch_loss 2.3104141762382104
# Round 1, cleint 16, epoch 3: epoch_accuracy 6.0444078947368425, epoch_loss 2.3093132972717285
# Round 1, cleint 16, epoch 4: epoch_accuracy 6.578947368421052, epoch_loss 2.308207712675396
# Round 1, cleint 16, epoch 5: epoch_accuracy 6.4555921052631575, epoch_loss 2.3073393169202303
# Round 1, cleint 17, epoch 1: epoch_accuracy 17.34375, epoch_loss 2.2875224113464356
# Round 1, cleint 17, epoch 2: epoch_accuracy 18.177083333333332, epoch_loss 2.2868838628133137
# Round 1, cleint 17, epoch 3: epoch_accuracy 18.75, epoch_loss 2.285865847269694
# Round 1, cleint 17, epoch 4: epoch_accuracy 18.177083333333332, epoch_loss 2.2863364537556965
# Round 1, cleint 17, epoch 5: epoch_accuracy 18.541666666666668, epoch_loss 2.2853971163431805
# Round 1, cleint 18, epoch 1: epoch_accuracy 2.34375, epoch_loss 2.315529224720407
# Round 1, cleint 18, epoch 2: epoch_accuracy 2.7593085106382977, epoch_loss 2.3139791539374817
# Round 1, cleint 18, epoch 3: epoch_accuracy 2.742686170212766, epoch_loss 2.312910110392469
# Round 1, cleint 18, epoch 4: epoch_accuracy 3.091755319148936, epoch_loss 2.31112835255075
# Round 1, cleint 18, epoch 5: epoch_accuracy 3.3577127659574466, epoch_loss 2.3101976627999163
# Round 1, cleint 19, epoch 1: epoch_accuracy 6.484375, epoch_loss 2.3076520681381227
# Round 1, cleint 19, epoch 2: epoch_accuracy 5.3125, epoch_loss 2.3080811738967895
# Round 1, cleint 19, epoch 3: epoch_accuracy 6.484375, epoch_loss 2.307411766052246
# Round 1, cleint 19, epoch 4: epoch_accuracy 6.5625, epoch_loss 2.3075263023376467
# Round 1, cleint 19, epoch 5: epoch_accuracy 6.953125, epoch_loss 2.306859612464905
# Round 1, cleint 20, epoch 1: epoch_accuracy 2.0572916666666665, epoch_loss 2.317071620623271
# Round 1, cleint 20, epoch 2: epoch_accuracy 1.953125, epoch_loss 2.316652202606201
# Round 1, cleint 20, epoch 3: epoch_accuracy 2.0833333333333335, epoch_loss 2.315302546819051
# Round 1, cleint 20, epoch 4: epoch_accuracy 1.796875, epoch_loss 2.314586941401164
# Round 1, cleint 20, epoch 5: epoch_accuracy 2.0572916666666665, epoch_loss 2.31304661432902
# Model's Round: 1, train accuracy of model: 11.858119773814273, train loss of model: 2.297553489893256
#
#
# Model's Round: 1, test accuracy of model: 10.013977635782748, test loss of model: 2.3027372984840464
#
#
# round 1 completed
# Round 2, cleint 1, epoch 1: epoch_accuracy 2.0833333333333335, epoch_loss 2.307457113265991
# Round 2, cleint 1, epoch 2: epoch_accuracy 1.3541666666666667, epoch_loss 2.3069228808085125
# Round 2, cleint 1, epoch 3: epoch_accuracy 2.1354166666666665, epoch_loss 2.3072492758433025
# Round 2, cleint 1, epoch 4: epoch_accuracy 1.71875, epoch_loss 2.306575123469035
# Round 2, cleint 1, epoch 5: epoch_accuracy 1.9270833333333333, epoch_loss 2.3063181241353354
# Round 2, cleint 2, epoch 1: epoch_accuracy 28.854166666666668, epoch_loss 2.2662843068440757
# Round 2, cleint 2, epoch 2: epoch_accuracy 30.3125, epoch_loss 2.2660873413085936
# Round 2, cleint 2, epoch 3: epoch_accuracy 30.3125, epoch_loss 2.2646303017934164
# Round 2, cleint 2, epoch 4: epoch_accuracy 30.3125, epoch_loss 2.263655646642049
# Round 2, cleint 2, epoch 5: epoch_accuracy 30.520833333333332, epoch_loss 2.2628483295440676
# Round 2, cleint 3, epoch 1: epoch_accuracy 4.947916666666667, epoch_loss 2.3216692959820784
# Round 2, cleint 3, epoch 2: epoch_accuracy 4.976851851851852, epoch_loss 2.320701351872197
# Round 2, cleint 3, epoch 3: epoch_accuracy 5.497685185185185, epoch_loss 2.3200763596428766
# Round 2, cleint 3, epoch 4: epoch_accuracy 4.947916666666667, epoch_loss 2.3197954760657415
# Round 2, cleint 3, epoch 5: epoch_accuracy 5.295138888888889, epoch_loss 2.31906118216338
# Round 2, cleint 4, epoch 1: epoch_accuracy 6.71875, epoch_loss 2.300697374343872
# Round 2, cleint 4, epoch 2: epoch_accuracy 7.34375, epoch_loss 2.3005075613657633
# Round 2, cleint 4, epoch 3: epoch_accuracy 6.822916666666667, epoch_loss 2.300787083307902
# Round 2, cleint 4, epoch 4: epoch_accuracy 7.65625, epoch_loss 2.29954415957133
# Round 2, cleint 4, epoch 5: epoch_accuracy 7.291666666666667, epoch_loss 2.2997204144795735
# Round 2, cleint 5, epoch 1: epoch_accuracy 32.60216346153846, epoch_loss 2.272697714658884
# Round 2, cleint 5, epoch 2: epoch_accuracy 33.26322115384615, epoch_loss 2.2714586624732385
# Round 2, cleint 5, epoch 3: epoch_accuracy 33.05288461538461, epoch_loss 2.270449299078721
# Round 2, cleint 5, epoch 4: epoch_accuracy 33.29326923076923, epoch_loss 2.2696830401053796
# Round 2, cleint 5, epoch 5: epoch_accuracy 33.68389423076923, epoch_loss 2.2682628539892344
# Round 2, cleint 6, epoch 1: epoch_accuracy 1.7578125, epoch_loss 2.308998870849609
# Round 2, cleint 6, epoch 2: epoch_accuracy 2.0703125, epoch_loss 2.307995283603668
# Round 2, cleint 6, epoch 3: epoch_accuracy 1.9140625, epoch_loss 2.3081750154495237
# Round 2, cleint 6, epoch 4: epoch_accuracy 2.3046875, epoch_loss 2.306998586654663
# Round 2, cleint 6, epoch 5: epoch_accuracy 2.03125, epoch_loss 2.3067166328430178
# Round 2, cleint 7, epoch 1: epoch_accuracy 3.3110119047619047, epoch_loss 2.294190225147066
# Round 2, cleint 7, epoch 2: epoch_accuracy 4.241071428571429, epoch_loss 2.2920890195029124
# Round 2, cleint 7, epoch 3: epoch_accuracy 4.9851190476190474, epoch_loss 2.291083653767904
# Round 2, cleint 7, epoch 4: epoch_accuracy 5.133928571428571, epoch_loss 2.2906387646993003
# Round 2, cleint 7, epoch 5: epoch_accuracy 6.994047619047619, epoch_loss 2.2883486974807012
# Round 2, cleint 8, epoch 1: epoch_accuracy 4.541015625, epoch_loss 2.2968583554029465
# Round 2, cleint 8, epoch 2: epoch_accuracy 5.029296875, epoch_loss 2.2965649515390396
# Round 2, cleint 8, epoch 3: epoch_accuracy 6.298828125, epoch_loss 2.2954484671354294
# Round 2, cleint 8, epoch 4: epoch_accuracy 6.73828125, epoch_loss 2.29390612244606
# Round 2, cleint 8, epoch 5: epoch_accuracy 7.568359375, epoch_loss 2.292578712105751
# Round 2, cleint 9, epoch 1: epoch_accuracy 19.071691176470587, epoch_loss 2.2923591557671044
# Round 2, cleint 9, epoch 2: epoch_accuracy 19.577205882352942, epoch_loss 2.291822405422435
# Round 2, cleint 9, epoch 3: epoch_accuracy 20.220588235294116, epoch_loss 2.2909679693334244
# Round 2, cleint 9, epoch 4: epoch_accuracy 18.887867647058822, epoch_loss 2.290869053672342
# Round 2, cleint 9, epoch 5: epoch_accuracy 18.933823529411764, epoch_loss 2.2911772026735195
# Round 2, cleint 10, epoch 1: epoch_accuracy 1.4322916666666667, epoch_loss 2.322419265906016
# Round 2, cleint 10, epoch 2: epoch_accuracy 1.3671875, epoch_loss 2.3218271136283875
# Round 2, cleint 10, epoch 3: epoch_accuracy 1.4322916666666667, epoch_loss 2.321558694044749
# Round 2, cleint 10, epoch 4: epoch_accuracy 1.171875, epoch_loss 2.3201194206873574
# Round 2, cleint 10, epoch 5: epoch_accuracy 1.4322916666666667, epoch_loss 2.3211559454600015
# Round 2, cleint 11, epoch 1: epoch_accuracy 11.40625, epoch_loss 2.290021514892578
# Round 2, cleint 11, epoch 2: epoch_accuracy 10.625, epoch_loss 2.288690614700317
# Round 2, cleint 11, epoch 3: epoch_accuracy 10.3125, epoch_loss 2.291068744659424
# Round 2, cleint 11, epoch 4: epoch_accuracy 12.5, epoch_loss 2.289720153808594
# Round 2, cleint 11, epoch 5: epoch_accuracy 11.25, epoch_loss 2.2895030975341797
# Round 2, cleint 12, epoch 1: epoch_accuracy 9.588068181818182, epoch_loss 2.295054890892722
# Round 2, cleint 12, epoch 2: epoch_accuracy 10.085227272727273, epoch_loss 2.2950154434550893
# Round 2, cleint 12, epoch 3: epoch_accuracy 9.446022727272727, epoch_loss 2.2937201153148306
# Round 2, cleint 12, epoch 4: epoch_accuracy 10.511363636363637, epoch_loss 2.2935527237978848
# Round 2, cleint 12, epoch 5: epoch_accuracy 10.653409090909092, epoch_loss 2.2922950224442915
# Round 2, cleint 13, epoch 1: epoch_accuracy 13.75, epoch_loss 2.3043710708618166
# Round 2, cleint 13, epoch 2: epoch_accuracy 12.96875, epoch_loss 2.3054808378219604
# Round 2, cleint 13, epoch 3: epoch_accuracy 13.359375, epoch_loss 2.3046946048736574
# Round 2, cleint 13, epoch 4: epoch_accuracy 14.84375, epoch_loss 2.303822708129883
# Round 2, cleint 13, epoch 5: epoch_accuracy 14.140625, epoch_loss 2.303965520858765
# Round 2, cleint 14, epoch 1: epoch_accuracy 7.378472222222222, epoch_loss 2.3092539310455322
# Round 2, cleint 14, epoch 2: epoch_accuracy 7.118055555555555, epoch_loss 2.308644798066881
# Round 2, cleint 14, epoch 3: epoch_accuracy 8.094618055555555, epoch_loss 2.307909289995829
# Round 2, cleint 14, epoch 4: epoch_accuracy 8.18142361111111, epoch_loss 2.308038148615095
# Round 2, cleint 14, epoch 5: epoch_accuracy 9.00607638888889, epoch_loss 2.306449751059214
# Round 2, cleint 15, epoch 1: epoch_accuracy 38.33705357142857, epoch_loss 2.2797355311257497
# Round 2, cleint 15, epoch 2: epoch_accuracy 37.94642857142857, epoch_loss 2.2793270519801547
# Round 2, cleint 15, epoch 3: epoch_accuracy 39.50892857142857, epoch_loss 2.278208374977112
# Round 2, cleint 15, epoch 4: epoch_accuracy 40.011160714285715, epoch_loss 2.2773248979023526
# Round 2, cleint 15, epoch 5: epoch_accuracy 39.0625, epoch_loss 2.277211274419512
# Round 2, cleint 16, epoch 1: epoch_accuracy 6.620065789473684, epoch_loss 2.3117580037367973
# Round 2, cleint 16, epoch 2: epoch_accuracy 6.8667763157894735, epoch_loss 2.310225988689222
# Round 2, cleint 16, epoch 3: epoch_accuracy 6.8256578947368425, epoch_loss 2.309594706485146
# Round 2, cleint 16, epoch 4: epoch_accuracy 6.784539473684211, epoch_loss 2.3084162410936857
# Round 2, cleint 16, epoch 5: epoch_accuracy 6.4555921052631575, epoch_loss 2.3070760275188245
# Round 2, cleint 17, epoch 1: epoch_accuracy 17.552083333333332, epoch_loss 2.2876277764638266
# Round 2, cleint 17, epoch 2: epoch_accuracy 18.333333333333332, epoch_loss 2.2865758577982587
# Round 2, cleint 17, epoch 3: epoch_accuracy 17.447916666666668, epoch_loss 2.2866618792215982
# Round 2, cleint 17, epoch 4: epoch_accuracy 18.333333333333332, epoch_loss 2.2856785933176678
# Round 2, cleint 17, epoch 5: epoch_accuracy 18.854166666666668, epoch_loss 2.2847678820292154
# Round 2, cleint 18, epoch 1: epoch_accuracy 2.393617021276596, epoch_loss 2.315275511843093
# Round 2, cleint 18, epoch 2: epoch_accuracy 2.726063829787234, epoch_loss 2.3141363681630884
# Round 2, cleint 18, epoch 3: epoch_accuracy 2.992021276595745, epoch_loss 2.3125754467984465
# Round 2, cleint 18, epoch 4: epoch_accuracy 3.174867021276596, epoch_loss 2.3114670540424105
# Round 2, cleint 18, epoch 5: epoch_accuracy 3.257978723404255, epoch_loss 2.309944751414847
# Round 2, cleint 19, epoch 1: epoch_accuracy 6.25, epoch_loss 2.307797002792358
# Round 2, cleint 19, epoch 2: epoch_accuracy 6.5625, epoch_loss 2.3070451736450197
# Round 2, cleint 19, epoch 3: epoch_accuracy 7.265625, epoch_loss 2.3076687812805177
# Round 2, cleint 19, epoch 4: epoch_accuracy 6.796875, epoch_loss 2.3060055494308473
# Round 2, cleint 19, epoch 5: epoch_accuracy 6.328125, epoch_loss 2.307328462600708
# Round 2, cleint 20, epoch 1: epoch_accuracy 2.0052083333333335, epoch_loss 2.317305064201355
# Round 2, cleint 20, epoch 2: epoch_accuracy 1.8229166666666667, epoch_loss 2.316439461708069
# Round 2, cleint 20, epoch 3: epoch_accuracy 1.9791666666666667, epoch_loss 2.3154061396916705
# Round 2, cleint 20, epoch 4: epoch_accuracy 2.0833333333333335, epoch_loss 2.314670618375142
# Round 2, cleint 20, epoch 5: epoch_accuracy 1.8489583333333333, epoch_loss 2.313187336921692
# Model's Round: 2, train accuracy of model: 11.826790997579145, train loss of model: 2.2973958610837917
#
#
# Model's Round: 2, test accuracy of model: 10.013977635782748, test loss of model: 2.3027274220134504
#
#
# round 2 completed
# Round 3, cleint 1, epoch 1: epoch_accuracy 1.5104166666666667, epoch_loss 2.307656494776408
# Round 3, cleint 1, epoch 2: epoch_accuracy 1.6666666666666667, epoch_loss 2.3073641618092853
# Round 3, cleint 1, epoch 3: epoch_accuracy 1.6666666666666667, epoch_loss 2.3069756984710694
# Round 3, cleint 1, epoch 4: epoch_accuracy 2.1354166666666665, epoch_loss 2.3066325346628824
# Round 3, cleint 1, epoch 5: epoch_accuracy 1.9270833333333333, epoch_loss 2.3065007368723554
# Round 3, cleint 2, epoch 1: epoch_accuracy 30.3125, epoch_loss 2.266820208231608
# Round 3, cleint 2, epoch 2: epoch_accuracy 29.791666666666668, epoch_loss 2.2662746906280518
# Round 3, cleint 2, epoch 3: epoch_accuracy 30.78125, epoch_loss 2.2646145820617676
# Round 3, cleint 2, epoch 4: epoch_accuracy 30.989583333333332, epoch_loss 2.2642422199249266
# Round 3, cleint 2, epoch 5: epoch_accuracy 30.416666666666668, epoch_loss 2.2628466924031576
# Round 3, cleint 3, epoch 1: epoch_accuracy 5.3530092592592595, epoch_loss 2.3211787011888294
# Round 3, cleint 3, epoch 2: epoch_accuracy 5.381944444444445, epoch_loss 2.320845877682721
# Round 3, cleint 3, epoch 3: epoch_accuracy 5.005787037037037, epoch_loss 2.319917502226653
# Round 3, cleint 3, epoch 4: epoch_accuracy 5.46875, epoch_loss 2.31920474546927
# Round 3, cleint 3, epoch 5: epoch_accuracy 5.381944444444445, epoch_loss 2.318376903180723
# Round 3, cleint 4, epoch 1: epoch_accuracy 7.1875, epoch_loss 2.301084884007772
# Round 3, cleint 4, epoch 2: epoch_accuracy 6.979166666666667, epoch_loss 2.30043527285258
# Round 3, cleint 4, epoch 3: epoch_accuracy 7.1875, epoch_loss 2.299859396616618
# Round 3, cleint 4, epoch 4: epoch_accuracy 7.395833333333333, epoch_loss 2.29899377822876
# Round 3, cleint 4, epoch 5: epoch_accuracy 7.1875, epoch_loss 2.298781458536784
# Round 3, cleint 5, epoch 1: epoch_accuracy 33.11298076923077, epoch_loss 2.2723032236099243
# Round 3, cleint 5, epoch 2: epoch_accuracy 33.14302884615385, epoch_loss 2.271599842951848
# Round 3, cleint 5, epoch 3: epoch_accuracy 32.48197115384615, epoch_loss 2.27079989359929
# Round 3, cleint 5, epoch 4: epoch_accuracy 33.14302884615385, epoch_loss 2.2695100032366238
# Round 3, cleint 5, epoch 5: epoch_accuracy 33.11298076923077, epoch_loss 2.268620885335482
# Round 3, cleint 6, epoch 1: epoch_accuracy 1.9140625, epoch_loss 2.3084622859954833
# Round 3, cleint 6, epoch 2: epoch_accuracy 2.03125, epoch_loss 2.3090797901153564
# Round 3, cleint 6, epoch 3: epoch_accuracy 2.3046875, epoch_loss 2.3070924520492553
# Round 3, cleint 6, epoch 4: epoch_accuracy 1.640625, epoch_loss 2.3082518219947814
# Round 3, cleint 6, epoch 5: epoch_accuracy 2.1484375, epoch_loss 2.3069782733917235
# Round 3, cleint 7, epoch 1: epoch_accuracy 3.6830357142857144, epoch_loss 2.2936280341375443
# Round 3, cleint 7, epoch 2: epoch_accuracy 4.092261904761905, epoch_loss 2.292810042699178
# Round 3, cleint 7, epoch 3: epoch_accuracy 4.799107142857143, epoch_loss 2.291007927485875
# Round 3, cleint 7, epoch 4: epoch_accuracy 5.431547619047619, epoch_loss 2.2903389590127126
# Round 3, cleint 7, epoch 5: epoch_accuracy 5.989583333333333, epoch_loss 2.2895475455692837
# Round 3, cleint 8, epoch 1: epoch_accuracy 4.931640625, epoch_loss 2.297163501381874
# Round 3, cleint 8, epoch 2: epoch_accuracy 5.126953125, epoch_loss 2.2958202809095383
# Round 3, cleint 8, epoch 3: epoch_accuracy 5.810546875, epoch_loss 2.2953217923641205
# Round 3, cleint 8, epoch 4: epoch_accuracy 6.34765625, epoch_loss 2.2943250238895416
# Round 3, cleint 8, epoch 5: epoch_accuracy 7.470703125, epoch_loss 2.29305300116539
# Round 3, cleint 9, epoch 1: epoch_accuracy 19.11764705882353, epoch_loss 2.2924722222720875
# Round 3, cleint 9, epoch 2: epoch_accuracy 19.16360294117647, epoch_loss 2.29169859605677
# Round 3, cleint 9, epoch 3: epoch_accuracy 19.11764705882353, epoch_loss 2.2914458302890552
# Round 3, cleint 9, epoch 4: epoch_accuracy 19.11764705882353, epoch_loss 2.2913365223828484
# Round 3, cleint 9, epoch 5: epoch_accuracy 19.071691176470587, epoch_loss 2.2903578141156364
# Round 3, cleint 10, epoch 1: epoch_accuracy 1.1067708333333333, epoch_loss 2.3220862547556558
# Round 3, cleint 10, epoch 2: epoch_accuracy 1.6276041666666667, epoch_loss 2.3218952218691506
# Round 3, cleint 10, epoch 3: epoch_accuracy 1.171875, epoch_loss 2.3215786019961038
# Round 3, cleint 10, epoch 4: epoch_accuracy 1.171875, epoch_loss 2.320818543434143
# Round 3, cleint 10, epoch 5: epoch_accuracy 1.5625, epoch_loss 2.320599595705668
# Round 3, cleint 11, epoch 1: epoch_accuracy 10.625, epoch_loss 2.290098762512207
# Round 3, cleint 11, epoch 2: epoch_accuracy 11.5625, epoch_loss 2.290592336654663
# Round 3, cleint 11, epoch 3: epoch_accuracy 11.09375, epoch_loss 2.2898535251617433
# Round 3, cleint 11, epoch 4: epoch_accuracy 11.40625, epoch_loss 2.289519786834717
# Round 3, cleint 11, epoch 5: epoch_accuracy 9.53125, epoch_loss 2.29100341796875
# Round 3, cleint 12, epoch 1: epoch_accuracy 8.948863636363637, epoch_loss 2.2961247834292324
# Round 3, cleint 12, epoch 2: epoch_accuracy 10.653409090909092, epoch_loss 2.295815879648382
# Round 3, cleint 12, epoch 3: epoch_accuracy 10.653409090909092, epoch_loss 2.293826775117354
# Round 3, cleint 12, epoch 4: epoch_accuracy 9.517045454545455, epoch_loss 2.2945248647169634
# Round 3, cleint 12, epoch 5: epoch_accuracy 10.724431818181818, epoch_loss 2.2930697961287065
# Round 3, cleint 13, epoch 1: epoch_accuracy 14.140625, epoch_loss 2.3044571399688722
# Round 3, cleint 13, epoch 2: epoch_accuracy 14.21875, epoch_loss 2.304618310928345
# Round 3, cleint 13, epoch 3: epoch_accuracy 13.515625, epoch_loss 2.3045763969421387
# Round 3, cleint 13, epoch 4: epoch_accuracy 14.375, epoch_loss 2.3039159059524534
# Round 3, cleint 13, epoch 5: epoch_accuracy 13.359375, epoch_loss 2.304566192626953
# Round 3, cleint 14, epoch 1: epoch_accuracy 6.944444444444445, epoch_loss 2.30914314587911
# Round 3, cleint 14, epoch 2: epoch_accuracy 7.530381944444445, epoch_loss 2.308565285470751
# Round 3, cleint 14, epoch 3: epoch_accuracy 8.37673611111111, epoch_loss 2.3077893919414945
# Round 3, cleint 14, epoch 4: epoch_accuracy 8.745659722222221, epoch_loss 2.3071044617229037
# Round 3, cleint 14, epoch 5: epoch_accuracy 9.526909722222221, epoch_loss 2.3065320518281727
# Round 3, cleint 15, epoch 1: epoch_accuracy 37.83482142857143, epoch_loss 2.279789226395743
# Round 3, cleint 15, epoch 2: epoch_accuracy 38.839285714285715, epoch_loss 2.2792781591415405
# Round 3, cleint 15, epoch 3: epoch_accuracy 38.392857142857146, epoch_loss 2.2789832183292935
# Round 3, cleint 15, epoch 4: epoch_accuracy 38.058035714285715, epoch_loss 2.2776843990598405
# Round 3, cleint 15, epoch 5: epoch_accuracy 40.345982142857146, epoch_loss 2.277052436556135
# Round 3, cleint 16, epoch 1: epoch_accuracy 6.0444078947368425, epoch_loss 2.311416425203022
# Round 3, cleint 16, epoch 2: epoch_accuracy 6.332236842105263, epoch_loss 2.31100102474815
# Round 3, cleint 16, epoch 3: epoch_accuracy 6.702302631578948, epoch_loss 2.309911138132999
# Round 3, cleint 16, epoch 4: epoch_accuracy 6.702302631578948, epoch_loss 2.3080699318333675
# Round 3, cleint 16, epoch 5: epoch_accuracy 6.743421052631579, epoch_loss 2.307015481748079
# Round 3, cleint 17, epoch 1: epoch_accuracy 16.979166666666668, epoch_loss 2.287413009007772
# Round 3, cleint 17, epoch 2: epoch_accuracy 18.802083333333332, epoch_loss 2.286071189244588
# Round 3, cleint 17, epoch 3: epoch_accuracy 18.28125, epoch_loss 2.2867209752400717
# Round 3, cleint 17, epoch 4: epoch_accuracy 18.645833333333332, epoch_loss 2.2855644543965656
# Round 3, cleint 17, epoch 5: epoch_accuracy 18.333333333333332, epoch_loss 2.2856414159139
# Round 3, cleint 18, epoch 1: epoch_accuracy 2.6595744680851063, epoch_loss 2.3152723515287357
# Round 3, cleint 18, epoch 2: epoch_accuracy 2.726063829787234, epoch_loss 2.3141523726443025
# Round 3, cleint 18, epoch 3: epoch_accuracy 3.1914893617021276, epoch_loss 2.3123868678478483
# Round 3, cleint 18, epoch 4: epoch_accuracy 3.2746010638297873, epoch_loss 2.311336004987676
# Round 3, cleint 18, epoch 5: epoch_accuracy 3.6569148936170213, epoch_loss 2.309686305675101
# Round 3, cleint 19, epoch 1: epoch_accuracy 6.40625, epoch_loss 2.30841007232666
# Round 3, cleint 19, epoch 2: epoch_accuracy 6.40625, epoch_loss 2.308065485954285
# Round 3, cleint 19, epoch 3: epoch_accuracy 6.484375, epoch_loss 2.3071161985397337
# Round 3, cleint 19, epoch 4: epoch_accuracy 6.875, epoch_loss 2.3063454151153566
# Round 3, cleint 19, epoch 5: epoch_accuracy 7.03125, epoch_loss 2.306924748420715
# Round 3, cleint 20, epoch 1: epoch_accuracy 1.640625, epoch_loss 2.317723027865092
# Round 3, cleint 20, epoch 2: epoch_accuracy 1.8229166666666667, epoch_loss 2.31647420724233
# Round 3, cleint 20, epoch 3: epoch_accuracy 1.6666666666666667, epoch_loss 2.3158756256103517
# Round 3, cleint 20, epoch 4: epoch_accuracy 2.109375, epoch_loss 2.314502231280009
# Round 3, cleint 20, epoch 5: epoch_accuracy 2.0833333333333335, epoch_loss 2.3130414485931396
# Model's Round: 3, train accuracy of model: 11.780264582232778, train loss of model: 2.297509810086793
#
#
# Model's Round: 3, test accuracy of model: 10.013977635782748, test loss of model: 2.3027174937458463
#
#
# round 3 completed
# Round 4, cleint 1, epoch 1: epoch_accuracy 2.1354166666666665, epoch_loss 2.3073206265767414
# Round 4, cleint 1, epoch 2: epoch_accuracy 1.9270833333333333, epoch_loss 2.3068654696146647
# Round 4, cleint 1, epoch 3: epoch_accuracy 1.7708333333333333, epoch_loss 2.3075527985890707
# Round 4, cleint 1, epoch 4: epoch_accuracy 1.9791666666666667, epoch_loss 2.306446568171183
# Round 4, cleint 1, epoch 5: epoch_accuracy 1.3020833333333333, epoch_loss 2.306511942545573
# Round 4, cleint 2, epoch 1: epoch_accuracy 29.479166666666668, epoch_loss 2.266977310180664
# Round 4, cleint 2, epoch 2: epoch_accuracy 31.875, epoch_loss 2.265633805592855
# Round 4, cleint 2, epoch 3: epoch_accuracy 30.572916666666668, epoch_loss 2.2652244726816813
# Round 4, cleint 2, epoch 4: epoch_accuracy 30.208333333333332, epoch_loss 2.2638741970062255
# Round 4, cleint 2, epoch 5: epoch_accuracy 29.84375, epoch_loss 2.2637086232503254
# Round 4, cleint 3, epoch 1: epoch_accuracy 5.034722222222222, epoch_loss 2.320959444399233
# Round 4, cleint 3, epoch 2: epoch_accuracy 5.150462962962963, epoch_loss 2.3202574253082275
# Round 4, cleint 3, epoch 3: epoch_accuracy 5.237268518518518, epoch_loss 2.319907612270779
# Round 4, cleint 3, epoch 4: epoch_accuracy 5.121527777777778, epoch_loss 2.31948834878427
# Round 4, cleint 3, epoch 5: epoch_accuracy 5.121527777777778, epoch_loss 2.318733153519807
# Round 4, cleint 4, epoch 1: epoch_accuracy 7.34375, epoch_loss 2.301155106226603
# Round 4, cleint 4, epoch 2: epoch_accuracy 7.291666666666667, epoch_loss 2.3001850763956706
# Round 4, cleint 4, epoch 3: epoch_accuracy 7.239583333333333, epoch_loss 2.3003043651580812
# Round 4, cleint 4, epoch 4: epoch_accuracy 8.072916666666666, epoch_loss 2.299680964152018
# Round 4, cleint 4, epoch 5: epoch_accuracy 7.395833333333333, epoch_loss 2.299506982167562
# Round 4, cleint 5, epoch 1: epoch_accuracy 31.94110576923077, epoch_loss 2.2727830226604757
# Round 4, cleint 5, epoch 2: epoch_accuracy 32.90264423076923, epoch_loss 2.2718781507932224
# Round 4, cleint 5, epoch 3: epoch_accuracy 33.08293269230769, epoch_loss 2.270666342515212
# Round 4, cleint 5, epoch 4: epoch_accuracy 33.11298076923077, epoch_loss 2.270276564818162
# Round 4, cleint 5, epoch 5: epoch_accuracy 31.790865384615383, epoch_loss 2.2688616605905385
# Round 4, cleint 6, epoch 1: epoch_accuracy 1.875, epoch_loss 2.309114456176758
# Round 4, cleint 6, epoch 2: epoch_accuracy 2.03125, epoch_loss 2.3082054376602175
# Round 4, cleint 6, epoch 3: epoch_accuracy 2.03125, epoch_loss 2.308389675617218
# Round 4, cleint 6, epoch 4: epoch_accuracy 2.03125, epoch_loss 2.3071029424667358
# Round 4, cleint 6, epoch 5: epoch_accuracy 2.65625, epoch_loss 2.3070701241493223
# Round 4, cleint 7, epoch 1: epoch_accuracy 3.980654761904762, epoch_loss 2.2936144102187384
# Round 4, cleint 7, epoch 2: epoch_accuracy 3.794642857142857, epoch_loss 2.2932346207754954
# Round 4, cleint 7, epoch 3: epoch_accuracy 4.836309523809524, epoch_loss 2.2912428151993525
# Round 4, cleint 7, epoch 4: epoch_accuracy 5.617559523809524, epoch_loss 2.2903068292708624
# Round 4, cleint 7, epoch 5: epoch_accuracy 6.287202380952381, epoch_loss 2.2888288611457464
# Round 4, cleint 8, epoch 1: epoch_accuracy 5.322265625, epoch_loss 2.296881675720215
# Round 4, cleint 8, epoch 2: epoch_accuracy 5.17578125, epoch_loss 2.295635297894478
# Round 4, cleint 8, epoch 3: epoch_accuracy 6.103515625, epoch_loss 2.295518472790718
# Round 4, cleint 8, epoch 4: epoch_accuracy 6.494140625, epoch_loss 2.2941706627607346
# Round 4, cleint 8, epoch 5: epoch_accuracy 6.93359375, epoch_loss 2.2933329343795776
# Round 4, cleint 9, epoch 1: epoch_accuracy 19.02573529411765, epoch_loss 2.292666701709523
# Round 4, cleint 9, epoch 2: epoch_accuracy 18.520220588235293, epoch_loss 2.2925325141233555
# Round 4, cleint 9, epoch 3: epoch_accuracy 18.979779411764707, epoch_loss 2.2913243770599365
# Round 4, cleint 9, epoch 4: epoch_accuracy 19.209558823529413, epoch_loss 2.2912988943212174
# Round 4, cleint 9, epoch 5: epoch_accuracy 18.566176470588236, epoch_loss 2.290978838415707
# Round 4, cleint 10, epoch 1: epoch_accuracy 0.9114583333333334, epoch_loss 2.321898639202118
# Round 4, cleint 10, epoch 2: epoch_accuracy 1.4322916666666667, epoch_loss 2.3215850591659546
# Round 4, cleint 10, epoch 3: epoch_accuracy 1.4973958333333333, epoch_loss 2.3209519584973655
# Round 4, cleint 10, epoch 4: epoch_accuracy 1.2369791666666667, epoch_loss 2.321419676144918
# Round 4, cleint 10, epoch 5: epoch_accuracy 1.2369791666666667, epoch_loss 2.3207788467407227
# Round 4, cleint 11, epoch 1: epoch_accuracy 11.5625, epoch_loss 2.2902083873748778
# Round 4, cleint 11, epoch 2: epoch_accuracy 10.625, epoch_loss 2.2898725032806397
# Round 4, cleint 11, epoch 3: epoch_accuracy 10.625, epoch_loss 2.2900135040283205
# Round 4, cleint 11, epoch 4: epoch_accuracy 11.25, epoch_loss 2.2900793075561525
# Round 4, cleint 11, epoch 5: epoch_accuracy 10.0, epoch_loss 2.289894723892212
# Round 4, cleint 12, epoch 1: epoch_accuracy 9.446022727272727, epoch_loss 2.2961093078960073
# Round 4, cleint 12, epoch 2: epoch_accuracy 10.227272727272727, epoch_loss 2.295127175071023
# Round 4, cleint 12, epoch 3: epoch_accuracy 10.795454545454545, epoch_loss 2.293604092164473
# Round 4, cleint 12, epoch 4: epoch_accuracy 9.943181818181818, epoch_loss 2.2935628674247046
# Round 4, cleint 12, epoch 5: epoch_accuracy 10.014204545454545, epoch_loss 2.293005097996105
# Round 4, cleint 13, epoch 1: epoch_accuracy 14.53125, epoch_loss 2.30547456741333
# Round 4, cleint 13, epoch 2: epoch_accuracy 12.578125, epoch_loss 2.3057394504547117
# Round 4, cleint 13, epoch 3: epoch_accuracy 13.59375, epoch_loss 2.304630470275879
# Round 4, cleint 13, epoch 4: epoch_accuracy 12.96875, epoch_loss 2.3047250509262085
# Round 4, cleint 13, epoch 5: epoch_accuracy 13.359375, epoch_loss 2.3046536207199098
# Round 4, cleint 14, epoch 1: epoch_accuracy 7.335069444444445, epoch_loss 2.3090594344668918
# Round 4, cleint 14, epoch 2: epoch_accuracy 7.660590277777778, epoch_loss 2.30883612897661
# Round 4, cleint 14, epoch 3: epoch_accuracy 7.986111111111111, epoch_loss 2.3082711630397372
# Round 4, cleint 14, epoch 4: epoch_accuracy 8.854166666666666, epoch_loss 2.3069520658916898
# Round 4, cleint 14, epoch 5: epoch_accuracy 9.00607638888889, epoch_loss 2.306104951434665
# Round 4, cleint 15, epoch 1: epoch_accuracy 38.392857142857146, epoch_loss 2.280568480491638
# Round 4, cleint 15, epoch 2: epoch_accuracy 38.839285714285715, epoch_loss 2.2792476075036183
# Round 4, cleint 15, epoch 3: epoch_accuracy 39.50892857142857, epoch_loss 2.2780537945883617
# Round 4, cleint 15, epoch 4: epoch_accuracy 39.39732142857143, epoch_loss 2.2786092587879727
# Round 4, cleint 15, epoch 5: epoch_accuracy 40.122767857142854, epoch_loss 2.276398539543152
# Round 4, cleint 16, epoch 1: epoch_accuracy 6.537828947368421, epoch_loss 2.3118515265615365
# Round 4, cleint 16, epoch 2: epoch_accuracy 6.373355263157895, epoch_loss 2.3107330422652397
# Round 4, cleint 16, epoch 3: epoch_accuracy 6.784539473684211, epoch_loss 2.3090026127664665
# Round 4, cleint 16, epoch 4: epoch_accuracy 6.373355263157895, epoch_loss 2.3077496101981714
# Round 4, cleint 16, epoch 5: epoch_accuracy 6.291118421052632, epoch_loss 2.307245317258333
# Round 4, cleint 17, epoch 1: epoch_accuracy 18.125, epoch_loss 2.287112315495809
# Round 4, cleint 17, epoch 2: epoch_accuracy 17.96875, epoch_loss 2.2864082495371503
# Round 4, cleint 17, epoch 3: epoch_accuracy 18.385416666666668, epoch_loss 2.285834566752116
# Round 4, cleint 17, epoch 4: epoch_accuracy 18.177083333333332, epoch_loss 2.2856542746225994
# Round 4, cleint 17, epoch 5: epoch_accuracy 19.166666666666668, epoch_loss 2.2856669267018637
# Round 4, cleint 18, epoch 1: epoch_accuracy 2.559840425531915, epoch_loss 2.3155548724722355
# Round 4, cleint 18, epoch 2: epoch_accuracy 2.559840425531915, epoch_loss 2.3140827797828836
# Round 4, cleint 18, epoch 3: epoch_accuracy 3.0585106382978724, epoch_loss 2.3125838117396578
# Round 4, cleint 18, epoch 4: epoch_accuracy 3.2081117021276597, epoch_loss 2.3108738889085485
# Round 4, cleint 18, epoch 5: epoch_accuracy 3.5405585106382977, epoch_loss 2.3100755569782665
# Round 4, cleint 19, epoch 1: epoch_accuracy 6.40625, epoch_loss 2.307715821266174
# Round 4, cleint 19, epoch 2: epoch_accuracy 6.484375, epoch_loss 2.3068458080291747
# Round 4, cleint 19, epoch 3: epoch_accuracy 6.328125, epoch_loss 2.3069865703582764
# Round 4, cleint 19, epoch 4: epoch_accuracy 6.015625, epoch_loss 2.307105827331543
# Round 4, cleint 19, epoch 5: epoch_accuracy 6.40625, epoch_loss 2.3064972162246704
# Round 4, cleint 20, epoch 1: epoch_accuracy 1.9010416666666667, epoch_loss 2.316943709055583
# Round 4, cleint 20, epoch 2: epoch_accuracy 1.9010416666666667, epoch_loss 2.3161145210266114
# Round 4, cleint 20, epoch 3: epoch_accuracy 2.1354166666666665, epoch_loss 2.315073768297831
# Round 4, cleint 20, epoch 4: epoch_accuracy 2.2395833333333335, epoch_loss 2.3143794298172
# Round 4, cleint 20, epoch 5: epoch_accuracy 2.0833333333333335, epoch_loss 2.313235354423523
# Model's Round: 4, train accuracy of model: 11.556230616022216, train loss of model: 2.297554463603879
#
#
# Model's Round: 4, test accuracy of model: 10.013977635782748, test loss of model: 2.3027075228218834
#
#
# round 4 completed
# Round 5, cleint 1, epoch 1: epoch_accuracy 1.9270833333333333, epoch_loss 2.3072176615397137
# Round 5, cleint 1, epoch 2: epoch_accuracy 1.875, epoch_loss 2.307327922185262
# Round 5, cleint 1, epoch 3: epoch_accuracy 2.1875, epoch_loss 2.3064110120137533
# Round 5, cleint 1, epoch 4: epoch_accuracy 1.9791666666666667, epoch_loss 2.3067079385121665
# Round 5, cleint 1, epoch 5: epoch_accuracy 2.03125, epoch_loss 2.3055904865264893
# Round 5, cleint 2, epoch 1: epoch_accuracy 30.364583333333332, epoch_loss 2.266550366083781
# Round 5, cleint 2, epoch 2: epoch_accuracy 30.625, epoch_loss 2.2664817651112874
# Round 5, cleint 2, epoch 3: epoch_accuracy 28.4375, epoch_loss 2.2652803738911946
# Round 5, cleint 2, epoch 4: epoch_accuracy 29.53125, epoch_loss 2.264206536610921
# Round 5, cleint 2, epoch 5: epoch_accuracy 29.84375, epoch_loss 2.2634263833363852
# Round 5, cleint 3, epoch 1: epoch_accuracy 4.947916666666667, epoch_loss 2.321148704599451
# Round 5, cleint 3, epoch 2: epoch_accuracy 5.179398148148148, epoch_loss 2.320540092609547
# Round 5, cleint 3, epoch 3: epoch_accuracy 4.918981481481482, epoch_loss 2.3194187923713967
# Round 5, cleint 3, epoch 4: epoch_accuracy 4.890046296296297, epoch_loss 2.319097404126768
# Round 5, cleint 3, epoch 5: epoch_accuracy 5.237268518518518, epoch_loss 2.318949655250267
# Round 5, cleint 4, epoch 1: epoch_accuracy 6.458333333333333, epoch_loss 2.3013808091481525
# Round 5, cleint 4, epoch 2: epoch_accuracy 6.875, epoch_loss 2.3001059373219808
# Round 5, cleint 4, epoch 3: epoch_accuracy 7.03125, epoch_loss 2.2999858538309734
# Round 5, cleint 4, epoch 4: epoch_accuracy 7.447916666666667, epoch_loss 2.3000603040059406
# Round 5, cleint 4, epoch 5: epoch_accuracy 7.8125, epoch_loss 2.2995073636372885
# Round 5, cleint 5, epoch 1: epoch_accuracy 31.640625, epoch_loss 2.2728570883090677
# Round 5, cleint 5, epoch 2: epoch_accuracy 32.45192307692308, epoch_loss 2.272120090631338
# Round 5, cleint 5, epoch 3: epoch_accuracy 32.39182692307692, epoch_loss 2.270849558023306
# Round 5, cleint 5, epoch 4: epoch_accuracy 33.23317307692308, epoch_loss 2.269446171247042
# Round 5, cleint 5, epoch 5: epoch_accuracy 33.29326923076923, epoch_loss 2.2690529273106503
# Round 5, cleint 6, epoch 1: epoch_accuracy 1.7578125, epoch_loss 2.3086920499801638
# Round 5, cleint 6, epoch 2: epoch_accuracy 1.3671875, epoch_loss 2.309108519554138
# Round 5, cleint 6, epoch 3: epoch_accuracy 2.5, epoch_loss 2.3076372504234315
# Round 5, cleint 6, epoch 4: epoch_accuracy 2.265625, epoch_loss 2.307290995121002
# Round 5, cleint 6, epoch 5: epoch_accuracy 2.0703125, epoch_loss 2.3064637303352358
# Round 5, cleint 7, epoch 1: epoch_accuracy 3.199404761904762, epoch_loss 2.2942952542077926
# Round 5, cleint 7, epoch 2: epoch_accuracy 4.427083333333333, epoch_loss 2.2925927752540227
# Round 5, cleint 7, epoch 3: epoch_accuracy 4.278273809523809, epoch_loss 2.2918496813092912
# Round 5, cleint 7, epoch 4: epoch_accuracy 5.245535714285714, epoch_loss 2.2903488250005815
# Round 5, cleint 7, epoch 5: epoch_accuracy 5.840773809523809, epoch_loss 2.2899562971932546
# Round 5, cleint 8, epoch 1: epoch_accuracy 4.39453125, epoch_loss 2.2973337173461914
# Round 5, cleint 8, epoch 2: epoch_accuracy 5.517578125, epoch_loss 2.2967029362916946
# Round 5, cleint 8, epoch 3: epoch_accuracy 6.494140625, epoch_loss 2.2950711101293564
# Round 5, cleint 8, epoch 4: epoch_accuracy 6.103515625, epoch_loss 2.2946006506681442
# Round 5, cleint 8, epoch 5: epoch_accuracy 8.0078125, epoch_loss 2.293442875146866
# Round 5, cleint 9, epoch 1: epoch_accuracy 18.566176470588236, epoch_loss 2.29223090059617
# Round 5, cleint 9, epoch 2: epoch_accuracy 18.658088235294116, epoch_loss 2.29183835141799
# Round 5, cleint 9, epoch 3: epoch_accuracy 19.347426470588236, epoch_loss 2.291798100751989
# Round 5, cleint 9, epoch 4: epoch_accuracy 18.428308823529413, epoch_loss 2.2915302024168125
# Round 5, cleint 9, epoch 5: epoch_accuracy 19.89889705882353, epoch_loss 2.290656103807337
# Round 5, cleint 10, epoch 1: epoch_accuracy 1.4322916666666667, epoch_loss 2.322070856889089
# Round 5, cleint 10, epoch 2: epoch_accuracy 1.3020833333333333, epoch_loss 2.3226251204808555
# Round 5, cleint 10, epoch 3: epoch_accuracy 1.171875, epoch_loss 2.321446657180786
# Round 5, cleint 10, epoch 4: epoch_accuracy 1.171875, epoch_loss 2.320790429910024
# Round 5, cleint 10, epoch 5: epoch_accuracy 1.3020833333333333, epoch_loss 2.3200616439183555
# Round 5, cleint 11, epoch 1: epoch_accuracy 11.40625, epoch_loss 2.290354776382446
# Round 5, cleint 11, epoch 2: epoch_accuracy 9.84375, epoch_loss 2.2913710117340087
# Round 5, cleint 11, epoch 3: epoch_accuracy 11.09375, epoch_loss 2.2920286655426025
# Round 5, cleint 11, epoch 4: epoch_accuracy 10.625, epoch_loss 2.2903580188751222
# Round 5, cleint 11, epoch 5: epoch_accuracy 10.3125, epoch_loss 2.28995099067688
# Round 5, cleint 12, epoch 1: epoch_accuracy 9.659090909090908, epoch_loss 2.295589425347068
# Round 5, cleint 12, epoch 2: epoch_accuracy 10.511363636363637, epoch_loss 2.294843782078136
# Round 5, cleint 12, epoch 3: epoch_accuracy 10.227272727272727, epoch_loss 2.2932316173206675
# Round 5, cleint 12, epoch 4: epoch_accuracy 10.795454545454545, epoch_loss 2.2939028306440874
# Round 5, cleint 12, epoch 5: epoch_accuracy 10.582386363636363, epoch_loss 2.292728402397849
# Round 5, cleint 13, epoch 1: epoch_accuracy 12.890625, epoch_loss 2.305297613143921
# Round 5, cleint 13, epoch 2: epoch_accuracy 13.59375, epoch_loss 2.3044569730758666
# Round 5, cleint 13, epoch 3: epoch_accuracy 13.515625, epoch_loss 2.3046055316925047
# Round 5, cleint 13, epoch 4: epoch_accuracy 13.90625, epoch_loss 2.304627203941345
# Round 5, cleint 13, epoch 5: epoch_accuracy 13.90625, epoch_loss 2.3044742345809937
# Round 5, cleint 14, epoch 1: epoch_accuracy 7.161458333333333, epoch_loss 2.309296210606893
# Round 5, cleint 14, epoch 2: epoch_accuracy 7.530381944444445, epoch_loss 2.308526542451647
# Round 5, cleint 14, epoch 3: epoch_accuracy 8.246527777777779, epoch_loss 2.308442850907644
# Round 5, cleint 14, epoch 4: epoch_accuracy 8.528645833333334, epoch_loss 2.307446241378784
# Round 5, cleint 14, epoch 5: epoch_accuracy 8.81076388888889, epoch_loss 2.306380854712592
# Round 5, cleint 15, epoch 1: epoch_accuracy 36.495535714285715, epoch_loss 2.2808479411261424
# Round 5, cleint 15, epoch 2: epoch_accuracy 38.22544642857143, epoch_loss 2.2793380362646922
# Round 5, cleint 15, epoch 3: epoch_accuracy 38.504464285714285, epoch_loss 2.2792460237230574
# Round 5, cleint 15, epoch 4: epoch_accuracy 40.625, epoch_loss 2.2776107617786954
# Round 5, cleint 15, epoch 5: epoch_accuracy 40.56919642857143, epoch_loss 2.2768960850579396
# Round 5, cleint 16, epoch 1: epoch_accuracy 6.620065789473684, epoch_loss 2.3117379765761528
# Round 5, cleint 16, epoch 2: epoch_accuracy 6.578947368421052, epoch_loss 2.3101845164048043
# Round 5, cleint 16, epoch 3: epoch_accuracy 6.4144736842105265, epoch_loss 2.3093722368541516
# Round 5, cleint 16, epoch 4: epoch_accuracy 6.578947368421052, epoch_loss 2.3083320165935315
# Round 5, cleint 16, epoch 5: epoch_accuracy 6.743421052631579, epoch_loss 2.3063975384360864
# Round 5, cleint 17, epoch 1: epoch_accuracy 17.708333333333332, epoch_loss 2.286884578069051
# Round 5, cleint 17, epoch 2: epoch_accuracy 18.541666666666668, epoch_loss 2.2867037932078045
# Round 5, cleint 17, epoch 3: epoch_accuracy 18.28125, epoch_loss 2.286252578099569
# Round 5, cleint 17, epoch 4: epoch_accuracy 18.854166666666668, epoch_loss 2.286076227823893
# Round 5, cleint 17, epoch 5: epoch_accuracy 18.385416666666668, epoch_loss 2.286054786046346
# Round 5, cleint 18, epoch 1: epoch_accuracy 2.6429521276595747, epoch_loss 2.3148463076733528
# Round 5, cleint 18, epoch 2: epoch_accuracy 2.7593085106382977, epoch_loss 2.3135753540282553
# Round 5, cleint 18, epoch 3: epoch_accuracy 2.8756648936170213, epoch_loss 2.312618499106549
# Round 5, cleint 18, epoch 4: epoch_accuracy 3.257978723404255, epoch_loss 2.3109489400336085
# Round 5, cleint 18, epoch 5: epoch_accuracy 3.5904255319148937, epoch_loss 2.3096466622454055
# Round 5, cleint 19, epoch 1: epoch_accuracy 6.796875, epoch_loss 2.3078559160232546
# Round 5, cleint 19, epoch 2: epoch_accuracy 6.640625, epoch_loss 2.3075523376464844
# Round 5, cleint 19, epoch 3: epoch_accuracy 5.859375, epoch_loss 2.308249282836914
# Round 5, cleint 19, epoch 4: epoch_accuracy 6.71875, epoch_loss 2.3063908338546755
# Round 5, cleint 19, epoch 5: epoch_accuracy 6.796875, epoch_loss 2.3056915044784545
# Round 5, cleint 20, epoch 1: epoch_accuracy 1.8229166666666667, epoch_loss 2.318109567960103
# Round 5, cleint 20, epoch 2: epoch_accuracy 1.71875, epoch_loss 2.3165781418482463
# Round 5, cleint 20, epoch 3: epoch_accuracy 1.875, epoch_loss 2.3151368856430055
# Round 5, cleint 20, epoch 4: epoch_accuracy 2.3697916666666665, epoch_loss 2.3143975337346396
# Round 5, cleint 20, epoch 5: epoch_accuracy 2.1614583333333335, epoch_loss 2.313501159350077
# Model's Round: 5, train accuracy of model: 11.85983051083058, train loss of model: 2.2974414842222375
#
#
# Model's Round: 5, test accuracy of model: 10.013977635782748, test loss of model: 2.302697599124604
#
#
# round 5 completed
# Round 6, cleint 1, epoch 1: epoch_accuracy 1.9791666666666667, epoch_loss 2.307408062616984
# Round 6, cleint 1, epoch 2: epoch_accuracy 1.6666666666666667, epoch_loss 2.307035303115845
# Round 6, cleint 1, epoch 3: epoch_accuracy 1.5625, epoch_loss 2.306208912531535
# Round 6, cleint 1, epoch 4: epoch_accuracy 2.2916666666666665, epoch_loss 2.3060481866200764
# Round 6, cleint 1, epoch 5: epoch_accuracy 1.6666666666666667, epoch_loss 2.306634775797526
# Round 6, cleint 2, epoch 1: epoch_accuracy 31.770833333333332, epoch_loss 2.266575225194295
# Round 6, cleint 2, epoch 2: epoch_accuracy 28.489583333333332, epoch_loss 2.2668168703715006
# Round 6, cleint 2, epoch 3: epoch_accuracy 30.3125, epoch_loss 2.265515184402466
# Round 6, cleint 2, epoch 4: epoch_accuracy 29.53125, epoch_loss 2.264373302459717
# Round 6, cleint 2, epoch 5: epoch_accuracy 30.104166666666668, epoch_loss 2.2638444900512695
# Round 6, cleint 3, epoch 1: epoch_accuracy 4.947916666666667, epoch_loss 2.3210507057331227
# Round 6, cleint 3, epoch 2: epoch_accuracy 5.150462962962963, epoch_loss 2.3203795044510453
# Round 6, cleint 3, epoch 3: epoch_accuracy 5.179398148148148, epoch_loss 2.319550982228032
# Round 6, cleint 3, epoch 4: epoch_accuracy 5.439814814814815, epoch_loss 2.318934679031372
# Round 6, cleint 3, epoch 5: epoch_accuracy 5.150462962962963, epoch_loss 2.318619586803295
# Round 6, cleint 4, epoch 1: epoch_accuracy 7.083333333333333, epoch_loss 2.3012553373972575
# Round 6, cleint 4, epoch 2: epoch_accuracy 6.927083333333333, epoch_loss 2.3002294063568116
# Round 6, cleint 4, epoch 3: epoch_accuracy 7.083333333333333, epoch_loss 2.299884589513143
# Round 6, cleint 4, epoch 4: epoch_accuracy 6.875, epoch_loss 2.299489736557007
# Round 6, cleint 4, epoch 5: epoch_accuracy 7.447916666666667, epoch_loss 2.2989919821421307
# ...
# Round 29, cleint 6, epoch 5: epoch_accuracy 2.03125, epoch_loss 2.305940532684326
# Round 29, cleint 7, epoch 1: epoch_accuracy 3.6086309523809526, epoch_loss 2.2960106304713657
# Round 29, cleint 7, epoch 2: epoch_accuracy 4.352678571428571, epoch_loss 2.2941758973257884
# Round 29, cleint 7, epoch 3: epoch_accuracy 4.055059523809524, epoch_loss 2.29327476592291
# Round 29, cleint 7, epoch 4: epoch_accuracy 5.208333333333333, epoch_loss 2.29224199340457
# Round 29, cleint 7, epoch 5: epoch_accuracy 6.584821428571429, epoch_loss 2.290313175746373
# Round 29, cleint 8, epoch 1: epoch_accuracy 5.76171875, epoch_loss 2.2963799089193344
# Round 29, cleint 8, epoch 2: epoch_accuracy 6.494140625, epoch_loss 2.2953820526599884
# Round 29, cleint 8, epoch 3: epoch_accuracy 7.91015625, epoch_loss 2.2939955443143845
# Round 29, cleint 8, epoch 4: epoch_accuracy 8.30078125, epoch_loss 2.293168991804123
# Round 29, cleint 8, epoch 5: epoch_accuracy 9.765625, epoch_loss 2.2922362089157104
# Round 29, cleint 9, epoch 1: epoch_accuracy 18.658088235294116, epoch_loss 2.2919020652770996
# Round 29, cleint 9, epoch 2: epoch_accuracy 17.647058823529413, epoch_loss 2.2923427048851464
# Round 29, cleint 9, epoch 3: epoch_accuracy 18.566176470588236, epoch_loss 2.291396337396958
# Round 29, cleint 9, epoch 4: epoch_accuracy 19.25551470588235, epoch_loss 2.291614251978257
# Round 29, cleint 9, epoch 5: epoch_accuracy 19.02573529411765, epoch_loss 2.2900560322929833
# Round 29, cleint 10, epoch 1: epoch_accuracy 1.3020833333333333, epoch_loss 2.3216023047765098
# Round 29, cleint 10, epoch 2: epoch_accuracy 1.3671875, epoch_loss 2.3210595846176147
# Round 29, cleint 10, epoch 3: epoch_accuracy 1.3671875, epoch_loss 2.3207122484842935
# Round 29, cleint 10, epoch 4: epoch_accuracy 1.953125, epoch_loss 2.319245199362437
# Round 29, cleint 10, epoch 5: epoch_accuracy 1.3020833333333333, epoch_loss 2.319234549999237
# Round 29, cleint 11, epoch 1: epoch_accuracy 10.3125, epoch_loss 2.2914249420166017
# Round 29, cleint 11, epoch 2: epoch_accuracy 11.5625, epoch_loss 2.291103219985962
# Round 29, cleint 11, epoch 3: epoch_accuracy 11.09375, epoch_loss 2.2908381462097167
# Round 29, cleint 11, epoch 4: epoch_accuracy 12.5, epoch_loss 2.2901241302490236
# Round 29, cleint 11, epoch 5: epoch_accuracy 11.09375, epoch_loss 2.2915180683135987
# Round 29, cleint 12, epoch 1: epoch_accuracy 10.369318181818182, epoch_loss 2.2943563894792036
# Round 29, cleint 12, epoch 2: epoch_accuracy 9.730113636363637, epoch_loss 2.295482180335305
# Round 29, cleint 12, epoch 3: epoch_accuracy 10.014204545454545, epoch_loss 2.294037016955289
# Round 29, cleint 12, epoch 4: epoch_accuracy 10.866477272727273, epoch_loss 2.2920032197778877
# Round 29, cleint 12, epoch 5: epoch_accuracy 11.221590909090908, epoch_loss 2.2919382832267066
# Round 29, cleint 13, epoch 1: epoch_accuracy 13.984375, epoch_loss 2.3045766592025756
# Round 29, cleint 13, epoch 2: epoch_accuracy 14.21875, epoch_loss 2.3041003704071046
# Round 29, cleint 13, epoch 3: epoch_accuracy 14.609375, epoch_loss 2.3037092208862306
# Round 29, cleint 13, epoch 4: epoch_accuracy 13.28125, epoch_loss 2.3046630144119264
# Round 29, cleint 13, epoch 5: epoch_accuracy 13.4375, epoch_loss 2.3048341274261475
# Round 29, cleint 14, epoch 1: epoch_accuracy 7.465277777777778, epoch_loss 2.308597809738583
# Round 29, cleint 14, epoch 2: epoch_accuracy 7.508680555555555, epoch_loss 2.3081133696768017
# Round 29, cleint 14, epoch 3: epoch_accuracy 7.465277777777778, epoch_loss 2.307794531186422
# Round 29, cleint 14, epoch 4: epoch_accuracy 8.7890625, epoch_loss 2.307104614045885
# Round 29, cleint 14, epoch 5: epoch_accuracy 9.20138888888889, epoch_loss 2.306097514099545
# Round 29, cleint 15, epoch 1: epoch_accuracy 36.830357142857146, epoch_loss 2.2814332587378368
# Round 29, cleint 15, epoch 2: epoch_accuracy 38.002232142857146, epoch_loss 2.2798670700618198
# Round 29, cleint 15, epoch 3: epoch_accuracy 38.61607142857143, epoch_loss 2.280146632875715
# Round 29, cleint 15, epoch 4: epoch_accuracy 38.950892857142854, epoch_loss 2.278792772974287
# Round 29, cleint 15, epoch 5: epoch_accuracy 38.61607142857143, epoch_loss 2.2780809232166837
# Round 29, cleint 16, epoch 1: epoch_accuracy 6.743421052631579, epoch_loss 2.31039413652922
# Round 29, cleint 16, epoch 2: epoch_accuracy 6.496710526315789, epoch_loss 2.3087664403413473
# Round 29, cleint 16, epoch 3: epoch_accuracy 6.8667763157894735, epoch_loss 2.3068876015512565
# Round 29, cleint 16, epoch 4: epoch_accuracy 7.113486842105263, epoch_loss 2.305750608444214
# Round 29, cleint 16, epoch 5: epoch_accuracy 6.8667763157894735, epoch_loss 2.304849762665598
# Round 29, cleint 17, epoch 1: epoch_accuracy 18.125, epoch_loss 2.2883127371470136
# Round 29, cleint 17, epoch 2: epoch_accuracy 18.072916666666668, epoch_loss 2.2872249444325763
# Round 29, cleint 17, epoch 3: epoch_accuracy 17.96875, epoch_loss 2.2873457431793214
# Round 29, cleint 17, epoch 4: epoch_accuracy 18.4375, epoch_loss 2.287501859664917
# Round 29, cleint 17, epoch 5: epoch_accuracy 18.072916666666668, epoch_loss 2.286768388748169
# Round 29, cleint 18, epoch 1: epoch_accuracy 2.942154255319149, epoch_loss 2.3135689015084124
# Round 29, cleint 18, epoch 2: epoch_accuracy 3.108377659574468, epoch_loss 2.3123641318463264
# Round 29, cleint 18, epoch 3: epoch_accuracy 3.5904255319148937, epoch_loss 2.310567135506488
# Round 29, cleint 18, epoch 4: epoch_accuracy 4.1888297872340425, epoch_loss 2.30894258681764
# Round 29, cleint 18, epoch 5: epoch_accuracy 4.055851063829787, epoch_loss 2.3077505192858108
# Round 29, cleint 19, epoch 1: epoch_accuracy 6.328125, epoch_loss 2.30739586353302
# Round 29, cleint 19, epoch 2: epoch_accuracy 6.015625, epoch_loss 2.3068645715713503
# Round 29, cleint 19, epoch 3: epoch_accuracy 6.71875, epoch_loss 2.306221079826355
# Round 29, cleint 19, epoch 4: epoch_accuracy 6.796875, epoch_loss 2.3059072971343992
# Round 29, cleint 19, epoch 5: epoch_accuracy 6.484375, epoch_loss 2.3054521322250365
# Round 29, cleint 20, epoch 1: epoch_accuracy 1.71875, epoch_loss 2.316973344484965
# Round 29, cleint 20, epoch 2: epoch_accuracy 1.796875, epoch_loss 2.315247352917989
# Round 29, cleint 20, epoch 3: epoch_accuracy 2.1875, epoch_loss 2.3142166058222453
# Round 29, cleint 20, epoch 4: epoch_accuracy 2.2135416666666665, epoch_loss 2.3135530789693197
# Round 29, cleint 20, epoch 5: epoch_accuracy 1.875, epoch_loss 2.3127355734507242
# Model's Round: 29, train accuracy of model: 11.966167411029874, train loss of model: 2.297271837054984
#
#
# Model's Round: 29, test accuracy of model: 10.013977635782748, test loss of model: 2.3024590426740557
#
#
# round 29 completed
# Round 30, cleint 1, epoch 1: epoch_accuracy 2.2916666666666665, epoch_loss 2.306793276468913
# Round 30, cleint 1, epoch 2: epoch_accuracy 1.8229166666666667, epoch_loss 2.3067934989929197
# Round 30, cleint 1, epoch 3: epoch_accuracy 2.1875, epoch_loss 2.3062299251556397
# Round 30, cleint 1, epoch 4: epoch_accuracy 2.2395833333333335, epoch_loss 2.3057862917582193
# Round 30, cleint 1, epoch 5: epoch_accuracy 1.8229166666666667, epoch_loss 2.3060683886210125
# Round 30, cleint 2, epoch 1: epoch_accuracy 29.583333333333332, epoch_loss 2.2696564197540283
# Round 30, cleint 2, epoch 2: epoch_accuracy 29.947916666666668, epoch_loss 2.26763710975647
# Round 30, cleint 2, epoch 3: epoch_accuracy 30.260416666666668, epoch_loss 2.2669230461120606
# Round 30, cleint 2, epoch 4: epoch_accuracy 30.052083333333332, epoch_loss 2.266373793284098
# Round 30, cleint 2, epoch 5: epoch_accuracy 29.791666666666668, epoch_loss 2.2653449376424155
# Round 30, cleint 3, epoch 1: epoch_accuracy 4.832175925925926, epoch_loss 2.3201559914482965
# Round 30, cleint 3, epoch 2: epoch_accuracy 5.266203703703703, epoch_loss 2.3193559028484203
# Round 30, cleint 3, epoch 3: epoch_accuracy 5.208333333333333, epoch_loss 2.3185395223123058
# Round 30, cleint 3, epoch 4: epoch_accuracy 5.150462962962963, epoch_loss 2.3176582566014043
# Round 30, cleint 3, epoch 5: epoch_accuracy 5.208333333333333, epoch_loss 2.317323508086028
# Round 30, cleint 4, epoch 1: epoch_accuracy 7.1875, epoch_loss 2.30052014986674
# Round 30, cleint 4, epoch 2: epoch_accuracy 7.8125, epoch_loss 2.301377868652344
# Round 30, cleint 4, epoch 3: epoch_accuracy 7.8125, epoch_loss 2.3010045369466146
# Round 30, cleint 4, epoch 4: epoch_accuracy 8.020833333333334, epoch_loss 2.299474064509074
# Round 30, cleint 4, epoch 5: epoch_accuracy 7.760416666666667, epoch_loss 2.299585501352946
# Round 30, cleint 5, epoch 1: epoch_accuracy 33.29326923076923, epoch_loss 2.273708545244657
# Round 30, cleint 5, epoch 2: epoch_accuracy 32.03125, epoch_loss 2.2731612829061656
# Round 30, cleint 5, epoch 3: epoch_accuracy 33.47355769230769, epoch_loss 2.2722579332498403
# Round 30, cleint 5, epoch 4: epoch_accuracy 33.71394230769231, epoch_loss 2.2710998333417454
# Round 30, cleint 5, epoch 5: epoch_accuracy 33.80408653846154, epoch_loss 2.2698108416337233
# Round 30, cleint 6, epoch 1: epoch_accuracy 1.875, epoch_loss 2.3083165645599366
# Round 30, cleint 6, epoch 2: epoch_accuracy 1.8359375, epoch_loss 2.3079877614974977
# Round 30, cleint 6, epoch 3: epoch_accuracy 2.1875, epoch_loss 2.3078148126602174
# Round 30, cleint 6, epoch 4: epoch_accuracy 2.03125, epoch_loss 2.3064653873443604
# Round 30, cleint 6, epoch 5: epoch_accuracy 2.1484375, epoch_loss 2.3059507489204405
# Round 30, cleint 7, epoch 1: epoch_accuracy 3.90625, epoch_loss 2.295491093680972
# Round 30, cleint 7, epoch 2: epoch_accuracy 4.799107142857143, epoch_loss 2.2944012710026334
# Round 30, cleint 7, epoch 3: epoch_accuracy 4.947916666666667, epoch_loss 2.2928716455187117
# Round 30, cleint 7, epoch 4: epoch_accuracy 4.799107142857143, epoch_loss 2.2917892705826532
# Round 30, cleint 7, epoch 5: epoch_accuracy 6.175595238095238, epoch_loss 2.290336597533453
# Round 30, cleint 8, epoch 1: epoch_accuracy 6.298828125, epoch_loss 2.2957698851823807
# Round 30, cleint 8, epoch 2: epoch_accuracy 5.615234375, epoch_loss 2.2955040633678436
# Round 30, cleint 8, epoch 3: epoch_accuracy 7.373046875, epoch_loss 2.2941804230213165
# Round 30, cleint 8, epoch 4: epoch_accuracy 8.251953125, epoch_loss 2.2928297370672226
# Round 30, cleint 8, epoch 5: epoch_accuracy 8.10546875, epoch_loss 2.293046846985817
# Round 30, cleint 9, epoch 1: epoch_accuracy 18.979779411764707, epoch_loss 2.2932697043699375
# Round 30, cleint 9, epoch 2: epoch_accuracy 18.658088235294116, epoch_loss 2.292551180895637
# Round 30, cleint 9, epoch 3: epoch_accuracy 19.347426470588236, epoch_loss 2.292015215929817
# Round 30, cleint 9, epoch 4: epoch_accuracy 18.24448529411765, epoch_loss 2.2915128539590275
# Round 30, cleint 9, epoch 5: epoch_accuracy 19.347426470588236, epoch_loss 2.2913597471573772
# Round 30, cleint 10, epoch 1: epoch_accuracy 1.171875, epoch_loss 2.3218176563580832
# Round 30, cleint 10, epoch 2: epoch_accuracy 1.3671875, epoch_loss 2.3216839035352073
# Round 30, cleint 10, epoch 3: epoch_accuracy 1.4973958333333333, epoch_loss 2.320355316003164
# Round 30, cleint 10, epoch 4: epoch_accuracy 1.2369791666666667, epoch_loss 2.319929778575897
# Round 30, cleint 10, epoch 5: epoch_accuracy 1.1067708333333333, epoch_loss 2.3198931415875754
# Round 30, cleint 11, epoch 1: epoch_accuracy 11.5625, epoch_loss 2.290430021286011
# Round 30, cleint 11, epoch 2: epoch_accuracy 10.46875, epoch_loss 2.291260099411011
# Round 30, cleint 11, epoch 3: epoch_accuracy 10.9375, epoch_loss 2.2910742282867433
# Round 30, cleint 11, epoch 4: epoch_accuracy 12.65625, epoch_loss 2.290961503982544
# Round 30, cleint 11, epoch 5: epoch_accuracy 9.6875, epoch_loss 2.292147731781006
# Round 30, cleint 12, epoch 1: epoch_accuracy 10.014204545454545, epoch_loss 2.294982758435336
# Round 30, cleint 12, epoch 2: epoch_accuracy 10.511363636363637, epoch_loss 2.294834917241877
# Round 30, cleint 12, epoch 3: epoch_accuracy 10.795454545454545, epoch_loss 2.2934315638108687
# Round 30, cleint 12, epoch 4: epoch_accuracy 12.144886363636363, epoch_loss 2.2921801046891646
# Round 30, cleint 12, epoch 5: epoch_accuracy 10.653409090909092, epoch_loss 2.2925111163746226
# Round 30, cleint 13, epoch 1: epoch_accuracy 13.984375, epoch_loss 2.3049665212631227
# Round 30, cleint 13, epoch 2: epoch_accuracy 13.671875, epoch_loss 2.304198384284973
# Round 30, cleint 13, epoch 3: epoch_accuracy 14.6875, epoch_loss 2.3043571949005126
# Round 30, cleint 13, epoch 4: epoch_accuracy 13.671875, epoch_loss 2.304659128189087
# Round 30, cleint 13, epoch 5: epoch_accuracy 13.90625, epoch_loss 2.3042840003967284
# Round 30, cleint 14, epoch 1: epoch_accuracy 7.291666666666667, epoch_loss 2.3084733022583857
# Round 30, cleint 14, epoch 2: epoch_accuracy 6.966145833333333, epoch_loss 2.3082566459973655
# Round 30, cleint 14, epoch 3: epoch_accuracy 8.02951388888889, epoch_loss 2.3080553478664823
# Round 30, cleint 14, epoch 4: epoch_accuracy 8.76736111111111, epoch_loss 2.3071400125821433
# Round 30, cleint 14, epoch 5: epoch_accuracy 9.5703125, epoch_loss 2.3059430850876703
# Round 30, cleint 15, epoch 1: epoch_accuracy 37.05357142857143, epoch_loss 2.2811944825308665
# Round 30, cleint 15, epoch 2: epoch_accuracy 38.058035714285715, epoch_loss 2.2804222788129533
# Round 30, cleint 15, epoch 3: epoch_accuracy 37.44419642857143, epoch_loss 2.2802096775599887
# Round 30, cleint 15, epoch 4: epoch_accuracy 39.285714285714285, epoch_loss 2.2790075881140575
# Round 30, cleint 15, epoch 5: epoch_accuracy 39.229910714285715, epoch_loss 2.278594034058707
# Round 30, cleint 16, epoch 1: epoch_accuracy 6.291118421052632, epoch_loss 2.3093200357336747
# Round 30, cleint 16, epoch 2: epoch_accuracy 6.25, epoch_loss 2.3090677888769853
# Round 30, cleint 16, epoch 3: epoch_accuracy 6.990131578947368, epoch_loss 2.3073126265877173
# Round 30, cleint 16, epoch 4: epoch_accuracy 6.743421052631579, epoch_loss 2.3058458503923918
# Round 30, cleint 16, epoch 5: epoch_accuracy 6.907894736842105, epoch_loss 2.3052631804817603
# Round 30, cleint 17, epoch 1: epoch_accuracy 18.385416666666668, epoch_loss 2.2883803208669025
# Round 30, cleint 17, epoch 2: epoch_accuracy 18.541666666666668, epoch_loss 2.287501589457194
# Round 30, cleint 17, epoch 3: epoch_accuracy 18.177083333333332, epoch_loss 2.2875791867574056
# Round 30, cleint 17, epoch 4: epoch_accuracy 18.75, epoch_loss 2.2865286509195966
# Round 30, cleint 17, epoch 5: epoch_accuracy 17.864583333333332, epoch_loss 2.286298974355062
# Round 30, cleint 18, epoch 1: epoch_accuracy 2.908909574468085, epoch_loss 2.3135512534608234
# Round 30, cleint 18, epoch 2: epoch_accuracy 3.158244680851064, epoch_loss 2.3120605336858873
# Round 30, cleint 18, epoch 3: epoch_accuracy 3.5405585106382977, epoch_loss 2.310921466096919
# Round 30, cleint 18, epoch 4: epoch_accuracy 3.856382978723404, epoch_loss 2.3094847050118954
# Round 30, cleint 18, epoch 5: epoch_accuracy 4.305186170212766, epoch_loss 2.307998444171662
# Round 30, cleint 19, epoch 1: epoch_accuracy 6.171875, epoch_loss 2.3077431201934813
# Round 30, cleint 19, epoch 2: epoch_accuracy 6.484375, epoch_loss 2.3054944038391114
# Round 30, cleint 19, epoch 3: epoch_accuracy 7.34375, epoch_loss 2.3064966201782227
# Round 30, cleint 19, epoch 4: epoch_accuracy 7.109375, epoch_loss 2.304546022415161
# Round 30, cleint 19, epoch 5: epoch_accuracy 6.40625, epoch_loss 2.3063717603683473
# Round 30, cleint 20, epoch 1: epoch_accuracy 1.9791666666666667, epoch_loss 2.3167183001836142
# Round 30, cleint 20, epoch 2: epoch_accuracy 1.9010416666666667, epoch_loss 2.3158740679423016
# Round 30, cleint 20, epoch 3: epoch_accuracy 1.8229166666666667, epoch_loss 2.3148998339970905
# Round 30, cleint 20, epoch 4: epoch_accuracy 2.578125, epoch_loss 2.313541809717814
# Round 30, cleint 20, epoch 5: epoch_accuracy 1.796875, epoch_loss 2.312681865692139
# Model's Round: 30, train accuracy of model: 11.779964510469735, train loss of model: 2.2975407226144244
#
#
# Model's Round: 30, test accuracy of model: 10.013977635782748, test loss of model: 2.302449113644731
#
#
# round 30 completed

# %% [markdown]
# # Reuslts

# %%
# Define the folder and file name
folder_name = f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"


# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
folder_name =  f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
