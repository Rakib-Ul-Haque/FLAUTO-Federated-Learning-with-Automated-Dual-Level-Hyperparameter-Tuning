# %% [markdown]
# <H1>Import Libraries</H1>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# from sklearn.metrics import confusion_matrix
from torchvision.datasets import CIFAR10
from collections import Counter
import random
import copy
import torch.nn.functional as F
import os
import sys
import time
import pickle
import pandas as pd
from torch import Tensor
from typing import Type
import torchvision.models as models
from torchvision import transforms

# Set font family for plots
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# <H1>Load Dataset</H1>

# %%
# transform = transforms.Compose([
#     transforms.ToTensor(), #This transformation converts a PIL (Python Imaging Library) Image or numpy.ndarray (with shape (H x W x C) in the range [0, 255]) into a PyTorch tensor of shape (C x H x W) in the range [0.0, 1.0]. It essentially rearranges the dimensions of the image data and scales it to a float value between 0 and 1.
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])


# train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# # train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)

# test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)
subset_dataset = torch.load('val_dataset.pth',weights_only=False)
remaining_dataset = torch.load('test_dataset.pth',weights_only=False)

# Create DataLoaders
val_loader = DataLoader(subset_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(remaining_dataset, batch_size=32, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <H1>IID</H1>

# %%
def distribute_dataset_equally(dataset, num_clients):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    # Distribute data
    client_data = [[] for _ in range(num_clients)]
    for label, data in class_data.items():
        data_len = len(data)
        base_size = data_len // num_clients
        remain = data_len - base_size * num_clients

        current_idx = 0
        for i in range(num_clients):
            end_idx = current_idx + base_size + (1 if i < remain else 0)
            client_data[i].extend(data[current_idx:end_idx])
            current_idx = end_idx


    print_iid_distribution(client_data)
    plot_iid_dataset(client_data,num_clients)

    return client_data

# %%
#print client iid_data distribution
def print_iid_distribution(iid_datasets):
    # Check if the distribution is correct
    for i, client_data in enumerate(iid_datasets):
        print(f"Client {i + 1} data size: {len(client_data)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# Plot client iid_data distribution
def plot_iid_dataset(iid_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in iid_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define colors for each class
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")
    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number',labelpad=5)
    ax.set_ylabel('CIFAR-10 Classes',labelpad=15)
    ax.set_zlabel('Fraction of Distribution',labelpad=5)
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], rotation=45)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names, rotation=-60)

    #ax.view_init(elev=40, azim=60)
    ax.view_init(elev=40, azim=10)

    plt.subplots_adjust(left=0.01, right=0.99, bottom=0.01, top=0.99)

    plt.show()

# %% [markdown]
# <H1>non-IID</H1>

# %%
#Print the distribution non IID
def print_distribution(client_data):
    # Check distribution
    for l, client_data_value in enumerate(client_data):
        print(f"Client {l + 1} data size: {len(client_data_value)}")
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data_value:
            class_counts[label] += 1
        print(f"Class distribution: {class_counts}")

# %%
# #Non IID code
def distribute_dataset_dirichlet(dataset, num_clients, alpha):
    # Group data by class
    class_data = {}
    for data, label in dataset:
        if label not in class_data:
            class_data[label] = []
        class_data[label].append((data, label))

    client_data = [[] for _ in range(num_clients)]
    for _, data_list in class_data.items():
        # Shuffle data for randomness
        np.random.shuffle(data_list)

        # Get proportions for data split based on Dirichlet distribution
        proportions = np.random.dirichlet([alpha]*num_clients)
        # print("Proportions: ", proportions)
        total_data = len(data_list)
        # print("total_data: ", total_data)
        data_splits = [int(proportions[i]*total_data) for i in range(num_clients)]
        # print("Data_Split: ", data_splits)

        # Adjust the splits to account for rounding errors
        # print("Before data_split:",data_splits)
        data_splits[-1] += total_data - sum(data_splits)
        print("After data_split:",data_splits)

        start_idx = 0
        for i, split in enumerate(data_splits):
            end_idx = start_idx + split
            client_data[i].extend(data_list[start_idx:end_idx])
            start_idx = end_idx
    print("Client Number: ",num_clients, "Alpha: ", alpha)
    print_distribution(client_data)
    plot_distribution(client_data, num_clients )
    return client_data

# %%
#show the graphs for nonIID
def plot_distribution(client_datasets, num_clients):
    # CIFAR-10 class names
    class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
    # Calculate fraction of distribution for each class across clients
    fractions = []
    for client_data in client_datasets:
        class_counts = {j: 0 for j in range(10)}
        for _, label in client_data:
            class_counts[label] += 1
        total_data = len(client_data)
        # print(total_data)
        fractions.append([class_counts[i] / total_data for i in range(10)])
    fractions = np.array(fractions)
    # Define distinct colors for classes using a colormap
    colors = ["r", "g", "b", "c", "m", "y", "#FFA500", "#FF00FF", "#808080", "#00FF00"]
    # # Generate the 3D bar chart
    # fig = plt.figure(figsize=(18, 12))
    # ax = fig.add_subplot(111, projection='3d')

    # Generate the 3D bar chart
    fig = plt.figure(figsize=(10, 7))  # Adjust the size here
    ax = fig.add_subplot(111, projection='3d')

    xpos, ypos = np.meshgrid(np.arange(num_clients), np.arange(10), indexing="ij")

    for i in range(10):
        ax.bar3d(xpos[:, i], ypos[:, i], np.zeros_like(xpos[:, i]),0.75, 0.75, fractions[:, i],shade=True, color=colors[i])

    ax.set_xlabel('Client Number')
    ax.set_ylabel('CIFAR-10 Classes')
    ax.set_zlabel('Fraction of Distribution')
    ax.set_title('Distribution of CIFAR-10 Classes across Clients based on Dirichlet Distribution')
    ax.set_xticks(np.arange(0.5, num_clients))
    ax.set_xticklabels([str(i+1) for i in range(num_clients)], fontsize=12)
    ax.set_yticks(np.arange(0.5, 10))
    ax.set_yticklabels(class_names)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Measures

# %%
def accuracy(outp, target):
    """Computes accuracy"""
    with torch.no_grad():
        pred = torch.argmax(outp, dim=1)
        correct = pred.eq(target).float().sum().item()
        return 100.0 * correct / target.size(0)

# %%
def Print(string, dictionary):
    first_key = next(iter(dictionary))
    first_value = dictionary[first_key]
    print(f"{string}:{first_key}: {first_value[0][0]}\n")

# %%
def forbinus_norm_function(w_i):
    value = 0
    for k in w_i.keys():
        value += torch.linalg.norm(w_i[k])
    return value.item()

# %%
def model_deviation_function(w_i, w_f):
    model_deviation = 0
    for k in w_i.keys():
        model_deviation += torch.linalg.norm(w_f[k].to(torch.float) - w_i[k].to(torch.float)) / torch.linalg.norm(w_i[k].to(torch.float))
    #print(model_deviation.item())
    return model_deviation.item()

# %% [markdown]
# # Model

# %%
class model(nn.Module):
    def __init__(self):
        super(model, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.5)
        
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.relu4 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.5)

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, 10)  # Change output to 10 for CIFAR-10 classes

    def forward(self, x):
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = self.relu3(self.conv3(x))
        x = self.relu4(self.conv4(x))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = x.view(x.size(0), -1)
        x = self.relu5(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Train

# %%
def train(i_weights, epochs, train_loader, le_rate, cli,roun, epoch_flag):
    global opti

    e_a, e_l=test(i_weights, test_loader)
    test_loss_epoch.append(e_l)
    
    local_model = model().to(device)
    criterion = nn.CrossEntropyLoss()
    if opti=="adam":
        optimizer = torch.optim.Adam(local_model.parameters(), lr=le_rate)
    elif opti=="sgd":
        optimizer = torch.optim.SGD(local_model.parameters(), lr=le_rate)
    
    epoch_train_accuracy=0 
    epoch_train_loss=0
    epoch_test_accuracy=0
    epoch_test_loss=0
    epoch_rmd=0

    local_model.load_state_dict(i_weights)

    local_model.train()  # Set the model to training mode

    flag_counter=0
    lr=le_rate
    # initial weights cathing and printing
    initial_weights = {k: v.clone() for k, v in local_model.state_dict().items()}
    #Print("Model's inside the function Initial weights for client",initial_weights)

    # Training loop
    for epoch in range(epochs):
        epoch_flag=epoch_flag+1
        # gradients_this_epoch = {}
        total_samples = 0
        total_loss=0
        correct_samples = 0
        for i, (inputs, labels) in enumerate(train_loader, 0):
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()
            # Forward + backward + optimize
            outputs = local_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()

            _, predicted = outputs.max(1)  # Get the index of the maximum value in outputs (predicted class)
            total_samples += labels.size(0)
            correct_samples += predicted.eq(labels).sum().item()
        
        if(total_samples!=0 and len(train_loader)!=0):
            epoch_accuracy = 100 * correct_samples / total_samples
            epoch_loss = total_loss / len(train_loader)
        else:
            epoch_accuracy = 100 * correct_samples / (total_samples+1)
            epoch_loss = total_loss / (len(train_loader)+1)
        print(f"Round {roun}, cleint {cli+1}, epoch {epoch+1}, current LR: {optimizer.param_groups[0]['lr']}, epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} ")

        a_f_w = {k: v.clone() for k, v in local_model.state_dict().items()}
        
        e_a, e_l=test(a_f_w, test_loader)
        test_loss_epoch.append(e_l)
        
        print(f"test loss difference {test_loss_epoch[epoch] - test_loss_epoch[epoch-1]}")
        
        if abs(test_loss_epoch[epoch] - test_loss_epoch[epoch-1]) < 0.002:
            lr= lr * 0.5
            optimizer.param_groups[0]['lr'] = lr

            current_learning_rate = optimizer.param_groups[0]['lr']
            #print("Current learning rate:", current_learning_rate)

            flag_counter=flag_counter+1

            if flag_counter==5:
                break


    
    f_weights = {k: v.clone() for k, v in local_model.state_dict().items()}

    #print(f"\n Round {roun}, cleint {cli}: epoch_accuracy {epoch_accuracy}, epoch_loss {epoch_loss} \n")
    epoch_train_accuracy=epoch_accuracy
    epoch_train_loss=epoch_loss
    epoch_test_accuracy, epoch_test_loss= test(f_weights, test_loader)
    
    
    epoch_rmd=model_deviation_function(initial_weights,f_weights)
    
    #saving data into dataframe
    epoch_data = [epoch_train_accuracy, epoch_train_loss, epoch_test_accuracy, epoch_test_loss, epoch_rmd]
    epoch_results.loc[len(epoch_results)] = epoch_data
    
    return epoch_accuracy,epoch_loss, f_weights, epoch_flag

# %% [markdown]
# # Test

# %%
def test(w,data):
    lmodel = model().to(device)
    criterion = nn.CrossEntropyLoss()  # Assuming a classification task
    #optimizer = torch.optim.SGD(lmodel.parameters(), lr=learning_rate)
    lmodel.load_state_dict(w)
    lmodel.eval()

    #checking the weights
    tw = lmodel.state_dict()
    #Print("Model's before testing the weights in global model",tw)

    # Evaluation phase for test set
    acc_list = []
    loss_list = []

    with torch.no_grad():
        for j, data in enumerate(data, 0):
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            out = lmodel(images)
            # Calculate loss
            loss = criterion(out, labels)
            loss_list.append(loss.item())
            #calculate accuracy
            acc = accuracy(out, labels)
            acc_list.append(acc)
    test_loss = np.mean(loss_list)
    test_accuracy = np.mean(acc_list)
    #print("Model's Test accuracy : {:.2f}%".format(test_accuracy))
    return test_accuracy, test_loss

# %% [markdown]
# # FL Structure

# %%
def federated_learning(i_w, data_client, C, P, R, E, learning_rate, b_size):
    
    global total_cleints_list, participating_client_list
    
    global_model.load_state_dict(i_w)
    #Print("Model's initial weights", i_w)

    #loop for round
    for r in range(1,R+1):
        round_train_accuracy=0
        round_train_loss=0
        round_test_accuracy=0
        round_test_loss=0
        epoch_flag=0

        #saving initial weights for spiking model
        i_w = {k: v.clone() for k, v in global_model.state_dict().items()}
        #Print("Model's initial weights", i_w)
        
        #colleting weights and results
        all_final_weights={}
        train_accuracy_list=[]
        train_loss_list=[]
        
        # Randomly select clients
        selected_clients = random.sample(total_cleints_list, P)
        participating_client_list.append(selected_clients)

        #loop for client
        for c, data in enumerate(data_client):
            
            if(c in selected_clients):
                
                train_loader = torch.utils.data.DataLoader(data, batch_size=b_size, shuffle=True, drop_last=True)
                
                #train model
                train_accuracy, train_loss, c_f_weights, epoch_flag = train(i_w, E, train_loader, learning_rate, c, r,epoch_flag)

                train_accuracy_list.append(train_accuracy)
                train_loss_list.append(train_loss)

                # Accumulate weights for the selected client
                for param_name, param_grad in c_f_weights.items():
                    if param_name in all_final_weights:
                        all_final_weights[param_name] += param_grad
                    else:
                        all_final_weights[param_name] = param_grad

            else:
                print(f"client {c} is not selectecd")
        
        round_epoch=(epoch_flag)
        
        #print("Total number of selected clients is", client_counter)
        round_train_loss=sum(train_loss_list)/len(train_loss_list)
        round_train_accuracy=sum(train_accuracy_list)/len(train_accuracy_list)

        print(f"Model's Round: {r}, train accuracy of model: {round_train_accuracy}, train loss of model: {round_train_loss} \n\n")

        for param_name in all_final_weights:
            all_final_weights[param_name] = all_final_weights[param_name].float() / len(selected_clients)

        round_test_accuracy, round_test_loss=test(all_final_weights, test_loader)
        print(f"Model's Round: {r}, test accuracy of model: {round_test_accuracy}, test loss of model: {round_test_loss} \n\n")

        #model deviation code
        round_rmd=model_deviation_function(i_w, all_final_weights)
        #print("Model deviation values: ", model_deviation)

        #saving data into dataframe
        round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
        round_results.loc[len(round_results)] = round_data
            
        global_model.load_state_dict(all_final_weights)
        print("round", r, "completed")

# %% [markdown]
# # Main Function

# %% [markdown]
# # Define parameters

# %%
#===========================Parameters==============================================================
client_no=20
participating_client=20
epochs=5
learning_rate=0.01
round_no=30
batch_size=128
distributions = "non_iid" # 'non_iid'
data_class=10
alpha=0.5
opti="sgd" # or sgd or adam

# List of clients

test_loss_epoch=[]

total_cleints_list = list(range(0, client_no))
# print(total_cleints_list)
participating_client_list=[]

method="fed_adap"

# Define dataframe for round results
round_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd', 'epoch']
round_results = pd.DataFrame(columns=round_columns)

# Define dataframe for epoch results
epoch_columns = ['train_accuracy', 'train_loss', 'test_accuracy', 'test_loss', 'rmd']
epoch_results = pd.DataFrame(columns=epoch_columns)

#===================================loading the saved weight list====================================================
global_model = model().to(device)
# initial_weights={k: v.clone() for k, v in global_model.state_dict().items()}
# Save the initial weights
file_path = "s_cnn.pth"
# torch.save(initial_weights, file_path)
initial_weights=torch.load(file_path,weights_only=True)
Print("Model's initial weights", initial_weights)
# Out:
# Model's initial weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')

# %% [markdown]
# <H1>Divide data among cleints</H1>

# %%
# #=================================loading IID data===========================
# if distributions == 'iid':
#     client_datasets = distribute_dataset_equally(train_dataset,client_no)
    
# elif distributions == 'non_iid':
#     client_datasets = distribute_dataset_dirichlet(train_dataset, client_no, alpha)
# else:
#     print("provide a valid distribution Please")

# %%
# # Save client_datasets to a file
# if distributions == 'iid':
#     with open('client_datasets_IID.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.5:
#     with open('client_datasets_non_IID_0_5.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)
# elif distributions == 'non_iid' and alpha==0.125:
#     with open('client_datasets_non_IID_0_125.pkl', 'wb') as f:
#         pickle.dump(client_datasets, f)

# print("client_datasets saved successfully.")

# %%
# Load client_datasets from a file
if distributions == 'iid':
    with open('20_client_datasets_IID.pkl', 'rb') as f:
        client_datasets = pickle.load(f)

elif distributions == 'non_iid' and alpha==0.5:
    with open('20_client_datasets_non_IID_0_5.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
    
elif distributions == 'non_iid' and alpha==0.125:
    with open('20_client_datasets_non_IID_0_125.pkl', 'rb') as f:
        client_datasets = pickle.load(f)
        
print("client_datasets loaded successfully.")
print_distribution(client_datasets)
# Out:
# client_datasets loaded successfully.
# Client 1 data size: 1928
# Class distribution: {0: 93, 1: 405, 2: 144, 3: 3, 4: 342, 5: 365, 6: 25, 7: 64, 8: 248, 9: 239}
# Client 2 data size: 1997
# Class distribution: {0: 38, 1: 0, 2: 921, 3: 588, 4: 14, 5: 9, 6: 58, 7: 51, 8: 11, 9: 307}
# Client 3 data size: 3557
# Class distribution: {0: 849, 1: 41, 2: 2, 3: 208, 4: 645, 5: 640, 6: 853, 7: 151, 8: 20, 9: 148}
# Client 4 data size: 1954
# Class distribution: {0: 369, 1: 91, 2: 9, 3: 135, 4: 108, 5: 65, 6: 267, 7: 30, 8: 673, 9: 207}
# Client 5 data size: 3332
# Class distribution: {0: 25, 1: 0, 2: 866, 3: 1163, 4: 6, 5: 194, 6: 13, 7: 375, 8: 61, 9: 629}
# Client 6 data size: 2673
# Class distribution: {0: 241, 1: 643, 2: 161, 3: 26, 4: 2, 5: 861, 6: 65, 7: 182, 8: 462, 9: 30}
# Client 7 data size: 2750
# Class distribution: {0: 161, 1: 0, 2: 503, 3: 26, 4: 184, 5: 443, 6: 6, 7: 6, 8: 1412, 9: 9}
# Client 8 data size: 2071
# Class distribution: {0: 217, 1: 128, 2: 136, 3: 37, 4: 20, 5: 19, 6: 42, 7: 371, 8: 37, 9: 1064}
# Client 9 data size: 2185
# Class distribution: {0: 0, 1: 286, 2: 426, 3: 441, 4: 223, 5: 651, 6: 5, 7: 23, 8: 107, 9: 23}
# Client 10 data size: 1544
# Class distribution: {0: 602, 1: 10, 2: 2, 3: 16, 4: 91, 5: 47, 6: 299, 7: 192, 8: 255, 9: 30}
# Client 11 data size: 681
# Class distribution: {0: 2, 1: 43, 2: 1, 3: 75, 4: 26, 5: 75, 6: 101, 7: 1, 8: 205, 9: 152}
# Client 12 data size: 1524
# Class distribution: {0: 10, 1: 2, 2: 79, 3: 142, 4: 1, 5: 6, 6: 670, 7: 90, 8: 1, 9: 523}
# Client 13 data size: 1346
# Class distribution: {0: 281, 1: 82, 2: 8, 3: 208, 4: 116, 5: 206, 6: 5, 7: 128, 8: 158, 9: 154}
# Client 14 data size: 4708
# Class distribution: {0: 596, 1: 249, 2: 1220, 3: 246, 4: 932, 5: 595, 6: 18, 7: 717, 8: 33, 9: 102}
# Client 15 data size: 1893
# Class distribution: {0: 30, 1: 9, 2: 65, 3: 842, 4: 145, 5: 0, 6: 605, 7: 34, 8: 64, 9: 99}
# Client 16 data size: 2479
# Class distribution: {0: 0, 1: 924, 2: 71, 3: 176, 4: 10, 5: 259, 6: 54, 7: 897, 8: 0, 9: 88}
# Client 17 data size: 2031
# Class distribution: {0: 78, 1: 165, 2: 14, 3: 412, 4: 10, 5: 397, 6: 69, 7: 1, 8: 643, 9: 242}
# Client 18 data size: 6129
# Class distribution: {0: 673, 1: 1721, 2: 41, 3: 127, 4: 1129, 5: 118, 6: 29, 7: 1383, 8: 100, 9: 808}
# Client 19 data size: 1348
# Class distribution: {0: 70, 1: 153, 2: 1, 3: 96, 4: 46, 5: 35, 6: 541, 7: 159, 8: 139, 9: 108}
# Client 20 data size: 3870
# Class distribution: {0: 665, 1: 48, 2: 330, 3: 33, 4: 950, 5: 15, 6: 1275, 7: 145, 8: 371, 9: 38}

# %% [markdown]
# <H1>Round zero</H1>

# %%
#train accuracy for cleints
round_train_accuracy=0
round_train_loss=0

train_accuracy_list=[]
train_loss_list=[]
for c, data in enumerate(client_datasets):
    train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True, drop_last=True)
    train_accuracy, train_loss=test(initial_weights, train_loader)
    train_accuracy_list.append(train_accuracy)
    train_loss_list.append(train_loss)
round_train_accuracy=(sum(train_accuracy_list)/len(train_accuracy_list))
round_train_loss=(sum(train_loss_list)/len(train_loss_list))


#test accuracy for server
round_test_accuracy=0
round_test_loss=0
test_accuracy,test_loss=test(initial_weights,test_loader)
round_test_accuracy=(test_accuracy)
round_test_loss=(test_loss)

round_rmd=0
round_epoch=0

round_data = [round_train_accuracy, round_train_loss, round_test_accuracy, round_test_loss, round_rmd, round_epoch]
round_results.loc[len(round_results)] = round_data

Print("initial_weights", initial_weights)
print(f' train accuracy: {round_train_accuracy}\n train_loss: {round_train_loss}\n test_accuracy: {round_test_accuracy}\n test_loss: {round_test_loss}')
# Out:
# initial_weights:conv1.weight: tensor([[-0.0619,  0.0628, -0.1613],
#         [-0.1879,  0.0229,  0.1701],
#         [-0.1736, -0.0053,  0.0203]], device='cuda:0')
#
#  train accuracy: 11.250832411472665
#  train_loss: 2.300243005113499
#  test_accuracy: 10.013977635782748
#  test_loss: 2.3027472800720994

# %% [markdown]
# <H1>Run FL</H1>

# %%
federated_learning(initial_weights, client_datasets, client_no, participating_client, round_no, epochs, learning_rate, batch_size)
# Out:
# Round 1, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 7.083333333333333, epoch_loss 2.297153425216675
# test loss difference -3.0545761791067605e-05
# Round 1, cleint 1, epoch 2, current LR: 0.005, epoch_accuracy 18.541666666666668, epoch_loss 2.2803323745727537
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 1, epoch 3, current LR: 0.0025, epoch_accuracy 20.260416666666668, epoch_loss 2.2704647064208983
# test loss difference 0.0002512078696543796
# Round 1, cleint 1, epoch 4, current LR: 0.00125, epoch_accuracy 19.84375, epoch_loss 2.2667646567026773
# test loss difference 0.00021266861083812927
# Round 1, cleint 1, epoch 5, current LR: 0.000625, epoch_accuracy 20.208333333333332, epoch_loss 2.2647414843241376
# test loss difference 0.00013053607635971076
# Round 1, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 38.59375, epoch_loss 2.222938299179077
# test loss difference -0.003094360089530568
# Round 1, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 45.78125, epoch_loss 2.087630335489909
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 46.302083333333336, epoch_loss 1.8662793477376303
# test loss difference 0.0002512078696543796
# Round 1, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 45.989583333333336, epoch_loss 1.6852032899856568
# test loss difference 0.00021266861083812927
# Round 1, cleint 2, epoch 5, current LR: 0.00125, epoch_accuracy 45.833333333333336, epoch_loss 1.5972732623418173
# test loss difference 0.00013053607635971076
# Round 1, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 15.046296296296296, epoch_loss 2.2893710136413574
# test loss difference -0.0006204344594058497
# Round 1, cleint 3, epoch 2, current LR: 0.005, epoch_accuracy 25.086805555555557, epoch_loss 2.230145498558327
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 3, epoch 3, current LR: 0.0025, epoch_accuracy 25.54976851851852, epoch_loss 2.18603253364563
# test loss difference 0.0002512078696543796
# Round 1, cleint 3, epoch 4, current LR: 0.00125, epoch_accuracy 25.23148148148148, epoch_loss 2.15744740874679
# test loss difference 0.00021266861083812927
# Round 1, cleint 3, epoch 5, current LR: 0.000625, epoch_accuracy 25.694444444444443, epoch_loss 2.1418074325278953
# test loss difference 0.00013053607635971076
# Round 1, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 23.072916666666668, epoch_loss 2.283086315790812
# test loss difference -0.0007485787327676796
# Round 1, cleint 4, epoch 2, current LR: 0.005, epoch_accuracy 34.322916666666664, epoch_loss 2.253729788462321
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 4, epoch 3, current LR: 0.0025, epoch_accuracy 34.322916666666664, epoch_loss 2.235360050201416
# test loss difference 0.0002512078696543796
# Round 1, cleint 4, epoch 4, current LR: 0.00125, epoch_accuracy 34.21875, epoch_loss 2.227707513173421
# test loss difference 0.00021266861083812927
# Round 1, cleint 4, epoch 5, current LR: 0.000625, epoch_accuracy 34.583333333333336, epoch_loss 2.222566239039103
# test loss difference 0.00013053607635971076
# Round 1, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 34.49519230769231, epoch_loss 2.221183098279513
# test loss difference -0.005508614805179057
# Round 1, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 34.85576923076923, epoch_loss 2.020855811926035
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 5, epoch 3, current LR: 0.005, epoch_accuracy 34.88581730769231, epoch_loss 1.7297391708080585
# test loss difference 0.0002512078696543796
# Round 1, cleint 5, epoch 4, current LR: 0.0025, epoch_accuracy 34.91586538461539, epoch_loss 1.6626139833376958
# test loss difference 0.00021266861083812927
# Round 1, cleint 5, epoch 5, current LR: 0.00125, epoch_accuracy 34.85576923076923, epoch_loss 1.6430343022713294
# test loss difference 0.00013053607635971076
# Round 1, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 16.5625, epoch_loss 2.280739963054657
# test loss difference -0.0007241754867020056
# Round 1, cleint 6, epoch 2, current LR: 0.005, epoch_accuracy 32.2265625, epoch_loss 2.226224970817566
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 6, epoch 3, current LR: 0.0025, epoch_accuracy 32.2265625, epoch_loss 2.191041350364685
# test loss difference 0.0002512078696543796
# Round 1, cleint 6, epoch 4, current LR: 0.00125, epoch_accuracy 32.3828125, epoch_loss 2.1653734683990478
# test loss difference 0.00021266861083812927
# Round 1, cleint 6, epoch 5, current LR: 0.000625, epoch_accuracy 32.265625, epoch_loss 2.1534875631332397
# test loss difference 0.00013053607635971076
# Round 1, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 42.15029761904762, epoch_loss 2.235266719545637
# test loss difference -0.004167093636509911
# Round 1, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 51.63690476190476, epoch_loss 2.030287822087606
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 7, epoch 3, current LR: 0.005, epoch_accuracy 51.26488095238095, epoch_loss 1.6776618843986875
# test loss difference 0.0002512078696543796
# Round 1, cleint 7, epoch 4, current LR: 0.0025, epoch_accuracy 51.413690476190474, epoch_loss 1.5520436650230771
# test loss difference 0.00021266861083812927
# Round 1, cleint 7, epoch 5, current LR: 0.00125, epoch_accuracy 51.52529761904762, epoch_loss 1.5199148711704074
# test loss difference 0.00013053607635971076
# Round 1, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 41.50390625, epoch_loss 2.2486964017152786
# test loss difference -0.0017967414551267602
# Round 1, cleint 8, epoch 2, current LR: 0.005, epoch_accuracy 51.46484375, epoch_loss 2.147307351231575
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 8, epoch 3, current LR: 0.0025, epoch_accuracy 51.220703125, epoch_loss 2.068852722644806
# test loss difference 0.0002512078696543796
# Round 1, cleint 8, epoch 4, current LR: 0.00125, epoch_accuracy 51.416015625, epoch_loss 2.0101793482899666
# test loss difference 0.00021266861083812927
# Round 1, cleint 8, epoch 5, current LR: 0.000625, epoch_accuracy 51.171875, epoch_loss 1.9794348999857903
# test loss difference 0.00013053607635971076
# Round 1, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 20.404411764705884, epoch_loss 2.2687028997084675
# test loss difference -0.0012919285807746483
# Round 1, cleint 9, epoch 2, current LR: 0.005, epoch_accuracy 22.28860294117647, epoch_loss 2.2251202499165252
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 9, epoch 3, current LR: 0.0025, epoch_accuracy 22.518382352941178, epoch_loss 2.196463136111989
# test loss difference 0.0002512078696543796
# Round 1, cleint 9, epoch 4, current LR: 0.00125, epoch_accuracy 25.643382352941178, epoch_loss 2.180162934695973
# test loss difference 0.00021266861083812927
# Round 1, cleint 9, epoch 5, current LR: 0.000625, epoch_accuracy 27.205882352941178, epoch_loss 2.171708808225744
# test loss difference 0.00013053607635971076
# Round 1, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 10.481770833333334, epoch_loss 2.299286166826884
# test loss difference -0.00020700445571275594
# Round 1, cleint 10, epoch 2, current LR: 0.005, epoch_accuracy 36.1328125, epoch_loss 2.2617097894350686
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 10, epoch 3, current LR: 0.0025, epoch_accuracy 38.606770833333336, epoch_loss 2.2392605543136597
# test loss difference 0.0002512078696543796
# Round 1, cleint 10, epoch 4, current LR: 0.00125, epoch_accuracy 39.192708333333336, epoch_loss 2.2263678312301636
# test loss difference 0.00021266861083812927
# Round 1, cleint 10, epoch 5, current LR: 0.000625, epoch_accuracy 38.997395833333336, epoch_loss 2.220223923524221
# test loss difference 0.00013053607635971076
# Round 1, cleint 11, epoch 1, current LR: 0.01, epoch_accuracy 12.5, epoch_loss 2.2857893466949464
# test loss difference -0.00013623755579939
# Round 1, cleint 11, epoch 2, current LR: 0.005, epoch_accuracy 15.9375, epoch_loss 2.2756662368774414
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 11, epoch 3, current LR: 0.0025, epoch_accuracy 21.40625, epoch_loss 2.269402503967285
# test loss difference 0.0002512078696543796
# Round 1, cleint 11, epoch 4, current LR: 0.00125, epoch_accuracy 21.09375, epoch_loss 2.268823528289795
# test loss difference 0.00021266861083812927
# Round 1, cleint 11, epoch 5, current LR: 0.000625, epoch_accuracy 22.03125, epoch_loss 2.2676319122314452
# test loss difference 0.00013053607635971076
# Round 1, cleint 12, epoch 1, current LR: 0.01, epoch_accuracy 25.071022727272727, epoch_loss 2.2638647989793257
# test loss difference -0.000597235493766668
# Round 1, cleint 12, epoch 2, current LR: 0.005, epoch_accuracy 41.76136363636363, epoch_loss 2.2050837603482334
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 12, epoch 3, current LR: 0.0025, epoch_accuracy 44.03409090909091, epoch_loss 2.1667906154285776
# test loss difference 0.0002512078696543796
# Round 1, cleint 12, epoch 4, current LR: 0.00125, epoch_accuracy 44.17613636363637, epoch_loss 2.1453682509335605
# test loss difference 0.00021266861083812927
# Round 1, cleint 12, epoch 5, current LR: 0.000625, epoch_accuracy 43.89204545454545, epoch_loss 2.134673595428467
# test loss difference 0.00013053607635971076
# Round 1, cleint 13, epoch 1, current LR: 0.01, epoch_accuracy 14.6875, epoch_loss 2.3003270864486693
# test loss difference 2.637914956160614e-05
# Round 1, cleint 13, epoch 2, current LR: 0.005, epoch_accuracy 15.390625, epoch_loss 2.2927716970443726
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 13, epoch 3, current LR: 0.0025, epoch_accuracy 15.234375, epoch_loss 2.2885223865509032
# test loss difference 0.0002512078696543796
# Round 1, cleint 13, epoch 4, current LR: 0.00125, epoch_accuracy 15.625, epoch_loss 2.2857065916061403
# test loss difference 0.00021266861083812927
# Round 1, cleint 13, epoch 5, current LR: 0.000625, epoch_accuracy 15.0, epoch_loss 2.2857726573944093
# test loss difference 0.00013053607635971076
# Round 1, cleint 14, epoch 1, current LR: 0.01, epoch_accuracy 22.743055555555557, epoch_loss 2.274863123893738
# test loss difference -0.0031356110740392573
# Round 1, cleint 14, epoch 2, current LR: 0.01, epoch_accuracy 25.9765625, epoch_loss 2.1615354816118875
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 14, epoch 3, current LR: 0.005, epoch_accuracy 25.911458333333332, epoch_loss 2.020677904287974
# test loss difference 0.0002512078696543796
# Round 1, cleint 14, epoch 4, current LR: 0.0025, epoch_accuracy 25.99826388888889, epoch_loss 1.9826707045237224
# test loss difference 0.00021266861083812927
# Round 1, cleint 14, epoch 5, current LR: 0.00125, epoch_accuracy 25.75954861111111, epoch_loss 1.967558844221963
# test loss difference 0.00013053607635971076
# Round 1, cleint 15, epoch 1, current LR: 0.01, epoch_accuracy 43.526785714285715, epoch_loss 2.242541176932199
# test loss difference -0.0017236101741606724
# Round 1, cleint 15, epoch 2, current LR: 0.005, epoch_accuracy 44.308035714285715, epoch_loss 2.1687937464032854
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 15, epoch 3, current LR: 0.0025, epoch_accuracy 44.47544642857143, epoch_loss 2.117051533290318
# test loss difference 0.0002512078696543796
# Round 1, cleint 15, epoch 4, current LR: 0.00125, epoch_accuracy 44.47544642857143, epoch_loss 2.0821492671966553
# test loss difference 0.00021266861083812927
# Round 1, cleint 15, epoch 5, current LR: 0.000625, epoch_accuracy 44.97767857142857, epoch_loss 2.0612521512167796
# test loss difference 0.00013053607635971076
# Round 1, cleint 16, epoch 1, current LR: 0.01, epoch_accuracy 25.904605263157894, epoch_loss 2.259370966961509
# test loss difference -0.0011282492750370743
# Round 1, cleint 16, epoch 2, current LR: 0.005, epoch_accuracy 37.3766447368421, epoch_loss 2.1447155726583382
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 16, epoch 3, current LR: 0.0025, epoch_accuracy 37.828947368421055, epoch_loss 2.0468028093639172
# test loss difference 0.0002512078696543796
# Round 1, cleint 16, epoch 4, current LR: 0.00125, epoch_accuracy 37.21217105263158, epoch_loss 1.9690164578588385
# test loss difference 0.00021266861083812927
# Round 1, cleint 16, epoch 5, current LR: 0.000625, epoch_accuracy 37.54111842105263, epoch_loss 1.9257386107193797
# test loss difference 0.00013053607635971076
# Round 1, cleint 17, epoch 1, current LR: 0.01, epoch_accuracy 22.239583333333332, epoch_loss 2.2674811363220213
# test loss difference -0.0010611272086733514
# Round 1, cleint 17, epoch 2, current LR: 0.005, epoch_accuracy 26.979166666666668, epoch_loss 2.2332891782124835
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 17, epoch 3, current LR: 0.0025, epoch_accuracy 30.260416666666668, epoch_loss 2.2119081179300943
# test loss difference 0.0002512078696543796
# Round 1, cleint 17, epoch 4, current LR: 0.00125, epoch_accuracy 30.520833333333332, epoch_loss 2.202027416229248
# test loss difference 0.00021266861083812927
# Round 1, cleint 17, epoch 5, current LR: 0.000625, epoch_accuracy 31.40625, epoch_loss 2.196517833073934
# test loss difference 0.00013053607635971076
# Round 1, cleint 18, epoch 1, current LR: 0.01, epoch_accuracy 23.0219414893617, epoch_loss 2.240240903610879
# test loss difference -0.010981647351298474
# Round 1, cleint 18, epoch 2, current LR: 0.01, epoch_accuracy 28.274601063829788, epoch_loss 1.9180026155837038
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 18, epoch 3, current LR: 0.005, epoch_accuracy 28.62367021276596, epoch_loss 1.7983302892522608
# test loss difference 0.0002512078696543796
# Round 1, cleint 18, epoch 4, current LR: 0.0025, epoch_accuracy 28.88962765957447, epoch_loss 1.7883736503885148
# test loss difference 0.00021266861083812927
# Round 1, cleint 18, epoch 5, current LR: 0.00125, epoch_accuracy 30.269281914893618, epoch_loss 1.7846295681405575
# test loss difference 0.00013053607635971076
# Round 1, cleint 19, epoch 1, current LR: 0.01, epoch_accuracy 13.984375, epoch_loss 2.2925817012786864
# test loss difference 3.076589907280436e-06
# Round 1, cleint 19, epoch 2, current LR: 0.005, epoch_accuracy 37.734375, epoch_loss 2.2672319412231445
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 19, epoch 3, current LR: 0.0025, epoch_accuracy 40.546875, epoch_loss 2.2524524450302126
# test loss difference 0.0002512078696543796
# Round 1, cleint 19, epoch 4, current LR: 0.00125, epoch_accuracy 40.15625, epoch_loss 2.2455332279205322
# test loss difference 0.00021266861083812927
# Round 1, cleint 19, epoch 5, current LR: 0.000625, epoch_accuracy 40.15625, epoch_loss 2.2416107416152955
# test loss difference 0.00013053607635971076
# Round 1, cleint 20, epoch 1, current LR: 0.01, epoch_accuracy 23.645833333333332, epoch_loss 2.2652249256769816
# test loss difference -0.003695839891037611
# Round 1, cleint 20, epoch 2, current LR: 0.01, epoch_accuracy 32.96875, epoch_loss 2.0521606326103212
# test loss difference 3.0545761791067605e-05
# Round 1, cleint 20, epoch 3, current LR: 0.005, epoch_accuracy 32.994791666666664, epoch_loss 1.7892093022664388
# test loss difference 0.0002512078696543796
# Round 1, cleint 20, epoch 4, current LR: 0.0025, epoch_accuracy 32.786458333333336, epoch_loss 1.7605514208475748
# test loss difference 0.00021266861083812927
# Round 1, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 32.8125, epoch_loss 1.7496179540952046
# test loss difference 0.00013053607635971076
# Model's Round: 1, train accuracy of model: 34.30936062267836, train loss of model: 2.026459832734056
#
#
# Model's Round: 1, test accuracy of model: 9.245207667731629, test loss of model: 2.302057823814904
#
#
# round 1 completed
# Round 2, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 13.90625, epoch_loss 2.2776992956797284
# test loss difference -0.0010470704148755061
# Round 2, cleint 1, epoch 2, current LR: 0.005, epoch_accuracy 20.208333333333332, epoch_loss 2.2255141576131185
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 1, epoch 3, current LR: 0.0025, epoch_accuracy 20.625, epoch_loss 2.193996620178223
# test loss difference 0.0002512078696543796
# Round 2, cleint 1, epoch 4, current LR: 0.00125, epoch_accuracy 21.041666666666668, epoch_loss 2.175097115834554
# test loss difference 0.00021266861083812927
# Round 2, cleint 1, epoch 5, current LR: 0.000625, epoch_accuracy 21.302083333333332, epoch_loss 2.166620063781738
# test loss difference 0.00013053607635971076
# Round 2, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 43.385416666666664, epoch_loss 2.087224308649699
# test loss difference -0.05669911372394987
# Round 2, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 45.625, epoch_loss 1.6077237606048584
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 44.427083333333336, epoch_loss 1.4479110797246297
# test loss difference 0.0002512078696543796
# Round 2, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 46.354166666666664, epoch_loss 1.4189626137415567
# test loss difference 0.00021266861083812927
# Round 2, cleint 2, epoch 5, current LR: 0.00125, epoch_accuracy 45.364583333333336, epoch_loss 1.4215702215830486
# test loss difference 0.00013053607635971076
# Round 2, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 21.556712962962962, epoch_loss 2.217596795823839
# test loss difference -0.030095600091611274
# Round 2, cleint 3, epoch 2, current LR: 0.01, epoch_accuracy 26.099537037037038, epoch_loss 1.9418030094217371
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 3, epoch 3, current LR: 0.005, epoch_accuracy 26.041666666666668, epoch_loss 1.8611728791837339
# test loss difference 0.0002512078696543796
# Round 2, cleint 3, epoch 4, current LR: 0.0025, epoch_accuracy 25.34722222222222, epoch_loss 1.8548501200146146
# test loss difference 0.00021266861083812927
# Round 2, cleint 3, epoch 5, current LR: 0.00125, epoch_accuracy 26.302083333333332, epoch_loss 1.8522053824530706
# test loss difference 0.00013053607635971076
# Round 2, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 25.572916666666668, epoch_loss 2.259522310892741
# test loss difference -0.0061139725267698175
# Round 2, cleint 4, epoch 2, current LR: 0.01, epoch_accuracy 34.53125, epoch_loss 2.1368220806121827
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 4, epoch 3, current LR: 0.005, epoch_accuracy 34.583333333333336, epoch_loss 2.0233574867248536
# test loss difference 0.0002512078696543796
# Round 2, cleint 4, epoch 4, current LR: 0.0025, epoch_accuracy 34.635416666666664, epoch_loss 1.9806191285451253
# test loss difference 0.00021266861083812927
# Round 2, cleint 4, epoch 5, current LR: 0.00125, epoch_accuracy 34.479166666666664, epoch_loss 1.966116770108541
# test loss difference 0.00013053607635971076
# Round 2, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 33.29326923076923, epoch_loss 2.0568913588157067
# test loss difference -0.17397398689684396
# Round 2, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 34.58533653846154, epoch_loss 1.6597760228010325
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 5, epoch 3, current LR: 0.005, epoch_accuracy 34.49519230769231, epoch_loss 1.6150266298880944
# test loss difference 0.0002512078696543796
# Round 2, cleint 5, epoch 4, current LR: 0.0025, epoch_accuracy 34.55528846153846, epoch_loss 1.611592132311601
# test loss difference 0.00021266861083812927
# Round 2, cleint 5, epoch 5, current LR: 0.00125, epoch_accuracy 35.42668269230769, epoch_loss 1.5980554268910334
# test loss difference 0.00013053607635971076
# Round 2, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 25.8203125, epoch_loss 2.2155535936355593
# test loss difference -0.018135024335818706
# Round 2, cleint 6, epoch 2, current LR: 0.01, epoch_accuracy 32.3828125, epoch_loss 1.9328984081745149
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 6, epoch 3, current LR: 0.005, epoch_accuracy 32.9296875, epoch_loss 1.816531389951706
# test loss difference 0.0002512078696543796
# Round 2, cleint 6, epoch 4, current LR: 0.0025, epoch_accuracy 33.1640625, epoch_loss 1.80157909989357
# test loss difference 0.00021266861083812927
# Round 2, cleint 6, epoch 5, current LR: 0.00125, epoch_accuracy 33.2421875, epoch_loss 1.8031298696994782
# test loss difference 0.00013053607635971076
# Round 2, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 44.15922619047619, epoch_loss 2.0922347477504184
# test loss difference -0.11115617797778432
# Round 2, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 51.22767857142857, epoch_loss 1.5782728933152699
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 7, epoch 3, current LR: 0.005, epoch_accuracy 51.450892857142854, epoch_loss 1.4604445979708718
# test loss difference 0.0002512078696543796
# Round 2, cleint 7, epoch 4, current LR: 0.0025, epoch_accuracy 51.15327380952381, epoch_loss 1.4424092996688116
# test loss difference 0.00021266861083812927
# Round 2, cleint 7, epoch 5, current LR: 0.00125, epoch_accuracy 51.59970238095238, epoch_loss 1.4324954066957747
# test loss difference 0.00013053607635971076
# Round 2, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 44.580078125, epoch_loss 2.122360736131668
# test loss difference -0.049376905916597824
# Round 2, cleint 8, epoch 2, current LR: 0.01, epoch_accuracy 51.318359375, epoch_loss 1.6611105650663376
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 8, epoch 3, current LR: 0.005, epoch_accuracy 51.318359375, epoch_loss 1.5679792985320091
# test loss difference 0.0002512078696543796
# Round 2, cleint 8, epoch 4, current LR: 0.0025, epoch_accuracy 51.416015625, epoch_loss 1.5590153634548187
# test loss difference 0.00021266861083812927
# Round 2, cleint 8, epoch 5, current LR: 0.00125, epoch_accuracy 51.318359375, epoch_loss 1.5644732937216759
# test loss difference 0.00013053607635971076
# Round 2, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 24.448529411764707, epoch_loss 2.2030930098365333
# test loss difference -0.017892612816807762
# Round 2, cleint 9, epoch 2, current LR: 0.01, epoch_accuracy 29.27389705882353, epoch_loss 1.9751928413615507
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 9, epoch 3, current LR: 0.005, epoch_accuracy 29.917279411764707, epoch_loss 1.8396900681888355
# test loss difference 0.0002512078696543796
# Round 2, cleint 9, epoch 4, current LR: 0.0025, epoch_accuracy 29.825367647058822, epoch_loss 1.8179363152560066
# test loss difference 0.00021266861083812927
# Round 2, cleint 9, epoch 5, current LR: 0.00125, epoch_accuracy 28.90625, epoch_loss 1.805104052319246
# test loss difference 0.00013053607635971076
# Round 2, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 24.739583333333332, epoch_loss 2.2599963545799255
# test loss difference -0.006110044333119902
# Round 2, cleint 10, epoch 2, current LR: 0.01, epoch_accuracy 38.802083333333336, epoch_loss 2.0799939731756845
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 10, epoch 3, current LR: 0.005, epoch_accuracy 39.0625, epoch_loss 1.8945589363574982
# test loss difference 0.0002512078696543796
# Round 2, cleint 10, epoch 4, current LR: 0.0025, epoch_accuracy 38.932291666666664, epoch_loss 1.824154923359553
# test loss difference 0.00021266861083812927
# Round 2, cleint 10, epoch 5, current LR: 0.00125, epoch_accuracy 38.997395833333336, epoch_loss 1.7994138797124226
# test loss difference 0.00013053607635971076
# Round 2, cleint 11, epoch 1, current LR: 0.01, epoch_accuracy 11.5625, epoch_loss 2.2840009212493895
# test loss difference 0.00028388035563997605
# Round 2, cleint 11, epoch 2, current LR: 0.005, epoch_accuracy 23.59375, epoch_loss 2.254408025741577
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 11, epoch 3, current LR: 0.0025, epoch_accuracy 24.53125, epoch_loss 2.240767812728882
# test loss difference 0.0002512078696543796
# Round 2, cleint 11, epoch 4, current LR: 0.00125, epoch_accuracy 25.625, epoch_loss 2.2338988304138185
# test loss difference 0.00021266861083812927
# Round 2, cleint 11, epoch 5, current LR: 0.000625, epoch_accuracy 27.5, epoch_loss 2.2276288986206056
# test loss difference 0.00013053607635971076
# Round 2, cleint 12, epoch 1, current LR: 0.01, epoch_accuracy 32.45738636363637, epoch_loss 2.1945512294769287
# test loss difference -0.0074878828213238435
# Round 2, cleint 12, epoch 2, current LR: 0.01, epoch_accuracy 44.03409090909091, epoch_loss 1.8208546313372524
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 12, epoch 3, current LR: 0.005, epoch_accuracy 43.32386363636363, epoch_loss 1.4717482111670754
# test loss difference 0.0002512078696543796
# Round 2, cleint 12, epoch 4, current LR: 0.0025, epoch_accuracy 44.95738636363637, epoch_loss 1.4120378277518533
# test loss difference 0.00021266861083812927
# Round 2, cleint 12, epoch 5, current LR: 0.00125, epoch_accuracy 42.89772727272727, epoch_loss 1.4121248613704334
# test loss difference 0.00013053607635971076
# Round 2, cleint 13, epoch 1, current LR: 0.01, epoch_accuracy 11.71875, epoch_loss 2.2937334299087526
# test loss difference -0.00020628615309270515
# Round 2, cleint 13, epoch 2, current LR: 0.005, epoch_accuracy 16.171875, epoch_loss 2.26856644153595
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 13, epoch 3, current LR: 0.0025, epoch_accuracy 15.9375, epoch_loss 2.2587644815444947
# test loss difference 0.0002512078696543796
# Round 2, cleint 13, epoch 4, current LR: 0.00125, epoch_accuracy 18.125, epoch_loss 2.2502609729766845
# test loss difference 0.00021266861083812927
# Round 2, cleint 13, epoch 5, current LR: 0.000625, epoch_accuracy 15.859375, epoch_loss 2.2472482919692993
# test loss difference 0.00013053607635971076
# Round 2, cleint 14, epoch 1, current LR: 0.01, epoch_accuracy 25.17361111111111, epoch_loss 2.1794403658972845
# test loss difference -0.0883185756853977
# Round 2, cleint 14, epoch 2, current LR: 0.01, epoch_accuracy 25.99826388888889, epoch_loss 1.9827771584192913
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 14, epoch 3, current LR: 0.005, epoch_accuracy 25.108506944444443, epoch_loss 1.9546704192956288
# test loss difference 0.0002512078696543796
# Round 2, cleint 14, epoch 4, current LR: 0.0025, epoch_accuracy 25.694444444444443, epoch_loss 1.9495146936840482
# test loss difference 0.00021266861083812927
# Round 2, cleint 14, epoch 5, current LR: 0.00125, epoch_accuracy 25.086805555555557, epoch_loss 1.9485078520245023
# test loss difference 0.00013053607635971076
# Round 2, cleint 15, epoch 1, current LR: 0.01, epoch_accuracy 41.40625, epoch_loss 2.1529753378459384
# test loss difference -0.02102465979969148
# Round 2, cleint 15, epoch 2, current LR: 0.01, epoch_accuracy 44.19642857142857, epoch_loss 1.709221797330039
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 15, epoch 3, current LR: 0.005, epoch_accuracy 43.526785714285715, epoch_loss 1.5222891058240617
# test loss difference 0.0002512078696543796
# Round 2, cleint 15, epoch 4, current LR: 0.0025, epoch_accuracy 44.53125, epoch_loss 1.4968149406569344
# test loss difference 0.00021266861083812927
# Round 2, cleint 15, epoch 5, current LR: 0.00125, epoch_accuracy 44.53125, epoch_loss 1.48307523557118
# test loss difference 0.00013053607635971076
# Round 2, cleint 16, epoch 1, current LR: 0.01, epoch_accuracy 30.550986842105264, epoch_loss 2.1243711709976196
# test loss difference -0.06048417243713766
# Round 2, cleint 16, epoch 2, current LR: 0.01, epoch_accuracy 38.733552631578945, epoch_loss 1.6148204113307751
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 16, epoch 3, current LR: 0.005, epoch_accuracy 40.00822368421053, epoch_loss 1.5332324191143638
# test loss difference 0.0002512078696543796
# Round 2, cleint 16, epoch 4, current LR: 0.0025, epoch_accuracy 42.1875, epoch_loss 1.5273011985578036
# test loss difference 0.00021266861083812927
# Round 2, cleint 16, epoch 5, current LR: 0.00125, epoch_accuracy 41.32401315789474, epoch_loss 1.5099975811807733
# test loss difference 0.00013053607635971076
# Round 2, cleint 17, epoch 1, current LR: 0.01, epoch_accuracy 21.614583333333332, epoch_loss 2.2324307600657147
# test loss difference -0.008148987834065036
# Round 2, cleint 17, epoch 2, current LR: 0.01, epoch_accuracy 29.791666666666668, epoch_loss 2.073852531115214
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 17, epoch 3, current LR: 0.005, epoch_accuracy 31.302083333333332, epoch_loss 1.9249396403630574
# test loss difference 0.0002512078696543796
# Round 2, cleint 17, epoch 4, current LR: 0.0025, epoch_accuracy 31.822916666666668, epoch_loss 1.8757187843322753
# test loss difference 0.00021266861083812927
# Round 2, cleint 17, epoch 5, current LR: 0.00125, epoch_accuracy 32.03125, epoch_loss 1.851849102973938
# test loss difference 0.00013053607635971076
# Round 2, cleint 18, epoch 1, current LR: 0.01, epoch_accuracy 25.033244680851062, epoch_loss 2.062990290053347
# test loss difference -0.3212260392527231
# Round 2, cleint 18, epoch 2, current LR: 0.01, epoch_accuracy 29.471409574468087, epoch_loss 1.7966791137735894
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 18, epoch 3, current LR: 0.005, epoch_accuracy 31.466090425531913, epoch_loss 1.765924945790717
# test loss difference 0.0002512078696543796
# Round 2, cleint 18, epoch 4, current LR: 0.0025, epoch_accuracy 33.31117021276596, epoch_loss 1.756471928129805
# test loss difference 0.00021266861083812927
# Round 2, cleint 18, epoch 5, current LR: 0.00125, epoch_accuracy 33.71010638297872, epoch_loss 1.7477709689038865
# test loss difference 0.00013053607635971076
# Round 2, cleint 19, epoch 1, current LR: 0.01, epoch_accuracy 23.828125, epoch_loss 2.272483205795288
# test loss difference -0.00024963720157122893
# Round 2, cleint 19, epoch 2, current LR: 0.005, epoch_accuracy 39.84375, epoch_loss 2.186622166633606
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 19, epoch 3, current LR: 0.0025, epoch_accuracy 40.0, epoch_loss 2.1308716773986816
# test loss difference 0.0002512078696543796
# Round 2, cleint 19, epoch 4, current LR: 0.00125, epoch_accuracy 40.546875, epoch_loss 2.1015053033828734
# test loss difference 0.00021266861083812927
# Round 2, cleint 19, epoch 5, current LR: 0.000625, epoch_accuracy 39.765625, epoch_loss 2.0894861936569216
# test loss difference 0.00013053607635971076
# Round 2, cleint 20, epoch 1, current LR: 0.01, epoch_accuracy 28.489583333333332, epoch_loss 2.1248371998469033
# test loss difference -0.16024172344146814
# Round 2, cleint 20, epoch 2, current LR: 0.01, epoch_accuracy 32.239583333333336, epoch_loss 1.7780784885088603
# test loss difference 3.0545761791067605e-05
# Round 2, cleint 20, epoch 3, current LR: 0.005, epoch_accuracy 32.369791666666664, epoch_loss 1.7350268999735514
# test loss difference 0.0002512078696543796
# Round 2, cleint 20, epoch 4, current LR: 0.0025, epoch_accuracy 32.682291666666664, epoch_loss 1.722199813524882
# test loss difference 0.00021266861083812927
# Round 2, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 32.317708333333336, epoch_loss 1.723317547639211
# test loss difference 0.00013053607635971076
# Model's Round: 2, train accuracy of model: 35.09811775753748, train loss of model: 1.782509545043839
#
#
# Model's Round: 2, test accuracy of model: 10.003993610223642, test loss of model: 2.29838649304911
#
#
# round 2 completed
# Round 3, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 18.177083333333332, epoch_loss 2.1761673132578534
# test loss difference -0.08201129901142545
# Round 3, cleint 1, epoch 2, current LR: 0.01, epoch_accuracy 21.875, epoch_loss 2.0340078751246136
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 1, epoch 3, current LR: 0.005, epoch_accuracy 22.65625, epoch_loss 2.0043572505315144
# test loss difference 0.0002512078696543796
# Round 3, cleint 1, epoch 4, current LR: 0.0025, epoch_accuracy 23.333333333333332, epoch_loss 1.9944867451985677
# test loss difference 0.00021266861083812927
# Round 3, cleint 1, epoch 5, current LR: 0.00125, epoch_accuracy 24.010416666666668, epoch_loss 1.9873850663503012
# test loss difference 0.00013053607635971076
# Round 3, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 43.072916666666664, epoch_loss 1.7052940527598064
# test loss difference -0.6633748528294672
# Round 3, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 43.020833333333336, epoch_loss 1.4454633633295695
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 44.010416666666664, epoch_loss 1.4114067554473877
# test loss difference 0.0002512078696543796
# Round 3, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 44.53125, epoch_loss 1.4126582225163777
# test loss difference 0.00021266861083812927
# Round 3, cleint 2, epoch 5, current LR: 0.00125, epoch_accuracy 45.052083333333336, epoch_loss 1.4054562409718832
# test loss difference 0.00013053607635971076
# Round 3, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 24.65277777777778, epoch_loss 1.9916638312516388
# test loss difference -0.3762551092872988
# Round 3, cleint 3, epoch 2, current LR: 0.01, epoch_accuracy 25.636574074074073, epoch_loss 1.8582077909398962
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 3, epoch 3, current LR: 0.005, epoch_accuracy 27.57523148148148, epoch_loss 1.8388789627287123
# test loss difference 0.0002512078696543796
# Round 3, cleint 3, epoch 4, current LR: 0.0025, epoch_accuracy 30.497685185185187, epoch_loss 1.8295790795926694
# test loss difference 0.00021266861083812927
# Round 3, cleint 3, epoch 5, current LR: 0.00125, epoch_accuracy 29.25347222222222, epoch_loss 1.8292673958672419
# test loss difference 0.00013053607635971076
# Round 3, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 30.15625, epoch_loss 2.1025081316630048
# test loss difference -0.16281261459326224
# Round 3, cleint 4, epoch 2, current LR: 0.01, epoch_accuracy 34.479166666666664, epoch_loss 1.9616727113723755
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 4, epoch 3, current LR: 0.005, epoch_accuracy 34.375, epoch_loss 1.926184884707133
# test loss difference 0.0002512078696543796
# Round 3, cleint 4, epoch 4, current LR: 0.0025, epoch_accuracy 34.270833333333336, epoch_loss 1.9227195103963217
# test loss difference 0.00021266861083812927
# Round 3, cleint 4, epoch 5, current LR: 0.00125, epoch_accuracy 34.479166666666664, epoch_loss 1.9204216321309409
# test loss difference 0.00013053607635971076
# Round 3, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 33.11298076923077, epoch_loss 1.7793047978327825
# test loss difference -0.6581787537462036
# Round 3, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 35.30649038461539, epoch_loss 1.6013013537113483
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 5, epoch 3, current LR: 0.005, epoch_accuracy 36.08774038461539, epoch_loss 1.5793907458965595
# test loss difference 0.0002512078696543796
# Round 3, cleint 5, epoch 4, current LR: 0.0025, epoch_accuracy 36.38822115384615, epoch_loss 1.5590738883385291
# test loss difference 0.00021266861083812927
# Round 3, cleint 5, epoch 5, current LR: 0.00125, epoch_accuracy 37.25961538461539, epoch_loss 1.5548720084703886
# test loss difference 0.00013053607635971076
# Round 3, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 30.3515625, epoch_loss 1.9755514144897461
# test loss difference -0.34257025231187743
# Round 3, cleint 6, epoch 2, current LR: 0.01, epoch_accuracy 32.7734375, epoch_loss 1.7865501284599303
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 6, epoch 3, current LR: 0.005, epoch_accuracy 34.8046875, epoch_loss 1.7528667330741883
# test loss difference 0.0002512078696543796
# Round 3, cleint 6, epoch 4, current LR: 0.0025, epoch_accuracy 36.6015625, epoch_loss 1.7537436008453369
# test loss difference 0.00021266861083812927
# Round 3, cleint 6, epoch 5, current LR: 0.00125, epoch_accuracy 35.9765625, epoch_loss 1.745763713121414
# test loss difference 0.00013053607635971076
# Round 3, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 48.10267857142857, epoch_loss 1.724164156686692
# test loss difference -0.75766677292772
# Round 3, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 51.11607142857143, epoch_loss 1.459903637568156
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 7, epoch 3, current LR: 0.005, epoch_accuracy 51.041666666666664, epoch_loss 1.4341569344202678
# test loss difference 0.0002512078696543796
# Round 3, cleint 7, epoch 4, current LR: 0.0025, epoch_accuracy 51.004464285714285, epoch_loss 1.4232374145871116
# test loss difference 0.00021266861083812927
# Round 3, cleint 7, epoch 5, current LR: 0.00125, epoch_accuracy 51.59970238095238, epoch_loss 1.4092142184575398
# test loss difference 0.00013053607635971076
# Round 3, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 48.681640625, epoch_loss 1.7651560828089714
# test loss difference -0.4920579564457124
# Round 3, cleint 8, epoch 2, current LR: 0.01, epoch_accuracy 51.26953125, epoch_loss 1.5503274723887444
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 8, epoch 3, current LR: 0.005, epoch_accuracy 51.318359375, epoch_loss 1.5305927470326424
# test loss difference 0.0002512078696543796
# Round 3, cleint 8, epoch 4, current LR: 0.0025, epoch_accuracy 51.7578125, epoch_loss 1.5145550295710564
# test loss difference 0.00021266861083812927
# Round 3, cleint 8, epoch 5, current LR: 0.00125, epoch_accuracy 51.26953125, epoch_loss 1.521666057407856
# test loss difference 0.00013053607635971076
# Round 3, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 28.079044117647058, epoch_loss 1.9888452151242424
# test loss difference -0.2966061544875367
# Round 3, cleint 9, epoch 2, current LR: 0.01, epoch_accuracy 28.814338235294116, epoch_loss 1.8148822153315824
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 9, epoch 3, current LR: 0.005, epoch_accuracy 29.136029411764707, epoch_loss 1.7799199959811043
# test loss difference 0.0002512078696543796
# Round 3, cleint 9, epoch 4, current LR: 0.0025, epoch_accuracy 28.860294117647058, epoch_loss 1.7753373735091265
# test loss difference 0.00021266861083812927
# Round 3, cleint 9, epoch 5, current LR: 0.00125, epoch_accuracy 29.549632352941178, epoch_loss 1.771186870687148
# test loss difference 0.00013053607635971076
# Round 3, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 33.463541666666664, epoch_loss 2.034989913304647
# test loss difference -0.24200988349061436
# Round 3, cleint 10, epoch 2, current LR: 0.01, epoch_accuracy 38.346354166666664, epoch_loss 1.782438576221466
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 10, epoch 3, current LR: 0.005, epoch_accuracy 38.802083333333336, epoch_loss 1.7491913636525471
# test loss difference 0.0002512078696543796
# Round 3, cleint 10, epoch 4, current LR: 0.0025, epoch_accuracy 38.997395833333336, epoch_loss 1.7318553626537323
# test loss difference 0.00021266861083812927
# Round 3, cleint 10, epoch 5, current LR: 0.00125, epoch_accuracy 38.8671875, epoch_loss 1.7333871722221375
# test loss difference 0.00013053607635971076
# Round 3, cleint 11, epoch 1, current LR: 0.01, epoch_accuracy 22.8125, epoch_loss 2.2041306495666504
# test loss difference -0.019971697475202
# Round 3, cleint 11, epoch 2, current LR: 0.01, epoch_accuracy 25.3125, epoch_loss 2.0514319896698
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 11, epoch 3, current LR: 0.005, epoch_accuracy 29.53125, epoch_loss 1.9653716802597045
# test loss difference 0.0002512078696543796
# Round 3, cleint 11, epoch 4, current LR: 0.0025, epoch_accuracy 28.90625, epoch_loss 1.9502052068710327
# test loss difference 0.00021266861083812927
# Round 3, cleint 11, epoch 5, current LR: 0.00125, epoch_accuracy 29.0625, epoch_loss 1.9292447566986084
# test loss difference 0.00013053607635971076
# Round 3, cleint 12, epoch 1, current LR: 0.01, epoch_accuracy 40.76704545454545, epoch_loss 1.7800499309193005
# test loss difference -0.4464761030178863
# Round 3, cleint 12, epoch 2, current LR: 0.01, epoch_accuracy 47.51420454545455, epoch_loss 1.3795502185821533
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 12, epoch 3, current LR: 0.005, epoch_accuracy 48.4375, epoch_loss 1.356289029121399
# test loss difference 0.0002512078696543796
# Round 3, cleint 12, epoch 4, current LR: 0.0025, epoch_accuracy 49.71590909090909, epoch_loss 1.3415938507426868
# test loss difference 0.00021266861083812927
# Round 3, cleint 12, epoch 5, current LR: 0.00125, epoch_accuracy 49.64488636363637, epoch_loss 1.3264085921374233
# test loss difference 0.00013053607635971076
# Round 3, cleint 13, epoch 1, current LR: 0.01, epoch_accuracy 16.25, epoch_loss 2.236168313026428
# test loss difference -0.026610427009412074
# Round 3, cleint 13, epoch 2, current LR: 0.01, epoch_accuracy 18.75, epoch_loss 2.1419831037521364
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 13, epoch 3, current LR: 0.005, epoch_accuracy 21.640625, epoch_loss 2.1185908555984496
# test loss difference 0.0002512078696543796
# Round 3, cleint 13, epoch 4, current LR: 0.0025, epoch_accuracy 20.46875, epoch_loss 2.103106474876404
# test loss difference 0.00021266861083812927
# Round 3, cleint 13, epoch 5, current LR: 0.00125, epoch_accuracy 20.078125, epoch_loss 2.1029053211212156
# test loss difference 0.00013053607635971076
# Round 3, cleint 14, epoch 1, current LR: 0.01, epoch_accuracy 23.98003472222222, epoch_loss 2.0441301895512476
# test loss difference -0.33912027224945973
# Round 3, cleint 14, epoch 2, current LR: 0.01, epoch_accuracy 24.131944444444443, epoch_loss 1.95522830552525
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 14, epoch 3, current LR: 0.005, epoch_accuracy 25.15190972222222, epoch_loss 1.9426950911680858
# test loss difference 0.0002512078696543796
# Round 3, cleint 14, epoch 4, current LR: 0.0025, epoch_accuracy 25.716145833333332, epoch_loss 1.9374938408533733
# test loss difference 0.00021266861083812927
# Round 3, cleint 14, epoch 5, current LR: 0.00125, epoch_accuracy 24.4140625, epoch_loss 1.9380855162938435
# test loss difference 0.00013053607635971076
# Round 3, cleint 15, epoch 1, current LR: 0.01, epoch_accuracy 41.629464285714285, epoch_loss 1.758255319935935
# test loss difference -0.5371033162735523
# Round 3, cleint 15, epoch 2, current LR: 0.01, epoch_accuracy 41.573660714285715, epoch_loss 1.532551646232605
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 15, epoch 3, current LR: 0.005, epoch_accuracy 42.354910714285715, epoch_loss 1.492310643196106
# test loss difference 0.0002512078696543796
# Round 3, cleint 15, epoch 4, current LR: 0.0025, epoch_accuracy 43.69419642857143, epoch_loss 1.4757370523044042
# test loss difference 0.00021266861083812927
# Round 3, cleint 15, epoch 5, current LR: 0.00125, epoch_accuracy 42.63392857142857, epoch_loss 1.4847259436334883
# test loss difference 0.00013053607635971076
# Round 3, cleint 16, epoch 1, current LR: 0.01, epoch_accuracy 36.5953947368421, epoch_loss 1.7514943449120772
# test loss difference -0.5298142303673985
# Round 3, cleint 16, epoch 2, current LR: 0.01, epoch_accuracy 41.5296052631579, epoch_loss 1.515907651499698
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 16, epoch 3, current LR: 0.005, epoch_accuracy 43.6266447368421, epoch_loss 1.4947585745861656
# test loss difference 0.0002512078696543796
# Round 3, cleint 16, epoch 4, current LR: 0.0025, epoch_accuracy 45.80592105263158, epoch_loss 1.4742246740742733
# test loss difference 0.00021266861083812927
# Round 3, cleint 16, epoch 5, current LR: 0.00125, epoch_accuracy 44.860197368421055, epoch_loss 1.4842159873560856
# test loss difference 0.00013053607635971076
# Round 3, cleint 17, epoch 1, current LR: 0.01, epoch_accuracy 27.916666666666668, epoch_loss 2.0285067240397137
# test loss difference -0.2464246300462718
# Round 3, cleint 17, epoch 2, current LR: 0.01, epoch_accuracy 30.677083333333332, epoch_loss 1.855241839090983
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 17, epoch 3, current LR: 0.005, epoch_accuracy 31.354166666666668, epoch_loss 1.8154990752538045
# test loss difference 0.0002512078696543796
# Round 3, cleint 17, epoch 4, current LR: 0.0025, epoch_accuracy 30.78125, epoch_loss 1.8024837255477906
# test loss difference 0.00021266861083812927
# Round 3, cleint 17, epoch 5, current LR: 0.00125, epoch_accuracy 32.96875, epoch_loss 1.7954777558644612
# test loss difference 0.00013053607635971076
# Round 3, cleint 18, epoch 1, current LR: 0.01, epoch_accuracy 27.809175531914892, epoch_loss 1.8884375805550433
# test loss difference -0.5107619823358309
# Round 3, cleint 18, epoch 2, current LR: 0.01, epoch_accuracy 32.11436170212766, epoch_loss 1.7598291990604806
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 18, epoch 3, current LR: 0.005, epoch_accuracy 34.973404255319146, epoch_loss 1.7112194604062019
# test loss difference 0.0002512078696543796
# Round 3, cleint 18, epoch 4, current LR: 0.0025, epoch_accuracy 35.90425531914894, epoch_loss 1.6912447924309588
# test loss difference 0.00021266861083812927
# Round 3, cleint 18, epoch 5, current LR: 0.00125, epoch_accuracy 36.58577127659574, epoch_loss 1.6893698814067435
# test loss difference 0.00013053607635971076
# Round 3, cleint 19, epoch 1, current LR: 0.01, epoch_accuracy 35.0, epoch_loss 2.0892080783843996
# test loss difference -0.12082919602196052
# Round 3, cleint 19, epoch 2, current LR: 0.01, epoch_accuracy 40.234375, epoch_loss 1.9016878128051757
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 19, epoch 3, current LR: 0.005, epoch_accuracy 40.546875, epoch_loss 1.863780438899994
# test loss difference 0.0002512078696543796
# Round 3, cleint 19, epoch 4, current LR: 0.0025, epoch_accuracy 40.234375, epoch_loss 1.8672501683235168
# test loss difference 0.00021266861083812927
# Round 3, cleint 19, epoch 5, current LR: 0.00125, epoch_accuracy 40.078125, epoch_loss 1.869952929019928
# test loss difference 0.00013053607635971076
# Round 3, cleint 20, epoch 1, current LR: 0.01, epoch_accuracy 31.067708333333332, epoch_loss 1.8806814352671306
# test loss difference -0.5234268915158111
# Round 3, cleint 20, epoch 2, current LR: 0.01, epoch_accuracy 32.005208333333336, epoch_loss 1.7343563596407572
# test loss difference 3.0545761791067605e-05
# Round 3, cleint 20, epoch 3, current LR: 0.005, epoch_accuracy 33.046875, epoch_loss 1.7102066238721212
# test loss difference 0.0002512078696543796
# Round 3, cleint 20, epoch 4, current LR: 0.0025, epoch_accuracy 32.916666666666664, epoch_loss 1.6988462766011556
# test loss difference 0.00021266861083812927
# Round 3, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 32.135416666666664, epoch_loss 1.7033624172210693
# test loss difference 0.00013053607635971076
# Model's Round: 3, train accuracy of model: 36.488956650207314, train loss of model: 1.7101184738219861
#
#
# Model's Round: 3, test accuracy of model: 15.155750798722044, test loss of model: 2.283576145720558
#
#
# round 3 completed
# Round 4, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 21.875, epoch_loss 2.076281428337097
# test loss difference -0.20823840516062964
# Round 4, cleint 1, epoch 2, current LR: 0.01, epoch_accuracy 22.760416666666668, epoch_loss 1.9885518153508503
# test loss difference 3.0545761791067605e-05
# Round 4, cleint 1, epoch 3, current LR: 0.005, epoch_accuracy 26.927083333333332, epoch_loss 1.9524213393529257
# test loss difference 0.0002512078696543796
# Round 4, cleint 1, epoch 4, current LR: 0.0025, epoch_accuracy 25.729166666666668, epoch_loss 1.943777823448181
# test loss difference 0.00021266861083812927
# Round 4, cleint 1, epoch 5, current LR: 0.00125, epoch_accuracy 25.625, epoch_loss 1.9356198151906332
# test loss difference 0.00013053607635971076
# Round 4, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 40.885416666666664, epoch_loss 1.5854301611582438
# test loss difference -0.9195429379947653
# Round 4, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 43.125, epoch_loss 1.406888206799825
# test loss difference 3.0545761791067605e-05
# Round 4, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 45.520833333333336, epoch_loss 1.3837433894475302
# test loss difference 0.0002512078696543796
# ...
# test loss difference 0.00021266861083812927
# Round 29, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 54.479166666666664, epoch_loss 1.2446442127227784
# test loss difference 0.00013053607635971076
# Model's Round: 29, train accuracy of model: 54.98245081754385, train loss of model: 1.260706562808848
#
#
# Model's Round: 29, test accuracy of model: 39.06749201277955, test loss of model: 1.7070125261434732
#
#
# round 29 completed
# Round 30, cleint 1, epoch 1, current LR: 0.01, epoch_accuracy 45.677083333333336, epoch_loss 1.5648363669713339
# test loss difference 0.3005902565325411
# Round 30, cleint 1, epoch 2, current LR: 0.01, epoch_accuracy 46.770833333333336, epoch_loss 1.5069787581761678
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 1, epoch 3, current LR: 0.005, epoch_accuracy 46.770833333333336, epoch_loss 1.4917355219523112
# test loss difference 0.0002512078696543796
# Round 30, cleint 1, epoch 4, current LR: 0.0025, epoch_accuracy 48.177083333333336, epoch_loss 1.476413893699646
# test loss difference 0.00021266861083812927
# Round 30, cleint 1, epoch 5, current LR: 0.00125, epoch_accuracy 47.1875, epoch_loss 1.4719978332519532
# test loss difference 0.00013053607635971076
# Round 30, cleint 2, epoch 1, current LR: 0.01, epoch_accuracy 55.677083333333336, epoch_loss 1.2075302680333455
# test loss difference -0.43477957164898484
# Round 30, cleint 2, epoch 2, current LR: 0.01, epoch_accuracy 59.166666666666664, epoch_loss 1.1144030690193176
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 2, epoch 3, current LR: 0.005, epoch_accuracy 59.21875, epoch_loss 1.0848976333936056
# test loss difference 0.0002512078696543796
# Round 30, cleint 2, epoch 4, current LR: 0.0025, epoch_accuracy 59.947916666666664, epoch_loss 1.0774181604385376
# test loss difference 0.00021266861083812927
# Round 30, cleint 2, epoch 5, current LR: 0.00125, epoch_accuracy 61.458333333333336, epoch_loss 1.0596004168192545
# test loss difference 0.00013053607635971076
# Round 30, cleint 3, epoch 1, current LR: 0.01, epoch_accuracy 50.66550925925926, epoch_loss 1.406673506454185
# test loss difference 0.10079298499293232
# Round 30, cleint 3, epoch 2, current LR: 0.01, epoch_accuracy 51.67824074074074, epoch_loss 1.3685564509144537
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 3, epoch 3, current LR: 0.005, epoch_accuracy 52.633101851851855, epoch_loss 1.3424309757020738
# test loss difference 0.0002512078696543796
# Round 30, cleint 3, epoch 4, current LR: 0.0025, epoch_accuracy 53.067129629629626, epoch_loss 1.335666334187543
# test loss difference 0.00021266861083812927
# Round 30, cleint 3, epoch 5, current LR: 0.00125, epoch_accuracy 52.57523148148148, epoch_loss 1.3386159914511222
# test loss difference 0.00013053607635971076
# Round 30, cleint 4, epoch 1, current LR: 0.01, epoch_accuracy 49.6875, epoch_loss 1.4170426925023396
# test loss difference 0.271776494888452
# Round 30, cleint 4, epoch 2, current LR: 0.01, epoch_accuracy 51.510416666666664, epoch_loss 1.3665912707646688
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 4, epoch 3, current LR: 0.005, epoch_accuracy 50.364583333333336, epoch_loss 1.36953919728597
# test loss difference 0.0002512078696543796
# Round 30, cleint 4, epoch 4, current LR: 0.0025, epoch_accuracy 51.770833333333336, epoch_loss 1.350261147816976
# test loss difference 0.00021266861083812927
# Round 30, cleint 4, epoch 5, current LR: 0.00125, epoch_accuracy 53.125, epoch_loss 1.3425273021062216
# test loss difference 0.00013053607635971076
# Round 30, cleint 5, epoch 1, current LR: 0.01, epoch_accuracy 52.34375, epoch_loss 1.3065622036273663
# test loss difference -0.2839201464058876
# Round 30, cleint 5, epoch 2, current LR: 0.01, epoch_accuracy 53.99639423076923, epoch_loss 1.233253070941338
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 5, epoch 3, current LR: 0.005, epoch_accuracy 54.71754807692308, epoch_loss 1.2285693150300245
# test loss difference 0.0002512078696543796
# Round 30, cleint 5, epoch 4, current LR: 0.0025, epoch_accuracy 54.86778846153846, epoch_loss 1.2327347627052894
# test loss difference 0.00021266861083812927
# Round 30, cleint 5, epoch 5, current LR: 0.00125, epoch_accuracy 54.89783653846154, epoch_loss 1.2237460108903737
# test loss difference 0.00013053607635971076
# Round 30, cleint 6, epoch 1, current LR: 0.01, epoch_accuracy 54.8046875, epoch_loss 1.3471695899963378
# test loss difference 0.09361933976316594
# Round 30, cleint 6, epoch 2, current LR: 0.01, epoch_accuracy 56.09375, epoch_loss 1.288311129808426
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 6, epoch 3, current LR: 0.005, epoch_accuracy 56.796875, epoch_loss 1.2429086148738862
# test loss difference 0.0002512078696543796
# Round 30, cleint 6, epoch 4, current LR: 0.0025, epoch_accuracy 56.796875, epoch_loss 1.2521932482719422
# test loss difference 0.00021266861083812927
# Round 30, cleint 6, epoch 5, current LR: 0.00125, epoch_accuracy 57.578125, epoch_loss 1.2520358622074128
# test loss difference 0.00013053607635971076
# Round 30, cleint 7, epoch 1, current LR: 0.01, epoch_accuracy 62.46279761904762, epoch_loss 1.0974096003032865
# test loss difference -0.7805929930446247
# Round 30, cleint 7, epoch 2, current LR: 0.01, epoch_accuracy 62.79761904761905, epoch_loss 1.0170169274012248
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 7, epoch 3, current LR: 0.005, epoch_accuracy 64.47172619047619, epoch_loss 0.9945105285871596
# test loss difference 0.0002512078696543796
# Round 30, cleint 7, epoch 4, current LR: 0.0025, epoch_accuracy 64.88095238095238, epoch_loss 0.9864870082764399
# test loss difference 0.00021266861083812927
# Round 30, cleint 7, epoch 5, current LR: 0.00125, epoch_accuracy 65.625, epoch_loss 0.9908650659379505
# test loss difference 0.00013053607635971076
# Round 30, cleint 8, epoch 1, current LR: 0.01, epoch_accuracy 63.0859375, epoch_loss 1.1798224374651909
# test loss difference 0.18228190394636146
# Round 30, cleint 8, epoch 2, current LR: 0.01, epoch_accuracy 63.720703125, epoch_loss 1.1466698609292507
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 8, epoch 3, current LR: 0.005, epoch_accuracy 64.453125, epoch_loss 1.118826188147068
# test loss difference 0.0002512078696543796
# Round 30, cleint 8, epoch 4, current LR: 0.0025, epoch_accuracy 65.478515625, epoch_loss 1.099212370812893
# test loss difference 0.00021266861083812927
# Round 30, cleint 8, epoch 5, current LR: 0.00125, epoch_accuracy 65.4296875, epoch_loss 1.092371266335249
# test loss difference 0.00013053607635971076
# Round 30, cleint 9, epoch 1, current LR: 0.01, epoch_accuracy 39.751838235294116, epoch_loss 1.5376988999983843
# test loss difference 0.06009364508973114
# Round 30, cleint 9, epoch 2, current LR: 0.01, epoch_accuracy 40.716911764705884, epoch_loss 1.4604754588183235
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 9, epoch 3, current LR: 0.005, epoch_accuracy 41.9577205882353, epoch_loss 1.4509545214035933
# test loss difference 0.0002512078696543796
# Round 30, cleint 9, epoch 4, current LR: 0.0025, epoch_accuracy 42.14154411764706, epoch_loss 1.440842025420245
# test loss difference 0.00021266861083812927
# Round 30, cleint 9, epoch 5, current LR: 0.00125, epoch_accuracy 41.86580882352941, epoch_loss 1.4333981275558472
# test loss difference 0.00013053607635971076
# Round 30, cleint 10, epoch 1, current LR: 0.01, epoch_accuracy 54.947916666666664, epoch_loss 1.293049802382787
# test loss difference -0.044751765248113085
# Round 30, cleint 10, epoch 2, current LR: 0.01, epoch_accuracy 57.6171875, epoch_loss 1.200941855708758
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 10, epoch 3, current LR: 0.005, epoch_accuracy 58.854166666666664, epoch_loss 1.1891022225220997
# test loss difference 0.0002512078696543796
# Round 30, cleint 10, epoch 4, current LR: 0.0025, epoch_accuracy 58.59375, epoch_loss 1.1696095963319142
# test loss difference 0.00021266861083812927
# Round 30, cleint 10, epoch 5, current LR: 0.00125, epoch_accuracy 59.1796875, epoch_loss 1.1824288765589397
# test loss difference 0.00013053607635971076
# Round 30, cleint 11, epoch 1, current LR: 0.01, epoch_accuracy 47.03125, epoch_loss 1.4448399305343629
# test loss difference 0.2520396747528171
# Round 30, cleint 11, epoch 2, current LR: 0.01, epoch_accuracy 50.46875, epoch_loss 1.3660233736038208
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 11, epoch 3, current LR: 0.005, epoch_accuracy 49.21875, epoch_loss 1.35209801197052
# test loss difference 0.0002512078696543796
# Round 30, cleint 11, epoch 4, current LR: 0.0025, epoch_accuracy 51.40625, epoch_loss 1.315444278717041
# test loss difference 0.00021266861083812927
# Round 30, cleint 11, epoch 5, current LR: 0.00125, epoch_accuracy 50.3125, epoch_loss 1.3493412971496581
# test loss difference 0.00013053607635971076
# Round 30, cleint 12, epoch 1, current LR: 0.01, epoch_accuracy 66.40625, epoch_loss 1.0494202050295742
# test loss difference -0.4927268770936961
# Round 30, cleint 12, epoch 2, current LR: 0.01, epoch_accuracy 71.02272727272727, epoch_loss 0.9211108196865428
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 12, epoch 3, current LR: 0.005, epoch_accuracy 70.88068181818181, epoch_loss 0.8954743905500933
# test loss difference 0.0002512078696543796
# Round 30, cleint 12, epoch 4, current LR: 0.0025, epoch_accuracy 70.8096590909091, epoch_loss 0.9114022363315929
# test loss difference 0.00021266861083812927
# Round 30, cleint 12, epoch 5, current LR: 0.00125, epoch_accuracy 72.1590909090909, epoch_loss 0.8826397819952532
# test loss difference 0.00013053607635971076
# Round 30, cleint 13, epoch 1, current LR: 0.01, epoch_accuracy 43.59375, epoch_loss 1.5926323771476745
# test loss difference 0.3711287289762648
# Round 30, cleint 13, epoch 2, current LR: 0.01, epoch_accuracy 41.953125, epoch_loss 1.5812010049819947
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 13, epoch 3, current LR: 0.005, epoch_accuracy 43.984375, epoch_loss 1.5361374497413636
# test loss difference 0.0002512078696543796
# Round 30, cleint 13, epoch 4, current LR: 0.0025, epoch_accuracy 45.46875, epoch_loss 1.5271767497062683
# test loss difference 0.00021266861083812927
# Round 30, cleint 13, epoch 5, current LR: 0.00125, epoch_accuracy 44.375, epoch_loss 1.5492456793785094
# test loss difference 0.00013053607635971076
# Round 30, cleint 14, epoch 1, current LR: 0.01, epoch_accuracy 38.91059027777778, epoch_loss 1.6167177425490484
# test loss difference 0.13995872480800742
# Round 30, cleint 14, epoch 2, current LR: 0.01, epoch_accuracy 40.19097222222222, epoch_loss 1.583542439672682
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 14, epoch 3, current LR: 0.005, epoch_accuracy 40.625, epoch_loss 1.5693436463673909
# test loss difference 0.0002512078696543796
# Round 30, cleint 14, epoch 4, current LR: 0.0025, epoch_accuracy 40.993923611111114, epoch_loss 1.5542247924539778
# test loss difference 0.00021266861083812927
# Round 30, cleint 14, epoch 5, current LR: 0.00125, epoch_accuracy 41.29774305555556, epoch_loss 1.5482937859164343
# test loss difference 0.00013053607635971076
# Round 30, cleint 15, epoch 1, current LR: 0.01, epoch_accuracy 53.96205357142857, epoch_loss 1.2637271455356054
# test loss difference -0.07649419825678816
# Round 30, cleint 15, epoch 2, current LR: 0.01, epoch_accuracy 57.86830357142857, epoch_loss 1.1882077242646898
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 15, epoch 3, current LR: 0.005, epoch_accuracy 57.47767857142857, epoch_loss 1.1619139909744263
# test loss difference 0.0002512078696543796
# Round 30, cleint 15, epoch 4, current LR: 0.0025, epoch_accuracy 57.645089285714285, epoch_loss 1.1576764157840185
# test loss difference 0.00021266861083812927
# Round 30, cleint 15, epoch 5, current LR: 0.00125, epoch_accuracy 58.705357142857146, epoch_loss 1.1485655733517237
# test loss difference 0.00013053607635971076
# Round 30, cleint 16, epoch 1, current LR: 0.01, epoch_accuracy 61.14309210526316, epoch_loss 1.1634097914946706
# test loss difference -0.2891816262619944
# Round 30, cleint 16, epoch 2, current LR: 0.01, epoch_accuracy 62.78782894736842, epoch_loss 1.1194306549273039
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 16, epoch 3, current LR: 0.005, epoch_accuracy 65.13157894736842, epoch_loss 1.0657746384018345
# test loss difference 0.0002512078696543796
# Round 30, cleint 16, epoch 4, current LR: 0.0025, epoch_accuracy 64.96710526315789, epoch_loss 1.057069392580735
# test loss difference 0.00021266861083812927
# Round 30, cleint 16, epoch 5, current LR: 0.00125, epoch_accuracy 65.54276315789474, epoch_loss 1.0409933893304122
# test loss difference 0.00013053607635971076
# Round 30, cleint 17, epoch 1, current LR: 0.01, epoch_accuracy 47.65625, epoch_loss 1.4226523876190185
# test loss difference 0.11641817732740867
# Round 30, cleint 17, epoch 2, current LR: 0.01, epoch_accuracy 47.864583333333336, epoch_loss 1.3730844656626384
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 17, epoch 3, current LR: 0.005, epoch_accuracy 50.15625, epoch_loss 1.3365556478500367
# test loss difference 0.0002512078696543796
# Round 30, cleint 17, epoch 4, current LR: 0.0025, epoch_accuracy 50.208333333333336, epoch_loss 1.3354247172673543
# test loss difference 0.00021266861083812927
# Round 30, cleint 17, epoch 5, current LR: 0.00125, epoch_accuracy 49.6875, epoch_loss 1.3287372748057047
# test loss difference 0.00013053607635971076
# Round 30, cleint 18, epoch 1, current LR: 0.01, epoch_accuracy 51.59574468085106, epoch_loss 1.348338728255414
# test loss difference -0.01139619632270028
# Round 30, cleint 18, epoch 2, current LR: 0.01, epoch_accuracy 52.892287234042556, epoch_loss 1.3104271508277732
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 18, epoch 3, current LR: 0.005, epoch_accuracy 54.055851063829785, epoch_loss 1.2812581950045647
# test loss difference 0.0002512078696543796
# Round 30, cleint 18, epoch 4, current LR: 0.0025, epoch_accuracy 53.922872340425535, epoch_loss 1.2774526565632922
# test loss difference 0.00021266861083812927
# Round 30, cleint 18, epoch 5, current LR: 0.00125, epoch_accuracy 55.285904255319146, epoch_loss 1.262951374053955
# test loss difference 0.00013053607635971076
# Round 30, cleint 19, epoch 1, current LR: 0.01, epoch_accuracy 52.5, epoch_loss 1.4456337690353394
# test loss difference 0.05125229922346408
# Round 30, cleint 19, epoch 2, current LR: 0.01, epoch_accuracy 54.140625, epoch_loss 1.3637494444847107
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 19, epoch 3, current LR: 0.005, epoch_accuracy 55.546875, epoch_loss 1.3478888154029847
# test loss difference 0.0002512078696543796
# Round 30, cleint 19, epoch 4, current LR: 0.0025, epoch_accuracy 58.203125, epoch_loss 1.3089072585105896
# test loss difference 0.00021266861083812927
# Round 30, cleint 19, epoch 5, current LR: 0.00125, epoch_accuracy 57.421875, epoch_loss 1.3064855217933655
# test loss difference 0.00013053607635971076
# Round 30, cleint 20, epoch 1, current LR: 0.01, epoch_accuracy 52.65625, epoch_loss 1.319896411895752
# test loss difference -0.04955327929780129
# Round 30, cleint 20, epoch 2, current LR: 0.01, epoch_accuracy 53.932291666666664, epoch_loss 1.266967527071635
# test loss difference 3.0545761791067605e-05
# Round 30, cleint 20, epoch 3, current LR: 0.005, epoch_accuracy 54.973958333333336, epoch_loss 1.2527058124542236
# test loss difference 0.0002512078696543796
# Round 30, cleint 20, epoch 4, current LR: 0.0025, epoch_accuracy 55.15625, epoch_loss 1.2485330780347188
# test loss difference 0.00021266861083812927
# Round 30, cleint 20, epoch 5, current LR: 0.00125, epoch_accuracy 55.46875, epoch_loss 1.2460936586062112
# test loss difference 0.00013053607635971076
# Model's Round: 30, train accuracy of model: 55.458934684876155, train loss of model: 1.2525467044747776
#
#
# Model's Round: 30, test accuracy of model: 39.48682108626198, test loss of model: 1.6957888938367558
#
#
# round 30 completed

# %% [markdown]
# # Reuslts

# %%
# Define the folder and file name
folder_name = f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"  # Folder where the Excel file will be saved
file_name = "round_results.xlsx"


# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

round_results.to_excel(file_path, index=False)

print("DataFrame successfully written for round results.")
# Out:
# DataFrame successfully written for round results.

# %%
# Define the folder and file name
folder_name =  f"{method}_{opti}_{learning_rate}_{participating_client}_{client_no}_{distributions}_{alpha}"   # Folder where the Excel file will be saved
file_name = "epoch_results.xlsx"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Full path where the Excel file will be saved
file_path = os.path.join(folder_name, file_name)

epoch_results.to_excel(file_path, index=False)

print("DataFrame successfully written for epoch results.")
# Out:
# DataFrame successfully written for epoch results.
